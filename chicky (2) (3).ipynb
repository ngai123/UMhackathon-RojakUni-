# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import seaborn as sns
from datetime import datetime, timedelta
import os
import joblib
import traceback
import warnings

warnings.filterwarnings('ignore')

# Import ML Libraries
from sklearn.model_selection import train_test_split, TimeSeriesSplit # Keep TimeSeriesSplit if needed for other CV purposes
from sklearn.preprocessing import RobustScaler # Keep relevant preprocessors
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report, accuracy_score
from sklearn.impute import SimpleImputer
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.neural_network import MLPClassifier
import xgboost as xgb

print("Libraries imported.")
# Out:
# Libraries imported.

# %%
# --- Global Configuration ---
# Basic configuration
np.random.seed(42) # To ensure consistent results
FILE_PATH = r"C:\Users\User\Downloads\final_merged_data_2.csv" # Data file path [cite: 2]
MODEL_OUTPUT_DIR = 'bitcoin_onchain_models/' # Location to save models [cite: 2]
PRICE_COLUMN = 'close' # Standardized to lowercase [cite: 2]
PERIODS_AHEAD = 1 # NOTE: If you change this, you MUST retrain the ML models [cite: 2]
TARGET_TYPE = 'Direction' # [cite: 2]
TARGET_COLUMN = 'target_direction' # Target column name [cite: 2]
SCORING_METRIC = 'f1' # Or 'accuracy' - Used for model evaluation [cite: 2]

# Data splitting parameters
TEST_SIZE = 0.20 # [cite: 2]
VALIDATION_SIZE = 0.15 # [cite: 2]

# --- Default Backtesting Parameters (Simplified) ---
# Start with reasonable defaults (TUNING PARAMETERS REMOVED)
BACKTESTING_PARAMS = {
    'INITIAL_CASH': 10000, # [cite: 2]
    'COMMISSION_PERC': 0.0006, # Fixed [cite: 2]

    # --- Base Parameters ---
    'BASE_POSITION_SIZE': 0.5, # [cite: 3]
    # Removed Adaptive Threshold and Position Sizing Tuning Params sections
}

print("Global configurations and simplified backtesting parameters set.")
print(f"Target column: {TARGET_COLUMN}")
print(f"Price column: {PRICE_COLUMN}")
# Out:
# Global configurations and simplified backtesting parameters set.
# Target column: target_direction
# Price column: close

# %%
# --- Default Model Parameters (using last known good/tuned values as fixed defaults) ---

# XGBoost parameters for Direction model (fixed defaults) [cite: 5]
XGB_CLS_DEFAULT_PARAMS = {
    'objective': 'binary:logistic',
    'eval_metric': 'logloss',
    'use_label_encoder': False,
    'n_estimators': 326,
    'learning_rate': 0.15592123566761282,
    'max_depth': 5,
    'subsample': 0.6478376983753207,
    'colsample_bytree': 0.7243929286862649,
    'gamma': 0.16259166101337352,
    'min_child_weight': 3,
    'random_state': 42,
    'n_jobs': -1,
    # Keep early stopping for fitting, but rounds won't be tuned
    'early_stopping_rounds': 10 # Or adjust as needed
}

# Random Forest parameters for Direction model (fixed defaults) [cite: 5, 6]
RF_CLS_DEFAULT_PARAMS = {
    'n_estimators': 234,
    'max_depth': 12,
    'min_samples_split': 9,
    'min_samples_leaf': 5,
    'max_features': 'sqrt',
    'class_weight': 'balanced',
    'random_state': 42,
    'n_jobs': -1
}

# MLP Classifier parameters (fixed defaults) [cite: 6]
MLP_CLS_DEFAULT_PARAMS = {
    'hidden_layer_sizes': (32,), 'activation': 'relu', 'solver': 'adam',
    'alpha': 0.0003058449429580245, 'batch_size': 'auto', 'learning_rate': 'adaptive',
    'learning_rate_init': 0.004109993861334124, 'max_iter': 300, 'shuffle': True,
    'random_state': 42, 'early_stopping': True, 'n_iter_no_change': 10,
    'validation_fraction': 0.1
}

# Logistic Regression parameters (fixed defaults) [cite: 6, 7]
LOGISTIC_DEFAULT_PARAMS = {
    'C': 0.5908361216819946, 'penalty': 'l2', 'solver': 'liblinear', 'random_state': 42,
    'max_iter': 1000, 'class_weight': 'balanced'
}

print("Default parameters for ML models defined.")
# Out:
# Default parameters for ML models defined.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans, AgglomerativeClustering
from hmmlearn.hmm import GaussianHMM
from scipy.stats import norm

class RegimeAnalysis:
    """
    Class to perform Hidden Markov Model regime analysis on financial time series data.
    Identifies market regimes, calculates statistics, transition probabilities, and
    provides trading suggestions.
    """
    
    def __init__(self, returns_series, n_regimes=6, lookback_period=None, existing_regimes=None):
        """
        Initialize regime analysis with return series and parameters.
        
        Parameters:
        -----------
        returns_series : pandas.Series
            Series of price returns to analyze
        n_regimes : int
            Number of regimes to identify (default=6)
        lookback_period : int
            Number of periods to use for model training (None=use all data)
        existing_regimes : pandas.Series
            Optional existing regime classifications to use instead of fitting HMM
        """
        self.returns = returns_series
        self.n_regimes = n_regimes
        
        # Create a DataFrame for analysis
        self.data = pd.DataFrame({'returns': returns_series})
        
        # Calculate volatility (using rolling standard deviation)
        self.data['volatility'] = self.data['returns'].rolling(window=21).std().fillna(method='bfill')
        
        # Use existing regime data if provided
        if existing_regimes is not None:
            self.data['regime'] = existing_regimes
            print(f"Using existing regime classifications with {len(existing_regimes.unique())} unique regimes")
            # Update n_regimes to match the existing data
            self.n_regimes = len(existing_regimes.unique())
        
        # Use lookback period if specified
        if lookback_period and lookback_period < len(self.data):
            self.train_data = self.data.iloc[-lookback_period:]
        else:
            self.train_data = self.data.copy()
            
        # Initialize results storage
        self.hmm_model = None
        self.regime_stats = None
        self.transition_probs = None
        self.regime_clusters = None
        
    def fit_hmm_model(self):
        """
        Fit Hidden Markov Model to the return and volatility data.
        """
        # If we already have regime assignments, skip fitting
        if 'regime' in self.data.columns:
            print("--- Analyzing Existing Regime Data ---")
            # Add regime_shift column for transition analysis
            self.data['regime_shift'] = self.data['regime'].shift(1)
            return True
            
        print("--- Fitting HMM Regimes ---")
        
        # Prepare features for HMM
        features = np.column_stack([
            self.train_data['returns'].values,
            self.train_data['volatility'].values
        ])
        
        # Ensure no NaN or inf values
        features = np.nan_to_num(features)
        
        # Add small amount of noise to prevent covariance issues
        np.random.seed(42)
        features += np.random.normal(0, 1e-6, features.shape)
        
        try:
            # Create and fit the HMM model
            hmm = GaussianHMM(
                n_components=self.n_regimes,
                covariance_type="diag",  # Use diagonal covariance instead of full
                n_iter=2000,
                random_state=42
            )
            
            hmm.fit(features)
            print(f"HMM model fitted successfully with {self.n_regimes} regimes.")
            print(f"Converged: {hmm.monitor_.converged}")
            
            # Store the trained model
            self.hmm_model = hmm
            
            # Predict regimes for all data
            self.data['regime'] = hmm.predict(np.column_stack([
                np.nan_to_num(self.data['returns'].values),
                np.nan_to_num(self.data['volatility'].values)
            ]))
            
            # Add regime_shift column for transition analysis
            self.data['regime_shift'] = self.data['regime'].shift(1)
            
            return True
        except Exception as e:
            print(f"Error fitting HMM: {e}")
            print("Falling back to K-means clustering for regime identification...")
            
            try:
                # Fallback: Use K-means clustering instead
                from sklearn.cluster import KMeans
                
                # Standardize features
                from sklearn.preprocessing import StandardScaler
                scaler = StandardScaler()
                features_scaled = scaler.fit_transform(features)
                
                # Fit K-means
                kmeans = KMeans(n_clusters=self.n_regimes, random_state=42, n_init=10)
                regimes = kmeans.fit_predict(features_scaled)
                
                # Store regimes
                self.data['regime'] = regimes
                
                # Add regime_shift column for transition analysis
                self.data['regime_shift'] = self.data['regime'].shift(1)
                
                print(f"K-means clustering completed with {self.n_regimes} regimes as fallback.")
                return True
            except Exception as e2:
                print(f"Error in fallback clustering: {e2}")
                return False
    
    def analyze_regimes(self):
        """
        Calculate statistics for each identified regime.
        """
        if 'regime' not in self.data.columns:
            print("Error: No regime column found. Run fit_hmm_model() first or provide existing regimes.")
            return False
        
        print("--- Regime Analysis ---")
        
        # Create empty DataFrame for regime statistics
        self.regime_stats = pd.DataFrame(index=range(self.n_regimes))
        
        # Calculate statistics for each regime
        regime_groups = self.data.groupby('regime')
        
        # Count of periods in each regime
        self.regime_stats['count'] = regime_groups.size()
        
        # Average return in each regime
        self.regime_stats['avg_return'] = regime_groups['returns'].mean()
        
        # Volatility in each regime
        self.regime_stats['volatility'] = regime_groups['returns'].std()
        
        # Sharpe ratio (annualized, assuming daily data)
        risk_free_rate = 0.035 / 252  # Daily risk-free rate, adjust as needed
        self.regime_stats['sharpe'] = (self.regime_stats['avg_return'] - risk_free_rate) / self.regime_stats['volatility']
        
        # Max drawdown (simplified calculation)
        self.regime_stats['max_drawdown'] = regime_groups.apply(
            lambda x: (x['returns'].cumsum() - x['returns'].cumsum().cummax()).min()
        )
        
        print("--- Regime Statistics (Calculated from Data) ---")
        print(self.regime_stats)
        
        # Print the counts
        print("\n--- Regime Counts (Calculated from Data) ---")
        regime_counts = self.data['regime'].value_counts().sort_index()
        print(regime_counts)
        
        # Assign descriptive names to regimes based on characteristics
        regime_descriptions = {}
        
        # Sort regimes by volatility
        volatility_order = self.regime_stats['volatility'].sort_values().index
        
        # Identify regimes with notable characteristics
        highest_vol_regime = self.regime_stats['volatility'].idxmax()
        lowest_vol_regime = self.regime_stats['volatility'].idxmin()
        highest_return_regime = self.regime_stats['avg_return'].idxmax()
        lowest_return_regime = self.regime_stats['avg_return'].idxmin()
        
        # Assign names based on characteristics
        for i in range(self.n_regimes):
            if i == highest_vol_regime and i == highest_return_regime:
                description = "High Activity/Volatile (Highest Returns)"
            elif i == lowest_vol_regime:
                description = "Low Activity/Calm (Lowest Volatility)"
            elif i == lowest_return_regime:
                description = "Whale Activity (Negative Returns)"
            elif i == volatility_order[1]:  # Second lowest volatility
                description = "Small High-Frequency (Moderate Volatility)"
            elif i == volatility_order[2]:  # Middle volatility
                description = "Medium Activity (Stable)"
            else:
                description = "Moderate Activity (Steady)"
                
            regime_descriptions[i] = description
        
        # Add descriptions to regime stats
        self.regime_stats['description'] = pd.Series(regime_descriptions)
        
        # Print a summary of regime stats
        print("\nRegime Stats Summary:")
        for i in range(self.n_regimes):
            desc = self.regime_stats.loc[i, 'description']
            avg_ret = self.regime_stats.loc[i, 'avg_return']
            vol = self.regime_stats.loc[i, 'volatility']
            print(f"Regime {i} ({desc}): AvgRet={avg_ret:.6f}, Vol={vol:.6f}")
        
        return True
    
    def calculate_transition_probabilities(self):
        """
        Calculate transition probabilities between regimes.
        """
        if 'regime' not in self.data.columns:
            print("Error: No regime column found.")
            return False
        
        print("--- Building Transition Probability Model ---")
        
        # Create a transition count matrix
        trans_counts = pd.crosstab(
            self.data['regime_shift'], 
            self.data['regime'],
            rownames=['regime_shift'],
            colnames=['regime']
        )
        
        print("--- Regime Transition Counts (Calculated from Data) ---")
        print(trans_counts)
        
        # Calculate transition probabilities
        trans_probs = trans_counts.div(trans_counts.sum(axis=1), axis=0)
        
        print("--- Regime Transition Probability Matrix ---")
        # Format for better display
        trans_probs_display = trans_probs.copy()
        trans_probs_display.columns = [f'To {c}' for c in trans_probs_display.columns]
        trans_probs_display.index = [f'From {i}' for i in trans_probs_display.index]
        print(trans_probs_display)
        
        # Calculate expected duration in each regime
        durations = {}
        for i in range(self.n_regimes):
            if i in trans_probs.index and i in trans_probs.columns:
                # Expected duration = 1 / (1 - p_ii) where p_ii is the probability of staying in the regime
                stay_prob = trans_probs.loc[i, i]
                duration = 1 / (1 - stay_prob) if stay_prob < 1 else float('inf')
                durations[i] = duration
        
        # Sort by duration (descending)
        durations = {k: v for k, v in sorted(durations.items(), key=lambda item: item[1], reverse=True)}
        
        print("--- Expected Duration in Each Regime (Periods) ---")
        for regime, duration in durations.items():
            desc = self.regime_stats.loc[regime, 'description']
            print(f"Regime {regime} ({desc}): {duration:.2f}")
        
        # Most likely next regimes (excluding self-transitions)
        print("--- Most Likely Next Regimes (Excluding Self-Transitions) ---")
        for i in range(self.n_regimes):
            if i in trans_probs.index:
                # Get transition probabilities excluding staying in the same regime
                next_probs = trans_probs.loc[i].copy()
                if i in next_probs.index:
                    next_probs[i] = 0  # Exclude self-transition
                
                # Sort by probability (descending)
                next_probs = next_probs.sort_values(ascending=False)
                
                print(f"From Regime {i} ({self.regime_stats.loc[i, 'description']}):")
                for j, prob in next_probs.items():
                    if prob > 0:
                        print(f"  → Regime {j} ({self.regime_stats.loc[j, 'description']}): {prob:.3f}")
        
        # Calculate transition impact (measure of how transitions affect return/volatility)
        print("Calculating transition impact...")
        
        # Calculate average return and volatility changes when transitioning between regimes
        transition_impact = {}
        
        for from_regime in range(self.n_regimes):
            for to_regime in range(self.n_regimes):
                if from_regime != to_regime:
                    # Get average return and volatility for each regime
                    from_ret = self.regime_stats.loc[from_regime, 'avg_return']
                    to_ret = self.regime_stats.loc[to_regime, 'avg_return']
                    from_vol = self.regime_stats.loc[from_regime, 'volatility']
                    to_vol = self.regime_stats.loc[to_regime, 'volatility']
                    
                    # Calculate the change
                    ret_diff = to_ret - from_ret
                    vol_diff = to_vol - from_vol
                    
                    # Calculate the transition probability
                    prob = trans_probs.loc[from_regime, to_regime] if from_regime in trans_probs.index and to_regime in trans_probs.columns else 0
                    
                    # Simplified impact score: return increase + volatility decrease
                    # Positive impact: higher returns and/or lower volatility
                    impact = ret_diff - vol_diff
                    
                    # Store weighted impact (impact * probability)
                    weighted_impact = impact * prob
                    
                    transition_impact[(from_regime, to_regime)] = {
                        'impact': impact,
                        'weighted_impact': weighted_impact,
                        'ret_diff': ret_diff,
                        'vol_diff': vol_diff,
                        'prob': prob
                    }
        
        # Store the transition model
        self.transition_probs = trans_probs
        self.transition_impact = transition_impact
        
        # Top positive impact transitions
        pos_impact = sorted(
            [(k, v) for k, v in transition_impact.items()],
            key=lambda x: x[1]['weighted_impact'],
            reverse=True
        )
        
        print("--- Top 5 Positive Impact Transitions (Prob * Impact) ---")
        for (from_r, to_r), data in pos_impact[:5]:
            print(f"  {from_r}→{to_r}: Impact={data['weighted_impact']:.6f}, Prob={data['prob']:.3f}, "
                  f"RetΔ={data['ret_diff']:.6f}, VolΔ={data['vol_diff']:.6f}")
        
        # Top negative impact transitions
        neg_impact = sorted(
            [(k, v) for k, v in transition_impact.items()],
            key=lambda x: x[1]['weighted_impact']
        )
        
        print("--- Top 5 Negative Impact Transitions (Prob * Impact) ---")
        for (from_r, to_r), data in neg_impact[:5]:
            print(f"  {from_r}→{to_r}: Impact={data['weighted_impact']:.6f}, Prob={data['prob']:.3f}, "
                  f"RetΔ={data['ret_diff']:.6f}, VolΔ={data['vol_diff']:.6f}")
        
        # Calculate expected impact for each regime
        expected_impact = {}
        for i in range(self.n_regimes):
            if i in trans_probs.index:
                impact_sum = 0
                for j in range(self.n_regimes):
                    if i != j and j in trans_probs.columns:
                        key = (i, j)
                        if key in transition_impact:
                            impact_sum += transition_impact[key]['weighted_impact']
                expected_impact[i] = impact_sum
        
        # Sort regimes by expected impact
        expected_impact = {k: v for k, v in sorted(expected_impact.items(), key=lambda item: item[1], reverse=True)}
        
        print("--- Expected Impact Score per Regime (Based on Transitions) ---")
        for regime, impact in expected_impact.items():
            desc = self.regime_stats.loc[regime, 'description']
            print(f"Regime {regime} ({desc}): {impact:.6f}")
        
        print("Regime transition probability model analysis complete.")
        
        return True
    
    def cluster_regimes(self, n_clusters=3):
        """
        Perform clustering on regimes to simplify into higher-level groups.
        
        Parameters:
        -----------
        n_clusters : int
            Number of clusters to create (default=3)
        """
        if self.regime_stats is None:
            print("Error: Regime statistics not calculated. Run analyze_regimes() first.")
            return False
        
        print("--- Performing Regime Cluster Analysis ---")
        
        # Features to use for clustering
        features = ['volatility', 'avg_return']
        
        # Prepare the data
        X = self.regime_stats[features].copy()
        
        # Scale the data
        scaler = StandardScaler()
        X_scaled = scaler.fit_transform(X)
        
        print("--- Analyzing Regime Clusters (Part 1: Stats Extraction) ---")
        print("Using pre-defined regime statistics for clustering.")
        print("Warning: Pre-defined stats missing required keys. Recalculating from data.")
        print(f"Features used for clustering: {features}")
        print("Data scaled using StandardScaler.")
        
        # Perform hierarchical clustering
        print("Performing Hierarchical Clustering...")
        hc = AgglomerativeClustering(n_clusters=n_clusters)
        
        # Perform K-means clustering
        print(f"Performing K-means Clustering (k={n_clusters})...")
        kmeans = KMeans(n_clusters=n_clusters, random_state=42, n_init=10)
        clusters = kmeans.fit_predict(X_scaled)
        
        # Add cluster assignments to regime stats
        self.regime_stats['cluster'] = clusters
        print("K-means cluster assignments added to stats DataFrame.")
        
        print("--- Regime Statistics with Cluster Assignments ---")
        display_df = self.regime_stats[['description', 'cluster'] + features].copy()
        print(display_df)
        
        # Group regimes by cluster
        self.regime_clusters = {}
        cluster_stats = {}
        
        for cluster_id in range(n_clusters):
            # Get regimes in this cluster
            cluster_regimes = self.regime_stats[self.regime_stats['cluster'] == cluster_id].index.tolist()
            self.regime_clusters[cluster_id] = cluster_regimes
            
            # Calculate cluster statistics
            cluster_data = self.regime_stats[self.regime_stats['cluster'] == cluster_id]
            cluster_stats[cluster_id] = {
                'regimes': cluster_regimes,
                'avg_volatility': cluster_data['volatility'].mean(),
                'avg_return': cluster_data['avg_return'].mean(),
                'contained_regimes': cluster_data['description'].tolist()
            }
        
        # Print simplified regime groups
        print("--- Simplified Regime Groups Based on Clustering ---")
        for cluster_id, stats in cluster_stats.items():
            print(f"Cluster {cluster_id}: Regimes {stats['regimes']}")
            print(f"  Avg Volatility: {stats['avg_volatility']:.6f}")
            print(f"  Avg Return: {stats['avg_return']:.6f}")
            print(f"  Contained Regimes: {', '.join(stats['contained_regimes'])}")
            print(f"--------------------")
        
        # Generate trading suggestions
        print("--- Suggested Trading Approach by Cluster (Illustrative) ---")
        for cluster_id, stats in cluster_stats.items():
            # Calculate average Sharpe ratio for the cluster
            cluster_data = self.regime_stats[self.regime_stats['cluster'] == cluster_id]
            avg_sharpe = cluster_data['sharpe'].mean()
            
            print(f"Cluster {cluster_id} (Regimes {stats['regimes']}):")
            print(f"  Characteristics: AvgRet={stats['avg_return']:.6f}, AvgVol={stats['avg_volatility']:.6f}, AvgSharpe={avg_sharpe:.4f}")
            
            # Determine suggested strategy based on characteristics
            if stats['avg_return'] > 0 and stats['avg_volatility'] > 0.003:
                strategy = "Trend Following / Momentum"
                size = "Larger"
                stop = "Wider (Trailing?)"
            elif stats['avg_return'] < 0:
                strategy = "Avoid / Counter-Trend (Risky)"
                size = "Minimum / None"
                stop = "Very Tight / Quick Exit"
            else:
                strategy = "Cautious Trend Following" 
                size = "Medium"
                stop = "Standard"
                
            print(f"  Suggested Strategy: {strategy}")
            print(f"  Suggested Size: {size}")
            print(f"  Stop Loss Type: {stop}")
            print(f"--------------------")
            
        print("Regime cluster analysis reporting complete.")
        print("Regime cluster analysis complete.")
        
        return True
    
    def plot_regime_distribution(self, figsize=(14, 8)):
        """
        Plot the distribution of regimes over time.
        """
        if 'regime' not in self.data.columns:
            print("Error: No regime column found.")
            return
        
        plt.figure(figsize=figsize)
        
        # Define colors for each regime
        colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b', '#e377c2', '#7f7f7f']
        
        # Create a colormap for regime visualization
        cmap = plt.cm.get_cmap('viridis', self.n_regimes)
        
        # Create a scatter plot with points colored by regime
        plt.scatter(
            range(len(self.data)), 
            self.data['returns'],
            c=self.data['regime'], 
            cmap=cmap, 
            alpha=0.6,
            s=30
        )
        
        # Add horizontal line at y=0
        plt.axhline(y=0, color='black', linestyle='-', alpha=0.3)
        
        # Add labels for each regime (in the legend)
        legend_elements = []
        for i in range(self.n_regimes):
            if i in self.regime_stats.index:
                desc = self.regime_stats.loc[i, 'description']
                color = cmap(i / self.n_regimes)
                legend_elements.append(plt.Line2D([0], [0], marker='o', color='w', 
                                      markerfacecolor=color, markersize=10,
                                      label=f"Regime {i}: {desc}"))
        
        plt.legend(handles=legend_elements, loc='upper left', bbox_to_anchor=(1, 1))
        
        plt.title('Regime Distribution Over Time', fontsize=16)
        plt.xlabel('Time', fontsize=12)
        plt.ylabel('Returns', fontsize=12)
        plt.grid(True, alpha=0.3)
        plt.tight_layout()
        
        # Save the plot if directory exists
        try:
            plt.savefig(os.path.join(MODEL_OUTPUT_DIR, 'regime_distribution.png'))
            print(f"Regime distribution plot saved to {os.path.join(MODEL_OUTPUT_DIR, 'regime_distribution.png')}")
        except Exception as e:
            print(f"Error saving regime plot: {e}")
            
        plt.show()
    
    def plot_volatility_return_by_regime(self, figsize=(12, 8)):
        """
        Plot regime distribution in volatility-return space.
        """
        if self.regime_stats is None:
            print("Error: Regime statistics not calculated.")
            return
        
        plt.figure(figsize=figsize)
        
        # Create scatter plot of regimes
        for i in range(self.n_regimes):
            if i in self.regime_stats.index:
                vol = self.regime_stats.loc[i, 'volatility']
                ret = self.regime_stats.loc[i, 'avg_return']
                count = self.regime_stats.loc[i, 'count']
                desc = self.regime_stats.loc[i, 'description']
                
                # Size point by count (sqrt for better visual scaling)
                size = 100 * np.sqrt(count / self.regime_stats['count'].max())
                
                plt.scatter(vol, ret, s=size, alpha=0.7, label=f"Regime {i}: {desc}")
                
                # Add text label
                plt.annotate(f"R{i}", (vol, ret), fontsize=12, 
                             ha='center', va='center', weight='bold')
        
        # Add vertical and horizontal lines at x=0, y=0
        plt.axvline(x=0, color='black', linestyle='-', alpha=0.3)
        plt.axhline(y=0, color='black', linestyle='-', alpha=0.3)
        
        plt.title('Regimes in Volatility-Return Space', fontsize=16)
        plt.xlabel('Volatility', fontsize=12)
        plt.ylabel('Average Return', fontsize=12)
        plt.grid(True, alpha=0.3)
        
        # Add legend
        plt.legend(loc='upper left', bbox_to_anchor=(1, 1))
        
        plt.tight_layout()
        
        # Save the plot if directory exists
        try:
            plt.savefig(os.path.join(MODEL_OUTPUT_DIR, 'regime_vol_return.png'))
            print(f"Regime volatility-return plot saved to {os.path.join(MODEL_OUTPUT_DIR, 'regime_vol_return.png')}")
        except Exception as e:
            print(f"Error saving regime plot: {e}")
            
        plt.show()
    
    def get_market_state(self):
        """
        Get the current market state based on the most recent regime.
        
        Returns:
        --------
        dict
            Dictionary with market state information
        """
        if 'regime' not in self.data.columns:
            print("Error: No regime column found.")
            return None
        
        # Get the current (most recent) regime
        latest_regime = self.data['regime'].iloc[-1]
        
        # Get statistics for this regime
        if latest_regime in self.regime_stats.index:
            regime_info = self.regime_stats.loc[latest_regime].to_dict()
            
            # Get the cluster this regime belongs to
            if 'cluster' in regime_info:
                cluster = regime_info['cluster']
                
                # Find all regimes in this cluster
                cluster_regimes = self.regime_stats[self.regime_stats['cluster'] == cluster].index.tolist()
                regime_info['cluster_regimes'] = cluster_regimes
            
            # Get transition probabilities from this regime
            if self.transition_probs is not None and latest_regime in self.transition_probs.index:
                next_probs = self.transition_probs.loc[latest_regime].to_dict()
                regime_info['transition_probs'] = next_probs
                
                # Get most likely next regime
                most_likely_next = max(next_probs.items(), key=lambda x: x[1])
                if most_likely_next[0] != latest_regime:  # If not staying in same regime
                    regime_info['most_likely_next'] = {
                        'regime': most_likely_next[0],
                        'probability': most_likely_next[1],
                        'description': self.regime_stats.loc[most_likely_next[0], 'description']
                    }
            
            return {
                'latest_regime': latest_regime,
                'description': regime_info['description'],
                'avg_return': regime_info['avg_return'],
                'volatility': regime_info['volatility'],
                'sharpe': regime_info['sharpe'],
                'regime_info': regime_info
            }
        
        return None

# %%
# --- OnChain Strategy Class (Buy, Hold, Sell Mode) ---
class OnChainBitcoinStrategy:
    """Bitcoin trading strategy using on-chain metrics with buy, hold, and sell signals"""

    # --- Initialization ---
    def __init__(self, df, predictions, params=None, price_col='close'):
        """Initializes the strategy."""
        print("[DEBUG] OnChainBitcoinStrategy.__init__ called (Buy, Hold, Sell Mode).") # DEBUG
        try:
            self.df = df.copy()
            if self.df.empty:
                 print("[DEBUG] ERROR: Input DataFrame 'df' is empty in __init__.")
                 self.results = None
                 self.trade_history = pd.DataFrame(columns=['entry_date', 'exit_date', 'entry_price', 'exit_price', 'pnl_pct', 'result'])
                 return # Stop initialization

            # Ensure predictions align with df index before assigning
            if not isinstance(predictions, pd.Series):
                 if len(predictions) == len(self.df.index): predictions = pd.Series(predictions, index=self.df.index)
                 elif len(predictions) > 0: predictions = pd.Series(predictions, index=self.df.index[-len(predictions):])
                 else: predictions = pd.Series(0.5, index=self.df.index)

            if not self.df.index.equals(predictions.index):
                print("[DEBUG] Warning: DataFrame index and predictions index do not match. Reindexing predictions...")
                predictions = predictions.reindex(self.df.index, fill_value=0.5)

            self.df['prediction'] = predictions
            nan_pred_count = self.df['prediction'].isnull().sum()
            if nan_pred_count > 0:
                print(f"[DEBUG] Warning: Found {nan_pred_count} NaNs in prediction column after alignment. Filling with 0.5.")
                self.df['prediction'].fillna(0.5, inplace=True)

            self.params = params if params is not None else BACKTESTING_PARAMS.copy()
            self.price_col = price_col
            if self.price_col not in self.df.columns:
                print(f"[DEBUG] ERROR: Price column '{self.price_col}' not found in DataFrame columns: {self.df.columns.tolist()}")
                raise ValueError(f"Price column '{self.price_col}' not found in input DataFrame for strategy.")

            self.results = None
            self.trade_history = pd.DataFrame(columns=['entry_date', 'exit_date', 'entry_price', 'exit_price', 'pnl_pct', 'result'])

            print("[DEBUG] Initializing strategy simulation (_run_strategy - Buy, Hold, Sell)...") # DEBUG
            # --- Call _run_strategy ---
            run_strategy_output = self._run_strategy()
            # --------------------------
            if isinstance(run_strategy_output, pd.DataFrame) and not run_strategy_output.empty:
                self.results = run_strategy_output
                print("[DEBUG] Strategy simulation finished, results DataFrame assigned.")
            else:
                print("[DEBUG] Warning: _run_strategy did not return a valid DataFrame.")
                self.results = None

        except AttributeError as ae: # Specific catch for the error
             print(f"[DEBUG] FATAL AttributeError during __init__: {ae}")
             print("[DEBUG] This likely means _run_strategy or another method was not correctly defined within the class scope.")
             traceback.print_exc()
             self.results = None
             self.trade_history = pd.DataFrame(columns=['entry_date', 'exit_date', 'entry_price', 'exit_price', 'pnl_pct', 'result'])
        except Exception as e:
            print(f"[DEBUG] ERROR during OnChainBitcoinStrategy initialization: {e}")
            traceback.print_exc()
            self.results = None
            self.trade_history = pd.DataFrame(columns=['entry_date', 'exit_date', 'entry_price', 'exit_price', 'pnl_pct', 'result'])
    
    # --- Strategy Execution Logic (_run_strategy - Buy, Hold, Sell MODE) ---
    def _run_strategy(self):
        """Implements the trading strategy logic using ML prediction with buy, hold, and sell signals."""
        print("[DEBUG] _run_strategy (Buy, Hold, Sell Mode) starting...") # DEBUG
        results = self.df.copy()
        if 'prediction' not in results.columns:
                print("[DEBUG] ERROR: 'prediction' column missing in DataFrame for _run_strategy.")
                return None
        if self.price_col not in results.columns:
                print(f"[DEBUG] ERROR: Price column '{self.price_col}' missing in DataFrame for _run_strategy.")
                return None
    
        # Initialize portfolio metrics & state
        results['position'] = 0.0
        results['position_signal'] = 0.0  # Add position signal column (1 for long, -1 for short, 0 for flat)
        results['cash'] = self.params['INITIAL_CASH']
        results['btc_held'] = 0.0
        results['portfolio_value'] = self.params['INITIAL_CASH']
        results['trade'] = 0
        results['trade_size'] = 0.0  # Track absolute change in position (trade size)
        results['entry_price'] = np.nan
        results['trade_result'] = np.nan
        results['pnl'] = 0.0  # Add PnL column for tracking
        results['signal'] = 0  # Add signal column for tracking the ML signal (buy/hold/sell)
        results['transaction_fee'] = 0.0  # Track transaction fees
        local_trade_history = []
        entry_dates = []
        exit_dates = []
    
        print(f"[DEBUG] Starting buy, hold, sell backtest loop for {len(results)} steps...")
    
        # --- Main Backtest Loop (Buy, Hold, Sell Mode) ---
        for i in range(1, len(results)):
            current_date = results.index[i]
            try: # Main data access block
                current_price = results.iloc[i][self.price_col]
                prediction = results.iloc[i]['prediction']
                
                # --- Generate signal based on prediction thresholds ---
                # We'll use thresholds to determine the signal:
                # Buy: prediction > 0.55 (bullish)
                # Hold: 0.45 <= prediction <= 0.55 (neutral/uncertain)
                # Sell: prediction < 0.45 (bearish)
                
                if prediction > 0.55:
                    ml_signal = 1  # Buy Signal
                elif prediction < 0.45:
                    ml_signal = -1  # Sell Signal
                else:
                    ml_signal = 0  # Hold Signal (neutral zone)
                
                # Store the signal in the results DataFrame
                results.iloc[i, results.columns.get_loc('signal')] = ml_signal
    
                if pd.isna(current_price) or pd.isna(prediction): # Skip step if data missing
                        results.iloc[i, results.columns.get_loc('portfolio_value')] = results.iloc[i-1]['portfolio_value'] # Carry forward
                        results.iloc[i, results.columns.get_loc('position')] = results.iloc[i-1]['position']
                        results.iloc[i, results.columns.get_loc('position_signal')] = results.iloc[i-1]['position_signal']
                        results.iloc[i, results.columns.get_loc('cash')] = results.iloc[i-1]['cash']
                        results.iloc[i, results.columns.get_loc('btc_held')] = results.iloc[i-1]['btc_held']
                        results.iloc[i, results.columns.get_loc('entry_price')] = results.iloc[i-1]['entry_price']
                        results.iloc[i, results.columns.get_loc('trade_result')] = results.iloc[i-1]['trade_result']
                        results.iloc[i, results.columns.get_loc('pnl')] = results.iloc[i-1]['pnl']
                        results.iloc[i, results.columns.get_loc('signal')] = results.iloc[i-1]['signal']
                        results.iloc[i, results.columns.get_loc('trade_size')] = 0.0
                        results.iloc[i, results.columns.get_loc('transaction_fee')] = 0.0
                        continue
            except (KeyError, IndexError) as e:
                    print(f"[DEBUG] ERROR accessing data at index {i} (Date: {current_date}): {e}. Stopping simulation.")
                    traceback.print_exc()
                    return None
    
            # Get previous state
            prev_position = results.iloc[i-1]['position']
            prev_position_signal = results.iloc[i-1]['position_signal']
            prev_cash = results.iloc[i-1]['cash']
            prev_btc_held = results.iloc[i-1]['btc_held']
            prev_entry_price = results.iloc[i-1]['entry_price']
    
            # Initialize current step
            results.iloc[i, results.columns.get_loc('cash')] = prev_cash
            results.iloc[i, results.columns.get_loc('btc_held')] = prev_btc_held
            results.iloc[i, results.columns.get_loc('position')] = prev_position
            results.iloc[i, results.columns.get_loc('position_signal')] = prev_position_signal
            results.iloc[i, results.columns.get_loc('entry_price')] = prev_entry_price
            results.iloc[i, results.columns.get_loc('trade')] = 0
            results.iloc[i, results.columns.get_loc('trade_result')] = np.nan
            results.iloc[i, results.columns.get_loc('pnl')] = 0.0
            results.iloc[i, results.columns.get_loc('transaction_fee')] = 0.0
    
            # --- Buy, Hold, Sell Strategy Logic ---
            trade_executed_this_step = False
            transaction_fee = 0.0
            current_position = prev_position  # Default to previous position
            current_position_signal = prev_position_signal  # Default to previous position signal
    
            # --- Buy Logic (Strong Bullish Signal) ---
            if ml_signal == 1: # If ML predicts strong rise, we buy
                position_size_factor = self.params['BASE_POSITION_SIZE']
                trade_amount = min(prev_cash * position_size_factor, prev_cash)
    
                if trade_amount > 10 and current_price > 0: # Minimum trade amount check
                    fee = trade_amount * self.params['COMMISSION_PERC']
                    transaction_fee += fee
                    
                    btc_to_buy = trade_amount / current_price * (1 - self.params['COMMISSION_PERC'])
                    results.iloc[i, results.columns.get_loc('cash')] = prev_cash - trade_amount
                    results.iloc[i, results.columns.get_loc('btc_held')] += btc_to_buy # Add to holdings
                    results.iloc[i, results.columns.get_loc('position')] = 1
                    results.iloc[i, results.columns.get_loc('position_signal')] = 1  # Set position signal to 1 (long)
                    results.iloc[i, results.columns.get_loc('trade')] = 1
                    
                    # Calculate average entry price
                    if pd.isna(prev_entry_price) or prev_btc_held == 0:
                        results.iloc[i, results.columns.get_loc('entry_price')] = current_price
                    else:
                        # Calculate weighted average price when adding to position
                        total_btc = prev_btc_held + btc_to_buy
                        if total_btc > 0:  # Avoid division by zero
                            avg_price = ((prev_btc_held * prev_entry_price) + (btc_to_buy * current_price)) / total_btc
                            results.iloc[i, results.columns.get_loc('entry_price')] = avg_price
                    
                    entry_dates.append(current_date)
                    trade_executed_this_step = True
                    current_position = 1
                    current_position_signal = 1
                    print(f"[DEBUG] Buy executed at {current_date} - Price: {current_price:.2f}, Pred: {prediction:.3f}, BTC Held: {results.iloc[i]['btc_held']:.6f}")
    
            # --- Hold Logic (Neutral Signal) ---
            elif ml_signal == 0:
                # Simply maintain the current position
                # No changes to cash, btc_held, or portfolio values needed
                print(f"[DEBUG] Hold position at {current_date} - Price: {current_price:.2f}, Pred: {prediction:.3f}, BTC Held: {prev_btc_held:.6f}")
    
            # --- Sell Logic (Strong Bearish Signal) ---
            elif ml_signal == -1 and prev_btc_held > 0: # If ML predicts strong drop and we hold BTC
                # In sell mode, we sell a portion of holdings (not necessarily all)
                sell_portion = 0.5  # Sell 50% of current holdings
                btc_to_sell = prev_btc_held * sell_portion
                
                if btc_to_sell > 0 and current_price > 0: # Process Sell
                    fee = btc_to_sell * current_price * self.params['COMMISSION_PERC']
                    transaction_fee += fee
                    
                    cash_return = btc_to_sell * current_price * (1 - self.params['COMMISSION_PERC'])
                    results.iloc[i, results.columns.get_loc('cash')] = prev_cash + cash_return
                    results.iloc[i, results.columns.get_loc('btc_held')] = prev_btc_held - btc_to_sell
                    
                    # If we still hold some BTC, maintain position as 1, otherwise 0
                    remaining_btc = prev_btc_held - btc_to_sell
                    if remaining_btc > 0:
                        current_position = 1
                        current_position_signal = 0.5  # We're still long but reduced position
                    else:
                        current_position = 0
                        current_position_signal = 0  # We're flat (no position)
                    
                    results.iloc[i, results.columns.get_loc('position')] = current_position
                    results.iloc[i, results.columns.get_loc('position_signal')] = current_position_signal
                    results.iloc[i, results.columns.get_loc('trade')] = -1
                    
                    # Only reset entry price if all BTC sold
                    if remaining_btc <= 0:
                        results.iloc[i, results.columns.get_loc('entry_price')] = np.nan
                    
                    trade_executed_this_step = True
                    exit_dates.append(current_date)
                    
                    # Calculate trade result for history
                    if not pd.isna(prev_entry_price) and prev_entry_price > 0:
                        pnl_pct = ((current_price / prev_entry_price) - 1) * 100
                        result_type = 'Win (Sell)' if current_price > prev_entry_price else 'Loss (Sell)'
                        results.iloc[i, results.columns.get_loc('trade_result')] = 1 if current_price > prev_entry_price else -1
                        
                        # Record the trade with partial sell information
                        local_trade_history.append({
                            'entry_date': entry_dates[-1] if entry_dates else None,
                            'exit_date': current_date,
                            'entry_price': prev_entry_price,
                            'exit_price': current_price,
                            'pnl_pct': pnl_pct,
                            'result': result_type,
                            'btc_sold': btc_to_sell,
                            'btc_remaining': remaining_btc
                        })
                    else:
                        results.iloc[i, results.columns.get_loc('trade_result')] = 0
                    
                    print(f"[DEBUG] Partial Sell executed at {current_date} - Price: {current_price:.2f}, Pred: {prediction:.3f}, Sold: {btc_to_sell:.6f} BTC, Remaining: {remaining_btc:.6f} BTC")
    
            # --- IMPLEMENT THE SPECIFIED FORMULA ---
            # Calculate trade size (absolute change in position)
            trade_size = abs(current_position - prev_position)
            results.iloc[i, results.columns.get_loc('trade_size')] = trade_size
            results.iloc[i, results.columns.get_loc('transaction_fee')] = transaction_fee
            
            # Calculate PnL based on the formula:
            # pnl = (price change * previous_position_signal) - trades * transaction fees
            if i > 1:  # Need at least two points for price change
                price_change = (current_price / results.iloc[i-1][self.price_col]) - 1
                
                # Calculate PnL using the formula
                pnl = (price_change * prev_position_signal) - (trade_size * transaction_fee)
                results.iloc[i, results.columns.get_loc('pnl')] = pnl
            
            # --- Update Portfolio Value ---
            try: # Wrap update in try-except
                current_btc_held = results.iloc[i]['btc_held']
                current_cash = results.iloc[i]['cash']
                if pd.notna(current_price) and current_price > 0:
                    btc_value = current_btc_held * current_price
                    results.iloc[i, results.columns.get_loc('portfolio_value')] = current_cash + btc_value
                elif pd.notna(results.iloc[i-1]['portfolio_value']):
                    results.iloc[i, results.columns.get_loc('portfolio_value')] = results.iloc[i-1]['portfolio_value']
                else:
                    results.iloc[i, results.columns.get_loc('portfolio_value')] = current_cash
    
            except Exception as e_update:
                print(f"[DEBUG] ERROR updating portfolio value at step {i}: {e_update}")
                traceback.print_exc()
                return None
        # --- End of Loop ---
        print("[DEBUG] Buy, hold, sell backtest loop finished.")
    
        # --- Post-Loop Calculations ---
        try:
            results['daily_return'] = results['portfolio_value'].pct_change().fillna(0)
            initial_cash = self.params.get('INITIAL_CASH', 1)
            initial_cash = 1 if initial_cash <= 0 else initial_cash
            results['cumulative_return'] = (results['portfolio_value'] / initial_cash) - 1
            
            # Save trade history
            self.trade_history = pd.DataFrame(local_trade_history) if local_trade_history else pd.DataFrame(
                columns=['entry_date', 'exit_date', 'entry_price', 'exit_price', 'pnl_pct', 'result', 'btc_sold', 'btc_remaining'])
                
        except Exception as e_post:
            print(f"[DEBUG] ERROR during post-loop calculations: {e_post}")
            traceback.print_exc()
            return results # Return partial results
    
        print(f"[DEBUG] Finished _run_strategy (Buy, Hold, Sell). Returning results DataFrame. Trades: {len(self.trade_history)}")
        return results
    
    # --- Metrics Calculation ---
    def calculate_metrics(self):
        """Calculate performance metrics using custom PnL and Sharpe ratio calculations"""
        if not hasattr(self, 'results') or self.results is None or 'portfolio_value' not in self.results.columns:
            print("Warning: results attribute missing or invalid for metrics calculation.")
            return {metric: 0 for metric in ['total_return', 'annual_return', 'sharpe', 'max_drawdown', 'win_rate', 'total_trades', 'profit_factor', 'sqn']}
        
        # Extract necessary data
        results = self.results
        epsilon = 1e-9
        initial_cash = self.params.get('INITIAL_CASH', 1)
        initial_cash = epsilon if initial_cash <= 0 else initial_cash
        final_value = results['portfolio_value'].iloc[-1] if not results.empty else initial_cash
        
        # Basic returns calculation
        total_return = (final_value / initial_cash) - 1
        
        # Use PnL values directly from results
        try:
            # Get PnL values
            pnl_values = results['pnl'].dropna()
            
            # Custom Sharpe ratio calculation
            # sharpe_ratio = average(pnl)/standard_deviation(pnl) * sqrt(365*24)
            if len(pnl_values) > 1:
                pnl_mean = pnl_values.mean()
                pnl_std = pnl_values.std()
                
                if pnl_std > epsilon:
                    # Using hourly factor as specified: √(365*24)
                    hourly_factor = np.sqrt(365 * 24)
                    sharpe_ratio = pnl_mean / pnl_std * hourly_factor
                else:
                    sharpe_ratio = 0
            else:
                sharpe_ratio = 0
            
            # Calculate max drawdown from portfolio value
            portfolio_value = results['portfolio_value']
            rolling_max = portfolio_value.cummax()
            safe_rolling_max = rolling_max.replace(0, np.nan).fillna(method='ffill').fillna(epsilon)
            drawdown = (portfolio_value - rolling_max) / safe_rolling_max
            max_drawdown = drawdown.min() if drawdown.notna().any() else 0
            
            # Count total trades based on trade_size > 0
            total_trades = (results['trade_size'] > 0).sum()
            
            # Calculate win rate based on positive PnLs
            positive_pnls = (pnl_values > 0).sum()
            win_rate = positive_pnls / len(pnl_values) if len(pnl_values) > 0 else 0
            
            # Calculate profit factor (sum of positive PnLs / abs(sum of negative PnLs))
            positive_pnl_sum = pnl_values[pnl_values > 0].sum()
            negative_pnl_sum = abs(pnl_values[pnl_values < 0].sum())
            profit_factor = positive_pnl_sum / negative_pnl_sum if negative_pnl_sum > epsilon else float('inf') if positive_pnl_sum > 0 else 0
            
            # Calculate SQN (System Quality Number)
            sqn = np.sqrt(len(pnl_values)) * pnl_values.mean() / pnl_values.std() if len(pnl_values) > 1 and pnl_values.std() > epsilon else 0
            
        except Exception as e:
            print(f"[DEBUG] Error calculating custom metrics: {e}")
            traceback.print_exc()
            # Return default values if calculation fails
            return {
                'total_return': total_return, 
                'annual_return': 0, 
                'sharpe': 0, 
                'max_drawdown': 0, 
                'win_rate': 0, 
                'total_trades': 0, 
                'profit_factor': 0, 
                'sqn': 0
            }
        
        # Return calculated metrics
        return {
            'total_return': total_return,
            'annual_return': total_return / (len(results) / (365 * 24)) if len(results) > 0 else 0,  # Annualized based on hourly data
            'sharpe': sharpe_ratio if np.isfinite(sharpe_ratio) else 0,
            'max_drawdown': max_drawdown if np.isfinite(max_drawdown) else 0,
            'win_rate': win_rate,
            'total_trades': total_trades,
            'profit_factor': profit_factor if np.isfinite(profit_factor) else 0,
            'sqn': sqn if np.isfinite(sqn) else 0
        }
    # --- Plotting Results ---
    def plot_results(self):
        """Plot backtest results: Portfolio Value vs Price and Cumulative Returns."""
        if not hasattr(self, 'results') or self.results is None or self.results.empty: 
            print("Cannot plot results: Results DataFrame is not available or empty.")
            return
        if self.price_col not in self.results.columns: 
            print(f"Cannot plot results: Price column '{self.price_col}' not found.")
            return
            
        results = self.results
        plt.style.use('seaborn-v0_8-darkgrid')
        # Change from 3 subplots to 2 subplots
        fig, axes = plt.subplots(2, 1, figsize=(14, 12), sharex=True)
        fig.suptitle('Buy, Hold, Sell Bitcoin Trading Backtest Results', fontsize=16)
        
        # Portfolio Value & Price Plot
        ax1 = axes[0]
        ax1.plot(results.index, results['portfolio_value'], label='Portfolio Value', color='blue', linewidth=1.5)
        ax1.set_ylabel('Portfolio Value ($)', color='blue', fontsize=12)
        ax1.tick_params(axis='y', labelcolor='blue')
        ax1.set_title('Portfolio Value & Trades vs Price', fontsize=14)
        
        ax1b = ax1.twinx()
        ax1b.plot(results.index, results[self.price_col], label=f'{self.price_col.capitalize()} Price', 
                color='orange', alpha=0.6, linewidth=1.5)
        ax1b.set_ylabel(f'{self.price_col.capitalize()} Price ($)', color='orange', fontsize=12)
        ax1b.tick_params(axis='y', labelcolor='orange')
        
        # Plot buy and sell signals
        buy_signals = results[results['trade'] == 1]
        sell_signals = results[results['trade'] == -1]
        hold_signals = results[results['signal'] == 0]  # Get the hold signals for visualization
        
        if not buy_signals.empty:
            ax1.scatter(buy_signals.index, buy_signals['portfolio_value'], marker='^', 
                    color='lime', s=70, label='Buy', alpha=0.9, edgecolors='k', linewidth=0.5, zorder=5)
        
        if not sell_signals.empty:
            ax1.scatter(sell_signals.index, sell_signals['portfolio_value'], marker='v', 
                    color='red', s=70, label='Sell', alpha=0.9, edgecolors='k', linewidth=0.5, zorder=5)
        
        # We could also mark hold signals, but they might clutter the chart
        # Let's just highlight a few significant hold signals 
        if not hold_signals.empty:
            # Sample only a few hold signals to avoid cluttering
            sample_size = min(20, len(hold_signals))
            sampled_holds = hold_signals.sample(sample_size) if len(hold_signals) > sample_size else hold_signals
            
            ax1.scatter(sampled_holds.index, sampled_holds['portfolio_value'], marker='o', 
                    color='yellow', s=50, label='Hold (sample)', alpha=0.7, edgecolors='k', linewidth=0.5, zorder=4)
        
        lines, labels = ax1.get_legend_handles_labels()
        lines2, labels2 = ax1b.get_legend_handles_labels()
        ax1.legend(lines + lines2, labels + labels2, loc='upper left')
        ax1.grid(True, alpha=0.5)
        
        # Cumulative Return Plot
        ax2 = axes[1]
        ax2.plot(results.index, results['cumulative_return'] * 100, 
                label='Strategy Cumulative Return', color='green', linewidth=2)
        
        start_price = results[self.price_col].iloc[0] if not results.empty and results[self.price_col].iloc[0] != 0 else 1
        btc_buy_hold_return = (results[self.price_col] / start_price) - 1
        ax2.plot(results.index, btc_buy_hold_return * 100, 
                label='Buy & Hold Cumulative Return', color='gray', linestyle='--')
        
        ax2.set_ylabel('Cumulative Return (%)', fontsize=12)
        ax2.set_title('Strategy vs Buy & Hold Returns', fontsize=14)
        ax2.legend(loc='upper left')
        ax2.grid(True, alpha=0.5)
        plt.tight_layout()
        plt.subplots_adjust(top=0.92)  # Adjust to make room for suptitle
        plt.show()

# %%
# --- Utility Functions ---
def load_and_prepare_data(file_path):
    """Loads data, standardizes columns, parses datetime, sets index, handles basic NaNs."""
    try:
        # Try reading with default UTF-8 encoding first
        df = pd.read_csv(file_path) #
        print(f"Successfully loaded data from: {file_path}") #
    except FileNotFoundError: #
        print(f"FATAL ERROR: File not found at {file_path}") #
        raise # Re-raise the error to stop execution
    except UnicodeDecodeError:
        # Try with a different encoding if default fails
        try:
            print("UTF-8 decoding failed. Trying encoding 'latin1'...") #
            df = pd.read_csv(file_path, encoding='latin1') #
            print(f"Successfully loaded data from: {file_path} (using latin1)") #
        except Exception as e_load:
            print(f"Error loading data with default and latin1 encoding: {e_load}") #
            raise # Re-raise if fallback also fails
    except Exception as e: # Catch other potential loading errors
         print(f"An unexpected error occurred during data loading: {e}") #
         raise

    print(f"Initial shape: {df.shape}") #
    # print(f"Initial columns: {df.columns.tolist()}") # Optional: print initial columns

    # Standardize column names (lowercase, replace spaces/special chars with underscores)
    df.columns = df.columns.str.lower().str.replace('[^A-Za-z0-9_]+', '_', regex=True).str.strip('_') #
    print(f"Standardized columns: {df.columns.tolist()}") #

    # --- Identify and parse datetime column ---
    date_col_found = None #
    # Look for common date/time column names (standardized to lowercase)
    potential_date_cols = ['datetime', 'date', 'timestamp', 'time', 'periodstart', 'bucket']
    for col in potential_date_cols: #
        if col in df.columns: #
            print(f"Attempting to parse '{col}' as datetime...") #
            try:
                # Try inferring format first for flexibility, coerce errors to NaT
                df[col] = pd.to_datetime(df[col], infer_datetime_format=True, errors='coerce') #
                # Check if parsing was successful for a significant portion
                if df[col].notna().sum() > 0.5 * len(df): # Check if at least half parsed correctly
                    date_col_found = col #
                    print(f"Successfully parsed '{col}' (or most of it).") #
                    break # Stop after finding and parsing one suitable column
                else:
                     print(f"Column '{col}' auto-parsing resulted in too many NaNs. Will try other columns/formats.")
                     df[col] = df[col].astype(str) # Revert if parsing failed badly
            except Exception as e_dt: #
                print(f"Could not auto-parse '{col}': {e_dt}. Trying specific formats...") #
                # Try common specific formats if inference fails
                formats_to_try = ['%Y-%m-%d %H:%M:%S', '%Y-%m-%d', '%m/%d/%Y', '%d-%b-%Y', '%Y%m%d'] #
                parsed_specific = False #
                original_dtype = df[col].dtype # Store original type in case all formats fail
                for fmt in formats_to_try: #
                    try:
                        # Attempt parsing with specific format, coercing errors
                        parsed_series = pd.to_datetime(df[col], format=fmt, errors='coerce') #
                        # Check if this format worked significantly better
                        if parsed_series.notna().sum() > 0.5 * len(df): #
                            df[col] = parsed_series # Assign the successfully parsed series
                            date_col_found = col #
                            print(f"Successfully parsed '{col}' with format '{fmt}'.") #
                            parsed_specific = True #
                            break # Stop checking formats for this column
                    except Exception: # Catch errors during specific format parsing
                         # print(f"Format '{fmt}' failed for '{col}'.") # Optional: Too verbose usually
                         continue # Try next format
                if parsed_specific: #
                    break # Stop checking other potential date columns if one was parsed
                else:
                     # Revert column to original type if no format worked well
                     # This prevents a column of mostly NaT if parsing failed
                     # df[col] = df[col].astype(original_dtype) # Be careful with this revert
                     print(f"Could not parse '{col}' successfully with common formats.")

    # --- Set Index and Handle Initial Missing Values ---
    if date_col_found: #
        df.dropna(subset=[date_col_found], inplace=True) # Drop rows where date parsing ultimately failed
        df = df.sort_values(date_col_found).set_index(date_col_found) #
        print(f"'{date_col_found}' column set as index.") #
    else: #
        print("Warning: No suitable datetime column found or parsed successfully.") #
        # Check if index is already datetime (e.g., loaded from specific format)
        if not isinstance(df.index, pd.DatetimeIndex): #
             raise ValueError("Could not identify/parse datetime column, and index is not datetime.") #
        else:
             print("Index is already DatetimeIndex.")

    # Convert object columns to numeric where possible, coercing errors
    for col in df.select_dtypes(include=['object']).columns: #
          df[col] = pd.to_numeric(df[col], errors='coerce') #

    # Basic NaN handling (forward fill, then backward fill) - More robust handling later
    df.ffill(inplace=True) #
    df.bfill(inplace=True) #
    # Fill any remaining NaNs (e.g., if entire columns were NaN) with 0 - may reconsider this
    df.fillna(0, inplace=True) #

    print(f"Data loaded and basic preparation complete. Shape: {df.shape}") #
    return df #

print("Utility functions for data loading and feature selection defined.")
# Out:
# Utility functions for data loading and feature selection defined.

# %%
def add_onchain_features(df):
    """Add on-chain specific features, including technical indicators and ratios."""
    print("Adding on-chain features...") #
    df_result = df.copy() #
    original_cols = set(df_result.columns) # Keep track of original columns

    # --- Technical/Ratio Features (Examples) ---
    # Ensure required base columns exist before calculating features
    required_numeric_cols = ['inflow_total', 'outflow_total', 'inflow_top10', 'outflow_top10', 'netflow_total', 'volume', 'transactions_count_flow', 'flow_mean']
    existing_numeric_cols = [col for col in required_numeric_cols if col in df_result.columns and pd.api.types.is_numeric_dtype(df_result[col])]

    epsilon = 1e-9 # Small number to avoid division by zero

    # 1. Inflow/outflow ratios
    if all(col in existing_numeric_cols for col in ['inflow_total', 'outflow_total']): #
        # Avoid division by zero or NaN
        denominator = df_result['outflow_total'].replace(0, epsilon) # Replace 0 with epsilon
        df_result['inflow_outflow_ratio'] = df_result['inflow_total'] / denominator #
        # Apply log transform to normalize - ensure non-negative input for log1p
        df_result['inflow_outflow_ratio_log'] = np.log1p(df_result['inflow_outflow_ratio'].clip(lower=0)) #

    # 2. Top wallet concentration
    if all(col in existing_numeric_cols for col in ['inflow_top10', 'inflow_total']): #
        denominator = df_result['inflow_total'].replace(0, epsilon) #
        df_result['top10_dominance_inflow'] = df_result['inflow_top10'] / denominator #
    if all(col in existing_numeric_cols for col in ['outflow_top10', 'outflow_total']): #
        denominator = df_result['outflow_total'].replace(0, epsilon) #
        df_result['top10_dominance_outflow'] = df_result['outflow_top10'] / denominator #

    # 3. Net flow features
    if 'netflow_total' in existing_numeric_cols: #
        df_result['netflow_sign'] = np.sign(df_result['netflow_total']) #
        if 'volume' in existing_numeric_cols: #
            denominator = df_result['volume'].replace(0, epsilon) #
            df_result['netflow_to_volume'] = df_result['netflow_total'] / denominator #

    # 4. Transaction count features
    if all(col in existing_numeric_cols for col in ['transactions_count_flow', 'volume']): #
        denominator = df_result['volume'].replace(0, epsilon) #
        df_result['tx_count_per_volume'] = df_result['transactions_count_flow'] / denominator #

    # 5. Flow rate changes (Percent change in mean flow)
    if 'flow_mean' in existing_numeric_cols: #
        df_result['flow_mean_change'] = df_result['flow_mean'].pct_change(1) #

    # 6. Lagged features (Example lags for key metrics)
    lag_features_base = ['inflow_outflow_ratio', 'netflow_total', 'top10_dominance_inflow'] #
    for lag in [1, 3, 7]: #
        for base_feat in lag_features_base: #
            if base_feat in df_result.columns: # Check if base feature was successfully created
                 df_result[f'{base_feat}_lag{lag}'] = df_result[base_feat].shift(lag) #

    # 7. Flow acceleration (Second difference of flow totals)
    for flow_type in ['inflow', 'outflow']: #
        total_col = f'{flow_type}_total' #
        if total_col in existing_numeric_cols: #
            df_result[f'{flow_type}_acceleration'] = df_result[total_col].diff().diff() #

    # 8. Moving average features of on-chain metrics
    ma_features_base = ['inflow_total', 'outflow_total', 'netflow_total'] #
    for window in [7, 14, 30]: #
        for base_feat in ma_features_base: #
            if base_feat in existing_numeric_cols: #
                df_result[f'{base_feat}_ma{window}'] = df_result[base_feat].rolling(window=window, min_periods=max(1, window//2)).mean() # Use min_periods

    # 9. Volatility (Rolling Standard Deviation / Mean) in on-chain metrics
    vol_features_base = ['inflow_total', 'outflow_total'] #
    vol_window = 7 #
    for base_feat in vol_features_base: #
         if base_feat in existing_numeric_cols: #
            rolling_mean = df_result[base_feat].rolling(vol_window, min_periods=max(2, vol_window//2)).mean() #
            rolling_std = df_result[base_feat].rolling(vol_window, min_periods=max(2, vol_window//2)).std() #
            # Calculate coefficient of variation, handle division by zero
            df_result[f'{base_feat}_volatility'] = (rolling_std / rolling_mean.replace(0, np.nan)).fillna(0) # Fill NaNs resulting from division or std dev calculation

    # 10. Divergence between inflow and outflow volatility
    if all(col in df_result.columns for col in ['inflow_volatility', 'outflow_volatility']): # Check if volatilities were created
         df_result['flow_divergence'] = abs(df_result['inflow_volatility'] - df_result['outflow_volatility']) #

    # 11. On-chain trend features (based on 7-day change)
    trend_features_base = ['inflow_total', 'outflow_total'] #
    trend_period = 7 #
    for base_feat in trend_features_base: #
         if base_feat in existing_numeric_cols: #
              df_result[f'{base_feat}_trend'] = (df_result[base_feat].pct_change(periods=trend_period) > 0).astype(int) #

    # 12. Trend alignment (Are inflow and outflow trends moving together?)
    if all(col in df_result.columns for col in ['inflow_trend', 'outflow_trend']): # Check if trends were created
        df_result['trend_alignment'] = (df_result['inflow_trend'] == df_result['outflow_trend']).astype(int) #

    # 13. On-chain momentum (Short MA / Long MA ratio)
    mom_features_base = ['inflow_total', 'outflow_total'] #
    short_ma_win = 7 #
    long_ma_win = 30 #
    for base_feat in mom_features_base: #
        if base_feat in existing_numeric_cols: #
            ma_short = df_result[base_feat].rolling(short_ma_win, min_periods=max(1, short_ma_win//2)).mean() #
            ma_long = df_result[base_feat].rolling(long_ma_win, min_periods=max(1, long_ma_win//2)).mean() #
            # Calculate momentum ratio, handle division by zero
            df_result[f'{base_feat}_momentum'] = (ma_short / ma_long.replace(0, np.nan)).fillna(1.0) - 1 # Center around 0

    # --- Features from jaybee.txt --- [cite: 1]
    # Exchange reserve metrics [cite: 19]
    if all(col in existing_numeric_cols for col in ['inflow_total', 'outflow_total']): # [cite: 19]
        df_result['cumulative_netflow'] = (df_result['inflow_total'] - df_result['outflow_total']).cumsum() # [cite: 19]
        df_result['reserve_change_rate'] = df_result['cumulative_netflow'].pct_change(7) # [cite: 19]

    # Whale transaction metrics [cite: 20]
    if all(col in existing_numeric_cols for col in ['inflow_top10', 'outflow_top10']): # [cite: 20]
        df_result['whale_netflow'] = df_result['inflow_top10'] - df_result['outflow_top10'] # [cite: 20]
        df_result['whale_activity'] = (df_result['inflow_top10'] + df_result['outflow_top10']) / 2 # [cite: 20]

    # Calculate whale dominance trend using previously calculated dominance features
    if all(col in df_result.columns for col in ['top10_dominance_inflow', 'top10_dominance_outflow']): # [cite: 20] Check required base features exist
         df_result['whale_dominance_trend'] = (df_result['top10_dominance_inflow'] + df_result['top10_dominance_outflow']) / 2 # [cite: 20]
         df_result['whale_dominance_change'] = df_result['whale_dominance_trend'].pct_change(3) # [cite: 20]

    # Transaction activity metrics [cite: 20]
    if 'transactions_count_flow' in existing_numeric_cols: # [cite: 20]
        df_result['tx_momentum'] = df_result['transactions_count_flow'].pct_change(7) # [cite: 20]
        df_result['tx_acceleration'] = df_result['tx_momentum'].diff(1) # [cite: 20]
        tx_rolling_mean = df_result['transactions_count_flow'].rolling(7, min_periods=max(2, 7//2)).mean() # [cite: 20]
        tx_rolling_std = df_result['transactions_count_flow'].rolling(7, min_periods=max(2, 7//2)).std() # [cite: 20]
        df_result['tx_volatility'] = (tx_rolling_std / tx_rolling_mean.replace(0, np.nan)).fillna(0) # [cite: 20] Handle NaNs

    # Market state classification [cite: 21, 22]
    if 'inflow_outflow_ratio' in df_result.columns: # [cite: 21] Check base feature exists
        ratio_ma7 = df_result['inflow_outflow_ratio'].rolling(7, min_periods=max(1, 7//2)).mean() # [cite: 21, 22]
        df_result['accumulation_phase'] = ((df_result['inflow_outflow_ratio'] < 0.8) & (ratio_ma7 < 0.9)).astype(int) # [cite: 21]
        df_result['distribution_phase'] = ((df_result['inflow_outflow_ratio'] > 1.2) & (ratio_ma7 > 1.1)).astype(int) # [cite: 22]
    # --- End New Features ---


    # Final cleanup of NaNs/Infs potentially introduced by feature engineering
    new_cols = list(set(df_result.columns) - original_cols) # Identify newly added columns
    print(f"Added {len(new_cols)} new features.") #
    # print(f"New features added: {new_cols}") # Optional: print list of new features

    df_result = df_result.replace([np.inf, -np.inf], np.nan) # Replace any infinities
    # Fill NaNs robustly - ffill, bfill, then 0 for anything remaining
    df_result.ffill(inplace=True) #
    df_result.bfill(inplace=True) #
    df_result.fillna(0, inplace=True) # Fill any remaining NaNs with 0

    print("On-chain feature engineering complete.") #
    return df_result #

print("Utility function for feature engineering defined.")
# Out:
# Utility function for feature engineering defined.

# %%
def create_target_variable(df, price_col='close', periods_ahead=1): # Use standardized lowercase default
    """Create target variables for model training (direction)."""
    print("Creating target variables...") #
    if price_col not in df.columns: #
        raise ValueError(f"Price column '{price_col}' not found in DataFrame.") #

    df_with_target = df.copy() #

    # Define standardized names for created columns
    future_price_col = 'future_price' #
    target_return_col = 'target_return' #
    # TARGET_COLUMN is defined globally ('target_direction')

    # Calculate future price by shifting the price column backwards
    df_with_target[future_price_col] = df_with_target[price_col].shift(-periods_ahead) #

    # Target Return (percentage change) - handle division by zero
    current_price_safe = df_with_target[price_col].replace(0, np.nan) # Avoid division by zero
    df_with_target[target_return_col] = (df_with_target[future_price_col] / current_price_safe - 1) #

    # Target Direction (binary classification: 1 for up/flat, 0 for strictly down)
    # Use the globally defined TARGET_COLUMN name here
    # Note: The condition > 0 means flat returns are treated as 'Down (0)'.
    # Change to >= 0 if flat should be considered 'Up (1)'.
    df_with_target[TARGET_COLUMN] = (df_with_target[target_return_col] > 0).astype(int) #

    # Drop rows where target cannot be calculated (typically at the end due to shifting)
    original_len = len(df_with_target) #
    # Drop based on the standardized target-related column names
    df_with_target.dropna(subset=[future_price_col, target_return_col, TARGET_COLUMN], inplace=True) #
    rows_dropped = original_len - len(df_with_target)
    print(f"Dropped {rows_dropped} rows due to missing target values (typically at the end).") #

    if df_with_target.empty: #
        raise ValueError("DataFrame became empty after dropping rows with missing target values. Check periods_ahead or data length.") #

    print(f"Created target variables using '{price_col}', looking {periods_ahead} period(s) ahead.") #
    print(f"Target Direction ('{TARGET_COLUMN}') distribution:") #
    print(df_with_target[TARGET_COLUMN].value_counts(normalize=True)) #

    return df_with_target #

print("Utility function for target variable creation defined.")
# Out:
# Utility function for target variable creation defined.

# %%
def split_data_chronological(df, target_col, test_size, validation_size):
    """Splits data chronologically into train, validation, and test sets."""
    print("\nSplitting data chronologically...")
    if target_col not in df.columns: #
        raise ValueError(f"Target column '{target_col}' not found in DataFrame for splitting.") #

    # Define feature columns: all columns except target and auxiliary target/price columns
    # Use standardized lowercase names for exclusion, including the main PRICE_COLUMN
    exclude_cols = [target_col, 'target_return', 'future_price', PRICE_COLUMN] # Exclude price itself
    # Ensure we only try to exclude columns that actually exist
    exclude_cols = [col for col in exclude_cols if col in df.columns]

    feature_cols = [col for col in df.columns if col not in exclude_cols] #

    # Select only features that are numeric and don't contain NaN/inf after handling
    X = df[feature_cols].copy() #
    X = X.select_dtypes(include=np.number) # Keep only numeric types

    # Double-check for NaN/inf that might have slipped through or were introduced
    X = X.replace([np.inf, -np.inf], np.nan) #
    cols_with_nan = X.columns[X.isnull().any()].tolist() #
    if cols_with_nan: #
        print(f"Warning: Features {cols_with_nan} still contain NaNs before split. Imputing with median.") #
        for col in cols_with_nan: #
             median_val = X[col].median() #
             fill_value = median_val if pd.notna(median_val) else 0 # Use 0 if median is NaN
             X[col].fillna(fill_value, inplace=True) #

    y = df[target_col] #
    final_feature_cols = X.columns.tolist() # Get the list of features actually used

    print(f"Using {len(final_feature_cols)} final numeric feature columns for splitting.") #
    # print(f"Final Features: {final_feature_cols}") # Uncomment to see list

    # --- Calculate split indices ---
    n = len(X) #
    if n == 0: #
        raise ValueError("DataFrame has no samples to split after feature selection.") #

    # Ensure split sizes are valid
    if not (0 < test_size < 1) or not (0 <= validation_size < 1) or (test_size + validation_size >= 1):
         raise ValueError("Invalid test/validation sizes. Ensure they are between 0 and 1, and their sum is less than 1.")

    test_split_idx = int(n * (1 - test_size)) # Index where test set begins
    # Calculate validation split index relative to the start of the data
    val_split_idx = int(n * (1 - test_size - validation_size)) # Index where validation set begins

    if not (0 <= val_split_idx < test_split_idx < n): # Check indices are valid and ordered
         raise ValueError(f"Calculated split indices are invalid (train_end={val_split_idx}, val_end={test_split_idx}, total={n}). Check sizes.")

    # --- Split the features and target ---
    X_train = X.iloc[:val_split_idx] #
    y_train = y.iloc[:val_split_idx] #
    X_val = X.iloc[val_split_idx:test_split_idx] #
    y_val = y.iloc[val_split_idx:test_split_idx] #
    X_test = X.iloc[test_split_idx:] #
    y_test = y.iloc[test_split_idx:] #

    # --- Split other potential targets if they exist (e.g., return for analysis) ---
    aux_targets_data = {} #
    # Use standardized lowercase name 'target_return'
    if 'target_return' in df.columns: #
        try:
            aux_targets_data["target_return_train"] = df['target_return'].iloc[:val_split_idx] #
            aux_targets_data["target_return_val"] = df['target_return'].iloc[val_split_idx:test_split_idx] #
            aux_targets_data["target_return_test"] = df['target_return'].iloc[test_split_idx:] #
        except IndexError: #
             print("Warning: Could not split auxiliary target 'target_return' due to index mismatch.") #

    print("\n--- Data Split Summary ---") #
    print(f"Total samples: {n}") #
    print(f"Training set:   {len(X_train)} samples (Index {X_train.index.min()} to {X_train.index.max()}) - Target mean: {y_train.mean():.3f}") #
    print(f"Validation set: {len(X_val)} samples (Index {X_val.index.min()} to {X_val.index.max()}) - Target mean: {y_val.mean():.3f}") #
    print(f"Test set:       {len(X_test)} samples (Index {X_test.index.min()} to {X_test.index.max()}) - Target mean: {y_test.mean():.3f}") #

    # Check for empty splits
    if X_train.empty or X_val.empty or X_test.empty: #
         raise ValueError("One or more data splits are empty. Check data length and split ratios.") #

    return X_train, X_val, X_test, y_train, y_val, y_test, aux_targets_data, final_feature_cols #

print("Utility function for chronological data splitting defined.")
# Out:
# Utility function for chronological data splitting defined.

# %%
def setup_preprocessor(X_train):
    """Creates and fits the preprocessor pipeline on training data."""
    # Identify numerical features based on the columns present in X_train
    numerical_features = X_train.select_dtypes(include=np.number).columns.tolist() #

    if not numerical_features: #
        print("Warning: No numerical features found in X_train for preprocessing.") #
        # Return a dummy preprocessor or handle appropriately
        return None, []

    print(f"Setting up preprocessor for {len(numerical_features)} numerical features.") #

    # Create transformers for numerical features
    # Using RobustScaler as it's less sensitive to outliers
    # Using SimpleImputer with median strategy for robustness
    numerical_transformer = Pipeline(steps=[
        ('imputer', SimpleImputer(strategy='median')), # Handle NaNs that might remain
        ('scaler', RobustScaler()) # Scale features
    ]) #

    # Create the ColumnTransformer
    # Only apply transformations to numerical features found
    preprocessor = ColumnTransformer(
        transformers=[
            ('num', numerical_transformer, numerical_features) # Apply to numerical features
        ],
        remainder='passthrough' # Keep any non-numerical columns if they exist (though X should be numeric)
        # Alternatively, use 'drop' if certain non-numeric should be discarded: remainder='drop'
    ) #

    # Fit on training data ONLY
    print("Fitting preprocessor on training data...") #
    try:
        preprocessor.fit(X_train) #
        print("Preprocessor fitted successfully.") #
    except Exception as e: #
        print(f"Error fitting preprocessor: {e}") #
        traceback.print_exc() #
        raise # Re-raise error to halt execution

    # Get the feature names after transformation (important for some models)
    # Simple case: for RobustScaler on numeric only, names usually remain the same.
    # If OneHotEncoder or other transformers were used, this would need adjustment.
    try:
        # Attempt to get feature names out - may depend on scikit-learn version
        transformed_feature_names = preprocessor.get_feature_names_out()
        print(f"Preprocessor produces {len(transformed_feature_names)} features.")
    except Exception:
         # Fallback if get_feature_names_out fails (e.g., older sklearn)
         print("Could not automatically get transformed feature names. Using original numeric names.")
         transformed_feature_names = numerical_features # Fallback

    return preprocessor, transformed_feature_names #

print("Preprocessor setup function defined.")
# Out:
# Preprocessor setup function defined.

# %%
def preprocess_features(preprocessor, X_train, X_val, X_test):
    """Applies preprocessing transformations to feature sets."""
    if preprocessor is None:
         print("Preprocessor is None. Skipping feature transformation.")
         # Return original data if no preprocessing is done
         return X_train, X_val, X_test

    print("Applying preprocessing transformations (train, val, test)...") #
    try:
        # Transform data using the fitted preprocessor
        X_train_processed = preprocessor.transform(X_train) #
        X_val_processed = preprocessor.transform(X_val) #
        X_test_processed = preprocessor.transform(X_test) #
        print(f"Processed feature shapes: Train {X_train_processed.shape}, Val {X_val_processed.shape}, Test {X_test_processed.shape}") #
    except Exception as e: #
        print(f"Error during feature transformation: {e}") #
        traceback.print_exc() #
        raise # Halt execution if transformation fails

    # Output is typically a NumPy array. Convert back to DataFrame if needed,
    # using transformed_feature_names obtained from setup_preprocessor.
    # Example (optional):
    # feature_names = preprocessor.get_feature_names_out() # Assuming this worked
    # X_train_proc_df = pd.DataFrame(X_train_processed, index=X_train.index, columns=feature_names)
    # X_val_proc_df = pd.DataFrame(X_val_processed, index=X_val.index, columns=feature_names)
    # X_test_proc_df = pd.DataFrame(X_test_processed, index=X_test.index, columns=feature_names)
    # return X_train_proc_df, X_val_proc_df, X_test_proc_df

    return X_train_processed, X_val_processed, X_test_processed #

print("Feature preprocessing application function defined.")
# Out:
# Feature preprocessing application function defined.

# %%
# --- Model Training Functions (Using Fixed Default Parameters) ---
# NOTE: Hyperparameter tuning functions and setup have been removed.

def train_xgboost_model(X_train, y_train, X_val, y_val, params=None):
    """Trains an XGBoost Classifier model with early stopping using fixed parameters."""
    print("\n--- Training XGBoost Model ---") #
    # Use provided params or fall back to the global fixed defaults
    current_params = params if params else XGB_CLS_DEFAULT_PARAMS.copy() # Use a copy

    print("Using fixed parameters for XGBoost Classifier:") #
    for key, value in current_params.items(): #
        print(f"- {key}: {value}") #

    model = xgb.XGBClassifier(**current_params) #

    # Define evaluation set for early stopping
    eval_set = [(X_val, y_val)] #

    try:
        print("Fitting XGBoost model...") #
        model.fit(
            X_train, y_train, #
            eval_set=eval_set, # Use validation set for early stopping
            verbose=False # Set to True or e.g., 50 to see progress during training
        ) #

        # XGBoost stores best iteration info if early stopping is effective
        best_iteration = getattr(model, 'best_iteration', 'N/A (Early stopping not triggered/used or attribute missing)') #
        # Note: best_score refers to the eval_metric (logloss here) on the validation set
        best_score = getattr(model, 'best_score', 'N/A') #
        print(f"XGBoost training complete. Best iteration: {best_iteration}, Best Score (eval_metric): {best_score}") #

    except Exception as e: #
         print(f"Error training XGBoost model: {e}") #
         traceback.print_exc() #
         return None # Return None if training fails

    return model #

print("XGBoost training function defined.")
# Out:
# XGBoost training function defined.

# %%
def train_random_forest_model(X_train, y_train, feature_names, params=None):
    """Trains a Random Forest Classifier model using fixed parameters."""
    # Note: RF doesn't intrinsically use a validation set during standard .fit() for early stopping
    print("\n--- Training Random Forest Model ---") #
    # Use provided params or fall back to the global fixed defaults
    current_params = params if params else RF_CLS_DEFAULT_PARAMS.copy() # Use a copy

    print("Using fixed parameters for Random Forest Classifier:") #
    for key, value in current_params.items(): #
        print(f"- {key}: {value}") #

    model = RandomForestClassifier(**current_params) #

    try:
        print("Fitting Random Forest model...") #
        model.fit(X_train, y_train) #
        print("Random Forest model trained.") #

        # Display Feature Importance if possible
        if feature_names is not None and hasattr(model, 'feature_importances_'): #
            importances = model.feature_importances_ #

            # Ensure feature_names aligns with importances array length
            num_features = len(feature_names) #
            num_importances = len(importances) #
            if num_features != num_importances: #
                 print(f"Warning: Mismatch between feature names ({num_features}) and importances ({num_importances}). Aligning...") #
                 # Take the minimum length to avoid index errors
                 min_len = min(num_features, num_importances)
                 feature_names_aligned = list(feature_names[:min_len]) # Ensure it's a list
                 importances_aligned = importances[:min_len] #
            else: #
                 feature_names_aligned = list(feature_names) # Ensure it's a list
                 importances_aligned = importances #

            # Create DataFrame for easier sorting and display
            feature_importance_df = pd.DataFrame({ #
                'feature': feature_names_aligned, #
                'importance': importances_aligned #
            }).sort_values('importance', ascending=False).reset_index(drop=True) #

            print("\nTop 15 features by importance (Random Forest):") #
            print(feature_importance_df.head(15).to_string()) #
        else: #
             print("Could not display feature importances (feature_names not provided or model lacks attribute).") #


    except Exception as e: #
        print(f"Error training Random Forest model: {e}") #
        traceback.print_exc() #
        return None # Return None if training fails

    return model #

print("Random Forest training function defined.")
# Out:
# Random Forest training function defined.

# %%
def train_mlp_model(X_train, y_train, X_val, y_val, params=None):
    """Trains an MLP Classifier model using fixed parameters (assuming pre-scaled data)."""
    # NOTE: Assumes X_train, X_val are already scaled by the global preprocessor.
    # The internal pipeline step for scaling is removed/commented out.
    print("\n--- Training MLP Model ---") #
    # Use provided params or fall back to the global fixed defaults
    current_params = params if params else MLP_CLS_DEFAULT_PARAMS.copy() # Use a copy

    print("Using fixed parameters for MLP Classifier:") #
    # Print MLP-specific params
    for key, value in current_params.items(): #
        print(f"- {key}: {value}") #

    # Define the MLP model component directly (no pipeline needed if data is pre-scaled)
    model = MLPClassifier(**current_params) #

    try:
        print("Fitting MLP model (using internal validation split for early stopping)...") #
        # MLP uses its own internal validation split ('validation_fraction') from the training data
        # for early stopping if 'early_stopping=True'. It doesn't use X_val passed here directly for stopping.
        # We pass X_val mainly for consistency or potential future use in custom callbacks.
        model.fit(X_train, y_train) #
        print("MLP model trained.") #

        # Access attributes from the trained MLP model
        if hasattr(model, 'loss_'): #
            print(f"MLP final loss: {model.loss_:.6f}") #
        if hasattr(model, 'n_iter_'): #
            print(f"MLP iterations: {model.n_iter_}") #
        if hasattr(model, 'best_loss_'): # If early stopping was used
             # Note: MLP calls validation score 'best_loss_' if using default score (accuracy)
             # Or use model.best_validation_score_ if available in newer versions/specific settings
             best_val_score = getattr(model, 'best_validation_score_', None)
             best_loss = getattr(model, 'best_loss_', None)
             if best_val_score is not None:
                  print(f"MLP best validation score (internal split): {best_val_score:.6f}")
             elif best_loss is not None:
                  print(f"MLP best validation loss (internal split): {best_loss:.6f}")


    except Exception as e: #
        print(f"Error training MLP model: {e}") #
        traceback.print_exc() #
        return None # Return None if training fails

    return model #

print("MLP training function defined.")
# Out:
# MLP training function defined.

# %%
def train_logistic_model(X_train, y_train, params=None):
    """Trains a Logistic Regression model using fixed parameters (assuming pre-scaled data)."""
    # NOTE: Assumes X_train is already scaled by the global preprocessor.
    print("\n--- Training Logistic Regression Model ---") #
    # Use provided params or fall back to the global fixed defaults
    current_params = params if params else LOGISTIC_DEFAULT_PARAMS.copy() # Use a copy

    print("Using fixed parameters for Logistic Regression:") #
    # Print LogisticRegression-specific params
    for key, value in current_params.items(): #
        print(f"- {key}: {value}") #

    # Define the Logistic Regression component directly
    model = LogisticRegression(**current_params) #

    try:
        print("Fitting Logistic Regression model...") #
        model.fit(X_train, y_train) #
        print("Logistic Regression model trained.") #

        # Optionally display coefficients (can be numerous)
        # if hasattr(model, 'coef_'):
        #     print(f"Logistic Regression Coefficients (sample): {model.coef_[0][:5]}...") #

    except Exception as e: #
        print(f"Error training Logistic Regression model: {e}") #
        traceback.print_exc() #
        return None # Return None if training fails

    return model #

print("Logistic Regression training function defined.")
# Out:
# Logistic Regression training function defined.

# %%
# --- Ensemble Helper Functions ---

def optimize_ensemble_weights(models, model_names, X_val, y_val, metric='accuracy'):
    """
    Uses validation set performance to determine ensemble weights based on a chosen metric.
    Returns a dictionary {model_name: weight} and a dict of models that successfully predicted.
    'metric' can be 'accuracy' or 'f1'.
    """
    print(f"\n--- Optimizing Ensemble Weights based on Validation {metric.capitalize()} ---") #

    val_preds_proba = {} # Store predicted probabilities
    val_scores = {} # Store scores for weighting
    valid_models = {} # Store models that successfully predict

    if X_val is None or y_val is None or len(X_val) == 0 or len(y_val) == 0:
         print("Error: Validation data (X_val or y_val) is missing or empty. Cannot optimize weights.")
         return None, None

    for idx, model in enumerate(models): #
        # Handle potential index out of bounds if model_names list is shorter
        if idx >= len(model_names):
             print(f"Warning: More models found than model names provided. Skipping model at index {idx}.")
             continue
        model_name = model_names[idx] #

        if model is None: #
            print(f"Skipping {model_name}: Model object is None.") #
            continue #

        try:
            # Get probability of class 1 (Up)
            if hasattr(model, 'predict_proba'): #
                # Ensure predict_proba returns 2 columns for binary classification
                proba_all_classes = model.predict_proba(X_val) #
                if proba_all_classes.shape[1] == 2:
                     pred_proba = proba_all_classes[:, 1] # Probability of class '1'
                elif proba_all_classes.shape[1] == 1: # Handle case where only one class is predicted
                     print(f"Warning: {model_name} predict_proba returned only one column. Assuming these are probabilities for class 1.")
                     pred_proba = proba_all_classes[:, 0]
                else:
                     print(f"Warning: {model_name} predict_proba returned unexpected shape {proba_all_classes.shape}. Skipping model.")
                     continue

            else: # Handle models that only have .predict() (less ideal for ensembles)
                print(f"Warning: {model_name} does not have predict_proba. Using predict() output.") #
                pred_proba = model.predict(X_val).astype(float) # Convert 0/1 output to float

            val_preds_proba[model_name] = pred_proba # Store probabilities

            # --- Calculate the chosen evaluation metric ---
            pred_labels = (pred_proba >= 0.5).astype(int) # Threshold probabilities to get labels

            score = 0.0 # Default score
            if metric == 'accuracy': #
                score = accuracy_score(y_val, pred_labels) #
            elif metric == 'f1': #
                 # Calculate F1 score (average='binary' assumes positive class is 1)
                 # Use zero_division=0 or 1 to avoid warnings/errors if a class has no predictions
                 report = classification_report(y_val, pred_labels, output_dict=True, zero_division=0) #
                 if '1' in report and isinstance(report['1'], dict): # Check positive class report exists
                      score = report['1'].get('f1-score', 0.0) # Get F1 for class '1'
                 else: # Handle case where class '1' might be missing in report
                      print(f"Warning: F1 score for class '1' not found in report for {model_name}. Using score 0.")
                      score = 0.0
            else: #
                 print(f"Warning: Unknown metric '{metric}'. Defaulting to accuracy.") #
                 score = accuracy_score(y_val, pred_labels) #

            # Store score, ensuring non-negative for weighting (use a small floor)
            val_scores[model_name] = max(1e-6, score) # Use a small floor value > 0
            valid_models[model_name] = model # Keep track of models that worked
            print(f"- {model_name} Validation {metric.capitalize()}: {score:.4f}") #

        except Exception as e: #
            print(f"Warning: Could not get predictions or score from {model_name}: {e}") #
            # traceback.print_exc() # Uncomment for detailed error during debugging

    # --- Calculate weights based on validation scores ---
    if not val_scores: #
        print("Error: No valid model scores obtained. Cannot calculate ensemble weights.") #
        return None, None # Return None for weights and valid models

    total_score = sum(val_scores.values()) #
    if total_score <= 1e-6: # Check if total score is effectively zero
        print("Warning: All model scores are zero or near-zero. Using equal weighting for valid models.") #
        num_valid = len(val_scores) #
        weights = {name: 1.0 / num_valid for name in val_scores.keys()} if num_valid > 0 else {} #
    else: #
        # Normalize scores to get weights
        weights = {name: score / total_score for name, score in val_scores.items()} #

    print("\nOptimized Model weights for ensemble:") #
    if weights: #
        for name, weight in sorted(weights.items(), key=lambda item: item[1], reverse=True): # Print sorted by weight
            print(f"- {name}: {weight:.4f}") #
    else: #
        print("No weights calculated.") #

    return weights, valid_models # Return weights and the dict of models that worked

print("Ensemble weight optimization function defined.")
# Out:
# Ensemble weight optimization function defined.

# %%
def predict_ensemble(models_dict, X, weights):
    """
    Make ensemble predictions using weighted average of probabilities.
    'models_dict' should be the dictionary of valid models from optimize_ensemble_weights.
    'weights' should be the weights dictionary.
    Returns ensemble probabilities and dictionary of individual model probabilities.
    """
    if not models_dict or not weights: #
         print("Error: Models dictionary or weights are empty/None for ensemble prediction.")
         # Return default prediction (e.g., 0.5 for neutral) or raise error
         default_pred = np.full(X.shape[0] if X is not None else 0, 0.5)
         return default_pred, {} # Return neutral prediction and empty dict

    if X is None or X.shape[0] == 0:
        print("Error: Input data X is missing or empty for ensemble prediction.")
        return np.array([]), {} # Return empty results

    ensemble_pred_proba = np.zeros(X.shape[0]) # Initialize array for weighted probabilities
    sum_of_weights_used = 0.0 # Track sum of weights for normalization
    individual_predictions = {} # Store individual model probabilities

    print("\n--- Generating Ensemble Predictions ---") #
    for name, model in models_dict.items(): # Iterate through valid models
        if name not in weights or weights.get(name, 0) <= 1e-6: # Skip if no weight or weight is near-zero
            # print(f"Skipping {name}: No significant weight assigned.") # Optional logging
            continue #

        current_weight = weights[name] #

        try:
            # Get probability for class 1
            if hasattr(model, 'predict_proba'): #
                proba_all_classes = model.predict_proba(X) #
                if proba_all_classes.shape[1] == 2: # Binary case
                     pred = proba_all_classes[:, 1] # Probability of class '1'
                elif proba_all_classes.shape[1] == 1: # Single class prediction case
                     pred = proba_all_classes[:, 0]
                else: # Unexpected shape
                     print(f"Warning: predict_proba for {name} returned shape {proba_all_classes.shape}. Skipping in ensemble.")
                     continue
            else: # Fallback for models without predict_proba
                 pred = model.predict(X).astype(float) # Output will be 0.0 or 1.0
                 print(f"Using predict() output (0/1) for {name} in ensemble.") #

            individual_predictions[name] = pred # Store individual prediction
            ensemble_pred_proba += pred * current_weight # Add weighted prediction
            sum_of_weights_used += current_weight # Accumulate weight used
            # print(f"Included {name} with weight {current_weight:.4f}") # Verbose debugging

        except Exception as e: #
            print(f"Warning: Could not get predictions from {name} during ensemble prediction: {e}") #
            # If a model fails here, its weight is effectively excluded.

    # Normalize the final prediction if the sum of weights used isn't exactly 1
    if sum_of_weights_used > 1e-6 and not np.isclose(sum_of_weights_used, 1.0): # Check if normalization needed
        print(f"Normalizing ensemble predictions (Sum of weights used: {sum_of_weights_used:.4f})") #
        ensemble_pred_proba /= sum_of_weights_used #
    elif sum_of_weights_used <= 1e-6: # Handle case where no models contributed
         print("Error: No models contributed significantly to the ensemble prediction. Returning neutral 0.5.") #
         # Return array of 0.5 (neutral)
         ensemble_pred_proba = np.full(X.shape[0], 0.5) #

    # Ensure final predictions are clipped within [0, 1] bounds
    ensemble_pred_proba = np.clip(ensemble_pred_proba, 0.0, 1.0) #

    print(f"Ensemble prediction generation complete. Shape: {ensemble_pred_proba.shape}") #
    return ensemble_pred_proba, individual_predictions # Return probabilities

print("Ensemble prediction function defined.")
# Out:
# Ensemble prediction function defined.

# %%
# --- Model Evaluation ---

def evaluate_model(y_true, y_pred_proba, model_name="Model", threshold=0.5):
    """Evaluate classification model performance using probabilities and a threshold."""
    print(f"\n--- {model_name} Evaluation (Threshold: {threshold:.2f}) ---") #

    # Input validation
    if y_true is None or y_pred_proba is None:
        print("Error: y_true or y_pred_proba is None.")
        return None
    if len(y_true) == 0 or len(y_pred_proba) == 0:
        print("Error: y_true or y_pred_proba is empty.")
        return None
    if len(y_true) != len(y_pred_proba): #
        print(f"Error: y_true (len {len(y_true)}) and y_pred_proba (len {len(y_pred_proba)}) have different lengths.") #
        return None #

    # Convert probabilities to class labels based on threshold
    y_pred_labels = (y_pred_proba >= threshold).astype(int) #

    # Calculate basic metrics
    accuracy = accuracy_score(y_true, y_pred_labels) #
    print(f"Accuracy: {accuracy:.4f}") #

    # Classification report (handle potential issues with labels)
    report_text = "N/A" # Default
    report_dict = None # Default
    try:
        # Ensure both 0 and 1 classes are present in y_true or y_pred_labels for a full report
        # Use labels=[0, 1] to force report for both classes even if one is missing in preds
        # Use zero_division=0 to handle cases where a class has no predicted samples
        report_text = classification_report(
            y_true,
            y_pred_labels,
            zero_division=0,
            labels=[0, 1], # Specify labels for binary case
            target_names=['Down (0)', 'Up (1)'] # Optional: Names for classes
        ) #
        print("\nClassification Report:") #
        print(report_text) #

        # Get report as dictionary for easier access to specific scores
        report_dict = classification_report(
            y_true, y_pred_labels, zero_division=0, labels=[0, 1], output_dict=True
        ) #

    except Exception as e: #
        print(f"Could not generate full classification report: {e}") #
        # Provide basic counts if report fails
        print("\nBasic Counts:") #
        print(f"True Distribution:\n{pd.Series(y_true).value_counts(normalize=True)}") #
        print(f"Predicted Distribution (Threshold {threshold:.2f}):\n{pd.Series(y_pred_labels).value_counts(normalize=True)}") #

    # Return metrics dictionary
    metrics = { #
        'model_name': model_name, #
        'threshold': threshold, #
        'accuracy': accuracy, #
        'classification_report_text': report_text, #
        'classification_report_dict': report_dict # Useful for extracting specific scores (e.g., F1)
    } #

    return metrics #

print("Model evaluation function defined.")
# Out:
# Model evaluation function defined.

# %%
# --- Feature Importance Plotting ---

def plot_feature_importance(model, feature_names, model_name="Model", top_n=20):
    """Plot feature importance from tree-based models or coefficients from linear models."""
    print(f"\n--- Plotting Feature Importance for {model_name} ---") #

    importances = None # Initialize
    importance_type = "Importance" # Default y-axis label

    # --- Extract Importances/Coefficients ---
    # Direct attribute access (RF, XGBoost)
    if hasattr(model, 'feature_importances_'):
        importances = model.feature_importances_ #
    # Check inside pipeline (common pattern)
    elif hasattr(model, 'named_steps'):
        # Look for common model step names
        pipeline_model_step = None
        for step_name in ['model', 'clf', 'classifier', 'xgb', 'rf', 'logreg', 'logisticregression', 'xgbclassifier', 'randomforestclassifier']:
             if step_name in model.named_steps:
                  pipeline_model_step = model.named_steps[step_name]
                  break

        if pipeline_model_step is not None:
             if hasattr(pipeline_model_step, 'feature_importances_'):
                 importances = pipeline_model_step.feature_importances_ #
                 print(f"Found importances in pipeline step: '{step_name}'") #
             elif hasattr(pipeline_model_step, 'coef_'):
                 # Use absolute value of coefficients for linear models
                 # Assuming binary classification, coef_ might be shape (1, n_features)
                 if pipeline_model_step.coef_.shape[0] == 1:
                      importances = np.abs(pipeline_model_step.coef_[0]) #
                      importance_type = "Absolute Coefficient" # Change label
                      print(f"Using absolute coefficients from pipeline step: '{step_name}' as importance.") #
                 else: # Handle multi-class coefficients if necessary (e.g., average abs coef)
                      print(f"Warning: Coefficient shape {pipeline_model_step.coef_.shape} not typical for binary classification. Using mean absolute coefficient.")
                      importances = np.mean(np.abs(pipeline_model_step.coef_), axis=0)
                      importance_type = "Mean Absolute Coefficient"
    # Direct access for Logistic Regression coefficients (if not in pipeline)
    elif hasattr(model, 'coef_'):
         if model.coef_.shape[0] == 1:
              importances = np.abs(model.coef_[0]) #
              importance_type = "Absolute Coefficient" #
         else:
              importances = np.mean(np.abs(model.coef_), axis=0)
              importance_type = "Mean Absolute Coefficient"


    # --- Validate and Plot ---
    if importances is None: #
        print(f"Could not extract feature importances/coefficients for {model_name}. Model type might not be supported or structure unrecognized.") #
        return None #

    if feature_names is None:
        print("Error: Feature names list is None. Cannot plot importance.")
        return None

    # Ensure feature_names aligns with importances array length
    num_features = len(feature_names) #
    num_importances = len(importances) #
    if num_features != num_importances: #
        print(f"Warning: Mismatch between feature names ({num_features}) and importances ({num_importances}). Truncating to minimum length ({min(num_features, num_importances)}).") #
        min_len = min(num_features, num_importances) #
        # Ensure feature_names_aligned is a list for consistent indexing
        feature_names_aligned = list(feature_names[:min_len]) #
        importances_aligned = importances[:min_len] #
    else: #
        feature_names_aligned = list(feature_names) # Ensure list type
        importances_aligned = importances #

    # Create a DataFrame for plotting
    importance_df = pd.DataFrame({ #
        'Feature': feature_names_aligned, #
        'Importance': importances_aligned #
    }).sort_values('Importance', ascending=False).reset_index(drop=True) #

    # Plot top N features
    top_features = importance_df.head(top_n) #

    if top_features.empty: #
        print("No feature importances found to plot.") #
        return None #

    # --- Create Plot ---
    plt.style.use('seaborn-v0_8-darkgrid') # Set style
    plt.figure(figsize=(12, max(6, top_n // 2.5))) # Adjust height based on N
    sns.barplot(x='Importance', y='Feature', data=top_features, palette='viridis', orient='h') # Horizontal bar plot
    plt.title(f'Top {min(top_n, len(top_features))} Features - {model_name}', fontsize=14) #
    plt.xlabel(importance_type, fontsize=12) # Use dynamic label
    plt.ylabel('Feature Name', fontsize=12) #
    plt.yticks(fontsize=10) # Adjust y-tick label size if needed
    plt.xticks(fontsize=10) #
    plt.grid(axis='x', linestyle='--', alpha=0.6) # Grid lines on x-axis
    plt.tight_layout() # Adjust layout

    # --- Save Plot ---
    # Ensure output directory exists
    os.makedirs(os.path.dirname(MODEL_OUTPUT_DIR) or '.', exist_ok=True) # Use '.' if path is just a directory name
    # Sanitize model name for filename (replace non-alphanumeric with underscore)
    safe_model_name = "".join([c if c.isalnum() else "_" for c in model_name]).strip('_') #
    img_path = os.path.join(MODEL_OUTPUT_DIR, f'feature_importance_{safe_model_name}.png') #
    try:
        plt.savefig(img_path) #
        print(f"Feature importance plot saved to {img_path}") #
    except Exception as e_save: #
        print(f"Error saving feature importance plot: {e_save}") #
    plt.show() # Display the plot

    return top_features # Return the DataFrame of top features

print("Feature importance plotting function defined.")
# Out:
# Feature importance plotting function defined.

# %%
def run_regime_analysis(df, returns_col='returns', price_col='close', n_regimes=6):
    """
    Run regime analysis on price/return data.
    
    Parameters:
    -----------
    df : pandas.DataFrame
        DataFrame containing price/return data
    returns_col : str
        Column name with returns data. If not present, will be calculated from price_col
    price_col : str
        Column name with price data (used to calculate returns if returns_col missing)
    n_regimes : int
        Number of regimes to identify
        
    Returns:
    --------
    RegimeAnalysis
        Populated RegimeAnalysis object
    """
    print("\n--- Starting Market Regime Analysis ---")
    
    # Check if returns column exists, if not calculate from price
    if returns_col not in df.columns and price_col in df.columns:
        print(f"Calculating returns from {price_col} column")
        df[returns_col] = df[price_col].pct_change().fillna(0)
    
    elif returns_col not in df.columns:
        print(f"Error: Neither {returns_col} nor {price_col} found in DataFrame")
        return None
    
    # Check if the regime column exists
    if 'current_regime' in df.columns:
        print(f"Found existing regime data in column 'current_regime'")
        df_with_regimes = df.copy()
        df_with_regimes['regime'] = df['current_regime']
    else:
        # Calculate volatility
        df_temp = df.copy()
        df_temp['volatility'] = df_temp[returns_col].rolling(window=21).std().fillna(method='bfill')
        
        # Prepare features for clustering
        features = np.column_stack([
            df_temp[returns_col].values,
            df_temp['volatility'].values
        ])
        
        # Ensure no NaN or inf values
        features = np.nan_to_num(features)
        
        # Standardize features
        from sklearn.preprocessing import StandardScaler
        scaler = StandardScaler()
        features_scaled = scaler.fit_transform(features)
        
        # Cluster using K-means
        from sklearn.cluster import KMeans
        kmeans = KMeans(n_clusters=n_regimes, random_state=42, n_init=10)
        regimes = kmeans.fit_predict(features_scaled)
        
        # Create DataFrame with regimes
        df_with_regimes = df_temp.copy()
        df_with_regimes['regime'] = regimes
    
    # Add regime shift column
    df_with_regimes['regime_shift'] = df_with_regimes['regime'].shift(1)
    
    # Create a RegimeAnalysis object with the pre-calculated regimes
    regime_analysis = RegimeAnalysis(
        df_with_regimes[returns_col], 
        n_regimes=n_regimes,
        existing_regimes=df_with_regimes['regime']
    )
    
    # Now run the analysis (with pre-set regimes - no HMM fitting)
    regime_analysis.fit_hmm_model()  # This will just process the existing regimes
    regime_analysis.analyze_regimes()
    regime_analysis.calculate_transition_probabilities()
    regime_analysis.cluster_regimes(n_clusters=3)
    
    # Plot regime distribution
    try:
        regime_analysis.plot_regime_distribution()
        regime_analysis.plot_volatility_return_by_regime()
    except Exception as e:
        print(f"Error generating regime plots: {e}")
    
    # Get current market state
    market_state = regime_analysis.get_market_state()
    if market_state:
        print("\n--- Current Market State ---")
        print(f"Latest Regime: {market_state['latest_regime']} - {market_state['description']}")
        print(f"Average Return: {market_state['avg_return']:.6f}")
        print(f"Volatility: {market_state['volatility']:.6f}")
        print(f"Sharpe Ratio: {market_state['sharpe']:.4f}")
        
        if 'most_likely_next' in market_state:
            next_info = market_state['most_likely_next']
            print(f"\nMost Likely Next Regime: {next_info['regime']} - {next_info['description']}")
            print(f"Transition Probability: {next_info['probability']:.4f}")
    
    print("Market regime analysis complete.")
    return regime_analysis

# %%
# --- Placeholder for Removed Utility Functions ---

# Functions 'generate_regime_based_signal' and 'scale_position' from the
# original jaybee2.txt file were removed during simplification as they
# were not fully integrated into the core backtesting logic and the user
# requested removal of tuning/adaptive features.

# If needed, these functions could be reintroduced and integrated into the
# OnChainBitcoinStrategy class.

print("Placeholder cell for removed utility functions.")
# Out:
# Placeholder cell for removed utility functions.

# %%
# ==============================================================================
# --- Main Execution Block ---
# ==============================================================================

# Record start time
start_time = datetime.now() #
print(f"Starting On-Chain Bitcoin Trading System: {start_time.strftime('%Y-%m-%d %H:%M:%S')}") # Format time
print("=" * 80) #
print("Configuration:") #
print(f"- Data file: {FILE_PATH}") #
print(f"- Output directory: {MODEL_OUTPUT_DIR}") #
print(f"- Target Type: {TARGET_TYPE}") #
print(f"- Target Column: {TARGET_COLUMN}") #
print(f"- Price Column: {PRICE_COLUMN}") #
print(f"- Periods Ahead: {PERIODS_AHEAD}") #
print("=" * 80) #

# Initialize variables to store results through the pipeline
raw_df = None
df_featured = None
df_cleaned = None
df_ready = None
X_train, X_val, X_test, y_train, y_val, y_test = None, None, None, None, None, None
aux_targets_data = {}
feature_cols = []
preprocessor = None
transformed_feature_names = []
X_train_proc, X_val_proc, X_test_proc = None, None, None
models = {} # Dictionary to store trained models
model_names = ['XGBoost', 'Random Forest', 'MLP', 'Logistic'] # Define model names
model_list = [] # List to store model objects in order
ensemble_weights = None
valid_ensemble_models = {}
val_ensemble_pred, val_individual_preds = None, {}
test_ensemble_pred, test_individual_preds = None, {}
all_metrics = {}
backtest = None
backtest_results_df = None
# Out:
# Starting On-Chain Bitcoin Trading System: 2025-04-19 22:35:15
# ================================================================================
# Configuration:
# - Data file: C:\Users\User\Downloads\final_merged_data_2.csv
# - Output directory: bitcoin_onchain_models/
# - Target Type: Direction
# - Target Column: target_direction
# - Price Column: close
# - Periods Ahead: 1
# ================================================================================

# %%
# --- Step 1: Loading and Preparing Data ---
print("\n--- Step 1: Loading and Preparing Data ---") #
try:
    # Load data using the utility function
    raw_df = load_and_prepare_data(FILE_PATH) #

    if raw_df is None or raw_df.empty: #
        raise ValueError("Data loading resulted in an empty or None DataFrame.") #

    print(f"Data loaded successfully. Shape: {raw_df.shape}") #
    print("Sample of loaded data (first 5 rows):") #
    print(raw_df.head()) #
    # print("\nData Info:") # Optional: Display detailed info
    # raw_df.info() #

except FileNotFoundError: #
    print(f"FATAL ERROR: Data file not found at {FILE_PATH}. Please check the path and filename.") #
    # Stop execution here in a real notebook scenario by raising the error
    raise #
except ValueError as ve: #
     print(f"FATAL ERROR during data loading/preparation: {ve}") #
     raise #
except Exception as e: #
    print(f"An unexpected FATAL error occurred during data loading: {e}") #
    traceback.print_exc() #
    raise # Stop execution
# Out:
# --- Step 1: Loading and Preparing Data ---
# Successfully loaded data from: C:\Users\User\Downloads\final_merged_data_2.csv
# Initial shape: (43225, 23)
# Standardized columns: ['datetime', 'transactions_count_flow_1', 'current_regime', 'predicted_next_regime', 'next_regime_probability', 'start_time', 'inflow_mean', 'inflow_mean_ma7', 'inflow_top10', 'inflow_total', 'outflow_mean', 'outflow_mean_ma7', 'outflow_top10', 'outflow_total', 'netflow_total', 'transactions_count_flow_2', 'open', 'high', 'low', 'close', 'volume', 'flow_mean', 'flow_total']
# Attempting to parse 'datetime' as datetime...
# Successfully parsed 'datetime' (or most of it).
# 'datetime' column set as index.
# Data loaded and basic preparation complete. Shape: (43225, 22)
# Data loaded successfully. Shape: (43225, 22)
# Sample of loaded data (first 5 rows):
#                      transactions_count_flow_1  current_regime  \
# datetime
# 2020-04-09 00:00:00                        401               5
# 2020-04-09 01:00:00                        558               5
# 2020-04-09 02:00:00                        633               5
# 2020-04-09 03:00:00                        488               5
# 2020-04-09 04:00:00                        709               5
#
#                      predicted_next_regime  next_regime_probability  \
# datetime
# 2020-04-09 00:00:00                      5                  0.46246
# 2020-04-09 01:00:00                      5                  0.46246
# 2020-04-09 02:00:00                      5                  0.46246
# 2020-04-09 03:00:00                      5                  0.46246
# 2020-04-09 04:00:00                      5                  0.46246
#
#                         start_time  inflow_mean  inflow_mean_ma7  \
# datetime
# 2020-04-09 00:00:00  1586390400000     0.800575         1.037722
# 2020-04-09 01:00:00  1586394000000     0.532598         0.985374
# 2020-04-09 02:00:00  1586397600000     0.531611         0.963363
# 2020-04-09 03:00:00  1586401200000     0.688415         0.986846
# 2020-04-09 04:00:00  1586404800000     1.294126         0.749810
#
#                      inflow_top10  inflow_total  outflow_mean  ...  \
# datetime                                                       ...
# 2020-04-09 00:00:00   1201.414725   1361.777521      2.077536  ...
# 2020-04-09 01:00:00    903.526470   1100.346962      1.772029  ...
# 2020-04-09 02:00:00   1232.476684   1521.470517      1.932810  ...
# 2020-04-09 03:00:00    970.117498   1120.050585      1.866773  ...
# 2020-04-09 04:00:00   2604.244845   2826.370613      3.503254  ...
#
#                      outflow_total  netflow_total  transactions_count_flow_2  \
# datetime
# 2020-04-09 00:00:00     895.418032     466.359489                        401
# 2020-04-09 01:00:00    1061.445288      38.901673                        558
# 2020-04-09 02:00:00    1294.982377     226.488140                        633
# 2020-04-09 03:00:00     955.787655     164.262931                        488
# 2020-04-09 04:00:00    2602.917771     223.452842                        709
#
#                         open     high      low    close      volume  \
# datetime
# 2020-04-09 00:00:00  7311.27  7373.03  7311.27  7325.30  235.856119
# 2020-04-09 01:00:00  7316.73  7372.00  7306.15  7327.71  141.574761
# 2020-04-09 02:00:00  7319.98  7385.44  7319.44  7368.71  161.761294
# 2020-04-09 03:00:00  7358.02  7400.00  7341.38  7367.36  116.642642
# 2020-04-09 04:00:00  7370.85  7376.59  7330.06  7356.98  112.308853
#
#                      flow_mean   flow_total
# datetime
# 2020-04-09 00:00:00  11.683679  4685.155179
# 2020-04-09 01:00:00   7.552804  4214.464499
# 2020-04-09 02:00:00   8.277723  5239.798655
# 2020-04-09 03:00:00   8.438286  4117.883564
# 2020-04-09 04:00:00   9.533256  6759.078698
#
# [5 rows x 22 columns]

# %%
# --- Step 2: Feature Engineering and Cleaning ---
print("\n--- Step 2: Feature Engineering and Cleaning ---") #
if raw_df is not None and not raw_df.empty: # Check if raw_df exists and is not empty
    try:
        # Add on-chain features using the utility function
        df_featured = add_onchain_features(raw_df) #

        if df_featured is None or df_featured.empty: #
            raise ValueError("Feature engineering resulted in an empty or None DataFrame.") #

        print(f"Feature engineering complete. Shape after adding features: {df_featured.shape}") #

        # REMOVED call to handle_outliers_and_missing_values as it's not defined
        # The 'add_onchain_features' function already handles NaNs/Infs created.
        # Assign df_featured directly to df_cleaned (or rename df_featured to df_cleaned)
        df_cleaned = df_featured # Use the output from feature engineering

        print(f"Final shape before target creation: {df_cleaned.shape}") #
        print("Sample of cleaned data with features (first 5 rows):") #
        print(df_cleaned.head()) #

    except Exception as e: #
        print(f"FATAL ERROR occurred during feature engineering or cleaning: {e}") #
        traceback.print_exc() #
        # Stop execution or handle error appropriately
        raise # Stop execution
else: #
    print("Skipping Step 2 because raw_df was not loaded successfully.") #
    # Optionally raise an error here if proceeding without data is impossible
    raise RuntimeError("Cannot proceed without successfully loaded data (raw_df is None or empty).")
# Out:
# --- Step 2: Feature Engineering and Cleaning ---
# Adding on-chain features...
# Added 41 new features.
# On-chain feature engineering complete.
# Feature engineering complete. Shape after adding features: (43225, 63)
# Final shape before target creation: (43225, 63)
# Sample of cleaned data with features (first 5 rows):
#                      transactions_count_flow_1  current_regime  \
# datetime
# 2020-04-09 00:00:00                        401               5
# 2020-04-09 01:00:00                        558               5
# 2020-04-09 02:00:00                        633               5
# 2020-04-09 03:00:00                        488               5
# 2020-04-09 04:00:00                        709               5
#
#                      predicted_next_regime  next_regime_probability  \
# datetime
# 2020-04-09 00:00:00                      5                  0.46246
# 2020-04-09 01:00:00                      5                  0.46246
# 2020-04-09 02:00:00                      5                  0.46246
# 2020-04-09 03:00:00                      5                  0.46246
# 2020-04-09 04:00:00                      5                  0.46246
#
#                         start_time  inflow_mean  inflow_mean_ma7  \
# datetime
# 2020-04-09 00:00:00  1586390400000     0.800575         1.037722
# 2020-04-09 01:00:00  1586394000000     0.532598         0.985374
# 2020-04-09 02:00:00  1586397600000     0.531611         0.963363
# 2020-04-09 03:00:00  1586401200000     0.688415         0.986846
# 2020-04-09 04:00:00  1586404800000     1.294126         0.749810
#
#                      inflow_top10  inflow_total  outflow_mean  ...  \
# datetime                                                       ...
# 2020-04-09 00:00:00   1201.414725   1361.777521      2.077536  ...
# 2020-04-09 01:00:00    903.526470   1100.346962      1.772029  ...
# 2020-04-09 02:00:00   1232.476684   1521.470517      1.932810  ...
# 2020-04-09 03:00:00    970.117498   1120.050585      1.866773  ...
# 2020-04-09 04:00:00   2604.244845   2826.370613      3.503254  ...
#
#                      inflow_total_momentum  outflow_total_momentum  \
# datetime
# 2020-04-09 00:00:00                    0.0                     0.0
# 2020-04-09 01:00:00                    0.0                     0.0
# 2020-04-09 02:00:00                    0.0                     0.0
# 2020-04-09 03:00:00                    0.0                     0.0
# 2020-04-09 04:00:00                    0.0                     0.0
#
#                      cumulative_netflow  reserve_change_rate  whale_netflow  \
# datetime
# 2020-04-09 00:00:00          466.359489           -17.714613     325.138119
# 2020-04-09 01:00:00          505.261162           -17.714613    -110.969132
# 2020-04-09 02:00:00          731.749302           -17.714613     -18.915737
# 2020-04-09 03:00:00          896.012232           -17.714613      32.064736
# 2020-04-09 04:00:00         1119.465074           -17.714613      44.757671
#
#                      whale_activity  whale_dominance_trend  \
# datetime
# 2020-04-09 00:00:00     1038.845666               0.930432
# 2020-04-09 01:00:00      959.011037               0.888448
# 2020-04-09 02:00:00     1241.934553               0.888198
# 2020-04-09 03:00:00      954.085130               0.923791
# 2020-04-09 04:00:00     2581.866010               0.952362
#
#                      whale_dominance_change  accumulation_phase  \
# datetime
# 2020-04-09 00:00:00               -0.007137                   0
# 2020-04-09 01:00:00               -0.007137                   0
# 2020-04-09 02:00:00               -0.007137                   0
# 2020-04-09 03:00:00               -0.007137                   0
# 2020-04-09 04:00:00                0.071939                   0
#
#                      distribution_phase
# datetime
# 2020-04-09 00:00:00                   0
# 2020-04-09 01:00:00                   0
# 2020-04-09 02:00:00                   0
# 2020-04-09 03:00:00                   0
# 2020-04-09 04:00:00                   0
#
# [5 rows x 63 columns]

# %%
# --- Step 3: Target Variable Creation and Data Splitting ---
print("\n--- Step 3: Target Variable Creation and Data Splitting ---") #
if df_cleaned is not None and not df_cleaned.empty: # Check if df_cleaned exists
    try:
        # Create the target variable
        df_ready = create_target_variable(df_cleaned, PRICE_COLUMN, PERIODS_AHEAD) #

        if df_ready is None or df_ready.empty: #
            raise ValueError("Target variable creation resulted in an empty DataFrame (maybe periods_ahead is too large or price column issue?).") #

        # Split data chronologically into train, validation, and test sets
        X_train, X_val, X_test, y_train, y_val, y_test, aux_targets_data, feature_cols = split_data_chronological(
            df_ready, TARGET_COLUMN, TEST_SIZE, VALIDATION_SIZE #
        ) #

        print("\nData splitting successful.") #
        print(f"Number of features used for training: {len(feature_cols)}") #
        # print(f"Features used: {feature_cols}") # Uncomment to see the list of features

    except Exception as e: #
        print(f"FATAL ERROR occurred during target creation or data splitting: {e}") #
        traceback.print_exc() #
        # Stop execution or handle error appropriately
        raise # Stop execution
else: #
     print("Skipping Step 3 because df_cleaned was not created successfully.") #
     raise RuntimeError("Cannot proceed without cleaned data (df_cleaned is None or empty).") # Stop if cleaned data isn't available
# Out:
# --- Step 3: Target Variable Creation and Data Splitting ---
# Creating target variables...
# Dropped 1 rows due to missing target values (typically at the end).
# Created target variables using 'close', looking 1 period(s) ahead.
# Target Direction ('target_direction') distribution:
# target_direction
# 0    0.52147
# 1    0.47853
# Name: proportion, dtype: float64
#
# Splitting data chronologically...
# Using 62 final numeric feature columns for splitting.
#
# --- Data Split Summary ---
# Total samples: 43224
# Training set:   28095 samples (Index 2020-04-09 00:00:00 to 2023-06-23 14:00:00) - Target mean: 0.507
# Validation set: 6484 samples (Index 2023-06-23 15:00:00 to 2024-03-19 18:00:00) - Target mean: 0.514
# Test set:       8645 samples (Index 2024-03-19 19:00:00 to 2025-03-14 23:00:00) - Target mean: 0.361
#
# Data splitting successful.
# Number of features used for training: 62

# %%
# --- Step 4: Preprocessing Features ---
print("\n--- Step 4: Preprocessing Features ---") #
# Check if split data exists before proceeding
if X_train is not None and X_val is not None and X_test is not None: #
    try:
        # Setup and fit the preprocessor on the training data
        preprocessor, transformed_feature_names = setup_preprocessor(X_train) #

        if preprocessor is None: #
             # Handle case where no numerical features were found
             print("Warning: Preprocessor setup returned None. Using original data for models.")
             # Assign original data to processed variables if no preprocessor used
             X_train_proc, X_val_proc, X_test_proc = X_train, X_val, X_test
             processed_feature_names = feature_cols # Use original feature names
        else:
            # Apply the fitted preprocessor to train, validation, and test sets
            X_train_proc, X_val_proc, X_test_proc = preprocess_features(
                preprocessor, X_train, X_val, X_test #
            ) #
            processed_feature_names = transformed_feature_names # Use names from preprocessor

            print("Preprocessing applied successfully.") #
            # Verify shapes
            print(f"X_train_proc shape: {X_train_proc.shape}, y_train shape: {y_train.shape}") #
            print(f"X_val_proc shape: {X_val_proc.shape}, y_val shape: {y_val.shape}") #
            print(f"X_test_proc shape: {X_test_proc.shape}, y_test shape: {y_test.shape}") #

    except Exception as e: #
        print(f"FATAL ERROR occurred during preprocessing: {e}") #
        traceback.print_exc() #
        # Stop execution or handle error appropriately
        raise # Stop execution
else: #
    print("Skipping Step 4 because data splitting did not complete successfully.") #
    raise RuntimeError("Cannot proceed without successfully split data.") # Stop if split data isn't available
# Out:
# --- Step 4: Preprocessing Features ---
# Setting up preprocessor for 62 numerical features.
# Fitting preprocessor on training data...
# Preprocessor fitted successfully.
# Preprocessor produces 62 features.
# Applying preprocessing transformations (train, val, test)...
# Processed feature shapes: Train (28095, 62), Val (6484, 62), Test (8645, 62)
# Preprocessing applied successfully.
# X_train_proc shape: (28095, 62), y_train shape: (28095,)
# X_val_proc shape: (6484, 62), y_val shape: (6484,)
# X_test_proc shape: (8645, 62), y_test shape: (8645,)

# %%
# --- Step 5: Training Models (Using Fixed Defaults) ---
print("\n--- Step 5: Training Models ---") #

# Ensure processed data is available
if X_train_proc is not None and y_train is not None and X_val_proc is not None and y_val is not None:
    # --- Train XGBoost ---
    try:
        xgb_model = train_xgboost_model(
            X_train_proc, y_train,
            X_val_proc, y_val,
            params=XGB_CLS_DEFAULT_PARAMS # Pass fixed defaults
        ) #
        if xgb_model is not None:
            models['XGBoost'] = xgb_model # Store the trained model
            print("XGBoost model trained successfully.")
        else:
            print("XGBoost model training failed.")
            models['XGBoost'] = None # Store None if failed
    except Exception as e:
        print(f"Error during XGBoost training: {e}")
        traceback.print_exc()
        models['XGBoost'] = None

else:
    print("Skipping Model Training because preprocessed data is not available.")
    # Set all models to None if training is skipped
    for name in model_names:
         models[name] = None
# Out:
# --- Step 5: Training Models ---
#
# --- Training XGBoost Model ---
# Using fixed parameters for XGBoost Classifier:
# - objective: binary:logistic
# - eval_metric: logloss
# - use_label_encoder: False
# - n_estimators: 326
# - learning_rate: 0.15592123566761282
# - max_depth: 5
# - subsample: 0.6478376983753207
# - colsample_bytree: 0.7243929286862649
# - gamma: 0.16259166101337352
# - min_child_weight: 3
# - random_state: 42
# - n_jobs: -1
# - early_stopping_rounds: 10
# Fitting XGBoost model...
# XGBoost training complete. Best iteration: 0, Best Score (eval_metric): 0.6929358193107331
# XGBoost model trained successfully.

# %%
# --- Step 5: Training Models (Continued - Random Forest) ---
if X_train_proc is not None and y_train is not None: # Check required data
    # --- Train Random Forest ---
    try:
        rf_model = train_random_forest_model(
            X_train_proc, y_train,
            feature_names=processed_feature_names, # Pass feature names for importance plot
            params=RF_CLS_DEFAULT_PARAMS # Pass fixed defaults
        ) #
        if rf_model is not None:
            models['Random Forest'] = rf_model # Store the trained model
            print("Random Forest model trained successfully.")
        else:
            print("Random Forest model training failed.")
            models['Random Forest'] = None # Store None if failed
    except Exception as e:
        print(f"Error during Random Forest training: {e}")
        traceback.print_exc()
        models['Random Forest'] = None
else:
     if 'Random Forest' not in models: # Avoid overwriting if already set to None
        print("Skipping Random Forest Training: preprocessed data missing.")
        models['Random Forest'] = None
# Out:
# --- Training Random Forest Model ---
# Using fixed parameters for Random Forest Classifier:
# - n_estimators: 234
# - max_depth: 12
# - min_samples_split: 9
# - min_samples_leaf: 5
# - max_features: sqrt
# - class_weight: balanced
# - random_state: 42
# - n_jobs: -1
# Fitting Random Forest model...
# Random Forest model trained.
#
# Top 15 features by importance (Random Forest):
#                              feature  importance
# 0   num__top10_dominance_inflow_lag7    0.022187
# 1                        num__volume    0.021754
# 2   num__top10_dominance_inflow_lag3    0.021580
# 3     num__inflow_outflow_ratio_lag1    0.020983
# 4       num__top10_dominance_outflow    0.020927
# 5     num__inflow_outflow_ratio_lag3    0.020722
# 6                     num__flow_mean    0.020503
# 7            num__cumulative_netflow    0.020472
# 8           num__inflow_acceleration    0.020262
# 9   num__top10_dominance_inflow_lag1    0.019926
# 10             num__flow_mean_change    0.019892
# 11       num__top10_dominance_inflow    0.019819
# 12           num__netflow_total_lag3    0.019760
# 13           num__netflow_total_lag7    0.019695
# 14            num__netflow_to_volume    0.019658
# Random Forest model trained successfully.

# %%
# --- Step 5: Training Models (Continued - MLP) ---
if X_train_proc is not None and y_train is not None and X_val_proc is not None and y_val is not None: # Check required data
    # --- Train MLP ---
    try:
        mlp_model = train_mlp_model(
            X_train_proc, y_train,
            X_val_proc, y_val, # Pass val data (used internally by MLP for early stopping check)
            params=MLP_CLS_DEFAULT_PARAMS # Pass fixed defaults
        ) #
        if mlp_model is not None:
            models['MLP'] = mlp_model # Store the trained model
            print("MLP model trained successfully.")
        else:
            print("MLP model training failed.")
            models['MLP'] = None # Store None if failed
    except Exception as e:
        print(f"Error during MLP training: {e}")
        traceback.print_exc()
        models['MLP'] = None
else:
     if 'MLP' not in models: # Avoid overwriting if already set to None
        print("Skipping MLP Training: preprocessed data missing.")
        models['MLP'] = None
# Out:
# --- Training MLP Model ---
# Using fixed parameters for MLP Classifier:
# - hidden_layer_sizes: (32,)
# - activation: relu
# - solver: adam
# - alpha: 0.0003058449429580245
# - batch_size: auto
# - learning_rate: adaptive
# - learning_rate_init: 0.004109993861334124
# - max_iter: 300
# - shuffle: True
# - random_state: 42
# - early_stopping: True
# - n_iter_no_change: 10
# - validation_fraction: 0.1
# Fitting MLP model (using internal validation split for early stopping)...
# MLP model trained.
# MLP final loss: 0.710819
# MLP iterations: 22
# MLP best validation score (internal split): 0.516726
# MLP model trained successfully.

# %%
# --- Step 5: Training Models (Continued - Logistic Regression) ---
if X_train_proc is not None and y_train is not None: # Check required data
    # --- Train Logistic Regression ---
    try:
        logreg_model = train_logistic_model(
            X_train_proc, y_train,
            params=LOGISTIC_DEFAULT_PARAMS # Pass fixed defaults
        ) #
        if logreg_model is not None:
            models['Logistic'] = logreg_model # Store the trained model
            print("Logistic Regression model trained successfully.")
        else:
            print("Logistic Regression model training failed.")
            models['Logistic'] = None # Store None if failed
    except Exception as e:
        print(f"Error during Logistic Regression training: {e}")
        traceback.print_exc()
        models['Logistic'] = None
else:
     if 'Logistic' not in models: # Avoid overwriting if already set to None
        print("Skipping Logistic Regression Training: preprocessed data missing.")
        models['Logistic'] = None

# Create the list of model objects in the defined order
# Ensure models that failed training are represented by None in the list
model_list = [models.get(name) for name in model_names] #

# Verify stored models
print("\n--- Trained Models Summary ---")
for name, model in models.items():
    status = "Trained" if model is not None else "Failed/Skipped"
    print(f"- {name}: {status}")

# Check if any models were successfully trained
if not any(model is not None for model in models.values()):
     print("\nWarning: No models were trained successfully. Ensemble and backtesting steps will be skipped.")
     # Optionally raise an error if at least one model is required to proceed
     # raise RuntimeError("Model training failed for all specified models.")
# Out:
# --- Training Logistic Regression Model ---
# Using fixed parameters for Logistic Regression:
# - C: 0.5908361216819946
# - penalty: l2
# - solver: liblinear
# - random_state: 42
# - max_iter: 1000
# - class_weight: balanced
# Fitting Logistic Regression model...
# Logistic Regression model trained.
# Logistic Regression model trained successfully.
#
# --- Trained Models Summary ---
# - XGBoost: Trained
# - Random Forest: Trained
# - MLP: Trained
# - Logistic: Trained

# %%
# --- Step 6: Optimizing Ensemble Weights ---
print("\n--- Step 6: Optimizing Ensemble Weights ---") #

ensemble_weights = None # Initialize
valid_ensemble_models = {} # Store models that were successfully used for weighting

# Proceed only if at least one model was trained and validation data exists
if any(model is not None for model in model_list) and X_val_proc is not None and y_val is not None: #
    try:
        # Optimize weights based on validation set performance
        # Using 'accuracy' here, but could use SCORING_METRIC ('f1') if preferred and calculated correctly in optimize_ensemble_weights
        ensemble_weights, valid_ensemble_models = optimize_ensemble_weights(
            model_list, model_names, X_val_proc, y_val, metric='accuracy'
        ) #

        if ensemble_weights: # Check if weights were determined
            print("Ensemble weights determined successfully based on validation performance.") #
        else: # Handle case where weighting failed (e.g., all models had score 0)
            print("Warning: Could not determine optimal ensemble weights (e.g., all validation scores were zero).") #
            # Fallback: Equal weights for models that provided valid predictions (in valid_ensemble_models)
            num_valid = len(valid_ensemble_models) #
            if num_valid > 0: #
                print(f"Falling back to equal weights for {num_valid} valid models.") #
                ensemble_weights = {name: 1.0 / num_valid for name in valid_ensemble_models.keys()} #
            else:
                 print("Error: No models provided valid predictions on the validation set. Cannot create ensemble.")
                 ensemble_weights = None # Ensure it remains None


    except Exception as e: #
        print(f"An error occurred during ensemble weight optimization: {e}") #
        traceback.print_exc() #
        ensemble_weights = None # Ensure weights are None if optimization fails
else: #
     print("Skipping ensemble weight optimization: No valid models trained or validation data missing.") #
     ensemble_weights = None # Ensure weights are None
     valid_ensemble_models = {} # Ensure valid models dict is empty
# Out:
# --- Step 6: Optimizing Ensemble Weights ---
#
# --- Optimizing Ensemble Weights based on Validation Accuracy ---
# - XGBoost Validation Accuracy: 0.5102
# - Random Forest Validation Accuracy: 0.5185
# - MLP Validation Accuracy: 0.5062
# - Logistic Validation Accuracy: 0.5022
#
# Optimized Model weights for ensemble:
# - Random Forest: 0.2545
# - XGBoost: 0.2505
# - MLP: 0.2485
# - Logistic: 0.2465
# Ensemble weights determined successfully based on validation performance.

# %%
# --- Step 7: Making Predictions ---
print("\n--- Step 7: Making Predictions ---") #

val_ensemble_pred = None # Initialize
val_individual_preds = {} # Initialize
test_ensemble_pred = None # Initialize
test_individual_preds = {} # Initialize

# Predict only if we have valid models, weights, and processed data
if ensemble_weights and valid_ensemble_models and X_val_proc is not None and X_test_proc is not None: #
    try:
        # --- Predictions on Validation Set ---
        print("Generating predictions on Validation Set...") #
        # Use only models that contributed to weights and have valid objects
        val_ensemble_pred, val_individual_preds = predict_ensemble(
            valid_ensemble_models, # Use only models that worked in weight optimization
            X_val_proc, #
            weights=ensemble_weights #
        ) #
        if val_ensemble_pred is not None:
             print(f"Generated validation predictions. Ensemble shape: {val_ensemble_pred.shape}") #
        else:
             print("Validation ensemble prediction failed.")

        # --- Predictions on Test Set ---
        print("\nGenerating predictions on Test Set...") #
        test_ensemble_pred, test_individual_preds = predict_ensemble(
             valid_ensemble_models, # Use the same models and weights
             X_test_proc, #
             weights=ensemble_weights #
        ) #
        if test_ensemble_pred is not None:
            print(f"Generated test predictions. Ensemble shape: {test_ensemble_pred.shape}") #
        else:
             print("Test ensemble prediction failed.")

    except Exception as e: #
        print(f"An error occurred during prediction generation: {e}") #
        traceback.print_exc() #
        # Clear predictions if error occurs
        val_ensemble_pred, test_ensemble_pred = None, None #
        val_individual_preds, test_individual_preds = {}, {} #
else: 
    print("Skipping prediction generation: Missing ensemble weights, valid models, or processed data.") #
# Out:
# --- Step 7: Making Predictions ---
# Generating predictions on Validation Set...
#
# --- Generating Ensemble Predictions ---
# Ensemble prediction generation complete. Shape: (6484,)
# Generated validation predictions. Ensemble shape: (6484,)
#
# Generating predictions on Test Set...
#
# --- Generating Ensemble Predictions ---
# Ensemble prediction generation complete. Shape: (8645,)
# Generated test predictions. Ensemble shape: (8645,)

# %%
# --- Step 8: Evaluating Models ---
print("\n--- Step 8: Evaluating Models ---") #

all_metrics = {} # Reset metrics dictionary

# Evaluate only if true labels and predictions are available
if y_val is not None and y_test is not None: #
    try:
        # --- Evaluate Ensemble on Validation Set ---
        if val_ensemble_pred is not None: #
            print("\n--- Evaluating Ensemble (Validation Set) ---") #
            # Use default threshold 0.5 for evaluation display
            val_ensemble_metrics = evaluate_model(y_val, val_ensemble_pred, "Ensemble (Validation)", threshold=0.5) #
            if val_ensemble_metrics: all_metrics['Ensemble_Validation'] = val_ensemble_metrics #

        # --- Evaluate Ensemble on Test Set ---
        if test_ensemble_pred is not None: #
            print("\n--- Evaluating Ensemble (Test Set) ---") #
            test_ensemble_metrics = evaluate_model(y_test, test_ensemble_pred, "Ensemble (Test)", threshold=0.5) #
            if test_ensemble_metrics: all_metrics['Ensemble_Test'] = test_ensemble_metrics #

        # --- Evaluate Individual Models on Test Set ---
        # Use the predictions generated during the ensemble step
        print("\n--- Evaluating Individual Models (Test Set) ---") #
        if test_individual_preds: # Check if dictionary is not empty
             # Iterate through the individual predictions dictionary
             for name, preds_proba in test_individual_preds.items(): #
                  if preds_proba is not None: # Check if prediction exists for this model
                      print(f"\n--- Evaluating {name} (Test Set) ---") #
                      individual_metrics = evaluate_model(y_test, preds_proba, f"{name} (Test)", threshold=0.5) #
                      if individual_metrics: all_metrics[f'{name}_Test'] = individual_metrics #
                  else:
                      print(f"Skipping evaluation for {name}: No test predictions found.")
        else: #
             print("No individual model predictions available for evaluation.") #


        # --- Print summary of test accuracies (if available) ---
        print("\n--- Test Set Accuracy Summary ---") #
        test_accuracies = {
            k: v['accuracy'] for k, v in all_metrics.items()
            if 'Test' in k and isinstance(v, dict) and 'accuracy' in v
        } # Filter for test set results with accuracy
        if test_accuracies: #
             # Sort by accuracy descending
             for name, acc in sorted(test_accuracies.items(), key=lambda item: item[1], reverse=True): #
                 print(f"- {name}: {acc:.4f}") #
        else: #
             print("No test set evaluation metrics recorded or available.") #


    except Exception as e: #
        print(f"An error occurred during model evaluation: {e}") #
        traceback.print_exc() #
else: #
    print("Skipping model evaluation: Target variables (y_val, y_test) or predictions are missing.") #
# Out:
# --- Step 8: Evaluating Models ---
#
# --- Evaluating Ensemble (Validation Set) ---
#
# --- Ensemble (Validation) Evaluation (Threshold: 0.50) ---
# Accuracy: 0.5153
#
# Classification Report:
#               precision    recall  f1-score   support
#
#     Down (0)       0.50      0.40      0.44      3154
#       Up (1)       0.52      0.63      0.57      3330
#
#     accuracy                           0.52      6484
#    macro avg       0.51      0.51      0.51      6484
# weighted avg       0.51      0.52      0.51      6484
#
#
# --- Evaluating Ensemble (Test Set) ---
#
# --- Ensemble (Test) Evaluation (Threshold: 0.50) ---
# Accuracy: 0.3544
#
# Classification Report:
#               precision    recall  f1-score   support
#
#     Down (0)       0.49      0.45      0.47      5527
#       Up (1)       0.16      0.19      0.18      3118
#
#     accuracy                           0.35      8645
#    macro avg       0.33      0.32      0.32      8645
# weighted avg       0.38      0.35      0.36      8645
#
#
# --- Evaluating Individual Models (Test Set) ---
#
# --- Evaluating XGBoost (Test Set) ---
#
# --- XGBoost (Test) Evaluation (Threshold: 0.50) ---
# Accuracy: 0.4534
#
# Classification Report:
#               precision    recall  f1-score   support
#
#     Down (0)       0.65      0.31      0.42      5527
#       Up (1)       0.37      0.71      0.49      3118
#
#     accuracy                           0.45      8645
#    macro avg       0.51      0.51      0.45      8645
# weighted avg       0.55      0.45      0.44      8645
#
#
# --- Evaluating Random Forest (Test Set) ---
#
# --- Random Forest (Test) Evaluation (Threshold: 0.50) ---
# Accuracy: 0.6300
#
# Classification Report:
#               precision    recall  f1-score   support
#
#     Down (0)       0.64      0.94      0.77      5527
#       Up (1)       0.42      0.07      0.12      3118
#
#     accuracy                           0.63      8645
#    macro avg       0.53      0.51      0.44      8645
# weighted avg       0.56      0.63      0.53      8645
#
#
# --- Evaluating MLP (Test Set) ---
#
# --- MLP (Test) Evaluation (Threshold: 0.50) ---
# Accuracy: 0.3584
#
# Classification Report:
#               precision    recall  f1-score   support
#
#     Down (0)       0.50      0.41      0.45      5527
#       Up (1)       0.21      0.28      0.24      3118
#
#     accuracy                           0.36      8645
#    macro avg       0.35      0.34      0.34      8645
# weighted avg       0.39      0.36      0.37      8645
#
#
# --- Evaluating Logistic (Test Set) ---
#
# --- Logistic (Test) Evaluation (Threshold: 0.50) ---
# Accuracy: 0.5021
#
# Classification Report:
#               precision    recall  f1-score   support
#
#     Down (0)       0.65      0.48      0.55      5527
#       Up (1)       0.37      0.54      0.44      3118
#
#     accuracy                           0.50      8645
#    macro avg       0.51      0.51      0.50      8645
# weighted avg       0.55      0.50      0.51      8645
#
#
# --- Test Set Accuracy Summary ---
# - Random Forest_Test: 0.6300
# - Logistic_Test: 0.5021
# - XGBoost_Test: 0.4534
# - MLP_Test: 0.3584
# - Ensemble_Test: 0.3544

# %%
# --- Step 9: Plotting Feature Importance ---
print("\n--- Step 9: Plotting Feature Importance ---") #

# Plot importance only if models dictionary and feature names list exist
if ('models' in locals() and models and
    'processed_feature_names' in locals() and
    processed_feature_names is not None): # Check models exists/populated and feature names exist

    # CORRECTION 3: Explicitly check if the feature names list/array is empty
    feature_names_is_empty = False
    try:
        # Use .size for numpy arrays, len() for lists
        if hasattr(processed_feature_names, 'size'): # Check if it has a 'size' attribute (like numpy array)
             if processed_feature_names.size == 0:
                  feature_names_is_empty = True
        elif isinstance(processed_feature_names, (list, tuple)): # Check if it's a list or tuple
             if len(processed_feature_names) == 0:
                  feature_names_is_empty = True
        # Add elif for other potential types if necessary

    except Exception as e_check:
         print(f"[DEBUG] Error checking if processed_feature_names is empty: {e_check}")
         # Assume it might be invalid if check fails, skip plotting
         feature_names_is_empty = True


    if feature_names_is_empty: # Check the flag
          print("Skipping feature importance plotting: 'processed_feature_names' is empty or invalid.")
    else:
        importance_plots_generated = [] # Track which plots were made

        # --- Plot for Models Supporting Importance ---
        # Iterate through the models dictionary
        for model_name, model_object in models.items(): #
            if model_object is not None: # Check if model was trained successfully
                 supported = False # Flag to check if importance can be plotted
                 importance_label = f"{model_name}" # Base label for the plot
                 # Check for tree-based importance or linear coefficients
                 if hasattr(model_object, 'feature_importances_') or \
                    (hasattr(model_object, 'coef_') and 'Logistic' in model_name) or \
                    (hasattr(model_object, 'named_steps') and any(hasattr(step, 'feature_importances_') or hasattr(step, 'coef_') for step in model_object.named_steps.values())): # Check model or pipeline steps
                      supported = True #
                      # Adjust label if using coefficients for Logistic Regression
                      if 'Logistic' in model_name and not hasattr(model_object, 'feature_importances_'): # Check direct attribute first
                           is_pipeline_logistic = False
                           if hasattr(model_object, 'named_steps'):
                               for step_name in ['logreg', 'logisticregression']:
                                   if step_name in model_object.named_steps and hasattr(model_object.named_steps[step_name], 'coef_'):
                                       is_pipeline_logistic = True
                                       break
                           if hasattr(model_object, 'coef_') or is_pipeline_logistic:
                                importance_label += " (Abs Coeff)" #


                 if supported: #
                     try:
                         print(f"\nPlotting {importance_label} Feature Importance...") #
                         # Ensure processed_feature_names is passed correctly
                         importance_df = plot_feature_importance(
                             model_object, # Pass the model object or pipeline
                             processed_feature_names, # Pass the feature names list/array
                             model_name=importance_label, # Use descriptive name
                             top_n=25 # Show top N features
                         ) #
                         if importance_df is not None: importance_plots_generated.append(model_name) # Track success
                     except Exception as e: #
                         print(f"Could not plot importance for {model_name}: {e}") #
                 # else: # Optional: Log unsupported models
                     # print(f"Skipping importance plot for {model_name}: Not a standard supported type.")

        # --- Summary ---
        if not importance_plots_generated: #
            print("No feature importance plots were generated (models might be missing, failed, or unsupported).") #
        else: #
            print(f"\nGenerated feature importance plots for: {', '.join(importance_plots_generated)}") #

else: #
     # Explain why plotting is skipped
     reason = []
     if 'models' not in locals() or not models: reason.append("'models' dictionary is missing or empty")
     if 'processed_feature_names' not in locals(): reason.append("'processed_feature_names' variable is missing")
     elif processed_feature_names is None: reason.append("'processed_feature_names' is None")
     # No longer include the ambiguous check reason
     print(f"Skipping feature importance plotting because: {', '.join(reason)}.") #
# Out:
# --- Step 9: Plotting Feature Importance ---
#
# Plotting XGBoost Feature Importance...
#
# --- Plotting Feature Importance for XGBoost ---
# Feature importance plot saved to bitcoin_onchain_models/feature_importance_XGBoost.png
# Plotting Random Forest Feature Importance...
#
# --- Plotting Feature Importance for Random Forest ---
# Feature importance plot saved to bitcoin_onchain_models/feature_importance_Random_Forest.png
# Plotting Logistic (Abs Coeff) Feature Importance...
#
# --- Plotting Feature Importance for Logistic (Abs Coeff) ---
# Feature importance plot saved to bitcoin_onchain_models/feature_importance_Logistic__Abs_Coeff.png
# Generated feature importance plots for: XGBoost, Random Forest, Logistic

# %%
# --- Step 10: Running Backtest on Test Set ---
# NOTE: Step 10a (Parameter Tuning) has been removed.
# This step uses the fixed BACKTESTING_PARAMS defined earlier.
print("\n--- Step 10: Running Final Backtest on Test Set ---") #

backtest = None # Initialize
backtest_results_df = None # Initialize

# Ensure we have the necessary components for the TEST set backtest
# Use test_ensemble_pred (or a fallback if ensemble failed but single model preds exist)
predictions_for_backtest = test_ensemble_pred
if predictions_for_backtest is None:
     print("Error: No predictions available for the test set. Cannot run backtest.")
     # Optional: Add fallback logic here if needed, e.g., use neutral predictions
     # predictions_for_backtest = pd.Series(0.5, index=X_test.index) # Example: Neutral prediction fallback
else:
     # Check if other necessary data exists
     if X_test is not None and not X_test.empty and df_ready is not None:
         try:
             # Prepare the TEST data slice - Ensure it has the PRICE_COLUMN and any other columns needed by strategy logic
             if not isinstance(X_test.index, pd.DatetimeIndex):
                  raise ValueError("X_test index must be DatetimeIndex for backtesting.")

             # Select the relevant slice from df_ready using the test set index
             test_data_for_backtest = df_ready.loc[X_test.index].copy() #

             # Ensure predictions are a pandas Series with the same index as test_data_for_backtest
             if not isinstance(predictions_for_backtest, pd.Series):
                  if len(predictions_for_backtest) == len(test_data_for_backtest.index):
                      test_predictions_series = pd.Series(predictions_for_backtest, index=test_data_for_backtest.index) #
                  else:
                       raise ValueError("Length mismatch between predictions and test data index.")
             else:
                  # Reindex predictions if necessary (should already match if predict_ensemble worked correctly)
                  test_predictions_series = predictions_for_backtest.reindex(test_data_for_backtest.index, fill_value=0.5) # Fill missing with neutral

             # Verify necessary columns exist in the slice
             required_cols_backtest = [PRICE_COLUMN] # Add other columns if needed by strategy/helpers
             missing_cols = [col for col in required_cols_backtest if col not in test_data_for_backtest.columns]
             if missing_cols:
                  raise ValueError(f"Missing required columns for backtest in test_data_for_backtest: {missing_cols}")


             print(f"\nRunning FINAL backtest on {len(test_data_for_backtest)} test samples...") #
             print("Using fixed parameters and test set predictions.") #
             print("Backtesting Parameters Used:")
             for key, value in BACKTESTING_PARAMS.items():
                  print(f"- {key}: {value}")

             # Instantiate and run the backtest strategy using the fixed BACKTESTING_PARAMS
             backtest = OnChainBitcoinStrategy(
                 df=test_data_for_backtest, # Pass the data slice for the test period
                 predictions=test_predictions_series, # Pass predictions aligned to test data
                 params=BACKTESTING_PARAMS.copy(), # Use the fixed global parameters
                 price_col=PRICE_COLUMN # Specify the price column
             ) #

             if backtest.results is not None and not backtest.results.empty: #
                 backtest_results_df = backtest.results # Store the results df
                 print("\nFinal backtest simulation complete.") #
                 print("Sample of final backtest results DataFrame (first 5 rows):") #
                 print(backtest_results_df.head()) #
             else: #
                 print("\nFinal backtest failed to produce results.") #
                 backtest_results_df = None # Ensure it's None

         except Exception as e: #
             print(f"FATAL ERROR occurred during the final backtesting run: {e}") #
             traceback.print_exc() #
             backtest = None # Ensure backtest object is None if it failed
             backtest_results_df = None
     else: #
         print("Skipping final backtest run: Missing test set data (X_test) or original data (df_ready).") #

# Final check if backtest object exists
if backtest is None:
     print("\nBacktest object was not successfully created. Evaluation and plotting will be skipped.")
# Out:
# --- Step 10: Running Final Backtest on Test Set ---
#
# Running FINAL backtest on 8645 test samples...
# Using fixed parameters and test set predictions.
# Backtesting Parameters Used:
# - INITIAL_CASH: 10000
# - COMMISSION_PERC: 0.0006
# - BASE_POSITION_SIZE: 0.5
# [DEBUG] OnChainBitcoinStrategy.__init__ called (Buy, Hold, Sell Mode).
# [DEBUG] Initializing strategy simulation (_run_strategy - Buy, Hold, Sell)...
# [DEBUG] _run_strategy (Buy, Hold, Sell Mode) starting...
# [DEBUG] Starting buy, hold, sell backtest loop for 8645 steps...
# [DEBUG] Hold position at 2024-03-19 20:00:00 - Price: 64963.00, Pred: 0.461, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-19 21:00:00 - Price: 64843.00, Pred: 0.494, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-19 22:00:00 - Price: 64701.00, Pred: 0.486, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-19 23:00:00 - Price: 64395.00, Pred: 0.468, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-20 00:00:00 - Price: 63755.00, Pred: 0.514, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-20 01:00:00 - Price: 63954.00, Pred: 0.484, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-20 02:00:00 - Price: 62584.00, Pred: 0.467, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-20 03:00:00 - Price: 61897.00, Pred: 0.490, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-20 04:00:00 - Price: 63182.00, Pred: 0.486, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-20 05:00:00 - Price: 62317.00, Pred: 0.494, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-20 06:00:00 - Price: 62825.00, Pred: 0.494, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-20 07:00:00 - Price: 61730.00, Pred: 0.469, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-20 08:00:00 - Price: 61627.00, Pred: 0.462, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-20 09:00:00 - Price: 61528.00, Pred: 0.498, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-20 10:00:00 - Price: 61712.00, Pred: 0.503, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-20 11:00:00 - Price: 62963.00, Pred: 0.484, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-20 12:00:00 - Price: 62686.00, Pred: 0.499, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-20 13:00:00 - Price: 63197.00, Pred: 0.469, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-20 14:00:00 - Price: 63014.00, Pred: 0.472, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-20 15:00:00 - Price: 63359.00, Pred: 0.488, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-20 16:00:00 - Price: 64031.00, Pred: 0.482, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-20 17:00:00 - Price: 63575.00, Pred: 0.528, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-20 18:00:00 - Price: 64234.00, Pred: 0.484, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-20 19:00:00 - Price: 63602.00, Pred: 0.506, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-20 20:00:00 - Price: 63118.00, Pred: 0.486, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-20 21:00:00 - Price: 64114.00, Pred: 0.493, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-20 22:00:00 - Price: 65402.00, Pred: 0.492, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-20 23:00:00 - Price: 65792.00, Pred: 0.496, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-21 00:00:00 - Price: 67082.00, Pred: 0.495, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-21 01:00:00 - Price: 67721.00, Pred: 0.469, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-21 02:00:00 - Price: 67706.00, Pred: 0.478, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-21 03:00:00 - Price: 67872.00, Pred: 0.477, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-21 04:00:00 - Price: 67666.00, Pred: 0.468, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-21 05:00:00 - Price: 67806.00, Pred: 0.466, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-21 06:00:00 - Price: 67533.00, Pred: 0.474, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-21 07:00:00 - Price: 66643.00, Pred: 0.491, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-21 08:00:00 - Price: 66731.00, Pred: 0.475, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-21 09:00:00 - Price: 66977.00, Pred: 0.474, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-21 10:00:00 - Price: 66996.00, Pred: 0.471, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-21 12:00:00 - Price: 67297.00, Pred: 0.486, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-21 13:00:00 - Price: 66836.00, Pred: 0.481, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-21 14:00:00 - Price: 66974.00, Pred: 0.477, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-21 15:00:00 - Price: 67047.00, Pred: 0.469, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-21 16:00:00 - Price: 67237.00, Pred: 0.488, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-21 17:00:00 - Price: 66750.00, Pred: 0.469, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-21 18:00:00 - Price: 66863.00, Pred: 0.482, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-21 19:00:00 - Price: 66525.00, Pred: 0.500, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-21 20:00:00 - Price: 66785.00, Pred: 0.481, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-21 21:00:00 - Price: 65706.00, Pred: 0.456, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-21 22:00:00 - Price: 65120.00, Pred: 0.469, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-21 23:00:00 - Price: 65264.00, Pred: 0.489, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-22 00:00:00 - Price: 65470.00, Pred: 0.496, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-22 01:00:00 - Price: 65621.00, Pred: 0.487, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-22 02:00:00 - Price: 65386.00, Pred: 0.476, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-22 03:00:00 - Price: 65485.00, Pred: 0.500, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-22 04:00:00 - Price: 65789.00, Pred: 0.497, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-22 05:00:00 - Price: 65241.00, Pred: 0.486, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-22 06:00:00 - Price: 65635.00, Pred: 0.473, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-22 07:00:00 - Price: 65964.00, Pred: 0.462, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-22 08:00:00 - Price: 66147.00, Pred: 0.472, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-22 09:00:00 - Price: 66431.00, Pred: 0.493, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-22 10:00:00 - Price: 66452.00, Pred: 0.471, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-22 11:00:00 - Price: 66170.00, Pred: 0.501, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-22 12:00:00 - Price: 65838.00, Pred: 0.477, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-22 13:00:00 - Price: 65492.00, Pred: 0.496, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-22 14:00:00 - Price: 64671.00, Pred: 0.457, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-22 15:00:00 - Price: 64233.00, Pred: 0.475, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-22 16:00:00 - Price: 64272.00, Pred: 0.485, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-22 17:00:00 - Price: 63069.00, Pred: 0.497, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-22 18:00:00 - Price: 62724.00, Pred: 0.483, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-22 19:00:00 - Price: 63869.00, Pred: 0.497, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-22 20:00:00 - Price: 63271.00, Pred: 0.457, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-22 21:00:00 - Price: 63572.00, Pred: 0.468, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-22 22:00:00 - Price: 63738.00, Pred: 0.465, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-22 23:00:00 - Price: 63883.00, Pred: 0.468, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-23 00:00:00 - Price: 63521.00, Pred: 0.481, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-23 01:00:00 - Price: 62989.00, Pred: 0.520, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-23 02:00:00 - Price: 63038.00, Pred: 0.473, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-23 03:00:00 - Price: 63807.00, Pred: 0.455, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-23 04:00:00 - Price: 63586.00, Pred: 0.468, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-23 05:00:00 - Price: 64108.00, Pred: 0.484, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-23 06:00:00 - Price: 63877.00, Pred: 0.470, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-23 07:00:00 - Price: 63577.00, Pred: 0.494, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-23 08:00:00 - Price: 63881.00, Pred: 0.455, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-23 09:00:00 - Price: 64085.00, Pred: 0.452, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-23 10:00:00 - Price: 64173.00, Pred: 0.475, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-23 11:00:00 - Price: 64579.00, Pred: 0.471, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-23 12:00:00 - Price: 64513.00, Pred: 0.480, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-23 13:00:00 - Price: 64465.00, Pred: 0.499, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-23 14:00:00 - Price: 64323.00, Pred: 0.453, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-23 15:00:00 - Price: 64634.00, Pred: 0.463, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-23 16:00:00 - Price: 64704.00, Pred: 0.452, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-23 17:00:00 - Price: 64601.00, Pred: 0.487, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-23 18:00:00 - Price: 65267.00, Pred: 0.480, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-23 19:00:00 - Price: 65108.00, Pred: 0.488, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-23 20:00:00 - Price: 65668.00, Pred: 0.478, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-23 21:00:00 - Price: 65662.00, Pred: 0.501, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-23 22:00:00 - Price: 65386.00, Pred: 0.469, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-23 23:00:00 - Price: 64893.00, Pred: 0.489, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-24 00:00:00 - Price: 65019.00, Pred: 0.489, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-24 01:00:00 - Price: 64951.00, Pred: 0.509, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-24 02:00:00 - Price: 64756.00, Pred: 0.481, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-24 03:00:00 - Price: 64001.00, Pred: 0.469, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-24 04:00:00 - Price: 64536.00, Pred: 0.475, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-24 05:00:00 - Price: 64490.00, Pred: 0.477, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-24 06:00:00 - Price: 64287.00, Pred: 0.472, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-24 07:00:00 - Price: 63982.00, Pred: 0.467, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-24 08:00:00 - Price: 64216.00, Pred: 0.495, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-24 09:00:00 - Price: 64317.00, Pred: 0.507, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-24 10:00:00 - Price: 64241.00, Pred: 0.512, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-24 11:00:00 - Price: 64586.00, Pred: 0.502, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-24 12:00:00 - Price: 65257.00, Pred: 0.488, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-24 13:00:00 - Price: 64892.00, Pred: 0.503, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-24 14:00:00 - Price: 65102.00, Pred: 0.493, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-24 15:00:00 - Price: 65340.00, Pred: 0.514, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-24 16:00:00 - Price: 65659.00, Pred: 0.482, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-24 17:00:00 - Price: 65349.00, Pred: 0.497, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-24 18:00:00 - Price: 65630.00, Pred: 0.473, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-24 19:00:00 - Price: 65659.00, Pred: 0.496, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-24 20:00:00 - Price: 65238.00, Pred: 0.482, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-24 21:00:00 - Price: 65340.00, Pred: 0.480, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-24 22:00:00 - Price: 65804.00, Pred: 0.488, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-24 23:00:00 - Price: 65846.00, Pred: 0.512, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-25 00:00:00 - Price: 66149.00, Pred: 0.475, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-25 01:00:00 - Price: 66544.00, Pred: 0.487, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-25 02:00:00 - Price: 66962.00, Pred: 0.475, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-25 03:00:00 - Price: 67188.00, Pred: 0.500, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-25 04:00:00 - Price: 66573.00, Pred: 0.469, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-25 05:00:00 - Price: 66546.00, Pred: 0.501, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-25 07:00:00 - Price: 67338.00, Pred: 0.500, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-25 08:00:00 - Price: 67503.00, Pred: 0.459, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-25 10:00:00 - Price: 67173.00, Pred: 0.460, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-25 11:00:00 - Price: 66852.00, Pred: 0.473, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-25 12:00:00 - Price: 66958.00, Pred: 0.469, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-25 13:00:00 - Price: 67087.00, Pred: 0.499, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-25 14:00:00 - Price: 67023.00, Pred: 0.457, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-25 15:00:00 - Price: 66836.00, Pred: 0.482, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-25 16:00:00 - Price: 67109.00, Pred: 0.458, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-25 17:00:00 - Price: 68041.00, Pred: 0.487, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-25 18:00:00 - Price: 69384.00, Pred: 0.493, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-25 19:00:00 - Price: 69821.00, Pred: 0.457, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-25 20:00:00 - Price: 70179.00, Pred: 0.512, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-25 21:00:00 - Price: 70587.00, Pred: 0.474, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-25 22:00:00 - Price: 70904.00, Pred: 0.463, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-25 23:00:00 - Price: 71043.00, Pred: 0.466, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-26 00:00:00 - Price: 70977.00, Pred: 0.493, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-26 01:00:00 - Price: 69865.00, Pred: 0.479, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-26 02:00:00 - Price: 70311.00, Pred: 0.470, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-26 03:00:00 - Price: 69898.00, Pred: 0.496, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-26 04:00:00 - Price: 69910.00, Pred: 0.479, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-26 05:00:00 - Price: 70293.00, Pred: 0.480, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-26 06:00:00 - Price: 70498.00, Pred: 0.485, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-26 07:00:00 - Price: 70471.00, Pred: 0.456, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-26 08:00:00 - Price: 70630.00, Pred: 0.460, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-26 09:00:00 - Price: 70325.00, Pred: 0.486, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-26 10:00:00 - Price: 70639.00, Pred: 0.468, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-26 11:00:00 - Price: 70512.00, Pred: 0.456, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-26 12:00:00 - Price: 70720.00, Pred: 0.491, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-26 13:00:00 - Price: 71168.00, Pred: 0.470, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-26 14:00:00 - Price: 70918.00, Pred: 0.504, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-26 15:00:00 - Price: 70700.00, Pred: 0.487, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-26 16:00:00 - Price: 71107.00, Pred: 0.482, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-26 17:00:00 - Price: 70404.00, Pred: 0.484, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-26 18:00:00 - Price: 70311.00, Pred: 0.486, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-26 19:00:00 - Price: 70279.00, Pred: 0.482, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-26 20:00:00 - Price: 69779.00, Pred: 0.471, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-26 22:00:00 - Price: 69971.00, Pred: 0.479, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-26 23:00:00 - Price: 69456.00, Pred: 0.476, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-27 00:00:00 - Price: 69829.00, Pred: 0.485, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-27 01:00:00 - Price: 70012.00, Pred: 0.513, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-27 02:00:00 - Price: 70248.00, Pred: 0.457, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-27 03:00:00 - Price: 69997.00, Pred: 0.474, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-27 04:00:00 - Price: 70612.00, Pred: 0.479, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-27 05:00:00 - Price: 70327.00, Pred: 0.481, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-27 06:00:00 - Price: 70579.00, Pred: 0.458, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-27 08:00:00 - Price: 70173.00, Pred: 0.472, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-27 09:00:00 - Price: 70461.00, Pred: 0.527, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-27 10:00:00 - Price: 70307.00, Pred: 0.469, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-27 11:00:00 - Price: 69741.00, Pred: 0.477, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-27 13:00:00 - Price: 70054.00, Pred: 0.474, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-27 14:00:00 - Price: 70117.00, Pred: 0.451, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-27 15:00:00 - Price: 70213.00, Pred: 0.484, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-27 16:00:00 - Price: 70171.00, Pred: 0.478, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-27 17:00:00 - Price: 69886.00, Pred: 0.500, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-27 18:00:00 - Price: 70025.00, Pred: 0.487, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-27 19:00:00 - Price: 68850.00, Pred: 0.459, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-27 20:00:00 - Price: 69231.00, Pred: 0.476, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-27 21:00:00 - Price: 68670.00, Pred: 0.474, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-27 23:00:00 - Price: 68595.00, Pred: 0.477, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-28 00:00:00 - Price: 68876.00, Pred: 0.458, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-28 01:00:00 - Price: 68916.00, Pred: 0.463, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-28 02:00:00 - Price: 69419.00, Pred: 0.471, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-28 03:00:00 - Price: 69421.00, Pred: 0.455, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-28 04:00:00 - Price: 69641.00, Pred: 0.483, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-28 05:00:00 - Price: 69409.00, Pred: 0.464, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-28 06:00:00 - Price: 69082.00, Pred: 0.467, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-28 07:00:00 - Price: 69281.00, Pred: 0.467, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-28 08:00:00 - Price: 69675.00, Pred: 0.458, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-28 09:00:00 - Price: 69690.00, Pred: 0.458, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-28 10:00:00 - Price: 70340.00, Pred: 0.471, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-28 11:00:00 - Price: 70387.00, Pred: 0.473, BTC Held: 0.000000
# [DEBUG] Hold position at 2024-03-28 12:00:00 - Price: 70539.00, Pred: 0.455, BTC Held: 0.000000
# [DEBUG] Buy executed at 2024-03-28 13:00:00 - Price: 70554.00, Pred: 0.568, BTC Held: 0.070825
# [DEBUG] Hold position at 2024-03-28 14:00:00 - Price: 70783.00, Pred: 0.498, BTC Held: 0.070825
# [DEBUG] Hold position at 2024-03-28 15:00:00 - Price: 70605.00, Pred: 0.509, BTC Held: 0.070825
# [DEBUG] Partial Sell executed at 2024-03-28 16:00:00 - Price: 70801.00, Pred: 0.439, Sold: 0.035413 BTC, Remaining: 0.035413 BTC
# [DEBUG] Hold position at 2024-03-28 17:00:00 - Price: 70870.00, Pred: 0.495, BTC Held: 0.035413
# [DEBUG] Partial Sell executed at 2024-03-28 18:00:00 - Price: 71587.00, Pred: 0.450, Sold: 0.017706 BTC, Remaining: 0.017706 BTC
# [DEBUG] Hold position at 2024-03-28 19:00:00 - Price: 71296.00, Pred: 0.475, BTC Held: 0.017706
# [DEBUG] Hold position at 2024-03-28 20:00:00 - Price: 70689.00, Pred: 0.497, BTC Held: 0.017706
# [DEBUG] Hold position at 2024-03-28 21:00:00 - Price: 70792.00, Pred: 0.491, BTC Held: 0.017706
# [DEBUG] Hold position at 2024-03-28 22:00:00 - Price: 70543.00, Pred: 0.466, BTC Held: 0.017706
# [DEBUG] Hold position at 2024-03-28 23:00:00 - Price: 70847.00, Pred: 0.484, BTC Held: 0.017706
# [DEBUG] Hold position at 2024-03-29 00:00:00 - Price: 70699.00, Pred: 0.464, BTC Held: 0.017706
# [DEBUG] Hold position at 2024-03-29 01:00:00 - Price: 70843.00, Pred: 0.455, BTC Held: 0.017706
# [DEBUG] Hold position at 2024-03-29 02:00:00 - Price: 70872.00, Pred: 0.471, BTC Held: 0.017706
# [DEBUG] Hold position at 2024-03-29 03:00:00 - Price: 70803.00, Pred: 0.454, BTC Held: 0.017706
# [DEBUG] Partial Sell executed at 2024-03-29 04:00:00 - Price: 70752.00, Pred: 0.447, Sold: 0.008853 BTC, Remaining: 0.008853 BTC
# [DEBUG] Hold position at 2024-03-29 05:00:00 - Price: 70807.00, Pred: 0.525, BTC Held: 0.008853
# [DEBUG] Hold position at 2024-03-29 06:00:00 - Price: 70640.00, Pred: 0.469, BTC Held: 0.008853
# [DEBUG] Hold position at 2024-03-29 07:00:00 - Price: 70462.00, Pred: 0.469, BTC Held: 0.008853
# [DEBUG] Hold position at 2024-03-29 08:00:00 - Price: 70374.00, Pred: 0.463, BTC Held: 0.008853
# [DEBUG] Hold position at 2024-03-29 09:00:00 - Price: 70209.00, Pred: 0.490, BTC Held: 0.008853
# [DEBUG] Hold position at 2024-03-29 10:00:00 - Price: 70437.00, Pred: 0.462, BTC Held: 0.008853
# [DEBUG] Hold position at 2024-03-29 11:00:00 - Price: 69800.00, Pred: 0.461, BTC Held: 0.008853
# [DEBUG] Hold position at 2024-03-29 12:00:00 - Price: 69946.00, Pred: 0.457, BTC Held: 0.008853
# [DEBUG] Hold position at 2024-03-29 13:00:00 - Price: 69749.00, Pred: 0.460, BTC Held: 0.008853
# [DEBUG] Hold position at 2024-03-29 14:00:00 - Price: 69909.00, Pred: 0.484, BTC Held: 0.008853
# [DEBUG] Hold position at 2024-03-29 15:00:00 - Price: 70167.00, Pred: 0.465, BTC Held: 0.008853
# [DEBUG] Buy executed at 2024-03-29 16:00:00 - Price: 70154.00, Pred: 0.569, BTC Held: 0.075798
# [DEBUG] Hold position at 2024-03-29 17:00:00 - Price: 70426.00, Pred: 0.456, BTC Held: 0.075798
# [DEBUG] Hold position at 2024-03-29 18:00:00 - Price: 70101.00, Pred: 0.451, BTC Held: 0.075798
# [DEBUG] Hold position at 2024-03-29 19:00:00 - Price: 69186.00, Pred: 0.456, BTC Held: 0.075798
# [DEBUG] Hold position at 2024-03-29 20:00:00 - Price: 69194.00, Pred: 0.459, BTC Held: 0.075798
# [DEBUG] Hold position at 2024-03-29 21:00:00 - Price: 69451.00, Pred: 0.481, BTC Held: 0.075798
# [DEBUG] Hold position at 2024-03-29 22:00:00 - Price: 69547.00, Pred: 0.459, BTC Held: 0.075798
# [DEBUG] Hold position at 2024-03-29 23:00:00 - Price: 69706.00, Pred: 0.503, BTC Held: 0.075798
# [DEBUG] Hold position at 2024-03-30 00:00:00 - Price: 69653.00, Pred: 0.465, BTC Held: 0.075798
# [DEBUG] Hold position at 2024-03-30 01:00:00 - Price: 69467.00, Pred: 0.462, BTC Held: 0.075798
# [DEBUG] Hold position at 2024-03-30 02:00:00 - Price: 69848.00, Pred: 0.502, BTC Held: 0.075798
# [DEBUG] Hold position at 2024-03-30 03:00:00 - Price: 69903.00, Pred: 0.482, BTC Held: 0.075798
# [DEBUG] Hold position at 2024-03-30 04:00:00 - Price: 69991.00, Pred: 0.476, BTC Held: 0.075798
# [DEBUG] Hold position at 2024-03-30 05:00:00 - Price: 70025.00, Pred: 0.477, BTC Held: 0.075798
# [DEBUG] Partial Sell executed at 2024-03-30 06:00:00 - Price: 69992.00, Pred: 0.439, Sold: 0.037899 BTC, Remaining: 0.037899 BTC
# [DEBUG] Partial Sell executed at 2024-03-30 07:00:00 - Price: 69829.00, Pred: 0.448, Sold: 0.018949 BTC, Remaining: 0.018949 BTC
# [DEBUG] Partial Sell executed at 2024-03-30 08:00:00 - Price: 70107.00, Pred: 0.449, Sold: 0.009475 BTC, Remaining: 0.009475 BTC
# [DEBUG] Hold position at 2024-03-30 09:00:00 - Price: 70057.00, Pred: 0.483, BTC Held: 0.009475
# [DEBUG] Hold position at 2024-03-30 10:00:00 - Price: 70010.00, Pred: 0.485, BTC Held: 0.009475
# [DEBUG] Hold position at 2024-03-30 11:00:00 - Price: 69898.00, Pred: 0.496, BTC Held: 0.009475
# [DEBUG] Hold position at 2024-03-30 12:00:00 - Price: 70003.00, Pred: 0.490, BTC Held: 0.009475
# [DEBUG] Hold position at 2024-03-30 13:00:00 - Price: 70052.00, Pred: 0.480, BTC Held: 0.009475
# [DEBUG] Hold position at 2024-03-30 14:00:00 - Price: 70056.00, Pred: 0.478, BTC Held: 0.009475
# [DEBUG] Hold position at 2024-03-30 15:00:00 - Price: 70218.00, Pred: 0.507, BTC Held: 0.009475
# [DEBUG] Hold position at 2024-03-30 16:00:00 - Price: 70256.00, Pred: 0.457, BTC Held: 0.009475
# [DEBUG] Hold position at 2024-03-30 17:00:00 - Price: 70200.00, Pred: 0.485, BTC Held: 0.009475
# [DEBUG] Hold position at 2024-03-30 18:00:00 - Price: 70093.00, Pred: 0.490, BTC Held: 0.009475
# [DEBUG] Hold position at 2024-03-30 19:00:00 - Price: 70055.00, Pred: 0.496, BTC Held: 0.009475
# [DEBUG] Hold position at 2024-03-30 20:00:00 - Price: 70233.00, Pred: 0.487, BTC Held: 0.009475
# [DEBUG] Hold position at 2024-03-30 21:00:00 - Price: 70088.00, Pred: 0.456, BTC Held: 0.009475
# [DEBUG] Hold position at 2024-03-30 22:00:00 - Price: 70006.00, Pred: 0.505, BTC Held: 0.009475
# [DEBUG] Hold position at 2024-03-30 23:00:00 - Price: 69946.00, Pred: 0.474, BTC Held: 0.009475
# [DEBUG] Hold position at 2024-03-31 00:00:00 - Price: 69867.00, Pred: 0.487, BTC Held: 0.009475
# [DEBUG] Hold position at 2024-03-31 01:00:00 - Price: 69758.00, Pred: 0.495, BTC Held: 0.009475
# [DEBUG] Hold position at 2024-03-31 02:00:00 - Price: 69753.00, Pred: 0.488, BTC Held: 0.009475
# [DEBUG] Hold position at 2024-03-31 03:00:00 - Price: 69613.00, Pred: 0.503, BTC Held: 0.009475
# [DEBUG] Hold position at 2024-03-31 04:00:00 - Price: 69896.00, Pred: 0.479, BTC Held: 0.009475
# [DEBUG] Hold position at 2024-03-31 05:00:00 - Price: 70069.00, Pred: 0.481, BTC Held: 0.009475
# [DEBUG] Hold position at 2024-03-31 06:00:00 - Price: 69985.00, Pred: 0.485, BTC Held: 0.009475
# [DEBUG] Hold position at 2024-03-31 07:00:00 - Price: 69939.00, Pred: 0.485, BTC Held: 0.009475
# [DEBUG] Hold position at 2024-03-31 08:00:00 - Price: 70115.00, Pred: 0.467, BTC Held: 0.009475
# [DEBUG] Hold position at 2024-03-31 09:00:00 - Price: 70355.00, Pred: 0.498, BTC Held: 0.009475
# [DEBUG] Hold position at 2024-03-31 10:00:00 - Price: 70238.00, Pred: 0.477, BTC Held: 0.009475
# [DEBUG] Hold position at 2024-03-31 11:00:00 - Price: 70292.00, Pred: 0.476, BTC Held: 0.009475
# [DEBUG] Hold position at 2024-03-31 12:00:00 - Price: 70275.00, Pred: 0.484, BTC Held: 0.009475
# [DEBUG] Hold position at 2024-03-31 13:00:00 - Price: 70240.00, Pred: 0.483, BTC Held: 0.009475
# [DEBUG] Hold position at 2024-03-31 14:00:00 - Price: 70273.00, Pred: 0.467, BTC Held: 0.009475
# [DEBUG] Hold position at 2024-03-31 15:00:00 - Price: 70379.00, Pred: 0.499, BTC Held: 0.009475
# [DEBUG] Hold position at 2024-03-31 16:00:00 - Price: 70523.00, Pred: 0.485, BTC Held: 0.009475
# [DEBUG] Hold position at 2024-03-31 17:00:00 - Price: 70609.00, Pred: 0.452, BTC Held: 0.009475
# [DEBUG] Hold position at 2024-03-31 18:00:00 - Price: 70558.00, Pred: 0.481, BTC Held: 0.009475
# [DEBUG] Hold position at 2024-03-31 19:00:00 - Price: 70395.00, Pred: 0.486, BTC Held: 0.009475
# [DEBUG] Hold position at 2024-03-31 20:00:00 - Price: 70474.00, Pred: 0.488, BTC Held: 0.009475
# [DEBUG] Hold position at 2024-03-31 21:00:00 - Price: 70517.00, Pred: 0.493, BTC Held: 0.009475
# [DEBUG] Hold position at 2024-03-31 22:00:00 - Price: 70881.00, Pred: 0.493, BTC Held: 0.009475
# [DEBUG] Hold position at 2024-03-31 23:00:00 - Price: 71034.00, Pred: 0.468, BTC Held: 0.009475
# [DEBUG] Hold position at 2024-04-01 00:00:00 - Price: 70851.00, Pred: 0.494, BTC Held: 0.009475
# [DEBUG] Hold position at 2024-04-01 01:00:00 - Price: 70860.00, Pred: 0.481, BTC Held: 0.009475
# [DEBUG] Hold position at 2024-04-01 02:00:00 - Price: 70979.00, Pred: 0.489, BTC Held: 0.009475
# [DEBUG] Hold position at 2024-04-01 03:00:00 - Price: 71285.00, Pred: 0.495, BTC Held: 0.009475
# [DEBUG] Hold position at 2024-04-01 04:00:00 - Price: 71182.00, Pred: 0.498, BTC Held: 0.009475
# [DEBUG] Hold position at 2024-04-01 05:00:00 - Price: 70848.00, Pred: 0.486, BTC Held: 0.009475
# [DEBUG] Hold position at 2024-04-01 06:00:00 - Price: 70878.00, Pred: 0.483, BTC Held: 0.009475
# [DEBUG] Partial Sell executed at 2024-04-01 07:00:00 - Price: 70619.00, Pred: 0.445, Sold: 0.004737 BTC, Remaining: 0.004737 BTC
# [DEBUG] Hold position at 2024-04-01 08:00:00 - Price: 70446.00, Pred: 0.477, BTC Held: 0.004737
# [DEBUG] Buy executed at 2024-04-01 09:00:00 - Price: 69156.00, Pred: 0.595, BTC Held: 0.074616
# [DEBUG] Hold position at 2024-04-01 10:00:00 - Price: 69641.00, Pred: 0.483, BTC Held: 0.074616
# [DEBUG] Partial Sell executed at 2024-04-01 11:00:00 - Price: 69625.00, Pred: 0.429, Sold: 0.037308 BTC, Remaining: 0.037308 BTC
# [DEBUG] Partial Sell executed at 2024-04-01 12:00:00 - Price: 69436.00, Pred: 0.427, Sold: 0.018654 BTC, Remaining: 0.018654 BTC
# [DEBUG] Hold position at 2024-04-01 13:00:00 - Price: 69456.00, Pred: 0.475, BTC Held: 0.018654
# [DEBUG] Hold position at 2024-04-01 14:00:00 - Price: 69581.00, Pred: 0.457, BTC Held: 0.018654
# [DEBUG] Partial Sell executed at 2024-04-01 15:00:00 - Price: 69478.00, Pred: 0.447, Sold: 0.009327 BTC, Remaining: 0.009327 BTC
# [DEBUG] Hold position at 2024-04-01 16:00:00 - Price: 69843.00, Pred: 0.497, BTC Held: 0.009327
# [DEBUG] Hold position at 2024-04-01 17:00:00 - Price: 69882.00, Pred: 0.521, BTC Held: 0.009327
# [DEBUG] Partial Sell executed at 2024-04-01 18:00:00 - Price: 68903.00, Pred: 0.445, Sold: 0.004664 BTC, Remaining: 0.004664 BTC
# [DEBUG] Hold position at 2024-04-01 19:00:00 - Price: 68231.00, Pred: 0.476, BTC Held: 0.004664
# [DEBUG] Hold position at 2024-04-01 20:00:00 - Price: 68590.00, Pred: 0.471, BTC Held: 0.004664
# [DEBUG] Hold position at 2024-04-01 21:00:00 - Price: 68742.00, Pred: 0.504, BTC Held: 0.004664
# [DEBUG] Hold position at 2024-04-01 22:00:00 - Price: 68930.00, Pred: 0.453, BTC Held: 0.004664
# [DEBUG] Hold position at 2024-04-01 23:00:00 - Price: 69713.00, Pred: 0.490, BTC Held: 0.004664
# [DEBUG] Hold position at 2024-04-02 00:00:00 - Price: 69764.00, Pred: 0.476, BTC Held: 0.004664
# [DEBUG] Hold position at 2024-04-02 01:00:00 - Price: 69617.00, Pred: 0.487, BTC Held: 0.004664
# [DEBUG] Hold position at 2024-04-02 02:00:00 - Price: 69740.00, Pred: 0.464, BTC Held: 0.004664
# [DEBUG] Hold position at 2024-04-02 03:00:00 - Price: 69699.00, Pred: 0.492, BTC Held: 0.004664
# [DEBUG] Hold position at 2024-04-02 04:00:00 - Price: 69384.00, Pred: 0.475, BTC Held: 0.004664
# [DEBUG] Hold position at 2024-04-02 05:00:00 - Price: 69434.00, Pred: 0.475, BTC Held: 0.004664
# [DEBUG] Hold position at 2024-04-02 06:00:00 - Price: 67139.00, Pred: 0.495, BTC Held: 0.004664
# [DEBUG] Hold position at 2024-04-02 07:00:00 - Price: 66756.00, Pred: 0.485, BTC Held: 0.004664
# [DEBUG] Hold position at 2024-04-02 08:00:00 - Price: 66672.00, Pred: 0.498, BTC Held: 0.004664
# [DEBUG] Hold position at 2024-04-02 09:00:00 - Price: 66814.00, Pred: 0.499, BTC Held: 0.004664
# [DEBUG] Hold position at 2024-04-02 10:00:00 - Price: 66925.00, Pred: 0.470, BTC Held: 0.004664
# [DEBUG] Hold position at 2024-04-02 11:00:00 - Price: 66528.00, Pred: 0.495, BTC Held: 0.004664
# [DEBUG] Hold position at 2024-04-02 12:00:00 - Price: 66278.00, Pred: 0.464, BTC Held: 0.004664
# [DEBUG] Hold position at 2024-04-02 13:00:00 - Price: 66107.00, Pred: 0.483, BTC Held: 0.004664
# [DEBUG] Hold position at 2024-04-02 14:00:00 - Price: 66001.00, Pred: 0.468, BTC Held: 0.004664
# [DEBUG] Hold position at 2024-04-02 15:00:00 - Price: 65623.00, Pred: 0.481, BTC Held: 0.004664
# [DEBUG] Hold position at 2024-04-02 16:00:00 - Price: 65338.00, Pred: 0.452, BTC Held: 0.004664
# [DEBUG] Hold position at 2024-04-02 17:00:00 - Price: 65217.00, Pred: 0.506, BTC Held: 0.004664
# [DEBUG] Hold position at 2024-04-02 18:00:00 - Price: 65719.00, Pred: 0.468, BTC Held: 0.004664
# [DEBUG] Hold position at 2024-04-02 19:00:00 - Price: 64900.00, Pred: 0.480, BTC Held: 0.004664
# [DEBUG] Hold position at 2024-04-02 20:00:00 - Price: 65561.00, Pred: 0.486, BTC Held: 0.004664
# [DEBUG] Hold position at 2024-04-02 21:00:00 - Price: 65633.00, Pred: 0.465, BTC Held: 0.004664
# [DEBUG] Hold position at 2024-04-02 22:00:00 - Price: 65837.00, Pred: 0.470, BTC Held: 0.004664
# [DEBUG] Hold position at 2024-04-02 23:00:00 - Price: 66000.00, Pred: 0.490, BTC Held: 0.004664
# [DEBUG] Hold position at 2024-04-03 00:00:00 - Price: 65708.00, Pred: 0.493, BTC Held: 0.004664
# [DEBUG] Hold position at 2024-04-03 01:00:00 - Price: 65719.00, Pred: 0.509, BTC Held: 0.004664
# [DEBUG] Hold position at 2024-04-03 02:00:00 - Price: 65842.00, Pred: 0.479, BTC Held: 0.004664
# [DEBUG] Hold position at 2024-04-03 03:00:00 - Price: 65469.00, Pred: 0.469, BTC Held: 0.004664
# [DEBUG] Hold position at 2024-04-03 04:00:00 - Price: 65408.00, Pred: 0.478, BTC Held: 0.004664
# [DEBUG] Hold position at 2024-04-03 05:00:00 - Price: 65827.00, Pred: 0.458, BTC Held: 0.004664
# [DEBUG] Hold position at 2024-04-03 06:00:00 - Price: 65946.00, Pred: 0.485, BTC Held: 0.004664
# [DEBUG] Hold position at 2024-04-03 07:00:00 - Price: 66243.00, Pred: 0.474, BTC Held: 0.004664
# [DEBUG] Hold position at 2024-04-03 08:00:00 - Price: 66356.00, Pred: 0.476, BTC Held: 0.004664
# [DEBUG] Hold position at 2024-04-03 09:00:00 - Price: 66118.00, Pred: 0.489, BTC Held: 0.004664
# [DEBUG] Hold position at 2024-04-03 10:00:00 - Price: 66395.00, Pred: 0.456, BTC Held: 0.004664
# [DEBUG] Hold position at 2024-04-03 11:00:00 - Price: 66188.00, Pred: 0.460, BTC Held: 0.004664
# [DEBUG] Partial Sell executed at 2024-04-03 12:00:00 - Price: 66555.00, Pred: 0.446, Sold: 0.002332 BTC, Remaining: 0.002332 BTC
# [DEBUG] Hold position at 2024-04-03 13:00:00 - Price: 66515.00, Pred: 0.470, BTC Held: 0.002332
# [DEBUG] Hold position at 2024-04-03 14:00:00 - Price: 66233.00, Pred: 0.474, BTC Held: 0.002332
# [DEBUG] Hold position at 2024-04-03 15:00:00 - Price: 66099.00, Pred: 0.461, BTC Held: 0.002332
# [DEBUG] Hold position at 2024-04-03 16:00:00 - Price: 65939.00, Pred: 0.472, BTC Held: 0.002332
# [DEBUG] Hold position at 2024-04-03 17:00:00 - Price: 65833.00, Pred: 0.454, BTC Held: 0.002332
# [DEBUG] Hold position at 2024-04-03 18:00:00 - Price: 66677.00, Pred: 0.494, BTC Held: 0.002332
# [DEBUG] Hold position at 2024-04-03 19:00:00 - Price: 65839.00, Pred: 0.479, BTC Held: 0.002332
# [DEBUG] Hold position at 2024-04-03 20:00:00 - Price: 66217.00, Pred: 0.512, BTC Held: 0.002332
# [DEBUG] Hold position at 2024-04-03 21:00:00 - Price: 65998.00, Pred: 0.480, BTC Held: 0.002332
# [DEBUG] Partial Sell executed at 2024-04-03 22:00:00 - Price: 66037.00, Pred: 0.449, Sold: 0.001166 BTC, Remaining: 0.001166 BTC
# [DEBUG] Hold position at 2024-04-03 23:00:00 - Price: 65816.00, Pred: 0.489, BTC Held: 0.001166
# [DEBUG] Hold position at 2024-04-04 00:00:00 - Price: 65747.00, Pred: 0.456, BTC Held: 0.001166
# [DEBUG] Partial Sell executed at 2024-04-04 01:00:00 - Price: 65943.00, Pred: 0.445, Sold: 0.000583 BTC, Remaining: 0.000583 BTC
# [DEBUG] Hold position at 2024-04-04 02:00:00 - Price: 66169.00, Pred: 0.498, BTC Held: 0.000583
# [DEBUG] Hold position at 2024-04-04 03:00:00 - Price: 65988.00, Pred: 0.488, BTC Held: 0.000583
# [DEBUG] Hold position at 2024-04-04 04:00:00 - Price: 66319.00, Pred: 0.468, BTC Held: 0.000583
# [DEBUG] Hold position at 2024-04-04 05:00:00 - Price: 66183.00, Pred: 0.525, BTC Held: 0.000583
# [DEBUG] Hold position at 2024-04-04 06:00:00 - Price: 65779.00, Pred: 0.471, BTC Held: 0.000583
# [DEBUG] Hold position at 2024-04-04 07:00:00 - Price: 65651.00, Pred: 0.526, BTC Held: 0.000583
# [DEBUG] Hold position at 2024-04-04 08:00:00 - Price: 65474.00, Pred: 0.488, BTC Held: 0.000583
# [DEBUG] Partial Sell executed at 2024-04-04 09:00:00 - Price: 65599.00, Pred: 0.447, Sold: 0.000291 BTC, Remaining: 0.000291 BTC
# [DEBUG] Hold position at 2024-04-04 10:00:00 - Price: 65780.00, Pred: 0.508, BTC Held: 0.000291
# [DEBUG] Hold position at 2024-04-04 11:00:00 - Price: 66076.00, Pred: 0.457, BTC Held: 0.000291
# [DEBUG] Hold position at 2024-04-04 12:00:00 - Price: 66229.00, Pred: 0.482, BTC Held: 0.000291
# [DEBUG] Hold position at 2024-04-04 13:00:00 - Price: 66266.00, Pred: 0.485, BTC Held: 0.000291
# [DEBUG] Hold position at 2024-04-04 14:00:00 - Price: 66284.00, Pred: 0.506, BTC Held: 0.000291
# [DEBUG] Hold position at 2024-04-04 15:00:00 - Price: 66356.00, Pred: 0.471, BTC Held: 0.000291
# [DEBUG] Partial Sell executed at 2024-04-04 16:00:00 - Price: 66712.00, Pred: 0.441, Sold: 0.000146 BTC, Remaining: 0.000146 BTC
# [DEBUG] Hold position at 2024-04-04 17:00:00 - Price: 67273.00, Pred: 0.485, BTC Held: 0.000146
# [DEBUG] Hold position at 2024-04-04 18:00:00 - Price: 67733.00, Pred: 0.485, BTC Held: 0.000146
# [DEBUG] Hold position at 2024-04-04 19:00:00 - Price: 67655.00, Pred: 0.492, BTC Held: 0.000146
# [DEBUG] Hold position at 2024-04-04 20:00:00 - Price: 67849.00, Pred: 0.475, BTC Held: 0.000146
# [DEBUG] Hold position at 2024-04-04 21:00:00 - Price: 68848.00, Pred: 0.471, BTC Held: 0.000146
# [DEBUG] Hold position at 2024-04-04 22:00:00 - Price: 68621.00, Pred: 0.494, BTC Held: 0.000146
# [DEBUG] Hold position at 2024-04-04 23:00:00 - Price: 68498.00, Pred: 0.496, BTC Held: 0.000146
# [DEBUG] Hold position at 2024-04-05 00:00:00 - Price: 67953.00, Pred: 0.496, BTC Held: 0.000146
# [DEBUG] Hold position at 2024-04-05 01:00:00 - Price: 67819.00, Pred: 0.471, BTC Held: 0.000146
# [DEBUG] Hold position at 2024-04-05 02:00:00 - Price: 67952.00, Pred: 0.469, BTC Held: 0.000146
# [DEBUG] Hold position at 2024-04-05 03:00:00 - Price: 68538.00, Pred: 0.468, BTC Held: 0.000146
# [DEBUG] Hold position at 2024-04-05 04:00:00 - Price: 68653.00, Pred: 0.470, BTC Held: 0.000146
# [DEBUG] Hold position at 2024-04-05 05:00:00 - Price: 68209.00, Pred: 0.457, BTC Held: 0.000146
# [DEBUG] Hold position at 2024-04-05 06:00:00 - Price: 67630.00, Pred: 0.475, BTC Held: 0.000146
# [DEBUG] Hold position at 2024-04-05 07:00:00 - Price: 67882.00, Pred: 0.463, BTC Held: 0.000146
# [DEBUG] Hold position at 2024-04-05 08:00:00 - Price: 67663.00, Pred: 0.466, BTC Held: 0.000146
# [DEBUG] Hold position at 2024-04-05 09:00:00 - Price: 66907.00, Pred: 0.488, BTC Held: 0.000146
# [DEBUG] Hold position at 2024-04-05 10:00:00 - Price: 67159.00, Pred: 0.464, BTC Held: 0.000146
# [DEBUG] Hold position at 2024-04-05 11:00:00 - Price: 66930.00, Pred: 0.473, BTC Held: 0.000146
# [DEBUG] Hold position at 2024-04-05 12:00:00 - Price: 67136.00, Pred: 0.477, BTC Held: 0.000146
# [DEBUG] Hold position at 2024-04-05 13:00:00 - Price: 66814.00, Pred: 0.497, BTC Held: 0.000146
# [DEBUG] Hold position at 2024-04-05 14:00:00 - Price: 67047.00, Pred: 0.496, BTC Held: 0.000146
# [DEBUG] Hold position at 2024-04-05 15:00:00 - Price: 66498.00, Pred: 0.482, BTC Held: 0.000146
# [DEBUG] Hold position at 2024-04-05 16:00:00 - Price: 66913.00, Pred: 0.492, BTC Held: 0.000146
# [DEBUG] Hold position at 2024-04-05 17:00:00 - Price: 67546.00, Pred: 0.490, BTC Held: 0.000146
# [DEBUG] Hold position at 2024-04-05 18:00:00 - Price: 68183.00, Pred: 0.497, BTC Held: 0.000146
# [DEBUG] Hold position at 2024-04-05 19:00:00 - Price: 68250.00, Pred: 0.479, BTC Held: 0.000146
# [DEBUG] Hold position at 2024-04-05 20:00:00 - Price: 68004.00, Pred: 0.491, BTC Held: 0.000146
# [DEBUG] Hold position at 2024-04-05 21:00:00 - Price: 67464.00, Pred: 0.492, BTC Held: 0.000146
# [DEBUG] Hold position at 2024-04-05 22:00:00 - Price: 67644.00, Pred: 0.489, BTC Held: 0.000146
# [DEBUG] Hold position at 2024-04-05 23:00:00 - Price: 67422.00, Pred: 0.498, BTC Held: 0.000146
# [DEBUG] Hold position at 2024-04-06 00:00:00 - Price: 67663.00, Pred: 0.467, BTC Held: 0.000146
# [DEBUG] Hold position at 2024-04-06 01:00:00 - Price: 67571.00, Pred: 0.476, BTC Held: 0.000146
# [DEBUG] Hold position at 2024-04-06 02:00:00 - Price: 67654.00, Pred: 0.491, BTC Held: 0.000146
# [DEBUG] Hold position at 2024-04-06 03:00:00 - Price: 67857.00, Pred: 0.477, BTC Held: 0.000146
# [DEBUG] Hold position at 2024-04-06 04:00:00 - Price: 67934.00, Pred: 0.460, BTC Held: 0.000146
# [DEBUG] Hold position at 2024-04-06 05:00:00 - Price: 67728.00, Pred: 0.464, BTC Held: 0.000146
# [DEBUG] Hold position at 2024-04-06 06:00:00 - Price: 67617.00, Pred: 0.475, BTC Held: 0.000146
# [DEBUG] Hold position at 2024-04-06 07:00:00 - Price: 67828.00, Pred: 0.484, BTC Held: 0.000146
# [DEBUG] Hold position at 2024-04-06 08:00:00 - Price: 67778.00, Pred: 0.486, BTC Held: 0.000146
# [DEBUG] Hold position at 2024-04-06 09:00:00 - Price: 68058.00, Pred: 0.476, BTC Held: 0.000146
# [DEBUG] Hold position at 2024-04-06 10:00:00 - Price: 68143.00, Pred: 0.486, BTC Held: 0.000146
# [DEBUG] Hold position at 2024-04-06 11:00:00 - Price: 68026.00, Pred: 0.484, BTC Held: 0.000146
# [DEBUG] Partial Sell executed at 2024-04-06 12:00:00 - Price: 68035.00, Pred: 0.438, Sold: 0.000073 BTC, Remaining: 0.000073 BTC
# [DEBUG] Hold position at 2024-04-06 13:00:00 - Price: 67829.00, Pred: 0.495, BTC Held: 0.000073
# [DEBUG] Hold position at 2024-04-06 14:00:00 - Price: 67864.00, Pred: 0.501, BTC Held: 0.000073
# [DEBUG] Hold position at 2024-04-06 15:00:00 - Price: 67679.00, Pred: 0.463, BTC Held: 0.000073
# [DEBUG] Hold position at 2024-04-06 16:00:00 - Price: 67769.00, Pred: 0.488, BTC Held: 0.000073
# [DEBUG] Hold position at 2024-04-06 17:00:00 - Price: 67728.00, Pred: 0.496, BTC Held: 0.000073
# [DEBUG] Hold position at 2024-04-06 18:00:00 - Price: 68016.00, Pred: 0.482, BTC Held: 0.000073
# [DEBUG] Hold position at 2024-04-06 19:00:00 - Price: 68125.00, Pred: 0.477, BTC Held: 0.000073
# [DEBUG] Hold position at 2024-04-06 20:00:00 - Price: 68161.00, Pred: 0.460, BTC Held: 0.000073
# [DEBUG] Hold position at 2024-04-06 21:00:00 - Price: 68314.00, Pred: 0.451, BTC Held: 0.000073
# [DEBUG] Hold position at 2024-04-06 22:00:00 - Price: 68328.00, Pred: 0.472, BTC Held: 0.000073
# [DEBUG] Hold position at 2024-04-06 23:00:00 - Price: 68280.00, Pred: 0.489, BTC Held: 0.000073
# [DEBUG] Hold position at 2024-04-07 00:00:00 - Price: 68412.00, Pred: 0.473, BTC Held: 0.000073
# [DEBUG] Hold position at 2024-04-07 01:00:00 - Price: 68331.00, Pred: 0.488, BTC Held: 0.000073
# [DEBUG] Hold position at 2024-04-07 02:00:00 - Price: 69070.00, Pred: 0.477, BTC Held: 0.000073
# [DEBUG] Hold position at 2024-04-07 03:00:00 - Price: 68917.00, Pred: 0.497, BTC Held: 0.000073
# [DEBUG] Hold position at 2024-04-07 04:00:00 - Price: 69032.00, Pred: 0.466, BTC Held: 0.000073
# [DEBUG] Hold position at 2024-04-07 05:00:00 - Price: 69570.00, Pred: 0.487, BTC Held: 0.000073
# [DEBUG] Hold position at 2024-04-07 06:00:00 - Price: 69338.00, Pred: 0.472, BTC Held: 0.000073
# [DEBUG] Hold position at 2024-04-07 07:00:00 - Price: 69441.00, Pred: 0.487, BTC Held: 0.000073
# [DEBUG] Hold position at 2024-04-07 08:00:00 - Price: 69342.00, Pred: 0.469, BTC Held: 0.000073
# [DEBUG] Hold position at 2024-04-07 09:00:00 - Price: 69421.00, Pred: 0.480, BTC Held: 0.000073
# [DEBUG] Hold position at 2024-04-07 10:00:00 - Price: 69262.00, Pred: 0.478, BTC Held: 0.000073
# [DEBUG] Hold position at 2024-04-07 11:00:00 - Price: 69390.00, Pred: 0.487, BTC Held: 0.000073
# [DEBUG] Buy executed at 2024-04-07 12:00:00 - Price: 69411.00, Pred: 0.612, BTC Held: 0.072057
# [DEBUG] Hold position at 2024-04-07 13:00:00 - Price: 69318.00, Pred: 0.511, BTC Held: 0.072057
# [DEBUG] Hold position at 2024-04-07 14:00:00 - Price: 69348.00, Pred: 0.503, BTC Held: 0.072057
# [DEBUG] Hold position at 2024-04-07 15:00:00 - Price: 69374.00, Pred: 0.475, BTC Held: 0.072057
# [DEBUG] Hold position at 2024-04-07 16:00:00 - Price: 69366.00, Pred: 0.491, BTC Held: 0.072057
# [DEBUG] Hold position at 2024-04-07 17:00:00 - Price: 69372.00, Pred: 0.492, BTC Held: 0.072057
# [DEBUG] Hold position at 2024-04-07 18:00:00 - Price: 69587.00, Pred: 0.504, BTC Held: 0.072057
# [DEBUG] Hold position at 2024-04-07 19:00:00 - Price: 69568.00, Pred: 0.489, BTC Held: 0.072057
# [DEBUG] Hold position at 2024-04-07 20:00:00 - Price: 70069.00, Pred: 0.477, BTC Held: 0.072057
# [DEBUG] Hold position at 2024-04-07 21:00:00 - Price: 69809.00, Pred: 0.463, BTC Held: 0.072057
# [DEBUG] Hold position at 2024-04-07 22:00:00 - Price: 69409.00, Pred: 0.494, BTC Held: 0.072057
# [DEBUG] Hold position at 2024-04-07 23:00:00 - Price: 69079.00, Pred: 0.482, BTC Held: 0.072057
# [DEBUG] Hold position at 2024-04-08 00:00:00 - Price: 69322.00, Pred: 0.477, BTC Held: 0.072057
# [DEBUG] Hold position at 2024-04-08 01:00:00 - Price: 69046.00, Pred: 0.506, BTC Held: 0.072057
# [DEBUG] Hold position at 2024-04-08 02:00:00 - Price: 69214.00, Pred: 0.497, BTC Held: 0.072057
# [DEBUG] Hold position at 2024-04-08 03:00:00 - Price: 69358.00, Pred: 0.482, BTC Held: 0.072057
# [DEBUG] Hold position at 2024-04-08 04:00:00 - Price: 69340.00, Pred: 0.482, BTC Held: 0.072057
# [DEBUG] Hold position at 2024-04-08 05:00:00 - Price: 69444.00, Pred: 0.463, BTC Held: 0.072057
# [DEBUG] Hold position at 2024-04-08 06:00:00 - Price: 69225.00, Pred: 0.498, BTC Held: 0.072057
# [DEBUG] Hold position at 2024-04-08 07:00:00 - Price: 69457.00, Pred: 0.464, BTC Held: 0.072057
# [DEBUG] Hold position at 2024-04-08 08:00:00 - Price: 69395.00, Pred: 0.505, BTC Held: 0.072057
# [DEBUG] Hold position at 2024-04-08 09:00:00 - Price: 69719.00, Pred: 0.473, BTC Held: 0.072057
# [DEBUG] Hold position at 2024-04-08 10:00:00 - Price: 69803.00, Pred: 0.486, BTC Held: 0.072057
# [DEBUG] Hold position at 2024-04-08 11:00:00 - Price: 70702.00, Pred: 0.484, BTC Held: 0.072057
# [DEBUG] Hold position at 2024-04-08 12:00:00 - Price: 71948.00, Pred: 0.475, BTC Held: 0.072057
# [DEBUG] Hold position at 2024-04-08 13:00:00 - Price: 72165.00, Pred: 0.481, BTC Held: 0.072057
# [DEBUG] Hold position at 2024-04-08 14:00:00 - Price: 72302.00, Pred: 0.476, BTC Held: 0.072057
# [DEBUG] Hold position at 2024-04-08 15:00:00 - Price: 72370.00, Pred: 0.471, BTC Held: 0.072057
# [DEBUG] Hold position at 2024-04-08 16:00:00 - Price: 72154.00, Pred: 0.492, BTC Held: 0.072057
# [DEBUG] Hold position at 2024-04-08 17:00:00 - Price: 71939.00, Pred: 0.459, BTC Held: 0.072057
# [DEBUG] Hold position at 2024-04-08 18:00:00 - Price: 71708.00, Pred: 0.487, BTC Held: 0.072057
# [DEBUG] Hold position at 2024-04-08 19:00:00 - Price: 71781.00, Pred: 0.477, BTC Held: 0.072057
# [DEBUG] Hold position at 2024-04-08 20:00:00 - Price: 71749.00, Pred: 0.485, BTC Held: 0.072057
# [DEBUG] Hold position at 2024-04-08 21:00:00 - Price: 71709.00, Pred: 0.480, BTC Held: 0.072057
# [DEBUG] Hold position at 2024-04-08 22:00:00 - Price: 71929.00, Pred: 0.474, BTC Held: 0.072057
# [DEBUG] Hold position at 2024-04-08 23:00:00 - Price: 71738.00, Pred: 0.470, BTC Held: 0.072057
# [DEBUG] Hold position at 2024-04-09 00:00:00 - Price: 71706.00, Pred: 0.467, BTC Held: 0.072057
# [DEBUG] Hold position at 2024-04-09 01:00:00 - Price: 71685.00, Pred: 0.489, BTC Held: 0.072057
# [DEBUG] Hold position at 2024-04-09 02:00:00 - Price: 71913.00, Pred: 0.491, BTC Held: 0.072057
# [DEBUG] Hold position at 2024-04-09 03:00:00 - Price: 71613.00, Pred: 0.484, BTC Held: 0.072057
# [DEBUG] Hold position at 2024-04-09 04:00:00 - Price: 71422.00, Pred: 0.471, BTC Held: 0.072057
# [DEBUG] Hold position at 2024-04-09 05:00:00 - Price: 71286.00, Pred: 0.471, BTC Held: 0.072057
# [DEBUG] Hold position at 2024-04-09 06:00:00 - Price: 71471.00, Pred: 0.478, BTC Held: 0.072057
# [DEBUG] Partial Sell executed at 2024-04-09 07:00:00 - Price: 71277.00, Pred: 0.445, Sold: 0.036029 BTC, Remaining: 0.036029 BTC
# [DEBUG] Hold position at 2024-04-09 08:00:00 - Price: 71203.00, Pred: 0.461, BTC Held: 0.036029
# [DEBUG] Hold position at 2024-04-09 09:00:00 - Price: 71058.00, Pred: 0.496, BTC Held: 0.036029
# [DEBUG] Hold position at 2024-04-09 10:00:00 - Price: 70772.00, Pred: 0.477, BTC Held: 0.036029
# ...
# [DEBUG] Partial Sell executed at 2025-03-04 14:00:00 - Price: 83109.00, Pred: 0.443, Sold: 0.022403 BTC, Remaining: 0.022403 BTC
# [DEBUG] Hold position at 2025-03-04 15:00:00 - Price: 82922.00, Pred: 0.490, BTC Held: 0.022403
# [DEBUG] Hold position at 2025-03-04 16:00:00 - Price: 83505.00, Pred: 0.466, BTC Held: 0.022403
# [DEBUG] Hold position at 2025-03-04 17:00:00 - Price: 85418.00, Pred: 0.501, BTC Held: 0.022403
# [DEBUG] Hold position at 2025-03-04 18:00:00 - Price: 86772.00, Pred: 0.496, BTC Held: 0.022403
# [DEBUG] Hold position at 2025-03-04 19:00:00 - Price: 88221.00, Pred: 0.456, BTC Held: 0.022403
# [DEBUG] Hold position at 2025-03-04 20:00:00 - Price: 86761.00, Pred: 0.517, BTC Held: 0.022403
# [DEBUG] Hold position at 2025-03-04 21:00:00 - Price: 87506.00, Pred: 0.470, BTC Held: 0.022403
# [DEBUG] Hold position at 2025-03-04 22:00:00 - Price: 87425.00, Pred: 0.465, BTC Held: 0.022403
# [DEBUG] Hold position at 2025-03-04 23:00:00 - Price: 87240.00, Pred: 0.490, BTC Held: 0.022403
# [DEBUG] Hold position at 2025-03-05 00:00:00 - Price: 87172.00, Pred: 0.512, BTC Held: 0.022403
# [DEBUG] Buy executed at 2025-03-05 01:00:00 - Price: 87172.00, Pred: 0.619, BTC Held: 0.097748
# [DEBUG] Buy executed at 2025-03-05 02:00:00 - Price: 87172.00, Pred: 0.607, BTC Held: 0.135420
# [DEBUG] Buy executed at 2025-03-05 03:00:00 - Price: 87172.00, Pred: 0.649, BTC Held: 0.154256
# [DEBUG] Buy executed at 2025-03-05 04:00:00 - Price: 87172.00, Pred: 0.619, BTC Held: 0.163674
# [DEBUG] Buy executed at 2025-03-05 05:00:00 - Price: 87172.00, Pred: 0.615, BTC Held: 0.168384
# [DEBUG] Buy executed at 2025-03-05 06:00:00 - Price: 87172.00, Pred: 0.601, BTC Held: 0.170738
# [DEBUG] Buy executed at 2025-03-05 07:00:00 - Price: 87172.00, Pred: 0.650, BTC Held: 0.171915
# [DEBUG] Buy executed at 2025-03-05 08:00:00 - Price: 87172.00, Pred: 0.606, BTC Held: 0.172504
# [DEBUG] Buy executed at 2025-03-05 09:00:00 - Price: 87172.00, Pred: 0.614, BTC Held: 0.172798
# [DEBUG] Buy executed at 2025-03-05 10:00:00 - Price: 87172.00, Pred: 0.590, BTC Held: 0.172945
# [DEBUG] Hold position at 2025-03-06 07:00:00 - Price: 91343.00, Pred: 0.488, BTC Held: 0.172945
# [DEBUG] Hold position at 2025-03-06 08:00:00 - Price: 91160.00, Pred: 0.475, BTC Held: 0.172945
# [DEBUG] Hold position at 2025-03-06 09:00:00 - Price: 90749.00, Pred: 0.458, BTC Held: 0.172945
# [DEBUG] Hold position at 2025-03-06 10:00:00 - Price: 91273.00, Pred: 0.467, BTC Held: 0.172945
# [DEBUG] Hold position at 2025-03-06 11:00:00 - Price: 91339.00, Pred: 0.480, BTC Held: 0.172945
# [DEBUG] Hold position at 2025-03-06 12:00:00 - Price: 90131.00, Pred: 0.468, BTC Held: 0.172945
# [DEBUG] Hold position at 2025-03-06 13:00:00 - Price: 89572.00, Pred: 0.474, BTC Held: 0.172945
# [DEBUG] Hold position at 2025-03-06 14:00:00 - Price: 89812.00, Pred: 0.471, BTC Held: 0.172945
# [DEBUG] Hold position at 2025-03-06 15:00:00 - Price: 90847.00, Pred: 0.477, BTC Held: 0.172945
# [DEBUG] Hold position at 2025-03-06 16:00:00 - Price: 89292.00, Pred: 0.464, BTC Held: 0.172945
# [DEBUG] Hold position at 2025-03-06 17:00:00 - Price: 88590.00, Pred: 0.481, BTC Held: 0.172945
# [DEBUG] Hold position at 2025-03-06 18:00:00 - Price: 88399.00, Pred: 0.477, BTC Held: 0.172945
# [DEBUG] Hold position at 2025-03-06 19:00:00 - Price: 88512.00, Pred: 0.471, BTC Held: 0.172945
# [DEBUG] Hold position at 2025-03-06 20:00:00 - Price: 89026.00, Pred: 0.484, BTC Held: 0.172945
# [DEBUG] Hold position at 2025-03-06 21:00:00 - Price: 89875.00, Pred: 0.491, BTC Held: 0.172945
# [DEBUG] Hold position at 2025-03-06 22:00:00 - Price: 90311.00, Pred: 0.486, BTC Held: 0.172945
# [DEBUG] Hold position at 2025-03-06 23:00:00 - Price: 89918.00, Pred: 0.518, BTC Held: 0.172945
# [DEBUG] Partial Sell executed at 2025-03-08 07:00:00 - Price: 86179.00, Pred: 0.447, Sold: 0.086473 BTC, Remaining: 0.086473 BTC
# [DEBUG] Hold position at 2025-03-08 08:00:00 - Price: 86078.00, Pred: 0.456, BTC Held: 0.086473
# [DEBUG] Hold position at 2025-03-08 09:00:00 - Price: 85926.00, Pred: 0.475, BTC Held: 0.086473
# [DEBUG] Hold position at 2025-03-08 10:00:00 - Price: 86101.00, Pred: 0.529, BTC Held: 0.086473
# [DEBUG] Hold position at 2025-03-08 11:00:00 - Price: 85922.00, Pred: 0.470, BTC Held: 0.086473
# [DEBUG] Hold position at 2025-03-08 12:00:00 - Price: 86190.00, Pred: 0.457, BTC Held: 0.086473
# [DEBUG] Hold position at 2025-03-08 13:00:00 - Price: 86299.00, Pred: 0.495, BTC Held: 0.086473
# [DEBUG] Hold position at 2025-03-08 14:00:00 - Price: 86330.00, Pred: 0.502, BTC Held: 0.086473
# [DEBUG] Hold position at 2025-03-08 15:00:00 - Price: 86367.00, Pred: 0.479, BTC Held: 0.086473
# [DEBUG] Hold position at 2025-03-08 16:00:00 - Price: 86113.00, Pred: 0.497, BTC Held: 0.086473
# [DEBUG] Hold position at 2025-03-08 17:00:00 - Price: 85927.00, Pred: 0.508, BTC Held: 0.086473
# [DEBUG] Hold position at 2025-03-08 18:00:00 - Price: 86019.00, Pred: 0.477, BTC Held: 0.086473
# [DEBUG] Hold position at 2025-03-08 19:00:00 - Price: 86199.00, Pred: 0.503, BTC Held: 0.086473
# [DEBUG] Hold position at 2025-03-08 20:00:00 - Price: 86247.00, Pred: 0.474, BTC Held: 0.086473
# [DEBUG] Hold position at 2025-03-08 21:00:00 - Price: 86211.00, Pred: 0.493, BTC Held: 0.086473
# [DEBUG] Hold position at 2025-03-08 22:00:00 - Price: 86314.00, Pred: 0.538, BTC Held: 0.086473
# [DEBUG] Hold position at 2025-03-08 23:00:00 - Price: 86192.00, Pred: 0.507, BTC Held: 0.086473
# [DEBUG] Buy executed at 2025-03-09 00:00:00 - Price: 86182.00, Pred: 0.626, BTC Held: 0.129730
# [DEBUG] Buy executed at 2025-03-09 01:00:00 - Price: 86182.00, Pred: 0.610, BTC Held: 0.151359
# [DEBUG] Buy executed at 2025-03-09 02:00:00 - Price: 86182.00, Pred: 0.621, BTC Held: 0.162173
# [DEBUG] Buy executed at 2025-03-09 03:00:00 - Price: 86182.00, Pred: 0.603, BTC Held: 0.167580
# [DEBUG] Buy executed at 2025-03-09 04:00:00 - Price: 86182.00, Pred: 0.609, BTC Held: 0.170284
# [DEBUG] Buy executed at 2025-03-09 05:00:00 - Price: 86182.00, Pred: 0.607, BTC Held: 0.171636
# [DEBUG] Buy executed at 2025-03-09 06:00:00 - Price: 86182.00, Pred: 0.625, BTC Held: 0.172312
# [DEBUG] Buy executed at 2025-03-09 07:00:00 - Price: 86182.00, Pred: 0.614, BTC Held: 0.172650
# [DEBUG] Buy executed at 2025-03-09 08:00:00 - Price: 86182.00, Pred: 0.611, BTC Held: 0.172819
# [DEBUG] Hold position at 2025-03-10 07:00:00 - Price: 82317.00, Pred: 0.506, BTC Held: 0.172819
# [DEBUG] Hold position at 2025-03-10 08:00:00 - Price: 81371.00, Pred: 0.481, BTC Held: 0.172819
# [DEBUG] Hold position at 2025-03-10 09:00:00 - Price: 82488.00, Pred: 0.507, BTC Held: 0.172819
# [DEBUG] Partial Sell executed at 2025-03-10 10:00:00 - Price: 82307.00, Pred: 0.441, Sold: 0.086409 BTC, Remaining: 0.086409 BTC
# [DEBUG] Hold position at 2025-03-10 11:00:00 - Price: 83483.00, Pred: 0.503, BTC Held: 0.086409
# [DEBUG] Hold position at 2025-03-10 12:00:00 - Price: 83267.00, Pred: 0.478, BTC Held: 0.086409
# [DEBUG] Hold position at 2025-03-10 13:00:00 - Price: 81520.00, Pred: 0.461, BTC Held: 0.086409
# [DEBUG] Hold position at 2025-03-10 14:00:00 - Price: 79807.00, Pred: 0.488, BTC Held: 0.086409
# [DEBUG] Hold position at 2025-03-10 15:00:00 - Price: 80004.00, Pred: 0.489, BTC Held: 0.086409
# [DEBUG] Hold position at 2025-03-10 16:00:00 - Price: 78969.00, Pred: 0.480, BTC Held: 0.086409
# [DEBUG] Hold position at 2025-03-10 17:00:00 - Price: 78424.00, Pred: 0.466, BTC Held: 0.086409
# [DEBUG] Hold position at 2025-03-10 18:00:00 - Price: 77600.00, Pred: 0.489, BTC Held: 0.086409
# [DEBUG] Hold position at 2025-03-10 19:00:00 - Price: 78938.00, Pred: 0.494, BTC Held: 0.086409
# [DEBUG] Hold position at 2025-03-10 20:00:00 - Price: 79260.00, Pred: 0.469, BTC Held: 0.086409
# [DEBUG] Hold position at 2025-03-10 21:00:00 - Price: 79470.00, Pred: 0.475, BTC Held: 0.086409
# [DEBUG] Hold position at 2025-03-10 22:00:00 - Price: 79517.00, Pred: 0.476, BTC Held: 0.086409
# [DEBUG] Hold position at 2025-03-10 23:00:00 - Price: 78561.00, Pred: 0.480, BTC Held: 0.086409
# [DEBUG] Hold position at 2025-03-11 00:00:00 - Price: 78763.00, Pred: 0.484, BTC Held: 0.086409
# [DEBUG] Buy executed at 2025-03-11 01:00:00 - Price: 78763.00, Pred: 0.614, BTC Held: 0.131596
# [DEBUG] Buy executed at 2025-03-11 02:00:00 - Price: 78763.00, Pred: 0.591, BTC Held: 0.154190
# [DEBUG] Buy executed at 2025-03-11 03:00:00 - Price: 78763.00, Pred: 0.615, BTC Held: 0.165486
# [DEBUG] Buy executed at 2025-03-11 04:00:00 - Price: 78763.00, Pred: 0.598, BTC Held: 0.171135
# [DEBUG] Buy executed at 2025-03-11 05:00:00 - Price: 78763.00, Pred: 0.617, BTC Held: 0.173959
# [DEBUG] Buy executed at 2025-03-11 06:00:00 - Price: 78763.00, Pred: 0.584, BTC Held: 0.175371
# [DEBUG] Buy executed at 2025-03-11 07:00:00 - Price: 78763.00, Pred: 0.613, BTC Held: 0.176077
# [DEBUG] Buy executed at 2025-03-11 08:00:00 - Price: 78763.00, Pred: 0.606, BTC Held: 0.176430
# [DEBUG] Buy executed at 2025-03-11 09:00:00 - Price: 78763.00, Pred: 0.605, BTC Held: 0.176607
# [DEBUG] Hold position at 2025-03-12 07:00:00 - Price: 82409.00, Pred: 0.489, BTC Held: 0.176607
# [DEBUG] Hold position at 2025-03-12 08:00:00 - Price: 82678.00, Pred: 0.488, BTC Held: 0.176607
# [DEBUG] Hold position at 2025-03-12 09:00:00 - Price: 82643.00, Pred: 0.492, BTC Held: 0.176607
# [DEBUG] Hold position at 2025-03-12 10:00:00 - Price: 82461.00, Pred: 0.481, BTC Held: 0.176607
# [DEBUG] Hold position at 2025-03-12 11:00:00 - Price: 82983.00, Pred: 0.477, BTC Held: 0.176607
# [DEBUG] Hold position at 2025-03-12 12:00:00 - Price: 84048.00, Pred: 0.488, BTC Held: 0.176607
# [DEBUG] Hold position at 2025-03-12 13:00:00 - Price: 82656.00, Pred: 0.450, BTC Held: 0.176607
# [DEBUG] Hold position at 2025-03-12 14:00:00 - Price: 81478.00, Pred: 0.484, BTC Held: 0.176607
# [DEBUG] Hold position at 2025-03-12 15:00:00 - Price: 81713.00, Pred: 0.497, BTC Held: 0.176607
# [DEBUG] Hold position at 2025-03-12 16:00:00 - Price: 81958.00, Pred: 0.475, BTC Held: 0.176607
# [DEBUG] Hold position at 2025-03-12 17:00:00 - Price: 81839.00, Pred: 0.501, BTC Held: 0.176607
# [DEBUG] Hold position at 2025-03-12 18:00:00 - Price: 82628.00, Pred: 0.460, BTC Held: 0.176607
# [DEBUG] Hold position at 2025-03-12 19:00:00 - Price: 82930.00, Pred: 0.501, BTC Held: 0.176607
# [DEBUG] Hold position at 2025-03-12 20:00:00 - Price: 83124.00, Pred: 0.506, BTC Held: 0.176607
# [DEBUG] Hold position at 2025-03-12 21:00:00 - Price: 83061.00, Pred: 0.481, BTC Held: 0.176607
# [DEBUG] Hold position at 2025-03-12 22:00:00 - Price: 83651.00, Pred: 0.495, BTC Held: 0.176607
# [DEBUG] Hold position at 2025-03-12 23:00:00 - Price: 83620.00, Pred: 0.472, BTC Held: 0.176607
# [DEBUG] Hold position at 2025-03-13 15:00:00 - Price: 83677.00, Pred: 0.498, BTC Held: 0.176607
# [DEBUG] Hold position at 2025-03-13 20:00:00 - Price: 83677.00, Pred: 0.548, BTC Held: 0.176607
# [DEBUG] Hold position at 2025-03-14 07:00:00 - Price: 82180.00, Pred: 0.466, BTC Held: 0.176607
# [DEBUG] Hold position at 2025-03-14 08:00:00 - Price: 82573.00, Pred: 0.488, BTC Held: 0.176607
# [DEBUG] Hold position at 2025-03-14 09:00:00 - Price: 82760.00, Pred: 0.491, BTC Held: 0.176607
# [DEBUG] Partial Sell executed at 2025-03-14 10:00:00 - Price: 83034.00, Pred: 0.445, Sold: 0.088303 BTC, Remaining: 0.088303 BTC
# [DEBUG] Hold position at 2025-03-14 11:00:00 - Price: 83248.00, Pred: 0.461, BTC Held: 0.088303
# [DEBUG] Hold position at 2025-03-14 12:00:00 - Price: 83406.00, Pred: 0.473, BTC Held: 0.088303
# [DEBUG] Hold position at 2025-03-14 13:00:00 - Price: 83622.00, Pred: 0.494, BTC Held: 0.088303
# [DEBUG] Partial Sell executed at 2025-03-14 14:00:00 - Price: 83502.00, Pred: 0.438, Sold: 0.044152 BTC, Remaining: 0.044152 BTC
# [DEBUG] Hold position at 2025-03-14 15:00:00 - Price: 84724.00, Pred: 0.462, BTC Held: 0.044152
# [DEBUG] Hold position at 2025-03-14 16:00:00 - Price: 84786.00, Pred: 0.493, BTC Held: 0.044152
# [DEBUG] Hold position at 2025-03-14 17:00:00 - Price: 84338.00, Pred: 0.490, BTC Held: 0.044152
# [DEBUG] Hold position at 2025-03-14 18:00:00 - Price: 84574.00, Pred: 0.474, BTC Held: 0.044152
# [DEBUG] Hold position at 2025-03-14 19:00:00 - Price: 84559.00, Pred: 0.480, BTC Held: 0.044152
# [DEBUG] Hold position at 2025-03-14 20:00:00 - Price: 84137.00, Pred: 0.475, BTC Held: 0.044152
# [DEBUG] Hold position at 2025-03-14 21:00:00 - Price: 84205.00, Pred: 0.501, BTC Held: 0.044152
# [DEBUG] Hold position at 2025-03-14 22:00:00 - Price: 84449.00, Pred: 0.463, BTC Held: 0.044152
# [DEBUG] Hold position at 2025-03-14 23:00:00 - Price: 83975.00, Pred: 0.484, BTC Held: 0.044152
# [DEBUG] Buy, hold, sell backtest loop finished.
# [DEBUG] Finished _run_strategy (Buy, Hold, Sell). Returning results DataFrame. Trades: 371
# [DEBUG] Strategy simulation finished, results DataFrame assigned.
#
# Final backtest simulation complete.
# Sample of final backtest results DataFrame (first 5 rows):
#                      transactions_count_flow_1  current_regime  \
# datetime
# 2024-03-19 19:00:00                        419               0
# 2024-03-19 20:00:00                        275               4
# 2024-03-19 21:00:00                        265               4
# 2024-03-19 22:00:00                        518               5
# 2024-03-19 23:00:00                        271               0
#
#                      predicted_next_regime  next_regime_probability  \
# datetime
# 2024-03-19 19:00:00                      0                 0.523820
# 2024-03-19 20:00:00                      4                 0.479277
# 2024-03-19 21:00:00                      4                 0.479277
# 2024-03-19 22:00:00                      5                 0.462460
# 2024-03-19 23:00:00                      0                 0.523820
#
#                         start_time  inflow_mean  inflow_mean_ma7  \
# datetime
# 2024-03-19 19:00:00  1710874800000     1.103701         1.503474
# 2024-03-19 20:00:00  1710878400000     0.790302         1.506955
# 2024-03-19 21:00:00  1710882000000     0.357682         1.385425
# 2024-03-19 22:00:00  1710885600000     0.573689         1.055405
# 2024-03-19 23:00:00  1710889200000     2.813808         1.133453
#
#                      inflow_top10  inflow_total  outflow_mean  ...  \
# datetime                                                       ...
# 2024-03-19 19:00:00   4216.807021   4304.432797     18.478542  ...
# 2024-03-19 20:00:00   2377.173031   2509.209044      5.122261  ...
# 2024-03-19 21:00:00    752.256818    777.958694      7.749355  ...
# 2024-03-19 22:00:00   2883.575312   3182.826458      9.204605  ...
# 2024-03-19 23:00:00   7729.321411   7847.709765      8.935983  ...
#
#                      portfolio_value  trade  trade_size  entry_price  \
# datetime
# 2024-03-19 19:00:00          10000.0      0         0.0          NaN
# 2024-03-19 20:00:00          10000.0      0         0.0          NaN
# 2024-03-19 21:00:00          10000.0      0         0.0          NaN
# 2024-03-19 22:00:00          10000.0      0         0.0          NaN
# 2024-03-19 23:00:00          10000.0      0         0.0          NaN
#
#                      trade_result  pnl  signal  transaction_fee  daily_return  \
# datetime
# 2024-03-19 19:00:00           NaN  0.0       0              0.0           0.0
# 2024-03-19 20:00:00           NaN  0.0       0              0.0           0.0
# 2024-03-19 21:00:00           NaN -0.0       0              0.0           0.0
# 2024-03-19 22:00:00           NaN -0.0       0              0.0           0.0
# 2024-03-19 23:00:00           NaN -0.0       0              0.0           0.0
#
#                      cumulative_return
# datetime
# 2024-03-19 19:00:00                0.0
# 2024-03-19 20:00:00                0.0
# 2024-03-19 21:00:00                0.0
# 2024-03-19 22:00:00                0.0
# 2024-03-19 23:00:00                0.0
#
# [5 rows x 81 columns]

# %%
# --- Step 10b: Running Backtest on Validation Set ---
# This step uses the fixed BACKTESTING_PARAMS defined earlier, similar to the test set run.
print("\n--- Step 10b: Running Backtest on Validation Set ---") #

val_backtest = None # Initialize for validation backtest
val_backtest_results_df = None # Initialize for validation backtest results

# Ensure we have the necessary components for the VALIDATION set backtest
# Use val_ensemble_pred
predictions_for_val_backtest = val_ensemble_pred
if predictions_for_val_backtest is None:
    print("Error: No predictions available for the validation set. Cannot run backtest.")
    # Optional: Add fallback logic here if needed
else:
    # Check if other necessary data exists
    if X_val is not None and not X_val.empty and df_ready is not None:
        try:
            # Prepare the VALIDATION data slice
            if not isinstance(X_val.index, pd.DatetimeIndex):
                raise ValueError("X_val index must be DatetimeIndex for backtesting.")

            # Select the relevant slice from df_ready using the validation set index
            val_data_for_backtest = df_ready.loc[X_val.index].copy() #

            # Ensure predictions are a pandas Series with the same index as val_data_for_backtest
            if not isinstance(predictions_for_val_backtest, pd.Series):
                if len(predictions_for_val_backtest) == len(val_data_for_backtest.index):
                    val_predictions_series = pd.Series(predictions_for_val_backtest, index=val_data_for_backtest.index) #
                else:
                    raise ValueError("Length mismatch between validation predictions and validation data index.")
            else:
                # Reindex predictions if necessary
                val_predictions_series = predictions_for_val_backtest.reindex(val_data_for_backtest.index, fill_value=0.5) # Fill missing with neutral

            # Verify necessary columns exist in the slice
            required_cols_backtest = [PRICE_COLUMN] # Add other columns if needed
            missing_cols = [col for col in required_cols_backtest if col not in val_data_for_backtest.columns]
            if missing_cols:
                raise ValueError(f"Missing required columns for backtest in val_data_for_backtest: {missing_cols}")


            print(f"\nRunning validation backtest on {len(val_data_for_backtest)} validation samples...") #
            print("Using fixed parameters and validation set predictions.") #
            print("Backtesting Parameters Used:")
            for key, value in BACKTESTING_PARAMS.items():
                print(f"- {key}: {value}")

            # Instantiate and run the backtest strategy using the fixed BACKTESTING_PARAMS
            # Using the same OnChainBitcoinStrategy class as the test set example
            val_backtest = OnChainBitcoinStrategy(
                df=val_data_for_backtest,         # Pass the data slice for the validation period
                predictions=val_predictions_series, # Pass predictions aligned to validation data
                params=BACKTESTING_PARAMS.copy(), # Use the fixed global parameters
                price_col=PRICE_COLUMN          # Specify the price column
            ) #

            if val_backtest.results is not None and not val_backtest.results.empty: #
                val_backtest_results_df = val_backtest.results # Store the validation results df
                print("\nValidation backtest simulation complete.") #
                print("Sample of validation backtest results DataFrame (first 5 rows):") #
                print(val_backtest_results_df.head()) #
            else: #
                print("\nValidation backtest failed to produce results.") #
                val_backtest_results_df = None # Ensure it's None

        except Exception as e: #
            print(f"ERROR occurred during the validation backtesting run: {e}") #
            traceback.print_exc() #
            val_backtest = None # Ensure val_backtest object is None if it failed
            val_backtest_results_df = None
    else: #
        print("Skipping validation backtest run: Missing validation set data (X_val) or original data (df_ready).") #

# Final check if val_backtest object exists
if val_backtest is None:
    print("\nValidation Backtest object was not successfully created. Evaluation and plotting for validation might be skipped.")
# Out:
# --- Step 10b: Running Backtest on Validation Set ---
#
# Running validation backtest on 6484 validation samples...
# Using fixed parameters and validation set predictions.
# Backtesting Parameters Used:
# - INITIAL_CASH: 10000
# - COMMISSION_PERC: 0.0006
# - BASE_POSITION_SIZE: 0.5
# [DEBUG] OnChainBitcoinStrategy.__init__ called (Buy, Hold, Sell Mode).
# [DEBUG] Initializing strategy simulation (_run_strategy - Buy, Hold, Sell)...
# [DEBUG] _run_strategy (Buy, Hold, Sell Mode) starting...
# [DEBUG] Starting buy, hold, sell backtest loop for 6484 steps...
# [DEBUG] Hold position at 2023-06-23 16:00:00 - Price: 30110.00, Pred: 0.509, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-23 17:00:00 - Price: 30088.00, Pred: 0.501, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-23 18:00:00 - Price: 30291.00, Pred: 0.504, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-23 19:00:00 - Price: 31243.00, Pred: 0.530, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-23 20:00:00 - Price: 31109.00, Pred: 0.519, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-23 21:00:00 - Price: 31259.00, Pred: 0.515, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-23 22:00:00 - Price: 30964.00, Pred: 0.506, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-23 23:00:00 - Price: 30905.00, Pred: 0.515, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-24 00:00:00 - Price: 30932.00, Pred: 0.512, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-24 01:00:00 - Price: 30681.00, Pred: 0.490, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-24 02:00:00 - Price: 30671.00, Pred: 0.510, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-24 03:00:00 - Price: 30716.00, Pred: 0.500, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-24 04:00:00 - Price: 30506.00, Pred: 0.504, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-24 05:00:00 - Price: 30642.00, Pred: 0.506, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-24 06:00:00 - Price: 30783.00, Pred: 0.506, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-24 07:00:00 - Price: 30752.00, Pred: 0.529, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-24 08:00:00 - Price: 30725.00, Pred: 0.514, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-24 09:00:00 - Price: 30745.00, Pred: 0.503, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-24 10:00:00 - Price: 30715.00, Pred: 0.513, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-24 11:00:00 - Price: 30581.00, Pred: 0.515, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-24 12:00:00 - Price: 30625.00, Pred: 0.503, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-24 13:00:00 - Price: 30638.00, Pred: 0.497, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-24 14:00:00 - Price: 30762.00, Pred: 0.497, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-24 15:00:00 - Price: 30694.00, Pred: 0.495, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-24 16:00:00 - Price: 30709.00, Pred: 0.519, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-24 17:00:00 - Price: 30670.00, Pred: 0.515, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-24 18:00:00 - Price: 30707.00, Pred: 0.487, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-24 19:00:00 - Price: 30415.00, Pred: 0.516, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-24 20:00:00 - Price: 30523.00, Pred: 0.513, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-24 21:00:00 - Price: 30589.00, Pred: 0.490, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-24 22:00:00 - Price: 30656.00, Pred: 0.500, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-24 23:00:00 - Price: 30646.00, Pred: 0.509, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-25 00:00:00 - Price: 30528.00, Pred: 0.503, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-25 01:00:00 - Price: 30532.00, Pred: 0.517, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-25 02:00:00 - Price: 30543.00, Pred: 0.508, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-25 03:00:00 - Price: 30548.00, Pred: 0.477, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-25 04:00:00 - Price: 30533.00, Pred: 0.519, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-25 05:00:00 - Price: 30618.00, Pred: 0.489, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-25 06:00:00 - Price: 30644.00, Pred: 0.475, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-25 07:00:00 - Price: 30761.00, Pred: 0.490, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-25 08:00:00 - Price: 30901.00, Pred: 0.501, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-25 09:00:00 - Price: 30869.00, Pred: 0.489, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-25 10:00:00 - Price: 30896.00, Pred: 0.492, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-25 11:00:00 - Price: 30743.00, Pred: 0.505, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-25 12:00:00 - Price: 30748.00, Pred: 0.493, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-25 13:00:00 - Price: 30693.00, Pred: 0.498, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-25 14:00:00 - Price: 30641.00, Pred: 0.516, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-25 15:00:00 - Price: 30721.00, Pred: 0.497, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-25 16:00:00 - Price: 30677.00, Pred: 0.516, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-25 17:00:00 - Price: 30686.00, Pred: 0.511, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-25 18:00:00 - Price: 30564.00, Pred: 0.506, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-25 19:00:00 - Price: 30596.00, Pred: 0.510, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-25 20:00:00 - Price: 30605.00, Pred: 0.516, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-25 21:00:00 - Price: 30542.00, Pred: 0.490, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-25 22:00:00 - Price: 30473.00, Pred: 0.512, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-25 23:00:00 - Price: 30443.00, Pred: 0.466, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-26 00:00:00 - Price: 30390.00, Pred: 0.528, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-26 01:00:00 - Price: 30454.00, Pred: 0.506, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-26 02:00:00 - Price: 30511.00, Pred: 0.535, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-26 03:00:00 - Price: 30477.00, Pred: 0.500, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-26 04:00:00 - Price: 30417.00, Pred: 0.519, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-26 05:00:00 - Price: 30190.00, Pred: 0.514, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-26 06:00:00 - Price: 30235.00, Pred: 0.518, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-26 07:00:00 - Price: 30301.00, Pred: 0.522, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-26 08:00:00 - Price: 30252.00, Pred: 0.495, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-26 09:00:00 - Price: 30221.00, Pred: 0.521, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-26 10:00:00 - Price: 30476.00, Pred: 0.503, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-26 11:00:00 - Price: 30410.00, Pred: 0.526, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-26 12:00:00 - Price: 30405.00, Pred: 0.486, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-26 13:00:00 - Price: 30266.00, Pred: 0.505, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-26 14:00:00 - Price: 30270.00, Pred: 0.514, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-26 15:00:00 - Price: 30327.00, Pred: 0.484, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-26 16:00:00 - Price: 30355.00, Pred: 0.522, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-26 17:00:00 - Price: 30648.00, Pred: 0.518, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-26 18:00:00 - Price: 30399.00, Pred: 0.514, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-26 19:00:00 - Price: 30425.00, Pred: 0.509, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-26 20:00:00 - Price: 30105.00, Pred: 0.512, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-26 21:00:00 - Price: 30090.00, Pred: 0.504, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-26 22:00:00 - Price: 30213.00, Pred: 0.522, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-26 23:00:00 - Price: 30254.00, Pred: 0.521, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-27 00:00:00 - Price: 30156.00, Pred: 0.500, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-27 01:00:00 - Price: 30178.00, Pred: 0.517, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-27 02:00:00 - Price: 30235.00, Pred: 0.518, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-27 03:00:00 - Price: 30274.00, Pred: 0.542, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-27 04:00:00 - Price: 30356.00, Pred: 0.521, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-27 05:00:00 - Price: 30380.00, Pred: 0.508, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-27 06:00:00 - Price: 30491.00, Pred: 0.519, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-27 07:00:00 - Price: 30374.00, Pred: 0.500, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-27 08:00:00 - Price: 30354.00, Pred: 0.528, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-27 09:00:00 - Price: 30325.00, Pred: 0.478, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-27 10:00:00 - Price: 30328.00, Pred: 0.517, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-27 11:00:00 - Price: 30410.00, Pred: 0.495, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-27 12:00:00 - Price: 30394.00, Pred: 0.521, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-27 13:00:00 - Price: 30375.00, Pred: 0.477, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-27 14:00:00 - Price: 30652.00, Pred: 0.509, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-27 15:00:00 - Price: 30726.00, Pred: 0.509, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-27 16:00:00 - Price: 30714.00, Pred: 0.516, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-27 17:00:00 - Price: 30612.00, Pred: 0.505, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-27 18:00:00 - Price: 30823.00, Pred: 0.520, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-27 19:00:00 - Price: 30500.00, Pred: 0.496, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-27 20:00:00 - Price: 30716.00, Pred: 0.507, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-27 21:00:00 - Price: 30736.00, Pred: 0.510, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-27 22:00:00 - Price: 30691.00, Pred: 0.517, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-27 23:00:00 - Price: 30679.00, Pred: 0.524, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-28 00:00:00 - Price: 30662.00, Pred: 0.506, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-28 01:00:00 - Price: 30720.00, Pred: 0.503, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-28 02:00:00 - Price: 30596.00, Pred: 0.505, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-28 03:00:00 - Price: 30696.00, Pred: 0.506, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-28 04:00:00 - Price: 30618.00, Pred: 0.500, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-28 05:00:00 - Price: 30506.00, Pred: 0.500, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-28 06:00:00 - Price: 30430.00, Pred: 0.522, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-28 07:00:00 - Price: 30458.00, Pred: 0.498, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-28 08:00:00 - Price: 30486.00, Pred: 0.515, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-28 09:00:00 - Price: 30456.00, Pred: 0.471, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-28 10:00:00 - Price: 30378.00, Pred: 0.516, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-28 11:00:00 - Price: 30186.00, Pred: 0.509, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-28 12:00:00 - Price: 30283.00, Pred: 0.486, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-28 13:00:00 - Price: 30297.00, Pred: 0.515, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-28 14:00:00 - Price: 30335.00, Pred: 0.514, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-28 15:00:00 - Price: 30314.00, Pred: 0.502, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-28 16:00:00 - Price: 30103.00, Pred: 0.495, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-28 17:00:00 - Price: 30203.00, Pred: 0.524, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-28 18:00:00 - Price: 30312.00, Pred: 0.498, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-28 19:00:00 - Price: 30415.00, Pred: 0.546, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-28 20:00:00 - Price: 30264.00, Pred: 0.480, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-28 21:00:00 - Price: 30151.00, Pred: 0.495, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-28 22:00:00 - Price: 30182.00, Pred: 0.473, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-28 23:00:00 - Price: 30095.00, Pred: 0.475, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-29 00:00:00 - Price: 30109.00, Pred: 0.506, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-29 01:00:00 - Price: 30140.00, Pred: 0.525, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-29 02:00:00 - Price: 30105.00, Pred: 0.505, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-29 03:00:00 - Price: 30079.00, Pred: 0.518, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-29 04:00:00 - Price: 30077.00, Pred: 0.494, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-29 05:00:00 - Price: 30163.00, Pred: 0.489, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-29 06:00:00 - Price: 30112.00, Pred: 0.514, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-29 07:00:00 - Price: 30164.00, Pred: 0.517, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-29 08:00:00 - Price: 30214.00, Pred: 0.508, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-29 09:00:00 - Price: 30182.00, Pred: 0.510, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-29 10:00:00 - Price: 30230.00, Pred: 0.536, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-29 11:00:00 - Price: 30330.00, Pred: 0.488, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-29 12:00:00 - Price: 30382.00, Pred: 0.509, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-29 13:00:00 - Price: 30432.00, Pred: 0.486, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-29 14:00:00 - Price: 30697.00, Pred: 0.518, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-29 15:00:00 - Price: 30664.00, Pred: 0.512, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-29 16:00:00 - Price: 30620.00, Pred: 0.508, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-29 17:00:00 - Price: 30554.00, Pred: 0.531, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-29 18:00:00 - Price: 30457.00, Pred: 0.492, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-29 19:00:00 - Price: 30473.00, Pred: 0.518, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-29 20:00:00 - Price: 30497.00, Pred: 0.516, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-29 21:00:00 - Price: 30533.00, Pred: 0.522, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-29 22:00:00 - Price: 30553.00, Pred: 0.507, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-29 23:00:00 - Price: 30585.00, Pred: 0.508, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-30 00:00:00 - Price: 30400.00, Pred: 0.512, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-30 01:00:00 - Price: 30418.00, Pred: 0.501, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-30 02:00:00 - Price: 30398.00, Pred: 0.498, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-30 03:00:00 - Price: 30444.00, Pred: 0.512, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-30 04:00:00 - Price: 30442.00, Pred: 0.536, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-30 05:00:00 - Price: 30386.00, Pred: 0.511, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-30 06:00:00 - Price: 30660.00, Pred: 0.496, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-30 07:00:00 - Price: 30734.00, Pred: 0.501, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-30 08:00:00 - Price: 30840.00, Pred: 0.520, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-30 09:00:00 - Price: 30728.00, Pred: 0.510, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-30 10:00:00 - Price: 30661.00, Pred: 0.504, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-30 11:00:00 - Price: 30760.00, Pred: 0.506, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-30 12:00:00 - Price: 30843.00, Pred: 0.510, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-30 13:00:00 - Price: 30770.00, Pred: 0.501, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-30 14:00:00 - Price: 30806.00, Pred: 0.505, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-30 15:00:00 - Price: 30906.00, Pred: 0.520, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-30 16:00:00 - Price: 31002.00, Pred: 0.503, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-30 17:00:00 - Price: 30139.00, Pred: 0.523, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-30 18:00:00 - Price: 30069.00, Pred: 0.521, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-30 19:00:00 - Price: 30066.00, Pred: 0.491, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-30 20:00:00 - Price: 30393.00, Pred: 0.511, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-30 21:00:00 - Price: 30431.00, Pred: 0.508, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-30 22:00:00 - Price: 30346.00, Pred: 0.492, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-06-30 23:00:00 - Price: 30368.00, Pred: 0.493, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-07-01 00:00:00 - Price: 30393.00, Pred: 0.508, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-07-01 01:00:00 - Price: 30473.00, Pred: 0.506, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-07-01 02:00:00 - Price: 30478.00, Pred: 0.487, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-07-01 03:00:00 - Price: 30469.00, Pred: 0.510, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-07-01 04:00:00 - Price: 30474.00, Pred: 0.499, BTC Held: 0.000000
# [DEBUG] Hold position at 2023-07-01 05:00:00 - Price: 30441.00, Pred: 0.474, BTC Held: 0.000000
# [DEBUG] Buy executed at 2023-07-01 06:00:00 - Price: 30427.00, Pred: 0.553, BTC Held: 0.164229
# [DEBUG] Hold position at 2023-07-01 07:00:00 - Price: 30393.00, Pred: 0.453, BTC Held: 0.164229
# [DEBUG] Hold position at 2023-07-01 08:00:00 - Price: 30387.00, Pred: 0.486, BTC Held: 0.164229
# [DEBUG] Hold position at 2023-07-01 09:00:00 - Price: 30422.00, Pred: 0.473, BTC Held: 0.164229
# [DEBUG] Hold position at 2023-07-01 10:00:00 - Price: 30444.00, Pred: 0.497, BTC Held: 0.164229
# [DEBUG] Hold position at 2023-07-01 11:00:00 - Price: 30459.00, Pred: 0.503, BTC Held: 0.164229
# [DEBUG] Hold position at 2023-07-01 12:00:00 - Price: 30436.00, Pred: 0.484, BTC Held: 0.164229
# [DEBUG] Partial Sell executed at 2023-07-01 13:00:00 - Price: 30439.00, Pred: 0.411, Sold: 0.082115 BTC, Remaining: 0.082115 BTC
# [DEBUG] Hold position at 2023-07-01 14:00:00 - Price: 30457.00, Pred: 0.498, BTC Held: 0.082115
# [DEBUG] Hold position at 2023-07-01 15:00:00 - Price: 30523.00, Pred: 0.502, BTC Held: 0.082115
# [DEBUG] Hold position at 2023-07-01 16:00:00 - Price: 30561.00, Pred: 0.509, BTC Held: 0.082115
# [DEBUG] Hold position at 2023-07-01 17:00:00 - Price: 30565.00, Pred: 0.505, BTC Held: 0.082115
# [DEBUG] Hold position at 2023-07-01 18:00:00 - Price: 30608.00, Pred: 0.500, BTC Held: 0.082115
# [DEBUG] Hold position at 2023-07-01 19:00:00 - Price: 30572.00, Pred: 0.497, BTC Held: 0.082115
# [DEBUG] Hold position at 2023-07-01 20:00:00 - Price: 30573.00, Pred: 0.513, BTC Held: 0.082115
# [DEBUG] Hold position at 2023-07-01 21:00:00 - Price: 30576.00, Pred: 0.510, BTC Held: 0.082115
# [DEBUG] Hold position at 2023-07-01 22:00:00 - Price: 30612.00, Pred: 0.523, BTC Held: 0.082115
# [DEBUG] Hold position at 2023-07-01 23:00:00 - Price: 30617.00, Pred: 0.516, BTC Held: 0.082115
# [DEBUG] Hold position at 2023-07-02 00:00:00 - Price: 30585.00, Pred: 0.486, BTC Held: 0.082115
# [DEBUG] Hold position at 2023-07-02 01:00:00 - Price: 30593.00, Pred: 0.537, BTC Held: 0.082115
# [DEBUG] Hold position at 2023-07-02 02:00:00 - Price: 30584.00, Pred: 0.484, BTC Held: 0.082115
# [DEBUG] Hold position at 2023-07-02 03:00:00 - Price: 30592.00, Pred: 0.478, BTC Held: 0.082115
# [DEBUG] Hold position at 2023-07-02 04:00:00 - Price: 30578.00, Pred: 0.499, BTC Held: 0.082115
# [DEBUG] Partial Sell executed at 2023-07-02 05:00:00 - Price: 30568.00, Pred: 0.434, Sold: 0.041057 BTC, Remaining: 0.041057 BTC
# [DEBUG] Hold position at 2023-07-02 06:00:00 - Price: 30543.00, Pred: 0.501, BTC Held: 0.041057
# [DEBUG] Hold position at 2023-07-02 07:00:00 - Price: 30514.00, Pred: 0.483, BTC Held: 0.041057
# [DEBUG] Hold position at 2023-07-02 08:00:00 - Price: 30531.00, Pred: 0.513, BTC Held: 0.041057
# [DEBUG] Hold position at 2023-07-02 09:00:00 - Price: 30485.00, Pred: 0.481, BTC Held: 0.041057
# [DEBUG] Hold position at 2023-07-02 10:00:00 - Price: 30481.00, Pred: 0.512, BTC Held: 0.041057
# [DEBUG] Buy executed at 2023-07-02 11:00:00 - Price: 30507.00, Pred: 0.552, BTC Held: 0.184418
# [DEBUG] Hold position at 2023-07-02 12:00:00 - Price: 30488.00, Pred: 0.520, BTC Held: 0.184418
# [DEBUG] Hold position at 2023-07-02 13:00:00 - Price: 30522.00, Pred: 0.521, BTC Held: 0.184418
# [DEBUG] Hold position at 2023-07-02 14:00:00 - Price: 30514.00, Pred: 0.518, BTC Held: 0.184418
# [DEBUG] Hold position at 2023-07-02 15:00:00 - Price: 30538.00, Pred: 0.496, BTC Held: 0.184418
# [DEBUG] Hold position at 2023-07-02 16:00:00 - Price: 30519.00, Pred: 0.499, BTC Held: 0.184418
# [DEBUG] Hold position at 2023-07-02 17:00:00 - Price: 30520.00, Pred: 0.517, BTC Held: 0.184418
# [DEBUG] Hold position at 2023-07-02 18:00:00 - Price: 30601.00, Pred: 0.515, BTC Held: 0.184418
# [DEBUG] Hold position at 2023-07-02 19:00:00 - Price: 30495.00, Pred: 0.539, BTC Held: 0.184418
# [DEBUG] Hold position at 2023-07-02 20:00:00 - Price: 30568.00, Pred: 0.512, BTC Held: 0.184418
# [DEBUG] Hold position at 2023-07-02 21:00:00 - Price: 30450.00, Pred: 0.516, BTC Held: 0.184418
# [DEBUG] Hold position at 2023-07-02 22:00:00 - Price: 30530.00, Pred: 0.532, BTC Held: 0.184418
# [DEBUG] Hold position at 2023-07-02 23:00:00 - Price: 30564.00, Pred: 0.530, BTC Held: 0.184418
# [DEBUG] Hold position at 2023-07-03 00:00:00 - Price: 30592.00, Pred: 0.518, BTC Held: 0.184418
# [DEBUG] Hold position at 2023-07-03 01:00:00 - Price: 30561.00, Pred: 0.520, BTC Held: 0.184418
# [DEBUG] Hold position at 2023-07-03 02:00:00 - Price: 30650.00, Pred: 0.515, BTC Held: 0.184418
# [DEBUG] Hold position at 2023-07-03 03:00:00 - Price: 30616.00, Pred: 0.514, BTC Held: 0.184418
# [DEBUG] Hold position at 2023-07-03 04:00:00 - Price: 30642.00, Pred: 0.494, BTC Held: 0.184418
# [DEBUG] Hold position at 2023-07-03 05:00:00 - Price: 30661.00, Pred: 0.531, BTC Held: 0.184418
# [DEBUG] Hold position at 2023-07-03 06:00:00 - Price: 30759.00, Pred: 0.501, BTC Held: 0.184418
# [DEBUG] Hold position at 2023-07-03 07:00:00 - Price: 30760.00, Pred: 0.512, BTC Held: 0.184418
# [DEBUG] Hold position at 2023-07-03 08:00:00 - Price: 30674.00, Pred: 0.509, BTC Held: 0.184418
# [DEBUG] Hold position at 2023-07-03 09:00:00 - Price: 30671.00, Pred: 0.527, BTC Held: 0.184418
# [DEBUG] Hold position at 2023-07-03 10:00:00 - Price: 30649.00, Pred: 0.504, BTC Held: 0.184418
# [DEBUG] Hold position at 2023-07-03 11:00:00 - Price: 30676.00, Pred: 0.493, BTC Held: 0.184418
# [DEBUG] Hold position at 2023-07-03 12:00:00 - Price: 30646.00, Pred: 0.505, BTC Held: 0.184418
# [DEBUG] Hold position at 2023-07-03 13:00:00 - Price: 30611.00, Pred: 0.497, BTC Held: 0.184418
# [DEBUG] Hold position at 2023-07-03 14:00:00 - Price: 30623.00, Pred: 0.509, BTC Held: 0.184418
# [DEBUG] Hold position at 2023-07-03 15:00:00 - Price: 30624.00, Pred: 0.518, BTC Held: 0.184418
# [DEBUG] Buy executed at 2023-07-03 16:00:00 - Price: 30624.00, Pred: 0.603, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-03 17:00:00 - Price: 30654.00, Pred: 0.503, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-03 18:00:00 - Price: 30737.00, Pred: 0.507, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-03 19:00:00 - Price: 31064.00, Pred: 0.497, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-03 20:00:00 - Price: 31048.00, Pred: 0.518, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-03 21:00:00 - Price: 31009.00, Pred: 0.503, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-03 22:00:00 - Price: 31212.00, Pred: 0.514, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-03 23:00:00 - Price: 31258.00, Pred: 0.518, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-04 00:00:00 - Price: 31128.00, Pred: 0.502, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-04 01:00:00 - Price: 31051.00, Pred: 0.502, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-04 02:00:00 - Price: 31128.00, Pred: 0.520, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-04 03:00:00 - Price: 31158.00, Pred: 0.513, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-04 04:00:00 - Price: 31122.00, Pred: 0.528, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-04 05:00:00 - Price: 31293.00, Pred: 0.530, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-04 06:00:00 - Price: 31268.00, Pred: 0.498, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-04 07:00:00 - Price: 31198.00, Pred: 0.518, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-04 08:00:00 - Price: 31057.00, Pred: 0.505, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-04 09:00:00 - Price: 30983.00, Pred: 0.530, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-04 10:00:00 - Price: 31011.00, Pred: 0.499, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-04 11:00:00 - Price: 30915.00, Pred: 0.521, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-04 12:00:00 - Price: 30940.00, Pred: 0.504, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-04 13:00:00 - Price: 31027.00, Pred: 0.511, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-04 14:00:00 - Price: 31032.00, Pred: 0.501, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-04 15:00:00 - Price: 31074.00, Pred: 0.517, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-04 16:00:00 - Price: 31057.00, Pred: 0.510, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-04 17:00:00 - Price: 31008.00, Pred: 0.496, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-04 18:00:00 - Price: 30979.00, Pred: 0.509, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-04 19:00:00 - Price: 30962.00, Pred: 0.514, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-04 20:00:00 - Price: 30955.00, Pred: 0.511, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-04 21:00:00 - Price: 30897.00, Pred: 0.507, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-04 22:00:00 - Price: 30905.00, Pred: 0.497, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-04 23:00:00 - Price: 30708.00, Pred: 0.492, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-05 00:00:00 - Price: 30807.00, Pred: 0.474, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-05 01:00:00 - Price: 30803.00, Pred: 0.509, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-05 02:00:00 - Price: 30822.00, Pred: 0.469, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-05 03:00:00 - Price: 30771.00, Pred: 0.513, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-05 04:00:00 - Price: 30758.00, Pred: 0.509, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-05 05:00:00 - Price: 30795.00, Pred: 0.489, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-05 06:00:00 - Price: 30836.00, Pred: 0.545, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-05 07:00:00 - Price: 30853.00, Pred: 0.499, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-05 08:00:00 - Price: 30836.00, Pred: 0.503, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-05 09:00:00 - Price: 30810.00, Pred: 0.513, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-05 10:00:00 - Price: 30812.00, Pred: 0.502, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-05 11:00:00 - Price: 30770.00, Pred: 0.504, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-05 12:00:00 - Price: 30765.00, Pred: 0.476, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-05 13:00:00 - Price: 30683.00, Pred: 0.508, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-05 14:00:00 - Price: 30435.00, Pred: 0.518, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-05 15:00:00 - Price: 30406.00, Pred: 0.522, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-05 16:00:00 - Price: 30320.00, Pred: 0.492, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-05 17:00:00 - Price: 30360.00, Pred: 0.508, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-05 18:00:00 - Price: 30415.00, Pred: 0.504, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-05 19:00:00 - Price: 30356.00, Pred: 0.508, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-05 20:00:00 - Price: 30462.00, Pred: 0.522, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-05 21:00:00 - Price: 30530.00, Pred: 0.512, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-05 22:00:00 - Price: 30499.00, Pred: 0.518, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-05 23:00:00 - Price: 30439.00, Pred: 0.501, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-06 00:00:00 - Price: 30468.00, Pred: 0.521, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-06 01:00:00 - Price: 30474.00, Pred: 0.521, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-06 02:00:00 - Price: 30446.00, Pred: 0.523, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-06 03:00:00 - Price: 30501.00, Pred: 0.506, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-06 04:00:00 - Price: 30419.00, Pred: 0.504, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-06 05:00:00 - Price: 30475.00, Pred: 0.518, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-06 06:00:00 - Price: 30476.00, Pred: 0.457, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-06 07:00:00 - Price: 30499.00, Pred: 0.519, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-06 08:00:00 - Price: 30463.00, Pred: 0.514, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-06 09:00:00 - Price: 30588.00, Pred: 0.496, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-06 10:00:00 - Price: 30700.00, Pred: 0.502, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-06 11:00:00 - Price: 30807.00, Pred: 0.505, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-06 12:00:00 - Price: 31323.00, Pred: 0.494, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-06 13:00:00 - Price: 31065.00, Pred: 0.500, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-06 14:00:00 - Price: 31235.00, Pred: 0.502, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-06 15:00:00 - Price: 30850.00, Pred: 0.517, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-06 16:00:00 - Price: 30608.00, Pred: 0.514, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-06 17:00:00 - Price: 30374.00, Pred: 0.512, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-06 18:00:00 - Price: 30221.00, Pred: 0.515, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-06 19:00:00 - Price: 30411.00, Pred: 0.508, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-06 20:00:00 - Price: 30309.00, Pred: 0.498, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-06 21:00:00 - Price: 30287.00, Pred: 0.519, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-06 22:00:00 - Price: 30372.00, Pred: 0.506, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-06 23:00:00 - Price: 30313.00, Pred: 0.495, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-07 00:00:00 - Price: 30314.00, Pred: 0.507, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-07 01:00:00 - Price: 30225.00, Pred: 0.518, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-07 02:00:00 - Price: 30163.00, Pred: 0.497, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-07 03:00:00 - Price: 29912.00, Pred: 0.509, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-07 04:00:00 - Price: 30056.00, Pred: 0.519, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-07 05:00:00 - Price: 30091.00, Pred: 0.505, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-07 06:00:00 - Price: 30100.00, Pred: 0.505, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-07 07:00:00 - Price: 30143.00, Pred: 0.490, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-07 08:00:00 - Price: 30091.00, Pred: 0.496, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-07 09:00:00 - Price: 30218.00, Pred: 0.504, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-07 10:00:00 - Price: 30132.00, Pred: 0.499, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-07 11:00:00 - Price: 30013.00, Pred: 0.498, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-07 12:00:00 - Price: 30058.00, Pred: 0.498, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-07 13:00:00 - Price: 30140.00, Pred: 0.506, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-07 14:00:00 - Price: 30166.00, Pred: 0.513, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-07 15:00:00 - Price: 30125.00, Pred: 0.531, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-07 16:00:00 - Price: 30212.00, Pred: 0.522, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-07 17:00:00 - Price: 30381.00, Pred: 0.518, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-07 18:00:00 - Price: 30427.00, Pred: 0.523, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-07 19:00:00 - Price: 30396.00, Pred: 0.515, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-07 20:00:00 - Price: 30361.00, Pred: 0.498, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-07 21:00:00 - Price: 30239.00, Pred: 0.495, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-07 22:00:00 - Price: 30169.00, Pred: 0.518, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-07 23:00:00 - Price: 30244.00, Pred: 0.532, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-08 00:00:00 - Price: 30273.00, Pred: 0.514, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-08 01:00:00 - Price: 30297.00, Pred: 0.520, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-08 02:00:00 - Price: 30321.00, Pred: 0.514, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-08 03:00:00 - Price: 30348.00, Pred: 0.509, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-08 04:00:00 - Price: 30296.00, Pred: 0.525, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-08 05:00:00 - Price: 30308.00, Pred: 0.467, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-08 06:00:00 - Price: 30360.00, Pred: 0.519, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-08 07:00:00 - Price: 30281.00, Pred: 0.493, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-08 08:00:00 - Price: 30237.00, Pred: 0.478, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-08 09:00:00 - Price: 30245.00, Pred: 0.522, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-08 10:00:00 - Price: 30183.00, Pred: 0.522, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-08 11:00:00 - Price: 30201.00, Pred: 0.474, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-08 12:00:00 - Price: 30278.00, Pred: 0.500, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-08 13:00:00 - Price: 30253.00, Pred: 0.511, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-08 14:00:00 - Price: 30229.00, Pred: 0.492, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-08 15:00:00 - Price: 30200.00, Pred: 0.510, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-08 16:00:00 - Price: 30179.00, Pred: 0.500, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-08 17:00:00 - Price: 30217.00, Pred: 0.517, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-08 18:00:00 - Price: 30214.00, Pred: 0.493, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-08 19:00:00 - Price: 30213.00, Pred: 0.514, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-08 20:00:00 - Price: 30260.00, Pred: 0.516, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-08 21:00:00 - Price: 30262.00, Pred: 0.499, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-08 22:00:00 - Price: 30206.00, Pred: 0.502, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-08 23:00:00 - Price: 30117.00, Pred: 0.492, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-09 00:00:00 - Price: 30162.00, Pred: 0.505, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-09 01:00:00 - Price: 30191.00, Pred: 0.459, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-09 02:00:00 - Price: 30224.00, Pred: 0.496, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-09 03:00:00 - Price: 30293.00, Pred: 0.479, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-09 04:00:00 - Price: 30343.00, Pred: 0.489, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-09 05:00:00 - Price: 30338.00, Pred: 0.512, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-09 06:00:00 - Price: 30308.00, Pred: 0.508, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-09 07:00:00 - Price: 30292.00, Pred: 0.506, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-09 08:00:00 - Price: 30291.00, Pred: 0.486, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-09 09:00:00 - Price: 30269.00, Pred: 0.490, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-09 10:00:00 - Price: 30263.00, Pred: 0.517, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-09 11:00:00 - Price: 30273.00, Pred: 0.501, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-09 12:00:00 - Price: 30312.00, Pred: 0.459, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-09 13:00:00 - Price: 30282.00, Pred: 0.476, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-09 14:00:00 - Price: 30277.00, Pred: 0.521, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-09 15:00:00 - Price: 30280.00, Pred: 0.470, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-09 16:00:00 - Price: 30342.00, Pred: 0.503, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-09 17:00:00 - Price: 30272.00, Pred: 0.492, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-09 18:00:00 - Price: 30350.00, Pred: 0.512, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-09 19:00:00 - Price: 30359.00, Pred: 0.501, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-09 20:00:00 - Price: 30297.00, Pred: 0.511, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-09 21:00:00 - Price: 30299.00, Pred: 0.499, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-09 22:00:00 - Price: 30269.00, Pred: 0.518, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-09 23:00:00 - Price: 30249.00, Pred: 0.543, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-10 00:00:00 - Price: 30202.00, Pred: 0.493, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-10 01:00:00 - Price: 30151.00, Pred: 0.518, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-10 02:00:00 - Price: 30175.00, Pred: 0.519, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-10 03:00:00 - Price: 30167.00, Pred: 0.480, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-10 04:00:00 - Price: 30097.00, Pred: 0.511, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-10 05:00:00 - Price: 30055.00, Pred: 0.507, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-10 06:00:00 - Price: 30206.00, Pred: 0.466, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-10 07:00:00 - Price: 30156.00, Pred: 0.497, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-10 08:00:00 - Price: 30119.00, Pred: 0.500, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-10 09:00:00 - Price: 30092.00, Pred: 0.515, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-10 10:00:00 - Price: 30096.00, Pred: 0.516, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-10 11:00:00 - Price: 30116.00, Pred: 0.512, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-10 12:00:00 - Price: 30102.00, Pred: 0.505, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-10 13:00:00 - Price: 30143.00, Pred: 0.475, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-10 14:00:00 - Price: 30186.00, Pred: 0.494, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-10 15:00:00 - Price: 30238.00, Pred: 0.517, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-10 16:00:00 - Price: 30161.00, Pred: 0.486, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-10 17:00:00 - Price: 30213.00, Pred: 0.524, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-10 18:00:00 - Price: 30310.00, Pred: 0.521, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-10 19:00:00 - Price: 30317.00, Pred: 0.509, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-10 20:00:00 - Price: 30356.00, Pred: 0.467, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-10 21:00:00 - Price: 30283.00, Pred: 0.504, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-10 22:00:00 - Price: 30525.00, Pred: 0.510, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-10 23:00:00 - Price: 30840.00, Pred: 0.519, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-11 00:00:00 - Price: 30786.00, Pred: 0.504, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-11 01:00:00 - Price: 30334.00, Pred: 0.511, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-11 02:00:00 - Price: 30338.00, Pred: 0.510, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-11 03:00:00 - Price: 30421.00, Pred: 0.505, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-11 04:00:00 - Price: 30429.00, Pred: 0.506, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-11 05:00:00 - Price: 30591.00, Pred: 0.515, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-11 06:00:00 - Price: 30491.00, Pred: 0.508, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-11 07:00:00 - Price: 30482.00, Pred: 0.498, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-11 08:00:00 - Price: 30448.00, Pred: 0.505, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-11 09:00:00 - Price: 30460.00, Pred: 0.475, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-11 10:00:00 - Price: 30641.00, Pred: 0.490, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-11 11:00:00 - Price: 30533.00, Pred: 0.478, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-11 12:00:00 - Price: 30500.00, Pred: 0.514, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-11 13:00:00 - Price: 30452.00, Pred: 0.530, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-11 14:00:00 - Price: 30401.00, Pred: 0.505, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-11 15:00:00 - Price: 30414.00, Pred: 0.514, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-11 16:00:00 - Price: 30434.00, Pred: 0.491, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-11 17:00:00 - Price: 30448.00, Pred: 0.510, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-11 18:00:00 - Price: 30524.00, Pred: 0.507, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-11 19:00:00 - Price: 30599.00, Pred: 0.522, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-11 20:00:00 - Price: 30644.00, Pred: 0.508, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-11 21:00:00 - Price: 30583.00, Pred: 0.514, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-11 22:00:00 - Price: 30486.00, Pred: 0.514, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-11 23:00:00 - Price: 30582.00, Pred: 0.522, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-12 00:00:00 - Price: 30570.00, Pred: 0.498, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-12 01:00:00 - Price: 30569.00, Pred: 0.503, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-12 02:00:00 - Price: 30585.00, Pred: 0.528, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-12 03:00:00 - Price: 30621.00, Pred: 0.501, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-12 04:00:00 - Price: 30513.00, Pred: 0.502, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-12 05:00:00 - Price: 30539.00, Pred: 0.502, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-12 06:00:00 - Price: 30615.00, Pred: 0.504, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-12 07:00:00 - Price: 30598.00, Pred: 0.494, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-12 08:00:00 - Price: 30643.00, Pred: 0.516, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-12 09:00:00 - Price: 30656.00, Pred: 0.527, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-12 10:00:00 - Price: 30719.00, Pred: 0.503, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-12 11:00:00 - Price: 30740.00, Pred: 0.517, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-12 12:00:00 - Price: 30736.00, Pred: 0.503, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-12 13:00:00 - Price: 30729.00, Pred: 0.478, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-12 14:00:00 - Price: 30683.00, Pred: 0.475, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-12 15:00:00 - Price: 30779.00, Pred: 0.505, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-12 16:00:00 - Price: 30723.00, Pred: 0.509, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-12 17:00:00 - Price: 30661.00, Pred: 0.502, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-12 18:00:00 - Price: 30738.00, Pred: 0.476, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-12 19:00:00 - Price: 30509.00, Pred: 0.499, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-12 20:00:00 - Price: 30475.00, Pred: 0.482, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-12 21:00:00 - Price: 30441.00, Pred: 0.501, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-12 22:00:00 - Price: 30519.00, Pred: 0.511, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-12 23:00:00 - Price: 30278.00, Pred: 0.513, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-13 00:00:00 - Price: 30350.00, Pred: 0.513, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-13 01:00:00 - Price: 30355.00, Pred: 0.512, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-13 02:00:00 - Price: 30370.00, Pred: 0.512, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-13 03:00:00 - Price: 30382.00, Pred: 0.513, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-13 04:00:00 - Price: 30359.00, Pred: 0.499, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-13 05:00:00 - Price: 30384.00, Pred: 0.496, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-13 06:00:00 - Price: 30338.00, Pred: 0.492, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-13 07:00:00 - Price: 30298.00, Pred: 0.484, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-13 08:00:00 - Price: 30294.00, Pred: 0.483, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-13 09:00:00 - Price: 30315.00, Pred: 0.486, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-13 10:00:00 - Price: 30384.00, Pred: 0.509, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-13 11:00:00 - Price: 30364.00, Pred: 0.484, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-13 12:00:00 - Price: 30415.00, Pred: 0.514, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-13 13:00:00 - Price: 30575.00, Pred: 0.533, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-13 14:00:00 - Price: 30577.00, Pred: 0.505, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-13 15:00:00 - Price: 30546.00, Pred: 0.512, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-13 16:00:00 - Price: 30522.00, Pred: 0.509, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-13 17:00:00 - Price: 30673.00, Pred: 0.506, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-13 18:00:00 - Price: 30577.00, Pred: 0.514, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-13 19:00:00 - Price: 30920.00, Pred: 0.520, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-13 20:00:00 - Price: 30839.00, Pred: 0.501, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-13 21:00:00 - Price: 31079.00, Pred: 0.519, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-13 22:00:00 - Price: 31281.00, Pred: 0.497, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-13 23:00:00 - Price: 31637.00, Pred: 0.506, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-14 00:00:00 - Price: 31396.00, Pred: 0.499, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-14 01:00:00 - Price: 31267.00, Pred: 0.522, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-14 02:00:00 - Price: 31324.00, Pred: 0.519, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-14 03:00:00 - Price: 31471.00, Pred: 0.516, BTC Held: 0.255825
# [DEBUG] Hold position at 2023-07-14 04:00:00 - Price: 31461.00, Pred: 0.506, BTC Held: 0.255825
# ...
# [DEBUG] Hold position at 2024-03-14 14:00:00 - Price: 73021.00, Pred: 0.473, BTC Held: 0.003594
# [DEBUG] Hold position at 2024-03-14 15:00:00 - Price: 72934.00, Pred: 0.462, BTC Held: 0.003594
# [DEBUG] Hold position at 2024-03-14 16:00:00 - Price: 72887.00, Pred: 0.493, BTC Held: 0.003594
# [DEBUG] Hold position at 2024-03-14 17:00:00 - Price: 71827.00, Pred: 0.497, BTC Held: 0.003594
# [DEBUG] Hold position at 2024-03-14 18:00:00 - Price: 71639.00, Pred: 0.499, BTC Held: 0.003594
# [DEBUG] Hold position at 2024-03-14 19:00:00 - Price: 70800.00, Pred: 0.494, BTC Held: 0.003594
# [DEBUG] Hold position at 2024-03-14 20:00:00 - Price: 71286.00, Pred: 0.464, BTC Held: 0.003594
# [DEBUG] Partial Sell executed at 2024-03-14 21:00:00 - Price: 71011.00, Pred: 0.438, Sold: 0.001797 BTC, Remaining: 0.001797 BTC
# [DEBUG] Hold position at 2024-03-14 22:00:00 - Price: 70088.00, Pred: 0.464, BTC Held: 0.001797
# [DEBUG] Hold position at 2024-03-14 23:00:00 - Price: 69339.00, Pred: 0.493, BTC Held: 0.001797
# [DEBUG] Hold position at 2024-03-15 00:00:00 - Price: 70692.00, Pred: 0.475, BTC Held: 0.001797
# [DEBUG] Hold position at 2024-03-15 01:00:00 - Price: 71068.00, Pred: 0.459, BTC Held: 0.001797
# [DEBUG] Hold position at 2024-03-15 02:00:00 - Price: 71513.00, Pred: 0.476, BTC Held: 0.001797
# [DEBUG] Partial Sell executed at 2024-03-15 03:00:00 - Price: 71371.00, Pred: 0.447, Sold: 0.000899 BTC, Remaining: 0.000899 BTC
# [DEBUG] Hold position at 2024-03-15 04:00:00 - Price: 71885.00, Pred: 0.464, BTC Held: 0.000899
# [DEBUG] Partial Sell executed at 2024-03-15 05:00:00 - Price: 71586.00, Pred: 0.436, Sold: 0.000449 BTC, Remaining: 0.000449 BTC
# [DEBUG] Hold position at 2024-03-15 06:00:00 - Price: 69000.00, Pred: 0.462, BTC Held: 0.000449
# [DEBUG] Hold position at 2024-03-15 07:00:00 - Price: 68200.00, Pred: 0.494, BTC Held: 0.000449
# [DEBUG] Hold position at 2024-03-15 08:00:00 - Price: 67423.00, Pred: 0.452, BTC Held: 0.000449
# [DEBUG] Hold position at 2024-03-15 09:00:00 - Price: 67376.00, Pred: 0.452, BTC Held: 0.000449
# [DEBUG] Hold position at 2024-03-15 10:00:00 - Price: 68604.00, Pred: 0.471, BTC Held: 0.000449
# [DEBUG] Hold position at 2024-03-15 11:00:00 - Price: 68409.00, Pred: 0.480, BTC Held: 0.000449
# [DEBUG] Hold position at 2024-03-15 12:00:00 - Price: 67033.00, Pred: 0.498, BTC Held: 0.000449
# [DEBUG] Hold position at 2024-03-15 13:00:00 - Price: 67760.00, Pred: 0.484, BTC Held: 0.000449
# [DEBUG] Partial Sell executed at 2024-03-15 14:00:00 - Price: 67219.00, Pred: 0.441, Sold: 0.000225 BTC, Remaining: 0.000225 BTC
# [DEBUG] Hold position at 2024-03-15 15:00:00 - Price: 67650.00, Pred: 0.463, BTC Held: 0.000225
# [DEBUG] Hold position at 2024-03-15 16:00:00 - Price: 67876.00, Pred: 0.464, BTC Held: 0.000225
# [DEBUG] Hold position at 2024-03-15 17:00:00 - Price: 68447.00, Pred: 0.460, BTC Held: 0.000225
# [DEBUG] Hold position at 2024-03-15 18:00:00 - Price: 68600.00, Pred: 0.468, BTC Held: 0.000225
# [DEBUG] Hold position at 2024-03-15 19:00:00 - Price: 68152.00, Pred: 0.478, BTC Held: 0.000225
# [DEBUG] Hold position at 2024-03-15 20:00:00 - Price: 67894.00, Pred: 0.491, BTC Held: 0.000225
# [DEBUG] Hold position at 2024-03-15 21:00:00 - Price: 68192.00, Pred: 0.463, BTC Held: 0.000225
# [DEBUG] Hold position at 2024-03-15 22:00:00 - Price: 70219.00, Pred: 0.513, BTC Held: 0.000225
# [DEBUG] Hold position at 2024-03-15 23:00:00 - Price: 68971.00, Pred: 0.488, BTC Held: 0.000225
# [DEBUG] Hold position at 2024-03-16 00:00:00 - Price: 67852.00, Pred: 0.482, BTC Held: 0.000225
# [DEBUG] Hold position at 2024-03-16 01:00:00 - Price: 68282.00, Pred: 0.481, BTC Held: 0.000225
# [DEBUG] Hold position at 2024-03-16 02:00:00 - Price: 69120.00, Pred: 0.476, BTC Held: 0.000225
# [DEBUG] Hold position at 2024-03-16 03:00:00 - Price: 69516.00, Pred: 0.466, BTC Held: 0.000225
# [DEBUG] Hold position at 2024-03-16 04:00:00 - Price: 69612.00, Pred: 0.486, BTC Held: 0.000225
# [DEBUG] Partial Sell executed at 2024-03-16 05:00:00 - Price: 69282.00, Pred: 0.414, Sold: 0.000112 BTC, Remaining: 0.000112 BTC
# [DEBUG] Hold position at 2024-03-16 06:00:00 - Price: 69061.00, Pred: 0.465, BTC Held: 0.000112
# [DEBUG] Hold position at 2024-03-16 07:00:00 - Price: 69189.00, Pred: 0.474, BTC Held: 0.000112
# [DEBUG] Hold position at 2024-03-16 08:00:00 - Price: 69001.00, Pred: 0.491, BTC Held: 0.000112
# [DEBUG] Hold position at 2024-03-16 09:00:00 - Price: 68964.00, Pred: 0.487, BTC Held: 0.000112
# [DEBUG] Hold position at 2024-03-16 10:00:00 - Price: 69183.00, Pred: 0.484, BTC Held: 0.000112
# [DEBUG] Hold position at 2024-03-16 11:00:00 - Price: 69430.00, Pred: 0.467, BTC Held: 0.000112
# [DEBUG] Hold position at 2024-03-16 12:00:00 - Price: 69037.00, Pred: 0.464, BTC Held: 0.000112
# [DEBUG] Partial Sell executed at 2024-03-16 13:00:00 - Price: 68944.00, Pred: 0.448, Sold: 0.000056 BTC, Remaining: 0.000056 BTC
# [DEBUG] Hold position at 2024-03-16 14:00:00 - Price: 68415.00, Pred: 0.482, BTC Held: 0.000056
# [DEBUG] Hold position at 2024-03-16 15:00:00 - Price: 68242.00, Pred: 0.495, BTC Held: 0.000056
# [DEBUG] Hold position at 2024-03-16 16:00:00 - Price: 67882.00, Pred: 0.454, BTC Held: 0.000056
# [DEBUG] Hold position at 2024-03-16 17:00:00 - Price: 67695.00, Pred: 0.489, BTC Held: 0.000056
# [DEBUG] Hold position at 2024-03-16 18:00:00 - Price: 68172.00, Pred: 0.469, BTC Held: 0.000056
# [DEBUG] Hold position at 2024-03-16 19:00:00 - Price: 68369.00, Pred: 0.519, BTC Held: 0.000056
# [DEBUG] Hold position at 2024-03-16 20:00:00 - Price: 68163.00, Pred: 0.484, BTC Held: 0.000056
# [DEBUG] Hold position at 2024-03-16 21:00:00 - Price: 67241.00, Pred: 0.456, BTC Held: 0.000056
# [DEBUG] Hold position at 2024-03-16 22:00:00 - Price: 67001.00, Pred: 0.458, BTC Held: 0.000056
# [DEBUG] Hold position at 2024-03-16 23:00:00 - Price: 66931.00, Pred: 0.501, BTC Held: 0.000056
# [DEBUG] Hold position at 2024-03-17 00:00:00 - Price: 67081.00, Pred: 0.487, BTC Held: 0.000056
# [DEBUG] Hold position at 2024-03-17 01:00:00 - Price: 66204.00, Pred: 0.523, BTC Held: 0.000056
# [DEBUG] Hold position at 2024-03-17 02:00:00 - Price: 66344.00, Pred: 0.495, BTC Held: 0.000056
# [DEBUG] Hold position at 2024-03-17 03:00:00 - Price: 65248.00, Pred: 0.479, BTC Held: 0.000056
# [DEBUG] Hold position at 2024-03-17 04:00:00 - Price: 65147.00, Pred: 0.484, BTC Held: 0.000056
# [DEBUG] Hold position at 2024-03-17 05:00:00 - Price: 66116.00, Pred: 0.507, BTC Held: 0.000056
# [DEBUG] Hold position at 2024-03-17 06:00:00 - Price: 66313.00, Pred: 0.460, BTC Held: 0.000056
# [DEBUG] Hold position at 2024-03-17 07:00:00 - Price: 66511.00, Pred: 0.521, BTC Held: 0.000056
# [DEBUG] Hold position at 2024-03-17 08:00:00 - Price: 66314.00, Pred: 0.476, BTC Held: 0.000056
# [DEBUG] Hold position at 2024-03-17 09:00:00 - Price: 66199.00, Pred: 0.460, BTC Held: 0.000056
# [DEBUG] Partial Sell executed at 2024-03-17 10:00:00 - Price: 64981.00, Pred: 0.431, Sold: 0.000028 BTC, Remaining: 0.000028 BTC
# [DEBUG] Hold position at 2024-03-17 11:00:00 - Price: 65588.00, Pred: 0.509, BTC Held: 0.000028
# [DEBUG] Hold position at 2024-03-17 12:00:00 - Price: 66433.00, Pred: 0.479, BTC Held: 0.000028
# [DEBUG] Hold position at 2024-03-17 13:00:00 - Price: 66373.00, Pred: 0.468, BTC Held: 0.000028
# [DEBUG] Hold position at 2024-03-17 14:00:00 - Price: 67080.00, Pred: 0.485, BTC Held: 0.000028
# [DEBUG] Hold position at 2024-03-17 15:00:00 - Price: 66863.00, Pred: 0.491, BTC Held: 0.000028
# [DEBUG] Hold position at 2024-03-17 16:00:00 - Price: 66516.00, Pred: 0.482, BTC Held: 0.000028
# [DEBUG] Hold position at 2024-03-17 17:00:00 - Price: 67052.00, Pred: 0.492, BTC Held: 0.000028
# [DEBUG] Hold position at 2024-03-17 18:00:00 - Price: 67530.00, Pred: 0.491, BTC Held: 0.000028
# [DEBUG] Buy executed at 2024-03-17 19:00:00 - Price: 67911.00, Pred: 0.554, BTC Held: 0.119741
# [DEBUG] Partial Sell executed at 2024-03-17 20:00:00 - Price: 67990.00, Pred: 0.446, Sold: 0.059870 BTC, Remaining: 0.059870 BTC
# [DEBUG] Hold position at 2024-03-17 21:00:00 - Price: 68499.00, Pred: 0.499, BTC Held: 0.059870
# [DEBUG] Partial Sell executed at 2024-03-17 22:00:00 - Price: 68130.00, Pred: 0.433, Sold: 0.029935 BTC, Remaining: 0.029935 BTC
# [DEBUG] Hold position at 2024-03-17 23:00:00 - Price: 68526.00, Pred: 0.496, BTC Held: 0.029935
# [DEBUG] Hold position at 2024-03-18 00:00:00 - Price: 68241.00, Pred: 0.457, BTC Held: 0.029935
# [DEBUG] Hold position at 2024-03-18 01:00:00 - Price: 68129.00, Pred: 0.460, BTC Held: 0.029935
# [DEBUG] Hold position at 2024-03-18 02:00:00 - Price: 68214.00, Pred: 0.503, BTC Held: 0.029935
# [DEBUG] Hold position at 2024-03-18 03:00:00 - Price: 68352.00, Pred: 0.512, BTC Held: 0.029935
# [DEBUG] Hold position at 2024-03-18 04:00:00 - Price: 67247.00, Pred: 0.468, BTC Held: 0.029935
# [DEBUG] Hold position at 2024-03-18 05:00:00 - Price: 67587.00, Pred: 0.483, BTC Held: 0.029935
# [DEBUG] Hold position at 2024-03-18 06:00:00 - Price: 67725.00, Pred: 0.500, BTC Held: 0.029935
# [DEBUG] Hold position at 2024-03-18 07:00:00 - Price: 67905.00, Pred: 0.511, BTC Held: 0.029935
# [DEBUG] Hold position at 2024-03-18 08:00:00 - Price: 68316.00, Pred: 0.461, BTC Held: 0.029935
# [DEBUG] Hold position at 2024-03-18 09:00:00 - Price: 68656.00, Pred: 0.489, BTC Held: 0.029935
# [DEBUG] Hold position at 2024-03-18 10:00:00 - Price: 68455.00, Pred: 0.474, BTC Held: 0.029935
# [DEBUG] Hold position at 2024-03-18 11:00:00 - Price: 68165.00, Pred: 0.487, BTC Held: 0.029935
# [DEBUG] Hold position at 2024-03-18 12:00:00 - Price: 68035.00, Pred: 0.464, BTC Held: 0.029935
# [DEBUG] Partial Sell executed at 2024-03-18 13:00:00 - Price: 67815.00, Pred: 0.442, Sold: 0.014968 BTC, Remaining: 0.014968 BTC
# [DEBUG] Hold position at 2024-03-18 14:00:00 - Price: 68077.00, Pred: 0.493, BTC Held: 0.014968
# [DEBUG] Hold position at 2024-03-18 15:00:00 - Price: 68207.00, Pred: 0.463, BTC Held: 0.014968
# [DEBUG] Hold position at 2024-03-18 16:00:00 - Price: 68488.00, Pred: 0.474, BTC Held: 0.014968
# [DEBUG] Hold position at 2024-03-18 17:00:00 - Price: 67505.00, Pred: 0.485, BTC Held: 0.014968
# [DEBUG] Hold position at 2024-03-18 18:00:00 - Price: 66952.00, Pred: 0.477, BTC Held: 0.014968
# [DEBUG] Hold position at 2024-03-18 19:00:00 - Price: 67456.00, Pred: 0.460, BTC Held: 0.014968
# [DEBUG] Hold position at 2024-03-18 20:00:00 - Price: 67117.00, Pred: 0.452, BTC Held: 0.014968
# [DEBUG] Hold position at 2024-03-18 21:00:00 - Price: 67374.00, Pred: 0.474, BTC Held: 0.014968
# [DEBUG] Hold position at 2024-03-18 22:00:00 - Price: 67000.00, Pred: 0.493, BTC Held: 0.014968
# [DEBUG] Hold position at 2024-03-18 23:00:00 - Price: 66950.00, Pred: 0.478, BTC Held: 0.014968
# [DEBUG] Hold position at 2024-03-19 00:00:00 - Price: 67370.00, Pred: 0.491, BTC Held: 0.014968
# [DEBUG] Hold position at 2024-03-19 01:00:00 - Price: 67615.00, Pred: 0.467, BTC Held: 0.014968
# [DEBUG] Hold position at 2024-03-19 02:00:00 - Price: 67704.00, Pred: 0.491, BTC Held: 0.014968
# [DEBUG] Hold position at 2024-03-19 03:00:00 - Price: 67613.00, Pred: 0.468, BTC Held: 0.014968
# [DEBUG] Hold position at 2024-03-19 04:00:00 - Price: 67093.00, Pred: 0.466, BTC Held: 0.014968
# [DEBUG] Hold position at 2024-03-19 05:00:00 - Price: 65862.00, Pred: 0.476, BTC Held: 0.014968
# [DEBUG] Hold position at 2024-03-19 06:00:00 - Price: 65870.00, Pred: 0.476, BTC Held: 0.014968
# [DEBUG] Hold position at 2024-03-19 07:00:00 - Price: 65879.00, Pred: 0.492, BTC Held: 0.014968
# [DEBUG] Hold position at 2024-03-19 08:00:00 - Price: 65354.00, Pred: 0.494, BTC Held: 0.014968
# [DEBUG] Hold position at 2024-03-19 09:00:00 - Price: 65182.00, Pred: 0.463, BTC Held: 0.014968
# [DEBUG] Hold position at 2024-03-19 10:00:00 - Price: 64888.00, Pred: 0.493, BTC Held: 0.014968
# [DEBUG] Hold position at 2024-03-19 11:00:00 - Price: 64663.00, Pred: 0.510, BTC Held: 0.014968
# [DEBUG] Hold position at 2024-03-19 12:00:00 - Price: 63399.00, Pred: 0.502, BTC Held: 0.014968
# [DEBUG] Hold position at 2024-03-19 13:00:00 - Price: 64154.00, Pred: 0.489, BTC Held: 0.014968
# [DEBUG] Hold position at 2024-03-19 14:00:00 - Price: 63226.00, Pred: 0.496, BTC Held: 0.014968
# [DEBUG] Hold position at 2024-03-19 15:00:00 - Price: 63016.00, Pred: 0.492, BTC Held: 0.014968
# [DEBUG] Hold position at 2024-03-19 16:00:00 - Price: 63570.00, Pred: 0.455, BTC Held: 0.014968
# [DEBUG] Hold position at 2024-03-19 17:00:00 - Price: 63542.00, Pred: 0.484, BTC Held: 0.014968
# [DEBUG] Hold position at 2024-03-19 18:00:00 - Price: 62820.00, Pred: 0.463, BTC Held: 0.014968
# [DEBUG] Buy, hold, sell backtest loop finished.
# [DEBUG] Finished _run_strategy (Buy, Hold, Sell). Returning results DataFrame. Trades: 43
# [DEBUG] Strategy simulation finished, results DataFrame assigned.
#
# Validation backtest simulation complete.
# Sample of validation backtest results DataFrame (first 5 rows):
#                      transactions_count_flow_1  current_regime  \
# datetime
# 2023-06-23 15:00:00                        386               0
# 2023-06-23 16:00:00                        374               0
# 2023-06-23 17:00:00                        338               4
# 2023-06-23 18:00:00                        427               4
# 2023-06-23 19:00:00                        368               4
#
#                      predicted_next_regime  next_regime_probability  \
# datetime
# 2023-06-23 15:00:00                      0                 0.523820
# 2023-06-23 16:00:00                      0                 0.523820
# 2023-06-23 17:00:00                      4                 0.479277
# 2023-06-23 18:00:00                      4                 0.479277
# 2023-06-23 19:00:00                      4                 0.479277
#
#                         start_time  inflow_mean  inflow_mean_ma7  \
# datetime
# 2023-06-23 15:00:00  1687532400000     1.096440         0.924393
# 2023-06-23 16:00:00  1687536000000     1.084985         0.963305
# 2023-06-23 17:00:00  1687539600000     1.233169         1.039511
# 2023-06-23 18:00:00  1687543200000     1.439951         1.149608
# 2023-06-23 19:00:00  1687546800000     0.641945         1.039661
#
#                      inflow_top10  inflow_total  outflow_mean  ...  \
# datetime                                                       ...
# 2023-06-23 15:00:00   3227.998343   4215.811792     10.410968  ...
# 2023-06-23 16:00:00   3287.801636   5100.516557      8.639932  ...
# 2023-06-23 17:00:00   2192.891110   2381.249675      9.437642  ...
# 2023-06-23 18:00:00   6032.626647   7304.872202      9.997582  ...
# 2023-06-23 19:00:00   2559.622882   3251.449807     10.229739  ...
#
#                      portfolio_value  trade  trade_size  entry_price  \
# datetime
# 2023-06-23 15:00:00          10000.0      0         0.0          NaN
# 2023-06-23 16:00:00          10000.0      0         0.0          NaN
# 2023-06-23 17:00:00          10000.0      0         0.0          NaN
# 2023-06-23 18:00:00          10000.0      0         0.0          NaN
# 2023-06-23 19:00:00          10000.0      0         0.0          NaN
#
#                      trade_result  pnl  signal  transaction_fee  daily_return  \
# datetime
# 2023-06-23 15:00:00           NaN  0.0       0              0.0           0.0
# 2023-06-23 16:00:00           NaN  0.0       0              0.0           0.0
# 2023-06-23 17:00:00           NaN -0.0       0              0.0           0.0
# 2023-06-23 18:00:00           NaN  0.0       0              0.0           0.0
# 2023-06-23 19:00:00           NaN  0.0       0              0.0           0.0
#
#                      cumulative_return
# datetime
# 2023-06-23 15:00:00                0.0
# 2023-06-23 16:00:00                0.0
# 2023-06-23 17:00:00                0.0
# 2023-06-23 18:00:00                0.0
# 2023-06-23 19:00:00                0.0
#
# [5 rows x 81 columns]

# %%
# --- Step 11: Evaluating Backtest Performance ---
print("\n--- Step 11: Evaluating Backtest Performance ---") #

if backtest is not None and backtest.results is not None and not backtest.results.empty: #
    try:
        # Calculate metrics using the method within the backtest object
        backtest_metrics = backtest.calculate_metrics() #

        print("\nBacktest Performance Metrics (Test Set):") #
        print("-" * 40)
        # Use .get() with default 0 for safety, format nicely
        print(f"- Initial Cash:        ${backtest.params.get('INITIAL_CASH', 0):,.2f}") #
        final_value = backtest.results['portfolio_value'].iloc[-1] #
        print(f"- Final Portfolio Value: ${final_value:,.2f}") #
        print(f"- Total Return:        {backtest_metrics.get('total_return', 0):.2%}") #
        print(f"- Annual Return:       {backtest_metrics.get('annual_return', 0):.2%}") #
        print(f"- Sharpe Ratio:        {backtest_metrics.get('sharpe', 0):.3f}") #
        print(f"- Max Drawdown:        {backtest_metrics.get('max_drawdown', 0):.2%}") #
        print(f"- Win Rate:            {backtest_metrics.get('win_rate', 0):.2%}") #
        print(f"- Total Trades:        {backtest_metrics.get('total_trades', 0)}") #
        print(f"- Profit Factor:       {backtest_metrics.get('profit_factor', 0):.2f}") #
        print(f"- System Quality (SQN):{backtest_metrics.get('sqn', 0):.2f}") #
        print("-" * 40)

        # --- Save metrics to a CSV file ---
        metrics_df = pd.DataFrame([backtest_metrics]) # Create DataFrame from metrics dict
        metrics_filename = os.path.join(MODEL_OUTPUT_DIR, 'backtest_metrics.csv') #
        os.makedirs(os.path.dirname(metrics_filename) or '.', exist_ok=True) # Ensure directory exists
        try:
            metrics_df.to_csv(metrics_filename, index=False) #
            print(f"\nBacktest metrics saved to: {metrics_filename}") #
        except Exception as e_save:
             print(f"Error saving backtest metrics to CSV: {e_save}")


    except Exception as e: #
        print(f"An error occurred during backtest evaluation: {e}") #
        traceback.print_exc() #
else: #
    print("Skipping backtest evaluation: Backtest object or results are not available.") #
# Out:
# --- Step 11: Evaluating Backtest Performance ---
#
# Backtest Performance Metrics (Test Set):
# ----------------------------------------
# - Initial Cash:        $10,000.00
# - Final Portfolio Value: $14,733.87
# - Total Return:        47.34%
# - Annual Return:       47.97%
# - Sharpe Ratio:        -0.842
# - Max Drawdown:        -22.31%
# - Win Rate:            34.69%
# - Total Trades:        1
# - Profit Factor:       0.75
# - System Quality (SQN):-0.84
# ----------------------------------------
#
# Backtest metrics saved to: bitcoin_onchain_models/backtest_metrics.csv

# %%
# --- Step 11b: Evaluating Validation Backtest Performance ---
print("\n--- Step 11b: Evaluating Validation Backtest Performance ---") #

# Check if the validation backtest ran successfully and produced results
if val_backtest is not None and val_backtest.results is not None and not val_backtest.results.empty: #
    try:
        # Calculate metrics using the method within the validation backtest object
        val_backtest_metrics = val_backtest.calculate_metrics() #

        print("\nBacktest Performance Metrics (Validation Set):") #
        print("-" * 40)
        # Use .get() with default 0 for safety, format nicely
        print(f"- Initial Cash:        ${val_backtest.params.get('INITIAL_CASH', 0):,.2f}") #
        val_final_value = val_backtest.results['portfolio_value'].iloc[-1] #
        print(f"- Final Portfolio Value: ${val_final_value:,.2f}") #
        print(f"- Total Return:        {val_backtest_metrics.get('total_return', 0):.2%}") #
        print(f"- Annual Return:       {val_backtest_metrics.get('annual_return', 0):.2%}") #
        print(f"- Sharpe Ratio:        {val_backtest_metrics.get('sharpe', 0):.3f}") #
        print(f"- Max Drawdown:        {val_backtest_metrics.get('max_drawdown', 0):.2%}") #
        print(f"- Win Rate:            {val_backtest_metrics.get('win_rate', 0):.2%}") #
        print(f"- Total Trades:        {val_backtest_metrics.get('total_trades', 0)}") #
        print(f"- Profit Factor:       {val_backtest_metrics.get('profit_factor', 0):.2f}") #
        print(f"- System Quality (SQN):{val_backtest_metrics.get('sqn', 0):.2f}") #
        print("-" * 40)

        # --- Save validation metrics to a separate CSV file ---
        val_metrics_df = pd.DataFrame([val_backtest_metrics]) # Create DataFrame from validation metrics dict
        val_metrics_filename = os.path.join(MODEL_OUTPUT_DIR, 'validation_backtest_metrics.csv') # Distinct filename
        os.makedirs(os.path.dirname(val_metrics_filename) or '.', exist_ok=True) # Ensure directory exists
        try:
            val_metrics_df.to_csv(val_metrics_filename, index=False) #
            print(f"\nValidation backtest metrics saved to: {val_metrics_filename}") #
        except Exception as e_save:
            print(f"Error saving validation backtest metrics to CSV: {e_save}")


    except Exception as e: #
        print(f"An error occurred during validation backtest evaluation: {e}") #
        traceback.print_exc() #
else: #
    print("Skipping validation backtest evaluation: Validation backtest object or results are not available.") #
# Out:
# --- Step 11b: Evaluating Validation Backtest Performance ---
#
# Backtest Performance Metrics (Validation Set):
# ----------------------------------------
# - Initial Cash:        $10,000.00
# - Final Portfolio Value: $16,195.79
# - Total Return:        61.96%
# - Annual Return:       83.71%
# - Sharpe Ratio:        -0.907
# - Max Drawdown:        -14.56%
# - Win Rate:            49.85%
# - Total Trades:        1
# - Profit Factor:       0.76
# - System Quality (SQN):-0.78
# ----------------------------------------
#
# Validation backtest metrics saved to: bitcoin_onchain_models/validation_backtest_metrics.csv

# %%
# --- Step 12: Plotting Backtest Results ---
print("\n--- Step 12: Plotting Backtest Results ---") #

if backtest is not None: # Check if backtest object was successfully created
    try:
        # Call the plotting methods of the strategy instance
        # This will generate plots for portfolio value and cumulative return,
        # and also call _plot_trade_analysis internally if trade history exists.
        print("Generating backtest plots...") #
        backtest.plot_results() #

        print("Backtest plots generated and potentially saved.") #

    except Exception as e: #
        print(f"An error occurred during backtest plotting: {e}") #
        traceback.print_exc() #
else: #
    print("Skipping backtest plotting: Backtest object is not available.") #
# Out:
# --- Step 12: Plotting Backtest Results ---
# Generating backtest plots...
# Backtest plots generated and potentially saved.

# %%
# --- Step 12b: Plotting Validation Backtest Results ---
print("\n--- Step 12b: Plotting Validation Backtest Results ---") #

if val_backtest is not None: # Check if validation backtest object was successfully created
    try:
        # Call the plotting methods of the validation strategy instance
        print("Generating validation backtest plots...") #
        val_backtest.plot_results() # Call plot_results on the validation backtest object

        print("Validation backtest plots generated and potentially saved.") #

    except Exception as e: #
        print(f"An error occurred during validation backtest plotting: {e}") #
        traceback.print_exc() #
else: #
    print("Skipping validation backtest plotting: Validation Backtest object is not available.") #
# Out:
# --- Step 12b: Plotting Validation Backtest Results ---
# Generating validation backtest plots...
# Validation backtest plots generated and potentially saved.

# %%
# --- Step 13: Saving Models and Components ---
print("\n--- Step 13: Saving Models and Components ---") #

# Ensure the output directory exists
os.makedirs(MODEL_OUTPUT_DIR, exist_ok=True) #
print(f"Attempting to save components to: {os.path.abspath(MODEL_OUTPUT_DIR)}") # Use absolute path for clarity

saved_items_count = 0 # Counter for saved items

try:
    # --- Save trained models ---
    if 'models' in locals() and models: # Check if models dict exists
        print("Saving trained models...")
        for name, model in models.items(): #
            if model is not None: # Only save successfully trained models
                try:
                    model_path = os.path.join(MODEL_OUTPUT_DIR, f'{name}_model.joblib') #
                    joblib.dump(model, model_path) #
                    print(f"- Saved model: {name} to {model_path}") #
                    saved_items_count += 1
                except Exception as e_model: #
                    print(f"Error saving model '{name}': {e_model}") #
            # else: # Optional: Log skipped models
                # print(f"- Skipping model: {name} (was None)")
    else: #
        print("- No 'models' dictionary found to save.") #

    # --- Save the preprocessor ---
    if 'preprocessor' in locals() and preprocessor: # Check if preprocessor exists
        print("Saving preprocessor...")
        try:
            preprocessor_path = os.path.join(MODEL_OUTPUT_DIR, 'preprocessor.joblib') #
            joblib.dump(preprocessor, preprocessor_path) #
            print(f"- Saved preprocessor to {preprocessor_path}") #
            saved_items_count += 1
        except Exception as e_prep: #
             print(f"Error saving preprocessor: {e_prep}") #
    else: #
         print("- Preprocessor not found or not created, skipping save.") #

    # --- Save the list of feature columns used after preprocessing ---
    if 'processed_feature_names' in locals() and len(processed_feature_names) > 0:
        print("Saving processed feature names...")
        try:
            features_path = os.path.join(MODEL_OUTPUT_DIR, 'feature_cols.joblib') #
            joblib.dump(processed_feature_names, features_path) #
            print(f"- Saved processed feature list ({len(processed_feature_names)} features) to {features_path}") #
            saved_items_count += 1
        except Exception as e_feat: #
             print(f"Error saving feature list: {e_feat}") #
    else: #
         print("- Processed feature names list not found, skipping save.") #

    # --- Save the ensemble weights ---
    if 'ensemble_weights' in locals() and ensemble_weights: # Check if weights exist
        print("Saving ensemble weights...")
        try:
            weights_path = os.path.join(MODEL_OUTPUT_DIR, 'ensemble_weights.joblib') #
            joblib.dump(ensemble_weights, weights_path) #
            print(f"- Saved ensemble weights to {weights_path}") #
            saved_items_count += 1
        except Exception as e_weights: #
            print(f"Error saving ensemble weights: {e_weights}") #
    else: #
        print("- Ensemble weights not found or not calculated, skipping save.") #

    print(f"\nSaving process complete. Items saved: {saved_items_count}") #

except Exception as e: # Catch any unexpected error during the overall saving process
     print(f"A critical error occurred during the saving process: {e}") #
     traceback.print_exc() #
# Out:
# --- Step 13: Saving Models and Components ---
# Attempting to save components to: c:\Users\User\Downloads\Monash\VS\chicky_chicky\bitcoin_onchain_models
# Saving trained models...
# - Saved model: XGBoost to bitcoin_onchain_models/XGBoost_model.joblib
# - Saved model: Random Forest to bitcoin_onchain_models/Random Forest_model.joblib
# - Saved model: MLP to bitcoin_onchain_models/MLP_model.joblib
# - Saved model: Logistic to bitcoin_onchain_models/Logistic_model.joblib
# Saving preprocessor...
# - Saved preprocessor to bitcoin_onchain_models/preprocessor.joblib
# Saving processed feature names...
# - Saved processed feature list (62 features) to bitcoin_onchain_models/feature_cols.joblib
# Saving ensemble weights...
# - Saved ensemble weights to bitcoin_onchain_models/ensemble_weights.joblib
#
# Saving process complete. Items saved: 7

# %%
# --- Step 14: Exporting Key Results to CSV Files ---
print("\n--- Step 14: Exporting Key Results to CSV Files ---") #

export_files_count = 0 # Counter for exported files

# --- 1. Export Backtest Results DataFrame ---
if 'backtest_results_df' in locals() and isinstance(backtest_results_df, pd.DataFrame) and not backtest_results_df.empty: #
    print("Exporting backtest simulation results...")
    try:
        backtest_results_filename = os.path.join(MODEL_OUTPUT_DIR, 'backtest_simulation_results.csv') #
        # Save with index (which is the date)
        backtest_results_df.to_csv(backtest_results_filename, index=True) #
        print(f"- Successfully exported backtest simulation results to: {backtest_results_filename}") #
        export_files_count += 1
    except Exception as e: #
        print(f"Error exporting backtest simulation results: {e}") #
else: #
    print("- Skipping export of backtest simulation results (DataFrame not found or empty).") #

# --- 2. Export Trade History DataFrame ---
# Check if the backtest object exists and has the trade_history attribute
if 'backtest' in locals() and backtest is not None and hasattr(backtest, 'trade_history') and isinstance(backtest.trade_history, pd.DataFrame) and not backtest.trade_history.empty: #
    print("Exporting trade history...")
    try:
        trade_history_filename = os.path.join(MODEL_OUTPUT_DIR, 'backtest_trade_history.csv') #
        # Usually save trade history without the default integer index
        backtest.trade_history.to_csv(trade_history_filename, index=False) #
        print(f"- Successfully exported trade history to: {trade_history_filename}") #
        export_files_count += 1
    except Exception as e: #
        print(f"Error exporting trade history: {e}") #
else: #
    print("- Skipping export of trade history (backtest object or history not found/empty).") #

# --- 3. Export Model Evaluation Metrics ---
if 'all_metrics' in locals() and isinstance(all_metrics, dict) and all_metrics: #
    print("Exporting model evaluation metrics...")
    try:
        # Convert the dictionary of dictionaries to a list of dictionaries for DataFrame creation
        metrics_list_for_export = [] #
        for eval_key, metrics_dict in all_metrics.items(): #
            if isinstance(metrics_dict, dict): #
                # Create a flat dictionary including the evaluation key (e.g., 'Ensemble_Test')
                flat_metrics = {'evaluation_key': eval_key} # Add key identifying the evaluation
                flat_metrics.update(metrics_dict) # Add metrics from the inner dict

                # Optional: Further flatten the classification report dict if needed
                if 'classification_report_dict' in flat_metrics and isinstance(flat_metrics['classification_report_dict'], dict): #
                     try: # Flatten specific scores like F1 for class 1
                          class_1_report = flat_metrics['classification_report_dict'].get('Up (1)', {}) # Use target name 'Up (1)'
                          if isinstance(class_1_report, dict):
                               flat_metrics['precision_1'] = class_1_report.get('precision')
                               flat_metrics['recall_1'] = class_1_report.get('recall')
                               flat_metrics['f1_score_1'] = class_1_report.get('f1-score')
                               flat_metrics['support_1'] = class_1_report.get('support')
                          # Flatten overall scores
                          flat_metrics['accuracy_overall'] = flat_metrics['classification_report_dict'].get('accuracy')
                          if 'macro avg' in flat_metrics['classification_report_dict']:
                                flat_metrics['f1_macro_avg'] = flat_metrics['classification_report_dict']['macro avg'].get('f1-score')
                          if 'weighted avg' in flat_metrics['classification_report_dict']:
                                flat_metrics['f1_weighted_avg'] = flat_metrics['classification_report_dict']['weighted avg'].get('f1-score')
                     except Exception as e_flat:
                          print(f"Warning: Could not fully flatten classification report for {eval_key}: {e_flat}")
                     # Remove the nested dict after flattening relevant parts
                     flat_metrics.pop('classification_report_dict', None) # Remove original dict
                # Remove text report if dict was processed
                if 'classification_report_text' in flat_metrics:
                    flat_metrics.pop('classification_report_text', None) # Optionally remove text version

                metrics_list_for_export.append(flat_metrics) # Add flattened dict to list
            # else: # Optional: Log unexpected format
                 # print(f"Warning: Unexpected format for metrics key '{eval_key}'. Skipping export.")

        if metrics_list_for_export: # Only proceed if we have data to export
            metrics_export_df = pd.DataFrame(metrics_list_for_export) # Create DataFrame
            evaluation_metrics_filename = os.path.join(MODEL_OUTPUT_DIR, 'model_evaluation_metrics.csv') #
            metrics_export_df.to_csv(evaluation_metrics_filename, index=False) #
            print(f"- Successfully exported evaluation metrics to: {evaluation_metrics_filename}") #
            export_files_count += 1
        else: #
            print("- No suitable metrics data found to export.") #

    except Exception as e: #
        print(f"Error exporting evaluation metrics: {e}") #
        traceback.print_exc() # More detail for debugging metric export
else: #
    print("- Skipping export of evaluation metrics (dictionary 'all_metrics' not found or empty).") #


print(f"\nCSV export process complete. Files exported: {export_files_count}") #
# Out:
# --- Step 14: Exporting Key Results to CSV Files ---
# Exporting backtest simulation results...
# - Successfully exported backtest simulation results to: bitcoin_onchain_models/backtest_simulation_results.csv
# Exporting trade history...
# - Successfully exported trade history to: bitcoin_onchain_models/backtest_trade_history.csv
# Exporting model evaluation metrics...
# - Successfully exported evaluation metrics to: bitcoin_onchain_models/model_evaluation_metrics.csv
#
# CSV export process complete. Files exported: 3

# %%
# --- Step 15: Running Regime Analysis ---
print("\n--- Step 15: Running Regime Analysis ---") #

# Run regime analysis on the full dataset (or you could use df_ready)
if 'df_ready' in locals() and df_ready is not None and not df_ready.empty:
    # Check if we have return data, price data, or existing regime data
    if 'current_regime' in df_ready.columns or PRICE_COLUMN in df_ready.columns:
        try:
            # Run the regime analysis
            regime_analysis = run_regime_analysis(
                df=df_ready,
                returns_col='returns',  # This will be calculated if not present
                price_col=PRICE_COLUMN,
                n_regimes=6
            )
            
            if regime_analysis and hasattr(regime_analysis, 'data') and 'regime' in regime_analysis.data.columns:
                # Save the regime data to CSV
                regime_data = regime_analysis.data[['regime', 'returns', 'volatility']].copy()
                regime_filename = os.path.join(MODEL_OUTPUT_DIR, 'regime_data.csv')
                regime_data.to_csv(regime_filename)
                print(f"Regime data saved to: {regime_filename}")
                
                # Save regime statistics to CSV
                if hasattr(regime_analysis, 'regime_stats'):
                    regime_stats_filename = os.path.join(MODEL_OUTPUT_DIR, 'regime_statistics.csv')
                    regime_analysis.regime_stats.to_csv(regime_stats_filename)
                    print(f"Regime statistics saved to: {regime_stats_filename}")
                
                # Save regime transitions to CSV
                if hasattr(regime_analysis, 'transition_probs'):
                    transition_filename = os.path.join(MODEL_OUTPUT_DIR, 'regime_transitions.csv')
                    regime_analysis.transition_probs.to_csv(transition_filename)
                    print(f"Regime transitions saved to: {transition_filename}")
            
        except Exception as e:
            print(f"Error during regime analysis: {e}")
            traceback.print_exc()
    else:
        print(f"Skipping regime analysis: Neither 'current_regime' nor '{PRICE_COLUMN}' found in data.")
else:
    print("Skipping regime analysis: Required data missing.")
# Out:
# --- Step 15: Running Regime Analysis ---
#
# --- Starting Market Regime Analysis ---
# Found existing regime data in column 'current_regime'
# Using existing regime classifications with 6 unique regimes
# --- Analyzing Existing Regime Data ---
# --- Regime Analysis ---
# --- Regime Statistics (Calculated from Data) ---
#    count  avg_return  volatility    sharpe  max_drawdown
# 0   7976    0.000154    0.007349  0.002019     -0.707287
# 1  10581    0.000040    0.004886 -0.020302     -0.290295
# 2   2240   -0.000187    0.009128 -0.035677     -0.907291
# 3   2457   -0.000096    0.008770 -0.026833     -0.641803
# 4  12055    0.000141    0.006130  0.000334     -0.553837
# 5   7915    0.000091    0.007361 -0.006485     -0.377153
#
# --- Regime Counts (Calculated from Data) ---
# regime
# 0     7976
# 1    10581
# 2     2240
# 3     2457
# 4    12055
# 5     7915
# Name: count, dtype: int64
#
# Regime Stats Summary:
# Regime 0 (Medium Activity (Stable)): AvgRet=0.000154, Vol=0.007349
# Regime 1 (Low Activity/Calm (Lowest Volatility)): AvgRet=0.000040, Vol=0.004886
# Regime 2 (Whale Activity (Negative Returns)): AvgRet=-0.000187, Vol=0.009128
# Regime 3 (Moderate Activity (Steady)): AvgRet=-0.000096, Vol=0.008770
# Regime 4 (Small High-Frequency (Moderate Volatility)): AvgRet=0.000141, Vol=0.006130
# Regime 5 (Moderate Activity (Steady)): AvgRet=0.000091, Vol=0.007361
# --- Building Transition Probability Model ---
# --- Regime Transition Counts (Calculated from Data) ---
# regime           0     1     2    3     4     5
# regime_shift
# 0.0           4186   492   495  208  2053   542
# 1.0            513  6864   134  197  1954   919
# 2.0            591   107  1236   39   191    76
# 3.0            230   115    43  726   254  1089
# 4.0           1963  2076   247  307  5960  1501
# 5.0            493   927    85  980  1643  3787
# --- Regime Transition Probability Matrix ---
#               To 0      To 1      To 2      To 3      To 4      To 5
# From 0.0  0.524824  0.061685  0.062061  0.026078  0.257397  0.067954
# From 1.0  0.048483  0.648710  0.012664  0.018618  0.184671  0.086854
# From 2.0  0.263839  0.047768  0.551786  0.017411  0.085268  0.033929
# From 3.0  0.093610  0.046805  0.017501  0.295482  0.103378  0.443223
# From 4.0  0.162851  0.172225  0.020491  0.025469  0.494442  0.124523
# From 5.0  0.062287  0.117119  0.010739  0.123816  0.207581  0.478459
# --- Expected Duration in Each Regime (Periods) ---
# Regime 1 (Low Activity/Calm (Lowest Volatility)): 2.85
# Regime 2 (Whale Activity (Negative Returns)): 2.23
# Regime 0 (Medium Activity (Stable)): 2.10
# Regime 4 (Small High-Frequency (Moderate Volatility)): 1.98
# Regime 5 (Moderate Activity (Steady)): 1.92
# Regime 3 (Moderate Activity (Steady)): 1.42
# --- Most Likely Next Regimes (Excluding Self-Transitions) ---
# From Regime 0 (Medium Activity (Stable)):
#   → Regime 4 (Small High-Frequency (Moderate Volatility)): 0.257
#   → Regime 5 (Moderate Activity (Steady)): 0.068
#   → Regime 2 (Whale Activity (Negative Returns)): 0.062
#   → Regime 1 (Low Activity/Calm (Lowest Volatility)): 0.062
#   → Regime 3 (Moderate Activity (Steady)): 0.026
# From Regime 1 (Low Activity/Calm (Lowest Volatility)):
#   → Regime 4 (Small High-Frequency (Moderate Volatility)): 0.185
#   → Regime 5 (Moderate Activity (Steady)): 0.087
#   → Regime 0 (Medium Activity (Stable)): 0.048
#   → Regime 3 (Moderate Activity (Steady)): 0.019
#   → Regime 2 (Whale Activity (Negative Returns)): 0.013
# From Regime 2 (Whale Activity (Negative Returns)):
#   → Regime 0 (Medium Activity (Stable)): 0.264
#   → Regime 4 (Small High-Frequency (Moderate Volatility)): 0.085
#   → Regime 1 (Low Activity/Calm (Lowest Volatility)): 0.048
#   → Regime 5 (Moderate Activity (Steady)): 0.034
#   → Regime 3 (Moderate Activity (Steady)): 0.017
# From Regime 3 (Moderate Activity (Steady)):
#   → Regime 5 (Moderate Activity (Steady)): 0.443
#   → Regime 4 (Small High-Frequency (Moderate Volatility)): 0.103
#   → Regime 0 (Medium Activity (Stable)): 0.094
#   → Regime 1 (Low Activity/Calm (Lowest Volatility)): 0.047
#   → Regime 2 (Whale Activity (Negative Returns)): 0.018
# From Regime 4 (Small High-Frequency (Moderate Volatility)):
#   → Regime 1 (Low Activity/Calm (Lowest Volatility)): 0.172
#   → Regime 0 (Medium Activity (Stable)): 0.163
#   → Regime 5 (Moderate Activity (Steady)): 0.125
#   → Regime 3 (Moderate Activity (Steady)): 0.025
#   → Regime 2 (Whale Activity (Negative Returns)): 0.020
# From Regime 5 (Moderate Activity (Steady)):
#   → Regime 4 (Small High-Frequency (Moderate Volatility)): 0.208
#   → Regime 3 (Moderate Activity (Steady)): 0.124
#   → Regime 1 (Low Activity/Calm (Lowest Volatility)): 0.117
#   → Regime 0 (Medium Activity (Stable)): 0.062
#   → Regime 2 (Whale Activity (Negative Returns)): 0.011
# Calculating transition impact...
# --- Top 5 Positive Impact Transitions (Prob * Impact) ---
#   3→5: Impact=0.000708, Prob=0.443, RetΔ=0.000188, VolΔ=-0.001409
#   2→0: Impact=0.000559, Prob=0.264, RetΔ=0.000340, VolΔ=-0.001778
#   0→4: Impact=0.000311, Prob=0.257, RetΔ=-0.000013, VolΔ=-0.001220
#   3→4: Impact=0.000297, Prob=0.103, RetΔ=0.000237, VolΔ=-0.002640
#   5→1: Impact=0.000284, Prob=0.117, RetΔ=-0.000051, VolΔ=-0.002475
# --- Top 5 Negative Impact Transitions (Prob * Impact) ---
#   1→4: Impact=-0.000211, Prob=0.185, RetΔ=0.000101, VolΔ=0.001244
#   1→5: Impact=-0.000211, Prob=0.087, RetΔ=0.000051, VolΔ=0.002475
#   5→3: Impact=-0.000198, Prob=0.124, RetΔ=-0.000188, VolΔ=0.001409
#   4→0: Impact=-0.000197, Prob=0.163, RetΔ=0.000013, VolΔ=0.001220
#   4→5: Impact=-0.000160, Prob=0.125, RetΔ=-0.000050, VolΔ=0.001231
# --- Expected Impact Score per Regime (Based on Transitions) ---
# Regime 3 (Moderate Activity (Steady)): 0.001342
# Regime 2 (Whale Activity (Negative Returns)): 0.001133
# Regime 5 (Moderate Activity (Steady)): 0.000335
# Regime 0 (Medium Activity (Stable)): 0.000275
# Regime 4 (Small High-Frequency (Moderate Volatility)): -0.000301
# Regime 1 (Low Activity/Calm (Lowest Volatility)): -0.000667
# Regime transition probability model analysis complete.
# --- Performing Regime Cluster Analysis ---
# --- Analyzing Regime Clusters (Part 1: Stats Extraction) ---
# Using pre-defined regime statistics for clustering.
# Warning: Pre-defined stats missing required keys. Recalculating from data.
# Features used for clustering: ['volatility', 'avg_return']
# Data scaled using StandardScaler.
# Performing Hierarchical Clustering...
# Performing K-means Clustering (k=3)...
# K-means cluster assignments added to stats DataFrame.
# --- Regime Statistics with Cluster Assignments ---
#                                   description  cluster  volatility  avg_return
# 0                    Medium Activity (Stable)        0    0.007349    0.000154
# 1       Low Activity/Calm (Lowest Volatility)        2    0.004886    0.000040
# 2           Whale Activity (Negative Returns)        1    0.009128   -0.000187
# 3                  Moderate Activity (Steady)        1    0.008770   -0.000096
# 4  Small High-Frequency (Moderate Volatility)        0    0.006130    0.000141
# 5                  Moderate Activity (Steady)        0    0.007361    0.000091
# --- Simplified Regime Groups Based on Clustering ---
# Cluster 0: Regimes [0, 4, 5]
#   Avg Volatility: 0.006947
#   Avg Return: 0.000129
#   Contained Regimes: Medium Activity (Stable), Small High-Frequency (Moderate Volatility), Moderate Activity (Steady)
# --------------------
# Cluster 1: Regimes [2, 3]
#   Avg Volatility: 0.008949
#   Avg Return: -0.000142
#   Contained Regimes: Whale Activity (Negative Returns), Moderate Activity (Steady)
# --------------------
# Cluster 2: Regimes [1]
#   Avg Volatility: 0.004886
#   Avg Return: 0.000040
#   Contained Regimes: Low Activity/Calm (Lowest Volatility)
# --------------------
# --- Suggested Trading Approach by Cluster (Illustrative) ---
# Cluster 0 (Regimes [0, 4, 5]):
#   Characteristics: AvgRet=0.000129, AvgVol=0.006947, AvgSharpe=-0.0014
#   Suggested Strategy: Trend Following / Momentum
#   Suggested Size: Larger
#   Stop Loss Type: Wider (Trailing?)
# --------------------
# Cluster 1 (Regimes [2, 3]):
#   Characteristics: AvgRet=-0.000142, AvgVol=0.008949, AvgSharpe=-0.0313
#   Suggested Strategy: Avoid / Counter-Trend (Risky)
#   Suggested Size: Minimum / None
#   Stop Loss Type: Very Tight / Quick Exit
# --------------------
# Cluster 2 (Regimes [1]):
#   Characteristics: AvgRet=0.000040, AvgVol=0.004886, AvgSharpe=-0.0203
#   Suggested Strategy: Trend Following / Momentum
#   Suggested Size: Larger
#   Stop Loss Type: Wider (Trailing?)
# --------------------
# Regime cluster analysis reporting complete.
# Regime cluster analysis complete.
# Regime distribution plot saved to bitcoin_onchain_models/regime_distribution.png
# Regime volatility-return plot saved to bitcoin_onchain_models/regime_vol_return.png
# --- Current Market State ---
# Latest Regime: 4 - Small High-Frequency (Moderate Volatility)
# Average Return: 0.000141
# Volatility: 0.006130
# Sharpe Ratio: 0.0003
# Market regime analysis complete.
# Regime data saved to: bitcoin_onchain_models/regime_data.csv
# Regime statistics saved to: bitcoin_onchain_models/regime_statistics.csv
# Regime transitions saved to: bitcoin_onchain_models/regime_transitions.csv

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime, timedelta

# Load the data
def load_data(file_path):
    """Load and preprocess the dataset."""
    try:
        df = pd.read_csv(file_path)
        # Convert datetime to proper format
        df['datetime'] = pd.to_datetime(df['datetime'])
        df.set_index('datetime', inplace=True)
        return df
    except Exception as e:
        print(f"Error loading data: {e}")
        return None

# Define trading strategy based on regime analysis
class SimpleRegimeTrader:
    def __init__(self, data):
        self.data = data
        self.positions = []
        self.trades = []
        self.equity_curve = []
        self.starting_balance = 10000
        self.balance = self.starting_balance
        self.regime_accuracy = {}
        
        # Initialize regime accuracy tracking
        for regime in range(6):
            self.regime_accuracy[regime] = {'correct': 0, 'total': 0}
        
        # Define simplified trading rules for each regime
        self.regime_rules = {
            # Medium Activity (Stable): Positive returns, moderate volatility
            0: {'action': 'BUY', 'size': 0.6, 'stop_loss_pct': 2.0, 'take_profit_pct': 3.0},
            
            # Low Activity/Calm (Lowest Volatility): Slight positive returns
            1: {'action': 'BUY', 'size': 0.8, 'stop_loss_pct': 1.5, 'take_profit_pct': 2.5},
            
            # Whale Activity (Negative Returns): High volatility, negative returns
            2: {'action': 'SELL', 'size': 0.3, 'stop_loss_pct': 1.0, 'take_profit_pct': 2.0},
            
            # Moderate Activity (Steady): Negative returns
            3: {'action': 'SELL', 'size': 0.4, 'stop_loss_pct': 1.5, 'take_profit_pct': 2.5},
            
            # Small High-Frequency (Moderate Volatility): Positive returns
            4: {'action': 'BUY', 'size': 0.6, 'stop_loss_pct': 1.8, 'take_profit_pct': 3.0},
            
            # Moderate Activity (Steady): Positive returns
            5: {'action': 'BUY', 'size': 0.5, 'stop_loss_pct': 2.0, 'take_profit_pct': 3.0}
        }
        
        # High-impact transitions from the analysis
        self.positive_transitions = [(3, 5), (2, 0), (0, 4), (3, 4), (5, 1)]
        self.negative_transitions = [(1, 4), (1, 5), (5, 3), (4, 0), (4, 5)]
    
    def check_prediction_accuracy(self, idx):
        """Check if the predicted next regime matches the actual next regime."""
        if idx + 1 >= len(self.data):
            return False
            
        current_row = self.data.iloc[idx]
        next_row = self.data.iloc[idx + 1]
        
        current_regime = int(current_row['current_regime'])
        predicted_next = int(current_row['predicted_next_regime'])
        actual_next = int(next_row['current_regime'])
        
        # Update accuracy stats
        self.regime_accuracy[current_regime]['total'] += 1
        
        if predicted_next == actual_next:
            self.regime_accuracy[current_regime]['correct'] += 1
            return True
        return False
    
    def execute_trade(self, idx):
        """Execute a trade based on current regime and prediction."""
        row = self.data.iloc[idx]
        
        current_regime = int(row['current_regime'])
        predicted_regime = int(row['predicted_next_regime'])
        prediction_prob = row['next_regime_probability']
        current_price = row['Close']
        timestamp = self.data.index[idx]
        
        # Get base trading rules for this regime
        rules = self.regime_rules[current_regime].copy()
        
        # Check if this is a high-impact transition
        transition = (current_regime, predicted_regime)
        
        # Adjust position size based on transition impact
        if transition in self.positive_transitions:
            rules['size'] *= 1.2  # Increase size for positive impact transitions
        elif transition in self.negative_transitions:
            rules['size'] *= 0.8  # Decrease size for negative impact transitions
            
        # Adjust size based on prediction confidence
        if prediction_prob > 0.6:
            rules['size'] *= 1.1
        elif prediction_prob < 0.4:
            rules['size'] *= 0.9
        
        # Calculate position details
        position_size = self.balance * rules['size']
        units = position_size / current_price
        
        # Set stop loss and take profit levels
        if rules['action'] == 'BUY':
            stop_loss = current_price * (1 - rules['stop_loss_pct']/100)
            take_profit = current_price * (1 + rules['take_profit_pct']/100)
        else:  # SELL
            stop_loss = current_price * (1 + rules['stop_loss_pct']/100)
            take_profit = current_price * (1 - rules['take_profit_pct']/100)
        
        # Record the trade
        trade = {
            'entry_time': timestamp,
            'entry_price': current_price,
            'type': rules['action'],
            'units': units,
            'stop_loss': stop_loss,
            'take_profit': take_profit,
            'size': position_size,
            'regime': current_regime,
            'predicted_regime': predicted_regime,
            'exit_time': None,
            'exit_price': None,
            'pnl': 0,
            'pnl_pct': 0,
            'status': 'OPEN'
        }
        
        self.trades.append(trade)
        self.balance -= position_size  # Deduct the position size from balance
        
        print(f"[{timestamp}] {rules['action']} at {current_price}, Size: ${position_size:.2f}, SL: {stop_loss:.2f}, TP: {take_profit:.2f}")
        return len(self.trades) - 1  # Return the trade index
    
    def check_exits(self, idx):
        """Check if any open trades should be closed."""
        if not self.trades:
            return
            
        current_price = self.data.iloc[idx]['Close']
        timestamp = self.data.index[idx]
        
        # Check each open trade
        for i, trade in enumerate(self.trades):
            if trade['status'] != 'OPEN':
                continue
                
            exit_reason = None
            
            # Check stop loss
            if (trade['type'] == 'BUY' and current_price <= trade['stop_loss']) or \
               (trade['type'] == 'SELL' and current_price >= trade['stop_loss']):
                exit_reason = 'STOP_LOSS'
            
            # Check take profit
            elif (trade['type'] == 'BUY' and current_price >= trade['take_profit']) or \
                 (trade['type'] == 'SELL' and current_price <= trade['take_profit']):
                exit_reason = 'TAKE_PROFIT'
            
            # If we have an exit reason, close the trade
            if exit_reason:
                # Calculate profit/loss
                if trade['type'] == 'BUY':
                    pnl = (current_price - trade['entry_price']) * trade['units']
                else:  # SELL
                    pnl = (trade['entry_price'] - current_price) * trade['units']
                
                # Update trade record
                self.trades[i]['exit_time'] = timestamp
                self.trades[i]['exit_price'] = current_price
                self.trades[i]['pnl'] = pnl
                self.trades[i]['pnl_pct'] = (pnl / trade['size']) * 100
                self.trades[i]['status'] = 'CLOSED'
                self.trades[i]['exit_reason'] = exit_reason
                
                # Update balance
                self.balance += trade['size'] + pnl
                
                print(f"[{timestamp}] Closed trade at {current_price}, Reason: {exit_reason}, P/L: ${pnl:.2f} ({self.trades[i]['pnl_pct']:.2f}%)")
    
    def run_backtest(self):
        """Run the backtest on the dataset."""
        print("Starting backtest...")
        
        # Skip the last row since we need to check if predictions were accurate
        for i in range(len(self.data) - 1):
            # Track current equity (balance + open positions)
            open_value = sum(
                (self.data.iloc[i]['Close'] - t['entry_price']) * t['units'] if t['type'] == 'BUY' 
                else (t['entry_price'] - self.data.iloc[i]['Close']) * t['units']
                for t in self.trades if t['status'] == 'OPEN'
            )
            self.equity_curve.append(self.balance + open_value)
            
            # Check if we should exit any positions
            self.check_exits(i)
            
            # Check prediction accuracy and execute new trades if no open positions
            is_prediction_accurate = self.check_prediction_accuracy(i)
            
            # Only open a trade if we have no open positions
            if not any(t['status'] == 'OPEN' for t in self.trades):
                confidence_threshold = 0.45
                if is_prediction_accurate or self.data.iloc[i]['next_regime_probability'] > confidence_threshold:
                    self.execute_trade(i)
        
        # Close any remaining open trades at the last price
        last_idx = len(self.data) - 1
        self.check_exits(last_idx)
        
        # Calculate final equity value
        final_open_value = sum(
            (self.data.iloc[last_idx]['Close'] - t['entry_price']) * t['units'] if t['type'] == 'BUY' 
            else (t['entry_price'] - self.data.iloc[last_idx]['Close']) * t['units']
            for t in self.trades if t['status'] == 'OPEN'
        )
        self.equity_curve.append(self.balance + final_open_value)
        
        return self.analyze_results()
    
    def analyze_results(self):
        """Analyze backtest results."""
        # Calculate overall performance
        initial_balance = self.starting_balance
        final_balance = self.balance
        pnl = final_balance - initial_balance
        pnl_pct = (pnl / initial_balance) * 100
        
        # Calculate trade statistics
        completed_trades = [t for t in self.trades if t['status'] == 'CLOSED']
        total_trades = len(completed_trades)
        winning_trades = [t for t in completed_trades if t['pnl'] > 0]
        losing_trades = [t for t in completed_trades if t['pnl'] <= 0]
        
        win_rate = len(winning_trades) / total_trades * 100 if total_trades > 0 else 0
        
        avg_win = sum(t['pnl'] for t in winning_trades) / len(winning_trades) if winning_trades else 0
        avg_loss = sum(t['pnl'] for t in losing_trades) / len(losing_trades) if losing_trades else 0
        
        profit_factor = abs(sum(t['pnl'] for t in winning_trades)) / abs(sum(t['pnl'] for t in losing_trades)) if losing_trades and sum(t['pnl'] for t in losing_trades) != 0 else float('inf')
        
        # Calculate max drawdown
        equity_curve = np.array(self.equity_curve)
        peak = np.maximum.accumulate(equity_curve)
        drawdown = 100 * ((peak - equity_curve) / peak)
        max_drawdown = np.max(drawdown)
        
        # Calculate regime prediction accuracy
        accuracy_by_regime = {}
        for regime, data in self.regime_accuracy.items():
            if data['total'] > 0:
                accuracy = (data['correct'] / data['total']) * 100
            else:
                accuracy = 0
            accuracy_by_regime[regime] = {
                'total': data['total'],
                'correct': data['correct'],
                'accuracy': accuracy
            }
        
        overall_correct = sum(data['correct'] for data in self.regime_accuracy.values())
        overall_total = sum(data['total'] for data in self.regime_accuracy.values())
        overall_accuracy = (overall_correct / overall_total) * 100 if overall_total > 0 else 0
        
        # Print results
        print("\n===== BACKTEST RESULTS =====")
        print(f"Initial Balance: ${initial_balance:.2f}")
        print(f"Final Balance: ${final_balance:.2f}")
        print(f"Profit/Loss: ${pnl:.2f} ({pnl_pct:.2f}%)")
        print(f"Total Trades: {total_trades}")
        print(f"Win Rate: {win_rate:.2f}%")
        print(f"Average Win: ${avg_win:.2f}")
        print(f"Average Loss: ${avg_loss:.2f}")
        print(f"Profit Factor: {profit_factor:.2f}")
        print(f"Maximum Drawdown: {max_drawdown:.2f}%")
        
        print("\n===== REGIME PREDICTION ACCURACY =====")
        print(f"Overall Accuracy: {overall_accuracy:.2f}%")
        for regime, stats in accuracy_by_regime.items():
            print(f"Regime {regime}: {stats['accuracy']:.2f}% ({stats['correct']}/{stats['total']})")
        
        # Plot equity curve
        plt.figure(figsize=(12, 6))
        plt.plot(equity_curve)
        plt.title('Equity Curve')
        plt.xlabel('Time')
        plt.ylabel('Account Value ($)')
        plt.grid(True)
        plt.savefig('equity_curve.png')
        
        # Determine regime classification effectiveness
        if overall_accuracy > 60 and pnl_pct > 10:
            assessment = "The regime classification system is HIGHLY ACCURATE and PROFITABLE."
        elif overall_accuracy > 50 and pnl_pct > 0:
            assessment = "The regime classification system is MODERATELY ACCURATE and shows POTENTIAL."
        elif overall_accuracy > 40 and pnl_pct > -10:
            assessment = "The regime classification system is SOMEWHAT PREDICTIVE but needs REFINEMENT."
        else:
            assessment = "The regime classification system is NOT RELIABLE for trading decisions."
        
        print(f"\n===== ASSESSMENT =====")
        print(assessment)
        
        # Return comprehensive results
        return {
            'pnl': pnl,
            'pnl_pct': pnl_pct,
            'win_rate': win_rate,
            'profit_factor': profit_factor,
            'max_drawdown': max_drawdown,
            'total_trades': total_trades,
            'regime_accuracy': accuracy_by_regime,
            'overall_accuracy': overall_accuracy,
            'assessment': assessment
        }


# Main execution
if __name__ == "__main__":
    # Replace with your actual file path
    file_path = "C:\\Users\\User\\Downloads\\final_merged_data_2.csv"
    
    # Load data
    data = load_data(file_path)
    
    if data is not None:
        # Run the simplified strategy
        strategy = SimpleRegimeTrader(data)
        results = strategy.run_backtest()
        
        # Print suggestions for improvement
        print("\n===== SUGGESTIONS FOR IMPROVEMENT =====")
        
        # Find worst performing regimes
        worst_regimes = sorted(
            [(r, stats['accuracy']) for r, stats in results['regime_accuracy'].items()],
            key=lambda x: x[1]
        )[:2]
        
        print(f"1. Focus on improving prediction for Regimes {worst_regimes[0][0]} and {worst_regimes[1][0]}")
        print(f"2. Adjust position sizing based on regime prediction confidence")
        print(f"3. Add additional market indicators to confirm regime transitions")
        print(f"4. Optimize stop-loss and take-profit levels for each regime")
    else:
        print("Failed to load data. Please check the file path.")
# Out:
# Starting backtest...
# [2020-04-09 00:00:00] BUY at 7325.3, Size: $5000.00, SL: 7178.79, TP: 7545.06
# [2020-04-10 08:00:00] Closed trade at 7148.89, Reason: STOP_LOSS, P/L: $-120.41 (-2.41%)
# [2020-04-10 08:00:00] SELL at 7148.89, Size: $4742.20, SL: 7256.12, TP: 6970.17
# [2020-04-10 09:00:00] Closed trade at 6954.71, Reason: TAKE_PROFIT, P/L: $128.81 (2.72%)
# [2020-04-10 09:00:00] BUY at 6954.71, Size: $5004.20, SL: 6815.62, TP: 7163.35
# [2020-04-10 19:00:00] Closed trade at 6776.81, Reason: STOP_LOSS, P/L: $-128.01 (-2.56%)
# [2020-04-10 19:00:00] SELL at 6776.81, Size: $2964.12, SL: 6844.58, TP: 6641.27
# [2020-04-10 20:00:00] Closed trade at 6865.4, Reason: STOP_LOSS, P/L: $-38.75 (-1.31%)
# [2020-04-10 20:00:00] SELL at 6865.4, Size: $2952.49, SL: 6934.05, TP: 6728.09
# [2020-04-11 09:00:00] Closed trade at 6936.23, Reason: STOP_LOSS, P/L: $-30.46 (-1.03%)
# [2020-04-11 10:00:00] SELL at 6936.6, Size: $2943.35, SL: 7005.97, TP: 6797.87
# [2020-04-12 00:00:00] Closed trade at 6792.17, Reason: TAKE_PROFIT, P/L: $61.28 (2.08%)
# [2020-04-12 00:00:00] BUY at 6792.17, Size: $5923.48, SL: 6669.91, TP: 6995.94
# [2020-04-12 19:00:00] Closed trade at 7034.06, Reason: TAKE_PROFIT, P/L: $210.95 (3.56%)
# [2020-04-12 19:00:00] BUY at 7034.06, Size: $8873.41, SL: 6928.55, TP: 7209.91
# [2020-04-13 03:00:00] Closed trade at 6908.24, Reason: STOP_LOSS, P/L: $-158.72 (-1.79%)
# [2020-04-13 03:00:00] BUY at 6908.24, Size: $4962.35, SL: 6770.08, TP: 7115.49
# [2020-04-13 04:00:00] Closed trade at 6730.0, Reason: STOP_LOSS, P/L: $-128.03 (-2.58%)
# [2020-04-13 04:00:00] BUY at 6730.0, Size: $4898.33, SL: 6595.40, TP: 6931.90
# [2020-04-14 20:00:00] Closed trade at 6969.43, Reason: TAKE_PROFIT, P/L: $174.27 (3.56%)
# [2020-04-14 20:00:00] BUY at 6969.43, Size: $4985.47, SL: 6830.04, TP: 7178.51
# [2020-04-15 14:00:00] Closed trade at 6792.27, Reason: STOP_LOSS, P/L: $-126.73 (-2.54%)
# [2020-04-15 15:00:00] BUY at 6780.48, Size: $8662.90, SL: 6678.77, TP: 6949.99
# [2020-04-16 03:00:00] Closed trade at 6619.0, Reason: STOP_LOSS, P/L: $-206.31 (-2.38%)
# [2020-04-16 03:00:00] BUY at 6619.0, Size: $4818.95, SL: 6486.62, TP: 6817.57
# [2020-04-16 11:00:00] Closed trade at 6900.02, Reason: TAKE_PROFIT, P/L: $204.60 (4.25%)
# [2020-04-16 11:00:00] BUY at 6900.02, Size: $5905.49, SL: 6762.02, TP: 7107.02
# [2020-04-17 02:00:00] Closed trade at 7168.04, Reason: TAKE_PROFIT, P/L: $229.39 (3.88%)
# [2020-04-17 02:00:00] BUY at 7168.04, Size: $6043.13, SL: 7024.68, TP: 7383.08
# [2020-04-18 03:00:00] Closed trade at 7024.19, Reason: STOP_LOSS, P/L: $-121.27 (-2.01%)
# [2020-04-18 03:00:00] BUY at 7024.19, Size: $4975.30, SL: 6883.71, TP: 7234.92
# [2020-04-18 17:00:00] Closed trade at 7250.0, Reason: TAKE_PROFIT, P/L: $159.94 (3.21%)
# [2020-04-18 17:00:00] BUY at 7250.0, Size: $6066.33, SL: 7119.50, TP: 7467.50
# [2020-04-19 17:00:00] Closed trade at 7103.83, Reason: STOP_LOSS, P/L: $-122.31 (-2.02%)
# [2020-04-19 17:00:00] BUY at 7103.83, Size: $5992.94, SL: 6975.96, TP: 7316.94
# [2020-04-20 15:00:00] Closed trade at 6965.03, Reason: STOP_LOSS, P/L: $-117.09 (-1.95%)
# [2020-04-20 15:00:00] BUY at 6965.03, Size: $4935.57, SL: 6825.73, TP: 7173.98
# [2020-04-20 23:00:00] Closed trade at 6768.81, Reason: STOP_LOSS, P/L: $-139.05 (-2.82%)
# [2020-04-20 23:00:00] BUY at 6768.81, Size: $5839.26, SL: 6646.97, TP: 6971.87
# [2020-04-22 17:00:00] Closed trade at 7075.0, Reason: TAKE_PROFIT, P/L: $264.14 (4.52%)
# [2020-04-22 17:00:00] BUY at 7075.0, Size: $5997.74, SL: 6947.65, TP: 7287.25
# [2020-04-23 18:00:00] Closed trade at 7546.0, Reason: TAKE_PROFIT, P/L: $399.28 (6.66%)
# [2020-04-23 18:00:00] BUY at 7546.0, Size: $6237.32, SL: 7410.17, TP: 7772.38
# [2020-04-28 02:00:00] Closed trade at 7776.55, Reason: TAKE_PROFIT, P/L: $190.57 (3.06%)
# [2020-04-28 02:00:00] BUY at 7776.55, Size: $6351.65, SL: 7621.02, TP: 8009.85
# [2020-04-29 14:00:00] Closed trade at 8133.44, Reason: TAKE_PROFIT, P/L: $291.50 (4.59%)
# [2020-04-29 14:00:00] BUY at 8133.44, Size: $5438.79, SL: 7970.77, TP: 8377.44
# [2020-04-29 20:00:00] Closed trade at 8597.29, Reason: TAKE_PROFIT, P/L: $310.17 (5.70%)
# [2020-04-29 20:00:00] SELL at 8597.29, Size: $3356.33, SL: 8683.26, TP: 8425.34
# [2020-04-29 21:00:00] Closed trade at 8715.65, Reason: STOP_LOSS, P/L: $-46.21 (-1.38%)
# [2020-04-29 21:00:00] SELL at 8715.65, Size: $3342.47, SL: 8802.81, TP: 8541.34
# [2020-04-30 00:00:00] Closed trade at 8929.05, Reason: STOP_LOSS, P/L: $-81.84 (-2.45%)
# [2020-04-30 00:00:00] SELL at 8929.05, Size: $3317.92, SL: 9018.34, TP: 8750.47
# [2020-04-30 07:00:00] Closed trade at 9292.88, Reason: STOP_LOSS, P/L: $-135.19 (-4.07%)
# [2020-04-30 07:00:00] SELL at 9292.88, Size: $3277.36, SL: 9385.81, TP: 9107.02
# [2020-04-30 13:00:00] Closed trade at 8660.18, Reason: TAKE_PROFIT, P/L: $223.14 (6.81%)
# [2020-04-30 14:00:00] SELL at 8900.55, Size: $3344.30, SL: 8989.56, TP: 8722.54
# [2020-04-30 20:00:00] Closed trade at 8689.28, Reason: TAKE_PROFIT, P/L: $79.38 (2.37%)
# [2020-04-30 20:00:00] SELL at 8689.28, Size: $3368.11, SL: 8776.17, TP: 8515.49
# [2020-04-30 23:00:00] Closed trade at 8847.01, Reason: STOP_LOSS, P/L: $-61.14 (-1.82%)
# [2020-05-01 00:00:00] BUY at 8823.08, Size: $6699.54, SL: 8646.62, TP: 9087.77
# [2020-05-01 03:00:00] Closed trade at 8627.32, Reason: STOP_LOSS, P/L: $-148.64 (-2.22%)
# [2020-05-01 03:00:00] BUY at 8627.32, Size: $6610.36, SL: 8454.77, TP: 8886.14
# [2020-05-01 14:00:00] Closed trade at 8905.1, Reason: TAKE_PROFIT, P/L: $212.84 (3.22%)
# [2020-05-01 16:00:00] SELL at 8880.0, Size: $5390.45, SL: 9013.20, TP: 8658.00
# [2020-05-03 04:00:00] Closed trade at 9128.54, Reason: STOP_LOSS, P/L: $-150.87 (-2.80%)
# [2020-05-03 04:00:00] BUY at 9128.54, Size: $5539.61, SL: 8945.97, TP: 9402.40
# [2020-05-03 17:00:00] Closed trade at 8936.77, Reason: STOP_LOSS, P/L: $-116.37 (-2.10%)
# [2020-05-03 17:00:00] BUY at 8936.77, Size: $5481.43, SL: 8758.03, TP: 9204.87
# [2020-05-04 05:00:00] Closed trade at 8692.03, Reason: STOP_LOSS, P/L: $-150.11 (-2.74%)
# [2020-05-04 05:00:00] BUY at 8692.03, Size: $5406.37, SL: 8518.19, TP: 8952.79
# [2020-05-05 08:00:00] Closed trade at 9053.68, Reason: TAKE_PROFIT, P/L: $224.94 (4.16%)
# [2020-05-05 11:00:00] BUY at 9021.76, Size: $9713.16, SL: 8886.43, TP: 9247.30
# [2020-05-05 14:00:00] Closed trade at 8861.68, Reason: STOP_LOSS, P/L: $-172.35 (-1.77%)
# [2020-05-05 14:00:00] BUY at 8861.68, Size: $5432.67, SL: 8684.45, TP: 9127.53
# [2020-05-06 14:00:00] Closed trade at 9240.88, Reason: TAKE_PROFIT, P/L: $232.47 (4.28%)
# [2020-05-06 14:00:00] BUY at 9240.88, Size: $5548.90, SL: 9056.06, TP: 9518.11
# [2020-05-07 19:00:00] Closed trade at 9532.35, Reason: TAKE_PROFIT, P/L: $175.02 (3.15%)
# [2020-05-07 19:00:00] BUY at 9532.35, Size: $9920.08, SL: 9389.36, TP: 9770.66
# [2020-05-07 21:00:00] Closed trade at 9848.56, Reason: TAKE_PROFIT, P/L: $329.07 (3.32%)
# [2020-05-07 21:00:00] BUY at 9848.56, Size: $5800.95, SL: 9651.59, TP: 10144.02
# [2020-05-09 11:00:00] Closed trade at 9606.87, Reason: STOP_LOSS, P/L: $-142.36 (-2.45%)
# [2020-05-09 11:00:00] BUY at 9606.87, Size: $5729.77, SL: 9414.73, TP: 9895.08
# [2020-05-10 04:00:00] Closed trade at 8711.45, Reason: STOP_LOSS, P/L: $-534.05 (-9.32%)
# [2020-05-10 04:00:00] BUY at 8711.45, Size: $5462.74, SL: 8537.22, TP: 8972.79
# [2020-05-10 20:00:00] Closed trade at 8279.42, Reason: STOP_LOSS, P/L: $-270.92 (-4.96%)
# [2020-05-10 20:00:00] BUY at 8279.42, Size: $5327.28, SL: 8113.83, TP: 8527.80
# [2020-05-11 00:00:00] Closed trade at 8670.75, Reason: TAKE_PROFIT, P/L: $251.80 (4.73%)
# [2020-05-11 00:00:00] BUY at 8670.75, Size: $5453.18, SL: 8497.33, TP: 8930.87
# [2020-05-11 13:00:00] Closed trade at 8494.52, Reason: STOP_LOSS, P/L: $-110.83 (-2.03%)
# [2020-05-11 13:00:00] SELL at 8494.52, Size: $3238.66, SL: 8579.47, TP: 8324.63
# [2020-05-11 14:00:00] Closed trade at 8810.75, Reason: STOP_LOSS, P/L: $-120.57 (-3.72%)
# [2020-05-11 14:00:00] SELL at 8810.75, Size: $5123.98, SL: 8942.91, TP: 8590.48
# [2020-05-11 21:00:00] Closed trade at 8509.83, Reason: TAKE_PROFIT, P/L: $175.00 (3.42%)
# [2020-05-11 21:00:00] BUY at 8509.83, Size: $6509.98, SL: 8356.65, TP: 8765.12
# [2020-05-12 13:00:00] Closed trade at 8794.47, Reason: TAKE_PROFIT, P/L: $217.75 (3.34%)
# [2020-05-12 13:00:00] SELL at 8794.47, Size: $5312.50, SL: 8926.39, TP: 8574.61
# [2020-05-12 20:00:00] Closed trade at 8934.37, Reason: STOP_LOSS, P/L: $-84.51 (-1.59%)
# [2020-05-12 20:00:00] SELL at 8934.37, Size: $3294.96, SL: 9023.71, TP: 8755.68
# [2020-05-13 15:00:00] Closed trade at 9042.44, Reason: STOP_LOSS, P/L: $-39.86 (-1.21%)
# [2020-05-13 15:00:00] BUY at 9042.44, Size: $7879.21, SL: 8861.59, TP: 9313.71
# [2020-05-14 01:00:00] Closed trade at 9369.3, Reason: TAKE_PROFIT, P/L: $284.81 (3.61%)
# [2020-05-14 01:00:00] BUY at 9369.3, Size: $6736.90, SL: 9200.65, TP: 9650.38
# [2020-05-14 13:00:00] Closed trade at 9811.98, Reason: TAKE_PROFIT, P/L: $318.30 (4.72%)
# [2020-05-14 14:00:00] BUY at 9652.99, Size: $10160.89, SL: 9508.20, TP: 9894.31
# [2020-05-15 06:00:00] Closed trade at 9495.03, Reason: STOP_LOSS, P/L: $-166.27 (-1.64%)
# [2020-05-15 06:00:00] SELL at 9495.03, Size: $5462.49, SL: 9637.46, TP: 9257.65
# [2020-05-15 11:00:00] Closed trade at 9681.29, Reason: STOP_LOSS, P/L: $-107.16 (-1.96%)
# [2020-05-15 11:00:00] BUY at 9681.29, Size: $9920.28, SL: 9536.07, TP: 9923.32
# [2020-05-15 16:00:00] Closed trade at 9513.78, Reason: STOP_LOSS, P/L: $-171.65 (-1.73%)
# [2020-05-15 16:00:00] BUY at 9513.78, Size: $5550.70, SL: 9323.50, TP: 9799.19
# [2020-05-16 00:00:00] Closed trade at 9250.19, Reason: STOP_LOSS, P/L: $-153.79 (-2.77%)
# [2020-05-16 00:00:00] BUY at 9250.19, Size: $6568.56, SL: 9083.69, TP: 9527.70
# [2020-05-17 07:00:00] Closed trade at 9536.42, Reason: TAKE_PROFIT, P/L: $203.25 (3.09%)
# [2020-05-17 07:00:00] BUY at 9536.42, Size: $6690.52, SL: 9345.69, TP: 9822.51
# [2020-05-17 19:00:00] Closed trade at 9826.22, Reason: TAKE_PROFIT, P/L: $203.32 (3.04%)
# [2020-05-17 19:00:00] BUY at 9826.22, Size: $6812.51, SL: 9649.35, TP: 10121.01
# [2020-05-18 12:00:00] Closed trade at 9582.19, Reason: STOP_LOSS, P/L: $-169.19 (-2.48%)
# [2020-05-18 12:00:00] SELL at 9582.19, Size: $3355.50, SL: 9678.01, TP: 9390.55
# [2020-05-18 18:00:00] Closed trade at 9708.59, Reason: STOP_LOSS, P/L: $-44.26 (-1.32%)
# [2020-05-18 18:00:00] BUY at 9708.59, Size: $6684.44, SL: 9514.42, TP: 9999.85
# [2020-05-20 19:00:00] Closed trade at 9412.45, Reason: STOP_LOSS, P/L: $-203.89 (-3.05%)
# [2020-05-20 19:00:00] BUY at 9412.45, Size: $9624.41, SL: 9271.26, TP: 9647.76
# [2020-05-21 18:00:00] Closed trade at 9066.0, Reason: STOP_LOSS, P/L: $-354.25 (-3.68%)
# [2020-05-21 18:00:00] BUY at 9066.0, Size: $5291.29, SL: 8884.68, TP: 9337.98
# [2020-05-21 22:00:00] Closed trade at 8814.93, Reason: STOP_LOSS, P/L: $-146.53 (-2.77%)
# [2020-05-21 22:00:00] BUY at 8814.93, Size: $5218.02, SL: 8638.63, TP: 9079.38
# [2020-05-22 01:00:00] Closed trade at 9103.08, Reason: TAKE_PROFIT, P/L: $170.57 (3.27%)
# [2020-05-22 01:00:00] BUY at 9103.08, Size: $5303.31, SL: 8921.02, TP: 9376.17
# [2020-05-25 03:00:00] Closed trade at 8718.77, Reason: STOP_LOSS, P/L: $-223.89 (-4.22%)
# [2020-05-25 04:00:00] BUY at 8812.0, Size: $9136.80, SL: 8679.82, TP: 9032.30
# [2020-05-27 14:00:00] Closed trade at 9124.14, Reason: TAKE_PROFIT, P/L: $323.65 (3.54%)
# [2020-05-27 15:00:00] BUY at 9155.47, Size: $6423.82, SL: 8972.36, TP: 9430.13
# [2020-05-28 16:00:00] Closed trade at 9431.83, Reason: TAKE_PROFIT, P/L: $193.90 (3.02%)
# [2020-05-28 16:00:00] BUY at 9431.83, Size: $5450.14, SL: 9243.19, TP: 9714.78
# [2020-05-31 02:00:00] Closed trade at 9733.1, Reason: TAKE_PROFIT, P/L: $174.09 (3.19%)
# [2020-05-31 02:00:00] BUY at 9733.1, Size: $5537.18, SL: 9538.44, TP: 10025.09
# [2020-05-31 12:00:00] Closed trade at 9535.66, Reason: STOP_LOSS, P/L: $-112.32 (-2.03%)
# [2020-05-31 12:00:00] BUY at 9535.66, Size: $5481.02, SL: 9344.95, TP: 9821.73
# [2020-06-02 03:00:00] Closed trade at 10203.64, Reason: TAKE_PROFIT, P/L: $383.95 (7.01%)
# [2020-06-02 03:00:00] BUY at 10203.64, Size: $5672.99, SL: 9999.57, TP: 10509.75
# [2020-06-02 18:00:00] Closed trade at 9587.02, Reason: STOP_LOSS, P/L: $-342.83 (-6.04%)
# [2020-06-02 18:00:00] BUY at 9587.02, Size: $6601.90, SL: 9395.28, TP: 9874.63
# [2020-06-11 02:00:00] Closed trade at 9896.53, Reason: TAKE_PROFIT, P/L: $213.14 (3.23%)
# [2020-06-11 02:00:00] BUY at 9896.53, Size: $5608.15, SL: 9698.60, TP: 10193.43
# [2020-06-11 17:00:00] Closed trade at 9622.43, Reason: STOP_LOSS, P/L: $-155.33 (-2.77%)
# [2020-06-11 17:00:00] BUY at 9622.43, Size: $5530.49, SL: 9429.98, TP: 9911.10
# [2020-06-11 20:00:00] Closed trade at 9088.0, Reason: STOP_LOSS, P/L: $-307.16 (-5.55%)
# [2020-06-11 20:00:00] BUY at 9088.0, Size: $6452.28, SL: 8924.42, TP: 9360.64
# [2020-06-11 21:00:00] Closed trade at 9374.55, Reason: TAKE_PROFIT, P/L: $203.44 (3.15%)
# [2020-06-11 21:00:00] BUY at 9374.55, Size: $6574.35, SL: 9187.06, TP: 9655.79
# [2020-06-15 07:00:00] Closed trade at 9150.54, Reason: STOP_LOSS, P/L: $-157.10 (-2.39%)
# [2020-06-15 07:00:00] BUY at 9150.54, Size: $5400.08, SL: 8967.53, TP: 9425.06
# [2020-06-16 00:00:00] Closed trade at 9485.28, Reason: TAKE_PROFIT, P/L: $197.54 (3.66%)
# [2020-06-16 00:00:00] BUY at 9485.28, Size: $5498.85, SL: 9295.57, TP: 9769.84
# [2020-06-19 06:00:00] Closed trade at 9265.19, Reason: STOP_LOSS, P/L: $-127.59 (-2.32%)
# [2020-06-19 06:00:00] SELL at 9265.19, Size: $3261.03, SL: 9357.84, TP: 9079.89
# [2020-06-19 14:00:00] Closed trade at 9383.1, Reason: STOP_LOSS, P/L: $-41.50 (-1.27%)
# [2020-06-19 14:00:00] SELL at 9383.1, Size: $5197.73, SL: 9523.85, TP: 9148.52
# [2020-06-22 20:00:00] Closed trade at 9591.09, Reason: STOP_LOSS, P/L: $-115.22 (-2.22%)
# [2020-06-22 20:00:00] BUY at 9591.09, Size: $6428.03, SL: 9399.27, TP: 9878.82
# [2020-06-24 14:00:00] Closed trade at 9361.43, Reason: STOP_LOSS, P/L: $-153.92 (-2.39%)
# [2020-06-24 14:00:00] SELL at 9361.43, Size: $5068.55, SL: 9501.85, TP: 9127.39
# [2020-06-25 07:00:00] Closed trade at 9078.41, Reason: TAKE_PROFIT, P/L: $153.24 (3.02%)
# [2020-06-25 07:00:00] BUY at 9078.41, Size: $5356.35, SL: 8896.84, TP: 9350.76
# [2020-07-08 17:00:00] Closed trade at 9441.99, Reason: TAKE_PROFIT, P/L: $214.52 (4.00%)
# [2020-07-08 17:00:00] BUY at 9441.99, Size: $6556.33, SL: 9272.03, TP: 9725.25
# [2020-07-09 19:00:00] Closed trade at 9205.0, Reason: STOP_LOSS, P/L: $-164.56 (-2.51%)
# [2020-07-09 19:00:00] BUY at 9205.0, Size: $6457.60, SL: 9039.31, TP: 9481.15
# [2020-07-23 02:00:00] Closed trade at 9513.0, Reason: TAKE_PROFIT, P/L: $216.07 (3.35%)
# [2020-07-23 03:00:00] BUY at 9539.51, Size: $6587.24, SL: 9367.80, TP: 9825.70
# [2020-07-26 13:00:00] Closed trade at 9850.37, Reason: TAKE_PROFIT, P/L: $214.66 (3.26%)
# [2020-07-26 13:00:00] SELL at 9850.37, Size: $5372.83, SL: 9998.13, TP: 9604.11
# [2020-07-26 14:00:00] Closed trade at 10016.94, Reason: STOP_LOSS, P/L: $-90.85 (-1.69%)
# [2020-07-26 14:00:00] BUY at 10016.94, Size: $5551.27, SL: 9816.60, TP: 10317.45
# [2020-07-27 17:00:00] Closed trade at 10372.46, Reason: TAKE_PROFIT, P/L: $197.02 (3.55%)
# [2020-07-27 17:00:00] SELL at 10372.46, Size: $5423.79, SL: 10528.05, TP: 10113.15
# [2020-07-27 20:00:00] Closed trade at 10734.62, Reason: STOP_LOSS, P/L: $-189.37 (-3.49%)
# [2020-07-27 20:00:00] BUY at 10734.62, Size: $6666.11, SL: 10541.40, TP: 11056.66
# [2020-07-28 01:00:00] Closed trade at 11129.42, Reason: TAKE_PROFIT, P/L: $245.17 (3.68%)
# [2020-07-28 01:00:00] SELL at 11129.42, Size: $5450.57, SL: 11296.36, TP: 10851.18
# [2020-07-28 12:00:00] Closed trade at 10735.0, Reason: TAKE_PROFIT, P/L: $193.16 (3.54%)
# [2020-07-28 12:00:00] BUY at 10735.0, Size: $6929.11, SL: 10541.77, TP: 11057.05
# [2020-07-28 18:00:00] Closed trade at 11190.0, Reason: TAKE_PROFIT, P/L: $293.69 (4.24%)
# [2020-07-28 18:00:00] SELL at 11190.0, Size: $3552.66, SL: 11301.90, TP: 10966.20
# [2020-07-28 21:00:00] Closed trade at 10951.71, Reason: TAKE_PROFIT, P/L: $75.65 (2.13%)
# [2020-07-28 21:00:00] BUY at 10951.71, Size: $7150.71, SL: 10732.68, TP: 11280.26
# [2020-07-29 20:00:00] Closed trade at 11280.65, Reason: TAKE_PROFIT, P/L: $214.78 (3.00%)
# [2020-07-29 20:00:00] BUY at 11280.65, Size: $7279.58, SL: 11055.04, TP: 11619.07
# [2020-07-30 06:00:00] Closed trade at 10982.02, Reason: STOP_LOSS, P/L: $-192.71 (-2.65%)
# [2020-07-30 06:00:00] BUY at 10982.02, Size: $5969.96, SL: 10762.38, TP: 11311.48
# [2020-07-31 19:00:00] Closed trade at 11359.99, Reason: TAKE_PROFIT, P/L: $205.47 (3.44%)
# [2020-07-31 19:00:00] BUY at 11359.99, Size: $7287.23, SL: 11155.51, TP: 11700.79
# [2020-08-01 13:00:00] Closed trade at 11705.7, Reason: TAKE_PROFIT, P/L: $221.77 (3.04%)
# [2020-08-01 14:00:00] BUY at 11626.96, Size: $7420.29, SL: 11417.67, TP: 11975.77
# [2020-08-02 07:00:00] Closed trade at 11998.45, Reason: TAKE_PROFIT, P/L: $237.08 (3.20%)
# [2020-08-02 07:00:00] BUY at 11998.45, Size: $6302.12, SL: 11758.48, TP: 12358.40
# [2020-08-02 08:00:00] Closed trade at 11187.84, Reason: STOP_LOSS, P/L: $-425.77 (-6.76%)
# [2020-08-02 08:00:00] BUY at 11187.84, Size: $6089.24, SL: 10964.08, TP: 11523.48
# [2020-08-05 16:00:00] Closed trade at 11583.38, Reason: TAKE_PROFIT, P/L: $215.28 (3.54%)
# [2020-08-05 16:00:00] BUY at 11583.38, Size: $7436.25, SL: 11351.71, TP: 11930.88
# [2020-08-10 06:00:00] Closed trade at 12007.76, Reason: TAKE_PROFIT, P/L: $272.44 (3.66%)
# [2020-08-10 06:00:00] BUY at 12007.76, Size: $6333.10, SL: 11767.60, TP: 12367.99
# [2020-08-10 14:00:00] Closed trade at 11692.3, Reason: STOP_LOSS, P/L: $-166.38 (-2.63%)
# [2020-08-10 14:00:00] SELL at 11692.3, Size: $5999.91, SL: 11867.68, TP: 11399.99
# [2020-08-10 16:00:00] Closed trade at 11892.35, Reason: STOP_LOSS, P/L: $-102.66 (-1.71%)
# [2020-08-10 16:00:00] BUY at 11892.35, Size: $7438.30, SL: 11678.29, TP: 12249.12
# [2020-08-11 16:00:00] Closed trade at 11673.01, Reason: STOP_LOSS, P/L: $-137.19 (-1.84%)
# [2020-08-11 16:00:00] BUY at 11673.01, Size: $6129.99, SL: 11439.55, TP: 12023.20
# [2020-08-11 20:00:00] Closed trade at 11434.49, Reason: STOP_LOSS, P/L: $-125.26 (-2.04%)
# [2020-08-11 20:00:00] BUY at 11434.49, Size: $6067.36, SL: 11205.80, TP: 11777.52
# [2020-08-12 00:00:00] Closed trade at 11201.27, Reason: STOP_LOSS, P/L: $-123.75 (-2.04%)
# [2020-08-12 00:00:00] BUY at 11201.27, Size: $7927.24, SL: 10977.24, TP: 11537.31
# [2020-08-12 17:00:00] Closed trade at 11566.98, Reason: TAKE_PROFIT, P/L: $258.82 (3.26%)
# [2020-08-12 17:00:00] BUY at 11566.98, Size: $6134.89, SL: 11335.64, TP: 11913.99
# [2020-08-15 04:00:00] Closed trade at 11922.96, Reason: TAKE_PROFIT, P/L: $188.80 (3.08%)
# [2020-08-15 04:00:00] BUY at 11922.96, Size: $6229.29, SL: 11684.50, TP: 12280.65
# [2020-08-17 19:00:00] Closed trade at 12420.08, Reason: TAKE_PROFIT, P/L: $259.73 (4.17%)
# [2020-08-17 19:00:00] BUY at 12420.08, Size: $9157.18, SL: 12171.68, TP: 12792.68
# [2020-08-18 18:00:00] Closed trade at 11948.97, Reason: STOP_LOSS, P/L: $-347.34 (-3.79%)
# [2020-08-18 18:00:00] BUY at 11948.97, Size: $6185.48, SL: 11709.99, TP: 12307.44
# [2020-08-19 23:00:00] Closed trade at 11652.83, Reason: STOP_LOSS, P/L: $-153.30 (-2.48%)
# [2020-08-20 01:00:00] SELL at 11720.17, Size: $5864.48, SL: 11895.97, TP: 11427.17
# [2020-08-22 04:00:00] Closed trade at 11411.69, Reason: TAKE_PROFIT, P/L: $154.36 (2.63%)
# [2020-08-22 04:00:00] SELL at 11411.69, Size: $5938.57, SL: 11582.87, TP: 11126.40
# [2020-08-22 11:00:00] Closed trade at 11586.52, Reason: STOP_LOSS, P/L: $-90.98 (-1.53%)
# [2020-08-22 11:00:00] BUY at 11586.52, Size: $6140.52, SL: 11354.79, TP: 11934.12
# [2020-08-25 20:00:00] Closed trade at 11322.92, Reason: STOP_LOSS, P/L: $-139.70 (-2.28%)
# [2020-08-25 20:00:00] BUY at 11322.92, Size: $7284.80, SL: 11119.11, TP: 11662.61
# [2020-08-30 20:00:00] Closed trade at 11663.79, Reason: TAKE_PROFIT, P/L: $219.30 (3.01%)
# [2020-08-30 20:00:00] BUY at 11663.79, Size: $10877.37, SL: 11488.83, TP: 11955.38
# [2020-09-01 13:00:00] Closed trade at 11955.7, Reason: TAKE_PROFIT, P/L: $272.23 (2.50%)
# [2020-09-01 13:00:00] BUY at 11955.7, Size: $6316.44, SL: 11716.59, TP: 12314.37
# [2020-09-02 12:00:00] Closed trade at 11710.73, Reason: STOP_LOSS, P/L: $-129.42 (-2.05%)
# [2020-09-02 12:00:00] BUY at 11710.73, Size: $6251.73, SL: 11476.52, TP: 12062.05
# [2020-09-02 15:00:00] Closed trade at 11412.04, Reason: STOP_LOSS, P/L: $-159.45 (-2.55%)
# [2020-09-02 16:00:00] BUY at 11439.4, Size: $7406.40, SL: 11210.61, TP: 11782.58
# [2020-09-03 16:00:00] Closed trade at 10814.55, Reason: STOP_LOSS, P/L: $-404.56 (-5.46%)
# [2020-09-03 16:00:00] SELL at 10814.55, Size: $3581.83, SL: 10922.70, TP: 10598.26
# [2020-09-03 20:00:00] Closed trade at 10563.85, Reason: TAKE_PROFIT, P/L: $83.03 (2.32%)
# [2020-09-03 20:00:00] BUY at 10563.85, Size: $7213.48, SL: 10373.70, TP: 10880.77
# [2020-09-04 03:00:00] Closed trade at 10160.0, Reason: STOP_LOSS, P/L: $-275.77 (-3.82%)
# [2020-09-04 06:00:00] BUY at 10273.09, Size: $7048.02, SL: 10088.17, TP: 10581.28
# [2020-09-04 23:00:00] Closed trade at 10588.05, Reason: TAKE_PROFIT, P/L: $216.08 (3.07%)
# [2020-09-04 23:00:00] BUY at 10588.05, Size: $7177.67, SL: 10376.29, TP: 10905.69
# [2020-09-05 12:00:00] Closed trade at 10329.72, Reason: STOP_LOSS, P/L: $-175.12 (-2.44%)
# [2020-09-05 12:00:00] BUY at 10329.72, Size: $5893.83, SL: 10123.13, TP: 10639.61
# [2020-09-05 16:00:00] Closed trade at 10005.41, Reason: STOP_LOSS, P/L: $-185.04 (-3.14%)
# [2020-09-05 16:00:00] BUY at 10005.41, Size: $5801.31, SL: 9805.30, TP: 10305.57
# [2020-09-05 18:00:00] Closed trade at 10324.57, Reason: TAKE_PROFIT, P/L: $185.05 (3.19%)
# [2020-09-05 18:00:00] BUY at 10324.57, Size: $5893.84, SL: 10118.08, TP: 10634.31
# [2020-09-05 23:00:00] Closed trade at 9948.93, Reason: STOP_LOSS, P/L: $-214.44 (-3.64%)
# [2020-09-05 23:00:00] BUY at 9948.93, Size: $6943.95, SL: 9769.85, TP: 10247.40
# [2020-09-06 15:00:00] Closed trade at 10266.82, Reason: TAKE_PROFIT, P/L: $221.87 (3.20%)
# [2020-09-06 15:00:00] BUY at 10266.82, Size: $5897.56, SL: 10061.48, TP: 10574.82
# [2020-09-07 15:00:00] Closed trade at 10029.31, Reason: STOP_LOSS, P/L: $-136.43 (-2.31%)
# [2020-09-07 15:00:00] BUY at 10029.31, Size: $6995.21, SL: 9828.72, TP: 10330.19
# [2020-09-08 02:00:00] Closed trade at 10389.96, Reason: TAKE_PROFIT, P/L: $251.55 (3.60%)
# [2020-09-08 02:00:00] BUY at 10389.96, Size: $5955.11, SL: 10182.16, TP: 10701.66
# [2020-09-08 12:00:00] Closed trade at 10179.98, Reason: STOP_LOSS, P/L: $-120.35 (-2.02%)
# [2020-09-08 12:00:00] BUY at 10179.98, Size: $5894.94, SL: 9976.38, TP: 10485.38
# [2020-09-13 07:00:00] Closed trade at 10561.82, Reason: TAKE_PROFIT, P/L: $221.11 (3.75%)
# [2020-09-13 07:00:00] BUY at 10561.82, Size: $6005.50, SL: 10350.58, TP: 10878.67
# [2020-09-13 15:00:00] Closed trade at 10325.0, Reason: STOP_LOSS, P/L: $-134.66 (-2.24%)
# [2020-09-13 15:00:00] BUY at 10325.0, Size: $5938.17, SL: 10118.50, TP: 10634.75
# [2020-09-14 17:00:00] Closed trade at 10645.11, Reason: TAKE_PROFIT, P/L: $184.10 (3.10%)
# [2020-09-14 17:00:00] BUY at 10645.11, Size: $6030.22, SL: 10432.21, TP: 10964.46
# [2020-09-16 19:00:00] Closed trade at 11007.66, Reason: TAKE_PROFIT, P/L: $205.38 (3.41%)
# [2020-09-16 19:00:00] BUY at 11007.66, Size: $7359.49, SL: 10809.52, TP: 11337.89
# [2020-09-17 16:00:00] Closed trade at 10801.66, Reason: STOP_LOSS, P/L: $-137.73 (-1.87%)
# [2020-09-17 16:00:00] BUY at 10801.66, Size: $7276.85, SL: 10607.23, TP: 11125.71
# [2020-09-19 15:00:00] Closed trade at 11146.13, Reason: TAKE_PROFIT, P/L: $232.06 (3.19%)
# [2020-09-19 15:00:00] BUY at 11146.13, Size: $6180.07, SL: 10923.21, TP: 11480.51
# [2020-09-20 06:00:00] Closed trade at 10916.34, Reason: STOP_LOSS, P/L: $-127.41 (-2.06%)
# [2020-09-20 06:00:00] BUY at 10916.34, Size: $6116.37, SL: 10698.01, TP: 11243.83
# [2020-09-21 13:00:00] Closed trade at 10695.43, Reason: STOP_LOSS, P/L: $-123.77 (-2.02%)
# [2020-09-21 13:00:00] SELL at 10695.43, Size: $5812.30, SL: 10855.86, TP: 10428.04
# [2020-09-21 18:00:00] Closed trade at 10405.59, Reason: TAKE_PROFIT, P/L: $157.51 (2.71%)
# [2020-09-21 18:00:00] BUY at 10405.59, Size: $7359.88, SL: 10218.29, TP: 10717.76
# [2020-09-25 02:00:00] Closed trade at 10763.81, Reason: TAKE_PROFIT, P/L: $253.37 (3.44%)
# [2020-09-25 02:00:00] BUY at 10763.81, Size: $6259.92, SL: 10548.53, TP: 11086.72
# [2020-10-01 20:00:00] Closed trade at 10510.0, Reason: STOP_LOSS, P/L: $-147.61 (-2.36%)
# [2020-10-01 21:00:00] SELL at 10479.46, Size: $3711.67, SL: 10584.25, TP: 10269.87
# [2020-10-01 22:00:00] Closed trade at 10585.35, Reason: STOP_LOSS, P/L: $-37.50 (-1.01%)
# [2020-10-01 22:00:00] BUY at 10585.35, Size: $7400.84, SL: 10394.81, TP: 10902.91
# [2020-10-08 18:00:00] Closed trade at 10914.62, Reason: TAKE_PROFIT, P/L: $230.21 (3.11%)
# [2020-10-08 18:00:00] BUY at 10914.62, Size: $7538.97, SL: 10696.33, TP: 11242.06
# [2020-10-10 06:00:00] Closed trade at 11391.49, Reason: TAKE_PROFIT, P/L: $329.38 (4.37%)
# [2020-10-10 06:00:00] BUY at 11391.49, Size: $6447.16, SL: 11163.66, TP: 11733.23
# [2020-10-19 19:00:00] Closed trade at 11818.28, Reason: TAKE_PROFIT, P/L: $241.55 (3.75%)
# [2020-10-19 19:00:00] BUY at 11818.28, Size: $7881.52, SL: 11605.55, TP: 12172.83
# [2020-10-21 07:00:00] Closed trade at 12201.72, Reason: TAKE_PROFIT, P/L: $255.71 (3.24%)
# [2020-10-21 07:00:00] BUY at 12201.72, Size: $6695.79, SL: 11957.69, TP: 12567.77
# [2020-10-21 18:00:00] Closed trade at 12749.89, Reason: TAKE_PROFIT, P/L: $300.81 (4.49%)
# [2020-10-21 18:00:00] BUY at 12749.89, Size: $8215.44, SL: 12494.89, TP: 13132.39
# [2020-10-22 02:00:00] Closed trade at 13216.17, Reason: TAKE_PROFIT, P/L: $300.45 (3.66%)
# [2020-10-22 02:00:00] BUY at 13216.17, Size: $6996.42, SL: 12951.85, TP: 13612.66
# [2020-10-22 03:00:00] Closed trade at 12802.67, Reason: STOP_LOSS, P/L: $-218.90 (-3.13%)
# [2020-10-22 03:00:00] BUY at 12802.67, Size: $6886.97, SL: 12546.62, TP: 13186.75
# [2020-10-25 07:00:00] Closed trade at 13303.83, Reason: TAKE_PROFIT, P/L: $269.59 (3.91%)
# [2020-10-25 07:00:00] BUY at 13303.83, Size: $7021.77, SL: 13037.75, TP: 13702.94
# [2020-10-25 09:00:00] Closed trade at 12969.86, Reason: STOP_LOSS, P/L: $-176.27 (-2.51%)
# [2020-10-25 09:00:00] BUY at 12969.86, Size: $6933.64, SL: 12710.46, TP: 13358.96
# [2020-10-27 15:00:00] Closed trade at 13446.44, Reason: TAKE_PROFIT, P/L: $254.78 (3.67%)
# [2020-10-27 15:00:00] SELL at 13446.44, Size: $4236.61, SL: 13580.90, TP: 13177.51
# [2020-10-27 19:00:00] Closed trade at 13607.41, Reason: STOP_LOSS, P/L: $-50.72 (-1.20%)
# [2020-10-27 19:00:00] BUY at 13607.41, Size: $8442.80, SL: 13335.26, TP: 14015.63
# [2020-10-28 15:00:00] Closed trade at 13325.87, Reason: STOP_LOSS, P/L: $-174.68 (-2.07%)
# [2020-10-28 15:00:00] BUY at 13325.87, Size: $8337.99, SL: 13059.35, TP: 13725.65
# [2020-10-28 18:00:00] Closed trade at 13058.57, Reason: STOP_LOSS, P/L: $-167.25 (-2.01%)
# [2020-10-28 18:00:00] BUY at 13058.57, Size: $8237.64, SL: 12797.40, TP: 13450.33
# [2020-10-29 20:00:00] Closed trade at 13563.53, Reason: TAKE_PROFIT, P/L: $318.54 (3.87%)
# [2020-10-29 20:00:00] BUY at 13563.53, Size: $7023.97, SL: 13292.26, TP: 13970.44
# [2020-10-30 09:00:00] Closed trade at 13186.02, Reason: STOP_LOSS, P/L: $-195.50 (-2.78%)
# [2020-10-30 09:00:00] BUY at 13186.02, Size: $8311.47, SL: 12948.67, TP: 13581.60
# [2020-10-31 00:00:00] Closed trade at 13634.62, Reason: TAKE_PROFIT, P/L: $282.76 (3.40%)
# [2020-10-31 00:00:00] BUY at 13634.62, Size: $8481.12, SL: 13389.20, TP: 14043.66
# [2020-11-02 17:00:00] Closed trade at 13318.59, Reason: STOP_LOSS, P/L: $-196.58 (-2.32%)
# [2020-11-02 17:00:00] BUY at 13318.59, Size: $8363.18, SL: 13078.86, TP: 13718.15
# [2020-11-03 19:00:00] Closed trade at 13796.99, Reason: TAKE_PROFIT, P/L: $300.40 (3.59%)
# [2020-11-03 20:00:00] BUY at 13713.79, Size: $8543.42, SL: 13439.51, TP: 14125.20
# [2020-11-05 00:00:00] Closed trade at 14125.43, Reason: TAKE_PROFIT, P/L: $256.44 (3.00%)
# [2020-11-05 00:00:00] SELL at 14125.43, Size: $4348.64, SL: 14266.68, TP: 13842.92
# [2020-11-05 08:00:00] Closed trade at 14324.72, Reason: STOP_LOSS, P/L: $-61.35 (-1.41%)
# [2020-11-05 08:00:00] BUY at 14324.72, Size: $7217.06, SL: 14038.23, TP: 14754.46
# [2020-11-05 17:00:00] Closed trade at 14886.47, Reason: TAKE_PROFIT, P/L: $283.02 (3.92%)
# [2020-11-05 17:00:00] BUY at 14886.47, Size: $8830.28, SL: 14588.74, TP: 15333.06
# [2020-11-06 03:00:00] Closed trade at 15561.38, Reason: TAKE_PROFIT, P/L: $400.34 (4.53%)
# [2020-11-06 03:00:00] BUY at 15561.38, Size: $7558.74, SL: 15250.15, TP: 16028.22
# [2020-11-07 22:00:00] Closed trade at 15242.63, Reason: STOP_LOSS, P/L: $-154.83 (-2.05%)
# [2020-11-07 22:00:00] BUY at 15242.63, Size: $8977.59, SL: 14937.78, TP: 15699.91
# [2020-11-07 23:00:00] Closed trade at 14927.93, Reason: STOP_LOSS, P/L: $-185.35 (-2.06%)
# [2020-11-07 23:00:00] BUY at 14927.93, Size: $8866.38, SL: 14629.37, TP: 15375.77
# [2020-11-08 21:00:00] Closed trade at 15409.0, Reason: TAKE_PROFIT, P/L: $285.73 (3.22%)
# [2020-11-08 21:00:00] BUY at 15409.0, Size: $9037.82, SL: 15131.64, TP: 15871.27
# [2020-11-09 19:00:00] Closed trade at 15061.05, Reason: STOP_LOSS, P/L: $-204.08 (-2.26%)
# [2020-11-09 19:00:00] BUY at 15061.05, Size: $13075.87, SL: 14835.13, TP: 15437.58
# [2020-11-11 05:00:00] Closed trade at 15478.72, Reason: TAKE_PROFIT, P/L: $362.62 (2.77%)
# [2020-11-11 05:00:00] BUY at 15478.72, Size: $7610.78, SL: 15169.15, TP: 15943.08
# [2020-11-12 14:00:00] Closed trade at 16064.13, Reason: TAKE_PROFIT, P/L: $287.84 (3.78%)
# [2020-11-12 14:00:00] SELL at 16064.13, Size: $7444.51, SL: 16305.09, TP: 15662.53
# [2020-11-13 05:00:00] Closed trade at 16411.41, Reason: STOP_LOSS, P/L: $-160.94 (-2.16%)
# [2020-11-13 05:00:00] BUY at 16411.41, Size: $7674.23, SL: 16083.18, TP: 16903.75
# [2020-11-14 13:00:00] Closed trade at 15978.81, Reason: STOP_LOSS, P/L: $-202.29 (-2.64%)
# [2020-11-14 13:00:00] SELL at 15978.81, Size: $7270.16, SL: 16218.49, TP: 15579.34
# [2020-11-16 11:00:00] Closed trade at 16255.51, Reason: STOP_LOSS, P/L: $-125.90 (-1.73%)
# [2020-11-16 11:00:00] BUY at 16255.51, Size: $9012.17, SL: 15962.91, TP: 16743.18
# [2020-11-17 00:00:00] Closed trade at 16800.42, Reason: TAKE_PROFIT, P/L: $302.10 (3.35%)
# [2020-11-17 00:00:00] BUY at 16800.42, Size: $7661.19, SL: 16464.41, TP: 17304.43
# [2020-11-17 20:00:00] Closed trade at 17337.45, Reason: TAKE_PROFIT, P/L: $244.89 (3.20%)
# [2020-11-17 20:00:00] BUY at 17337.45, Size: $9340.36, SL: 16990.70, TP: 17857.57
# [2020-11-18 08:00:00] Closed trade at 18041.16, Reason: TAKE_PROFIT, P/L: $379.12 (4.06%)
# [2020-11-18 08:00:00] BUY at 18041.16, Size: $7973.20, SL: 17680.34, TP: 18582.39
# [2020-11-18 10:00:00] Closed trade at 17638.26, Reason: STOP_LOSS, P/L: $-178.06 (-2.23%)
# [2020-11-18 10:00:00] BUY at 17638.26, Size: $9461.00, SL: 17285.49, TP: 18167.41
# [2020-11-18 13:00:00] Closed trade at 18222.03, Reason: TAKE_PROFIT, P/L: $313.13 (3.31%)
# [2020-11-18 14:00:00] SELL at 18125.52, Size: $7719.10, SL: 18397.40, TP: 17672.38
# [2020-11-19 00:00:00] Closed trade at 17668.0, Reason: TAKE_PROFIT, P/L: $194.84 (2.52%)
# [2020-11-19 00:00:00] BUY at 17668.0, Size: $9765.78, SL: 17349.98, TP: 18198.04
# [2020-11-20 09:00:00] Closed trade at 18205.8, Reason: TAKE_PROFIT, P/L: $297.26 (3.04%)
# [2020-11-20 09:00:00] BUY at 18205.8, Size: $8286.78, SL: 17841.68, TP: 18751.97
# [2020-11-21 05:00:00] Closed trade at 18878.0, Reason: TAKE_PROFIT, P/L: $305.97 (3.69%)
# [2020-11-21 05:00:00] BUY at 18878.0, Size: $8439.77, SL: 18500.44, TP: 19444.34
# [2020-11-22 06:00:00] Closed trade at 18468.68, Reason: STOP_LOSS, P/L: $-182.99 (-2.17%)
# [2020-11-22 06:00:00] BUY at 18468.68, Size: $10017.92, SL: 18099.31, TP: 19022.74
# [2020-11-22 16:00:00] Closed trade at 17884.18, Reason: STOP_LOSS, P/L: $-317.05 (-3.16%)
# [2020-11-22 16:00:00] BUY at 17884.18, Size: $9827.69, SL: 17562.26, TP: 18420.71
# [2020-11-22 21:00:00] Closed trade at 18560.1, Reason: TAKE_PROFIT, P/L: $371.43 (3.78%)
# [2020-11-22 21:00:00] BUY at 18560.1, Size: $10050.55, SL: 18226.02, TP: 19116.90
# [2020-11-23 05:00:00] Closed trade at 18143.85, Reason: STOP_LOSS, P/L: $-225.41 (-2.24%)
# [2020-11-23 05:00:00] BUY at 18143.85, Size: $8262.76, SL: 17780.97, TP: 18688.17
# [2020-11-23 15:00:00] Closed trade at 18763.59, Reason: TAKE_PROFIT, P/L: $282.23 (3.42%)
# [2020-11-23 15:00:00] BUY at 18763.59, Size: $10084.65, SL: 18388.32, TP: 19326.50
# [2020-11-23 20:00:00] Closed trade at 18273.24, Reason: STOP_LOSS, P/L: $-263.54 (-2.61%)
# [2020-11-23 20:00:00] BUY at 18273.24, Size: $9926.52, SL: 17907.78, TP: 18821.44
# [2020-11-24 14:00:00] Closed trade at 18971.97, Reason: TAKE_PROFIT, P/L: $379.57 (3.82%)
# [2020-11-24 14:00:00] BUY at 18971.97, Size: $10154.26, SL: 18630.47, TP: 19541.13
# [2020-11-26 07:00:00] Closed trade at 18399.47, Reason: STOP_LOSS, P/L: $-306.42 (-3.02%)
# [2020-11-26 07:00:00] BUY at 18399.47, Size: $8308.68, SL: 18031.48, TP: 18951.45
# [2020-11-26 08:00:00] Closed trade at 17946.45, Reason: STOP_LOSS, P/L: $-204.57 (-2.46%)
# [2020-11-26 08:00:00] BUY at 17946.45, Size: $8206.39, SL: 17587.52, TP: 18484.84
# [2020-11-26 13:00:00] Closed trade at 16848.13, Reason: STOP_LOSS, P/L: $-502.23 (-6.12%)
# [2020-11-26 16:00:00] BUY at 17115.6, Size: $9546.33, SL: 16773.29, TP: 17629.07
# [2020-11-26 19:00:00] Closed trade at 16750.0, Reason: STOP_LOSS, P/L: $-203.92 (-2.14%)
# [2020-11-26 19:00:00] BUY at 16750.0, Size: $9423.98, SL: 16415.00, TP: 17252.50
# [2020-11-27 05:00:00] Closed trade at 17400.01, Reason: TAKE_PROFIT, P/L: $365.71 (3.88%)
# [2020-11-27 05:00:00] SELL at 17400.01, Size: $7714.73, SL: 17661.01, TP: 16965.01
# [2020-11-27 13:00:00] Closed trade at 16839.47, Reason: TAKE_PROFIT, P/L: $248.53 (3.22%)
# [2020-11-27 14:00:00] BUY at 16643.1, Size: $9792.53, SL: 16310.24, TP: 17142.39
# [2020-11-28 04:00:00] Closed trade at 17154.39, Reason: TAKE_PROFIT, P/L: $300.83 (3.07%)
# [2020-11-28 04:00:00] BUY at 17154.39, Size: $14627.11, SL: 16897.07, TP: 17583.25
# [2020-11-28 13:00:00] Closed trade at 16889.76, Reason: STOP_LOSS, P/L: $-225.64 (-1.54%)
# [2020-11-28 13:00:00] SELL at 16889.76, Size: $7870.12, SL: 17143.11, TP: 16467.52
# [2020-11-28 15:00:00] Closed trade at 17201.53, Reason: STOP_LOSS, P/L: $-145.28 (-1.85%)
# [2020-11-28 15:00:00] BUY at 17201.53, Size: $9750.48, SL: 16891.90, TP: 17717.58
# [2020-11-28 21:00:00] Closed trade at 17728.13, Reason: TAKE_PROFIT, P/L: $298.50 (3.06%)
# [2020-11-28 21:00:00] BUY at 17728.13, Size: $9929.58, SL: 17373.57, TP: 18259.97
# [2020-11-30 05:00:00] Closed trade at 18445.7, Reason: TAKE_PROFIT, P/L: $401.91 (4.05%)
# [2020-11-30 05:00:00] BUY at 18445.7, Size: $8475.60, SL: 18076.79, TP: 18999.07
# [2020-11-30 18:00:00] Closed trade at 19165.93, Reason: TAKE_PROFIT, P/L: $330.94 (3.90%)
# [2020-11-30 18:00:00] BUY at 19165.93, Size: $10369.29, SL: 18782.61, TP: 19740.91
# [2020-12-01 15:00:00] Closed trade at 19764.88, Reason: TAKE_PROFIT, P/L: $324.05 (3.13%)
# [2020-12-01 15:00:00] BUY at 19764.88, Size: $10563.72, SL: 19369.58, TP: 20357.83
# [2020-12-01 17:00:00] Closed trade at 18585.78, Reason: STOP_LOSS, P/L: $-630.19 (-5.97%)
# [2020-12-01 17:00:00] BUY at 18585.78, Size: $8488.00, SL: 18214.06, TP: 19143.35
# [2020-12-01 19:00:00] Closed trade at 19294.05, Reason: TAKE_PROFIT, P/L: $323.46 (3.81%)
# [2020-12-01 19:00:00] BUY at 19294.05, Size: $10379.68, SL: 18908.17, TP: 19872.87
# [2020-12-01 23:00:00] Closed trade at 18748.89, Reason: STOP_LOSS, P/L: $-293.28 (-2.83%)
# [2020-12-01 23:00:00] BUY at 18748.89, Size: $8503.09, SL: 18373.91, TP: 19311.36
# [2020-12-03 13:00:00] Closed trade at 19399.08, Reason: TAKE_PROFIT, P/L: $294.88 (3.47%)
# [2020-12-03 14:00:00] BUY at 19384.12, Size: $10380.64, SL: 19035.21, TP: 19965.64
# [2020-12-04 15:00:00] Closed trade at 19008.21, Reason: STOP_LOSS, P/L: $-201.31 (-1.94%)
# [2020-12-04 15:00:00] BUY at 19008.21, Size: $10259.85, SL: 18628.05, TP: 19578.46
# [2020-12-09 03:00:00] Closed trade at 18328.0, Reason: STOP_LOSS, P/L: $-367.15 (-3.58%)
# [2020-12-09 03:00:00] BUY at 18328.0, Size: $10039.56, SL: 17998.10, TP: 18877.84
# [2020-12-09 12:00:00] Closed trade at 17903.92, Reason: STOP_LOSS, P/L: $-232.30 (-2.31%)
# [2020-12-09 12:00:00] BUY at 17903.92, Size: $8250.15, SL: 17545.84, TP: 18441.04
# [2020-12-09 18:00:00] Closed trade at 18496.11, Reason: TAKE_PROFIT, P/L: $272.88 (3.31%)
# [2020-12-09 18:00:00] BUY at 18496.11, Size: $8386.59, SL: 18126.19, TP: 19050.99
# [2020-12-10 19:00:00] Closed trade at 18070.09, Reason: STOP_LOSS, P/L: $-193.17 (-2.30%)
# [2020-12-10 19:00:00] BUY at 18070.09, Size: $9948.01, SL: 17744.83, TP: 18612.19
# [2020-12-11 15:00:00] Closed trade at 17739.73, Reason: STOP_LOSS, P/L: $-181.87 (-1.83%)
# [2020-12-11 15:00:00] BUY at 17739.73, Size: $9838.89, SL: 17384.94, TP: 18271.92
# [2020-12-12 05:00:00] Closed trade at 18347.2, Reason: TAKE_PROFIT, P/L: $336.92 (3.42%)
# [2020-12-12 05:00:00] BUY at 18347.2, Size: $8367.53, SL: 17980.26, TP: 18897.62
# [2020-12-13 11:00:00] Closed trade at 18988.37, Reason: TAKE_PROFIT, P/L: $292.42 (3.49%)
# [2020-12-13 11:00:00] BUY at 18988.37, Size: $8513.74, SL: 18608.60, TP: 19558.02
# [2020-12-16 15:00:00] Closed trade at 19797.73, Reason: TAKE_PROFIT, P/L: $362.89 (4.26%)
# [2020-12-16 15:00:00] SELL at 19797.73, Size: $5217.11, SL: 19995.71, TP: 19401.78
# [2020-12-16 18:00:00] Closed trade at 20341.6, Reason: STOP_LOSS, P/L: $-143.32 (-2.75%)
# [2020-12-16 18:00:00] BUY at 20341.6, Size: $10348.23, SL: 19934.77, TP: 20951.85
# [2020-12-17 02:00:00] Closed trade at 21215.49, Reason: TAKE_PROFIT, P/L: $444.57 (4.30%)
# [2020-12-17 02:00:00] BUY at 21215.49, Size: $10614.97, SL: 20791.18, TP: 21851.95
# [2020-12-17 07:00:00] Closed trade at 21942.99, Reason: TAKE_PROFIT, P/L: $364.00 (3.43%)
# [2020-12-17 07:00:00] BUY at 21942.99, Size: $9027.81, SL: 21504.13, TP: 22601.28
# [2020-12-17 13:00:00] Closed trade at 22912.05, Reason: TAKE_PROFIT, P/L: $398.69 (4.42%)
# [2020-12-17 13:00:00] BUY at 22912.05, Size: $11072.58, SL: 22453.81, TP: 23599.41
# [2020-12-17 21:00:00] Closed trade at 23632.22, Reason: TAKE_PROFIT, P/L: $348.03 (3.14%)
# [2020-12-17 21:00:00] SELL at 23632.22, Size: $5640.70, SL: 23868.54, TP: 23159.58
# [2020-12-17 22:00:00] Closed trade at 23054.44, Reason: TAKE_PROFIT, P/L: $137.91 (2.44%)
# [2020-12-17 22:00:00] BUY at 23054.44, Size: $11364.15, SL: 22593.35, TP: 23746.07
# [2020-12-18 18:00:00] Closed trade at 22555.04, Reason: STOP_LOSS, P/L: $-246.17 (-2.17%)
# [2020-12-18 18:00:00] BUY at 22555.04, Size: $11216.45, SL: 22103.94, TP: 23231.69
# [2020-12-19 07:00:00] Closed trade at 23236.51, Reason: TAKE_PROFIT, P/L: $338.89 (3.02%)
# [2020-12-19 07:00:00] BUY at 23236.51, Size: $9516.48, SL: 22771.78, TP: 23933.61
# [2020-12-19 21:00:00] Closed trade at 24001.64, Reason: TAKE_PROFIT, P/L: $313.36 (3.29%)
# [2020-12-19 21:00:00] BUY at 24001.64, Size: $11607.80, SL: 23569.61, TP: 24721.69
# [2020-12-20 05:00:00] Closed trade at 23513.9, Reason: STOP_LOSS, P/L: $-235.88 (-2.03%)
# [2020-12-20 05:00:00] BUY at 23513.9, Size: $9555.22, SL: 23043.62, TP: 24219.32
# [2020-12-21 15:00:00] Closed trade at 22438.27, Reason: STOP_LOSS, P/L: $-437.10 (-4.57%)
# [2020-12-21 15:00:00] BUY at 22438.27, Size: $11204.01, SL: 21989.50, TP: 23111.42
# [2020-12-21 19:00:00] Closed trade at 23188.53, Reason: TAKE_PROFIT, P/L: $374.62 (3.34%)
# [2020-12-21 19:00:00] BUY at 23188.53, Size: $11428.78, SL: 22771.14, TP: 23884.19
# [2020-12-21 22:00:00] Closed trade at 22726.43, Reason: STOP_LOSS, P/L: $-227.75 (-1.99%)
# [2020-12-21 22:00:00] BUY at 22726.43, Size: $16561.79, SL: 22385.53, TP: 23294.59
# [2020-12-22 18:00:00] Closed trade at 23484.76, Reason: TAKE_PROFIT, P/L: $552.63 (3.34%)
# [2020-12-22 18:00:00] BUY at 23484.76, Size: $11623.71, SL: 23062.03, TP: 24189.30
# [2020-12-24 05:00:00] Closed trade at 23057.06, Reason: STOP_LOSS, P/L: $-211.69 (-1.82%)
# [2020-12-24 05:00:00] SELL at 23057.06, Size: $9197.36, SL: 23402.92, TP: 22480.63
# [2020-12-24 13:00:00] Closed trade at 23446.6, Reason: STOP_LOSS, P/L: $-155.39 (-1.69%)
# [2020-12-24 13:00:00] SELL at 23446.6, Size: $9122.77, SL: 23798.30, TP: 22860.43
# [2020-12-25 14:00:00] Closed trade at 23922.51, Reason: STOP_LOSS, P/L: $-185.17 (-2.03%)
# [2020-12-25 14:00:00] SELL at 23922.51, Size: $9033.89, SL: 24281.35, TP: 23324.45
# [2020-12-25 16:00:00] Closed trade at 24531.7, Reason: STOP_LOSS, P/L: $-230.05 (-2.55%)
# [2020-12-25 16:00:00] BUY at 24531.7, Size: $11154.33, SL: 24041.07, TP: 25267.65
# [2020-12-25 19:00:00] Closed trade at 24025.63, Reason: STOP_LOSS, P/L: $-230.11 (-2.06%)
# [2020-12-25 19:00:00] BUY at 24025.63, Size: $11016.27, SL: 23593.17, TP: 24746.40
# [2020-12-26 06:00:00] Closed trade at 24891.32, Reason: TAKE_PROFIT, P/L: $396.94 (3.60%)
# [2020-12-26 06:00:00] BUY at 24891.32, Size: $16506.50, SL: 24517.95, TP: 25513.60
# [2020-12-26 20:00:00] Closed trade at 25621.41, Reason: TAKE_PROFIT, P/L: $484.15 (2.93%)
# [2020-12-26 20:00:00] BUY at 25621.41, Size: $9620.77, SL: 25108.98, TP: 26390.05
# [2020-12-27 01:00:00] Closed trade at 26409.2, Reason: TAKE_PROFIT, P/L: $295.81 (3.07%)
# [2020-12-27 01:00:00] BUY at 26409.2, Size: $9768.68, SL: 25881.02, TP: 27201.48
# [2020-12-27 11:00:00] Closed trade at 27603.96, Reason: TAKE_PROFIT, P/L: $441.94 (4.52%)
# [2020-12-27 11:00:00] BUY at 27603.96, Size: $9989.65, SL: 27051.88, TP: 28432.08
# [2020-12-27 21:00:00] Closed trade at 27048.37, Reason: STOP_LOSS, P/L: $-201.06 (-2.01%)
# [2020-12-27 21:00:00] BUY at 27048.37, Size: $17404.84, SL: 26642.64, TP: 27724.58
# [2020-12-28 01:00:00] Closed trade at 26185.3, Reason: STOP_LOSS, P/L: $-555.36 (-3.19%)
# [2020-12-28 01:00:00] BUY at 26185.3, Size: $9611.43, SL: 25661.59, TP: 26970.86
# [2020-12-28 06:00:00] Closed trade at 27048.5, Reason: TAKE_PROFIT, P/L: $316.84 (3.30%)
# [2020-12-28 06:00:00] SELL at 27048.5, Size: $9379.06, SL: 27454.23, TP: 26372.29
# [2020-12-29 11:00:00] Closed trade at 26328.86, Reason: TAKE_PROFIT, P/L: $249.53 (2.66%)
# [2020-12-29 11:00:00] BUY at 26328.86, Size: $9894.62, SL: 25802.28, TP: 27118.73
# [2020-12-30 04:00:00] Closed trade at 27370.0, Reason: TAKE_PROFIT, P/L: $391.27 (3.95%)
# [2020-12-30 04:00:00] BUY at 27370.0, Size: $10090.26, SL: 26822.60, TP: 28191.10
# [2020-12-30 11:00:00] Closed trade at 28372.8, Reason: TAKE_PROFIT, P/L: $369.69 (3.66%)
# [2020-12-30 11:00:00] BUY at 28372.8, Size: $10275.10, SL: 27805.34, TP: 29223.98
# [2020-12-30 13:00:00] Closed trade at 27717.42, Reason: STOP_LOSS, P/L: $-237.34 (-2.31%)
# [2020-12-30 13:00:00] SELL at 27717.42, Size: $9750.17, SL: 28133.18, TP: 27024.48
# [2020-12-30 19:00:00] Closed trade at 28193.92, Reason: STOP_LOSS, P/L: $-167.62 (-1.72%)
# [2020-12-30 19:00:00] BUY at 28193.92, Size: $12087.15, SL: 27686.43, TP: 29039.74
# [2020-12-31 05:00:00] Closed trade at 29136.05, Reason: TAKE_PROFIT, P/L: $403.90 (3.34%)
# [2020-12-31 06:00:00] SELL at 28768.41, Size: $9863.59, SL: 29199.94, TP: 28049.20
# [2021-01-01 06:00:00] Closed trade at 29479.12, Reason: STOP_LOSS, P/L: $-243.68 (-2.47%)
# [2021-01-01 07:00:00] SELL at 29249.33, Size: $9746.63, SL: 29688.07, TP: 28518.10
# [2021-01-02 11:00:00] Closed trade at 29790.49, Reason: STOP_LOSS, P/L: $-180.33 (-1.85%)
# [2021-01-02 11:00:00] SELL at 29790.49, Size: $9660.07, SL: 30237.35, TP: 29045.73
# [2021-01-02 17:00:00] Closed trade at 30668.76, Reason: STOP_LOSS, P/L: $-284.79 (-2.95%)
# [2021-01-02 17:00:00] BUY at 30668.76, Size: $11904.21, SL: 30055.38, TP: 31588.82
# [2021-01-02 20:00:00] Closed trade at 31782.96, Reason: TAKE_PROFIT, P/L: $432.48 (3.63%)
# [2021-01-02 20:00:00] BUY at 31782.96, Size: $10136.42, SL: 31147.30, TP: 32736.45
# [2021-01-02 22:00:00] Closed trade at 32914.41, Reason: TAKE_PROFIT, P/L: $360.85 (3.56%)
# [2021-01-02 22:00:00] BUY at 32914.41, Size: $10316.84, SL: 32256.12, TP: 33901.84
# [2021-01-03 01:00:00] Closed trade at 30682.47, Reason: STOP_LOSS, P/L: $-699.59 (-6.78%)
# [2021-01-03 01:00:00] BUY at 30682.47, Size: $9967.05, SL: 30068.82, TP: 31602.94
# [2021-01-03 02:00:00] Closed trade at 31700.0, Reason: TAKE_PROFIT, P/L: $330.54 (3.32%)
# [2021-01-03 02:00:00] BUY at 31700.0, Size: $10132.32, SL: 31066.00, TP: 32651.00
# [2021-01-03 07:00:00] Closed trade at 32746.89, Reason: TAKE_PROFIT, P/L: $334.62 (3.30%)
# [2021-01-03 07:00:00] BUY at 32746.89, Size: $10299.63, SL: 32091.95, TP: 33729.30
# [2021-01-03 11:00:00] Closed trade at 33992.16, Reason: TAKE_PROFIT, P/L: $391.67 (3.80%)
# [2021-01-03 11:00:00] SELL at 33992.16, Size: $10075.64, SL: 34502.04, TP: 33142.36
# [2021-01-03 21:00:00] Closed trade at 32399.99, Reason: TAKE_PROFIT, P/L: $471.94 (4.68%)
# [2021-01-03 21:00:00] BUY at 32399.99, Size: $12877.71, SL: 31816.79, TP: 33371.99
# [2021-01-04 01:00:00] Closed trade at 33722.25, Reason: TAKE_PROFIT, P/L: $525.55 (4.08%)
# [2021-01-04 01:00:00] BUY at 33722.25, Size: $10994.20, SL: 33047.81, TP: 34733.92
# [2021-01-04 05:00:00] Closed trade at 32895.35, Reason: STOP_LOSS, P/L: $-269.59 (-2.45%)
# [2021-01-04 13:00:00] SELL at 32044.41, Size: $10425.03, SL: 32525.08, TP: 31243.30
# [2021-01-04 14:00:00] Closed trade at 31000.0, Reason: TAKE_PROFIT, P/L: $339.78 (3.26%)
# [2021-01-04 14:00:00] BUY at 31000.0, Size: $11029.29, SL: 30380.00, TP: 31930.00
# [2021-01-04 15:00:00] Closed trade at 30270.0, Reason: STOP_LOSS, P/L: $-259.72 (-2.35%)
# [2021-01-04 16:00:00] BUY at 30796.34, Size: $13079.32, SL: 30180.41, TP: 31720.23
# [2021-01-04 19:00:00] Closed trade at 32144.43, Reason: TAKE_PROFIT, P/L: $572.54 (4.38%)
# [2021-01-04 19:00:00] BUY at 32144.43, Size: $13422.84, SL: 31501.54, TP: 33108.76
# [2021-01-04 21:00:00] Closed trade at 31298.75, Reason: STOP_LOSS, P/L: $-353.14 (-2.63%)
# [2021-01-04 21:00:00] BUY at 31298.75, Size: $13210.96, SL: 30672.77, TP: 32237.71
# [2021-01-05 05:00:00] Closed trade at 32489.99, Reason: TAKE_PROFIT, P/L: $502.81 (3.81%)
# [2021-01-05 05:00:00] BUY at 32489.99, Size: $11260.54, SL: 31840.19, TP: 33464.69
# [2021-01-05 08:00:00] Closed trade at 31183.83, Reason: STOP_LOSS, P/L: $-452.70 (-4.02%)
# [2021-01-05 08:00:00] SELL at 31183.83, Size: $8827.35, SL: 31651.59, TP: 30404.23
# [2021-01-05 16:00:00] Closed trade at 31810.58, Reason: STOP_LOSS, P/L: $-177.42 (-2.01%)
# [2021-01-05 16:00:00] BUY at 31810.58, Size: $10945.48, SL: 31174.37, TP: 32764.90
# [2021-01-05 22:00:00] Closed trade at 32828.65, Reason: TAKE_PROFIT, P/L: $350.30 (3.20%)
# [2021-01-05 22:00:00] BUY at 32828.65, Size: $11120.63, SL: 32172.08, TP: 33813.51
# [2021-01-06 01:00:00] Closed trade at 34085.71, Reason: TAKE_PROFIT, P/L: $425.83 (3.83%)
# [2021-01-06 01:00:00] BUY at 34085.71, Size: $11333.55, SL: 33404.00, TP: 35108.28
# [2021-01-06 09:00:00] Closed trade at 35458.5, Reason: TAKE_PROFIT, P/L: $456.45 (4.03%)
# [2021-01-06 10:00:00] SELL at 35124.2, Size: $11099.30, SL: 35651.06, TP: 34246.09
# [2021-01-06 14:00:00] Closed trade at 34000.0, Reason: TAKE_PROFIT, P/L: $355.25 (3.20%)
# [2021-01-06 14:00:00] BUY at 34000.0, Size: $14087.28, SL: 33320.00, TP: 35020.00
# [2021-01-06 16:00:00] Closed trade at 35040.81, Reason: TAKE_PROFIT, P/L: $431.24 (3.06%)
# [2021-01-06 16:00:00] BUY at 35040.81, Size: $14346.02, SL: 34339.99, TP: 36092.03
# [2021-01-07 01:00:00] Closed trade at 36112.62, Reason: TAKE_PROFIT, P/L: $438.81 (3.06%)
# [2021-01-07 01:00:00] BUY at 36112.62, Size: $12174.42, SL: 35390.37, TP: 37196.00
# [2021-01-07 05:00:00] Closed trade at 37247.77, Reason: TAKE_PROFIT, P/L: $382.69 (3.14%)
# [2021-01-07 06:00:00] SELL at 36968.82, Size: $11871.14, SL: 37523.35, TP: 36044.60
# [2021-01-07 08:00:00] Closed trade at 37560.18, Reason: STOP_LOSS, P/L: $-189.89 (-1.60%)
# [2021-01-07 08:00:00] SELL at 37560.18, Size: $9816.66, SL: 38123.58, TP: 36621.18
# [2021-01-07 18:00:00] Closed trade at 38218.96, Reason: STOP_LOSS, P/L: $-172.18 (-1.75%)
# [2021-01-07 18:00:00] BUY at 38218.96, Size: $14621.68, SL: 37454.58, TP: 39365.53
# [2021-01-07 22:00:00] Closed trade at 39801.01, Reason: TAKE_PROFIT, P/L: $605.26 (4.14%)
# [2021-01-07 22:00:00] SELL at 39801.01, Size: $7492.42, SL: 40199.02, TP: 39004.99
# [2021-01-07 23:00:00] Closed trade at 38938.35, Reason: TAKE_PROFIT, P/L: $162.39 (2.17%)
# [2021-01-07 23:00:00] BUY at 38938.35, Size: $12568.56, SL: 38159.58, TP: 40106.50
# [2021-01-08 07:00:00] Closed trade at 37207.69, Reason: STOP_LOSS, P/L: $-558.62 (-4.44%)
# [2021-01-08 07:00:00] BUY at 37207.69, Size: $12289.24, SL: 36463.54, TP: 38323.92
# [2021-01-08 08:00:00] Closed trade at 38419.28, Reason: TAKE_PROFIT, P/L: $400.17 (3.26%)
# [2021-01-08 08:00:00] BUY at 38419.28, Size: $12489.33, SL: 37650.89, TP: 39571.86
# [2021-01-08 15:00:00] Closed trade at 40727.52, Reason: TAKE_PROFIT, P/L: $750.36 (6.01%)
# [2021-01-08 15:00:00] SELL at 40727.52, Size: $12349.93, SL: 41338.43, TP: 39709.33
# [2021-01-08 17:00:00] Closed trade at 41356.37, Reason: STOP_LOSS, P/L: $-190.69 (-1.54%)
# [2021-01-08 17:00:00] BUY at 41356.37, Size: $12258.40, SL: 40611.96, TP: 42597.06
# ...
# [2024-10-22 07:00:00] BUY at 67356.0, Size: $52542.69, SL: 66345.66, TP: 69039.90
# [2024-10-28 18:00:00] Closed trade at 69180.0, Reason: TAKE_PROFIT, P/L: $1422.86 (2.71%)
# [2024-10-28 18:00:00] BUY at 69180.0, Size: $53794.80, SL: 68142.30, TP: 70909.50
# [2024-10-30 07:00:00] Closed trade at 72200.0, Reason: TAKE_PROFIT, P/L: $2348.37 (4.37%)
# [2024-10-30 07:00:00] BUY at 72200.0, Size: $38087.30, SL: 70756.00, TP: 74366.00
# [2024-11-01 07:00:00] Closed trade at 69220.0, Reason: STOP_LOSS, P/L: $-1572.02 (-4.13%)
# [2024-11-01 07:00:00] BUY at 69220.0, Size: $37144.08, SL: 67974.04, TP: 71296.60
# [2024-11-03 14:00:00] Closed trade at 67749.0, Reason: STOP_LOSS, P/L: $-789.35 (-2.13%)
# [2024-11-03 14:00:00] BUY at 67749.0, Size: $53783.36, SL: 66732.76, TP: 69442.72
# [2024-11-05 14:00:00] Closed trade at 69962.0, Reason: TAKE_PROFIT, P/L: $1756.82 (3.27%)
# [2024-11-05 14:00:00] BUY at 69962.0, Size: $37724.56, SL: 68562.76, TP: 72060.86
# [2024-11-07 07:00:00] Closed trade at 74799.0, Reason: TAKE_PROFIT, P/L: $2608.18 (6.91%)
# [2024-11-07 07:00:00] BUY at 74799.0, Size: $57624.56, SL: 73677.01, TP: 76668.97
# [2024-11-07 18:00:00] Closed trade at 76683.0, Reason: TAKE_PROFIT, P/L: $1451.42 (2.52%)
# [2024-11-07 18:00:00] BUY at 76683.0, Size: $40160.32, SL: 75149.34, TP: 78983.49
# [2024-11-11 07:00:00] Closed trade at 81198.0, Reason: TAKE_PROFIT, P/L: $2364.59 (5.89%)
# [2024-11-11 07:00:00] BUY at 81198.0, Size: $41579.07, SL: 79736.44, TP: 83633.94
# [2024-11-11 15:00:00] Closed trade at 84200.0, Reason: TAKE_PROFIT, P/L: $1537.23 (3.70%)
# [2024-11-11 15:00:00] BUY at 84200.0, Size: $42501.42, SL: 82684.40, TP: 86726.00
# [2024-11-11 20:00:00] Closed trade at 87064.0, Reason: TAKE_PROFIT, P/L: $1445.65 (3.40%)
# [2024-11-11 20:00:00] BUY at 87064.0, Size: $43368.81, SL: 85322.72, TP: 89675.92
# [2024-11-13 14:00:00] Closed trade at 91670.0, Reason: TAKE_PROFIT, P/L: $2294.37 (5.29%)
# [2024-11-13 14:00:00] BUY at 91670.0, Size: $44745.43, SL: 90019.94, TP: 94420.10
# [2024-11-13 20:00:00] Closed trade at 89814.0, Reason: STOP_LOSS, P/L: $-905.94 (-2.02%)
# [2024-11-13 20:00:00] BUY at 89814.0, Size: $44201.86, SL: 88197.35, TP: 92508.42
# [2024-11-15 07:00:00] Closed trade at 87681.0, Reason: STOP_LOSS, P/L: $-1049.75 (-2.37%)
# [2024-11-15 07:00:00] BUY at 87681.0, Size: $63905.62, SL: 86365.79, TP: 89873.02
# [2024-11-15 13:00:00] Closed trade at 90160.0, Reason: TAKE_PROFIT, P/L: $1806.80 (2.83%)
# [2024-11-15 13:00:00] BUY at 90160.0, Size: $65495.60, SL: 88807.60, TP: 92414.00
# [2024-11-15 15:00:00] Closed trade at 88451.0, Reason: STOP_LOSS, P/L: $-1241.48 (-1.90%)
# [2024-11-15 15:00:00] BUY at 88451.0, Size: $64403.10, SL: 87124.24, TP: 90662.27
# [2024-11-15 20:00:00] Closed trade at 91500.0, Reason: TAKE_PROFIT, P/L: $2220.04 (3.45%)
# [2024-11-15 20:00:00] BUY at 91500.0, Size: $45243.23, SL: 89670.00, TP: 94245.00
# [2024-11-17 20:00:00] Closed trade at 89635.0, Reason: STOP_LOSS, P/L: $-922.17 (-2.04%)
# [2024-11-17 20:00:00] BUY at 89635.0, Size: $65545.22, SL: 88290.48, TP: 91875.87
# [2024-11-19 12:00:00] Closed trade at 92516.0, Reason: TAKE_PROFIT, P/L: $2106.72 (3.21%)
# [2024-11-19 12:00:00] BUY at 92516.0, Size: $45953.96, SL: 90850.71, TP: 95291.48
# [2024-11-21 07:00:00] Closed trade at 96969.0, Reason: TAKE_PROFIT, P/L: $2211.87 (4.81%)
# [2024-11-21 07:00:00] BUY at 96969.0, Size: $69345.58, SL: 95514.46, TP: 99393.22
# [2024-11-25 14:00:00] Closed trade at 95384.0, Reason: STOP_LOSS, P/L: $-1133.48 (-1.63%)
# [2024-11-25 14:00:00] BUY at 95384.0, Size: $46600.99, SL: 93476.32, TP: 98245.52
# [2024-11-25 23:00:00] Closed trade at 93035.0, Reason: STOP_LOSS, P/L: $-1147.63 (-2.46%)
# [2024-11-25 23:00:00] BUY at 93035.0, Size: $45912.41, SL: 91360.37, TP: 95826.05
# [2024-11-27 17:00:00] Closed trade at 96356.0, Reason: TAKE_PROFIT, P/L: $1638.90 (3.57%)
# [2024-11-27 17:00:00] BUY at 96356.0, Size: $46895.75, SL: 94621.59, TP: 99246.68
# [2024-12-03 13:00:00] Closed trade at 93730.0, Reason: STOP_LOSS, P/L: $-1278.05 (-2.73%)
# [2024-12-03 13:00:00] BUY at 93730.0, Size: $46128.92, SL: 91855.40, TP: 96541.90
# [2024-12-05 07:00:00] Closed trade at 102300.0, Reason: TAKE_PROFIT, P/L: $4217.70 (9.14%)
# [2024-12-05 07:00:00] BUY at 102300.0, Size: $48659.53, SL: 100254.00, TP: 105369.00
# [2024-12-05 18:00:00] Closed trade at 100240.0, Reason: STOP_LOSS, P/L: $-979.85 (-2.01%)
# [2024-12-05 18:00:00] BUY at 100240.0, Size: $40059.69, SL: 98235.20, TP: 103247.20
# [2024-12-05 22:00:00] Closed trade at 96810.0, Reason: STOP_LOSS, P/L: $-1370.76 (-3.42%)
# [2024-12-05 22:00:00] BUY at 96810.0, Size: $47249.17, SL: 94873.80, TP: 99714.30
# [2024-12-07 09:00:00] Closed trade at 99782.0, Reason: TAKE_PROFIT, P/L: $1450.52 (3.07%)
# [2024-12-07 09:00:00] BUY at 99782.0, Size: $52931.43, SL: 97985.92, TP: 102775.46
# [2024-12-09 15:00:00] Closed trade at 97822.0, Reason: STOP_LOSS, P/L: $-1039.72 (-1.96%)
# [2024-12-09 15:00:00] BUY at 97822.0, Size: $47495.65, SL: 95865.56, TP: 100756.66
# [2024-12-11 19:00:00] Closed trade at 101248.0, Reason: TAKE_PROFIT, P/L: $1663.43 (3.50%)
# [2024-12-11 19:00:00] BUY at 101248.0, Size: $48493.70, SL: 99223.04, TP: 104285.44
# [2024-12-15 23:00:00] Closed trade at 104427.0, Reason: TAKE_PROFIT, P/L: $1522.61 (3.14%)
# [2024-12-15 23:00:00] BUY at 104427.0, Size: $72464.00, SL: 102860.60, TP: 107037.67
# [2024-12-17 08:00:00] Closed trade at 107387.0, Reason: TAKE_PROFIT, P/L: $2054.00 (2.83%)
# [2024-12-17 08:00:00] BUY at 107387.0, Size: $50639.67, SL: 105239.26, TP: 110608.61
# [2024-12-19 07:00:00] Closed trade at 101611.0, Reason: STOP_LOSS, P/L: $-2723.74 (-5.38%)
# [2024-12-19 07:00:00] BUY at 101611.0, Size: $49005.43, SL: 99782.00, TP: 104659.33
# [2024-12-19 17:00:00] Closed trade at 98821.0, Reason: STOP_LOSS, P/L: $-1345.57 (-2.75%)
# [2024-12-19 17:00:00] BUY at 98821.0, Size: $48198.08, SL: 97042.22, TP: 101785.63
# [2024-12-19 20:00:00] Closed trade at 96290.0, Reason: STOP_LOSS, P/L: $-1234.45 (-2.56%)
# [2024-12-19 20:00:00] BUY at 96290.0, Size: $47457.41, SL: 94364.20, TP: 99178.70
# [2024-12-23 14:00:00] Closed trade at 94274.0, Reason: STOP_LOSS, P/L: $-993.60 (-2.09%)
# [2024-12-23 14:00:00] BUY at 94274.0, Size: $46861.25, SL: 92577.07, TP: 97102.22
# [2024-12-25 07:00:00] Closed trade at 98018.0, Reason: TAKE_PROFIT, P/L: $1861.05 (3.97%)
# [2024-12-25 07:00:00] BUY at 98018.0, Size: $47977.88, SL: 96057.64, TP: 100958.54
# [2024-12-27 07:00:00] Closed trade at 94988.0, Reason: STOP_LOSS, P/L: $-1483.13 (-3.09%)
# [2024-12-27 07:00:00] BUY at 94988.0, Size: $47088.01, SL: 93278.22, TP: 97837.64
# [2024-12-29 21:00:00] Closed trade at 93236.0, Reason: STOP_LOSS, P/L: $-868.51 (-1.84%)
# [2024-12-29 21:00:00] BUY at 93236.0, Size: $46566.90, SL: 91557.75, TP: 96033.08
# [2025-01-02 09:00:00] Closed trade at 96634.0, Reason: TAKE_PROFIT, P/L: $1697.14 (3.64%)
# [2025-01-02 09:00:00] BUY at 96634.0, Size: $47585.18, SL: 94894.59, TP: 99533.02
# [2025-01-06 14:00:00] Closed trade at 100741.0, Reason: TAKE_PROFIT, P/L: $2022.40 (4.25%)
# [2025-01-06 14:00:00] BUY at 100741.0, Size: $48798.62, SL: 98927.66, TP: 103763.23
# [2025-01-08 07:00:00] Closed trade at 95630.0, Reason: STOP_LOSS, P/L: $-2475.75 (-5.07%)
# [2025-01-08 07:00:00] BUY at 95630.0, Size: $69392.65, SL: 94195.55, TP: 98020.75
# [2025-01-08 17:00:00] Closed trade at 94001.0, Reason: STOP_LOSS, P/L: $-1182.06 (-1.70%)
# [2025-01-08 17:00:00] BUY at 94001.0, Size: $46603.93, SL: 92120.98, TP: 96821.03
# [2025-01-14 09:00:00] Closed trade at 97120.0, Reason: TAKE_PROFIT, P/L: $1546.34 (3.32%)
# [2025-01-14 09:00:00] BUY at 97120.0, Size: $47531.74, SL: 95371.84, TP: 100033.60
# [2025-01-16 19:00:00] Closed trade at 100394.0, Reason: TAKE_PROFIT, P/L: $1602.34 (3.37%)
# [2025-01-16 19:00:00] BUY at 100394.0, Size: $48493.14, SL: 98386.12, TP: 103405.82
# [2025-01-18 11:00:00] Closed trade at 103521.0, Reason: TAKE_PROFIT, P/L: $1510.43 (3.11%)
# [2025-01-18 11:00:00] BUY at 103521.0, Size: $49399.40, SL: 101450.58, TP: 106626.63
# [2025-01-20 07:00:00] Closed trade at 106945.0, Reason: TAKE_PROFIT, P/L: $1633.91 (3.31%)
# [2025-01-20 07:00:00] BUY at 106945.0, Size: $50379.74, SL: 104806.10, TP: 110153.35
# [2025-01-20 15:00:00] Closed trade at 104791.0, Reason: STOP_LOSS, P/L: $-1014.71 (-2.01%)
# [2025-01-20 15:00:00] BUY at 104791.0, Size: $49770.91, SL: 102904.76, TP: 107934.73
# [2025-01-20 17:00:00] Closed trade at 102877.0, Reason: STOP_LOSS, P/L: $-909.06 (-1.83%)
# [2025-01-20 17:00:00] BUY at 102877.0, Size: $49225.48, SL: 100819.46, TP: 105963.31
# [2025-01-24 17:00:00] Closed trade at 106488.0, Reason: TAKE_PROFIT, P/L: $1727.82 (3.51%)
# [2025-01-24 17:00:00] BUY at 106488.0, Size: $50262.17, SL: 104571.22, TP: 109682.64
# [2025-01-26 21:00:00] Closed trade at 104558.0, Reason: STOP_LOSS, P/L: $-910.96 (-1.81%)
# [2025-01-26 21:00:00] BUY at 104558.0, Size: $72916.21, SL: 102989.63, TP: 107171.95
# [2025-01-26 23:00:00] Closed trade at 102573.0, Reason: STOP_LOSS, P/L: $-1384.29 (-1.90%)
# [2025-01-26 23:00:00] BUY at 102573.0, Size: $71698.03, SL: 101034.40, TP: 105137.32
# [2025-01-28 21:00:00] Closed trade at 100298.0, Reason: STOP_LOSS, P/L: $-1590.21 (-2.22%)
# [2025-01-28 21:00:00] BUY at 100298.0, Size: $47930.89, SL: 98492.64, TP: 103306.94
# [2025-01-29 19:00:00] Closed trade at 103586.0, Reason: TAKE_PROFIT, P/L: $1571.29 (3.28%)
# [2025-01-29 19:00:00] BUY at 103586.0, Size: $48873.66, SL: 101514.28, TP: 106693.58
# [2025-02-01 20:00:00] Closed trade at 101288.0, Reason: STOP_LOSS, P/L: $-1084.24 (-2.22%)
# [2025-02-01 20:00:00] BUY at 101288.0, Size: $70727.25, SL: 99768.68, TP: 103820.20
# [2025-02-02 07:00:00] Closed trade at 99605.0, Reason: STOP_LOSS, P/L: $-1175.20 (-1.66%)
# [2025-02-02 07:00:00] BUY at 99605.0, Size: $69693.07, SL: 98110.93, TP: 102095.12
# [2025-02-02 17:00:00] Closed trade at 97141.0, Reason: STOP_LOSS, P/L: $-1724.05 (-2.47%)
# [2025-02-02 17:00:00] BUY at 97141.0, Size: $46483.57, SL: 95392.46, TP: 100055.23
# [2025-02-03 09:00:00] Closed trade at 95386.0, Reason: STOP_LOSS, P/L: $-839.80 (-1.81%)
# [2025-02-03 09:00:00] BUY at 95386.0, Size: $67436.89, SL: 93955.21, TP: 97770.65
# [2025-02-03 15:00:00] Closed trade at 99031.0, Reason: TAKE_PROFIT, P/L: $2576.98 (3.82%)
# [2025-02-03 15:00:00] BUY at 99031.0, Size: $47525.88, SL: 97050.38, TP: 102001.93
# [2025-02-03 19:00:00] Closed trade at 102065.0, Reason: TAKE_PROFIT, P/L: $1456.04 (3.06%)
# [2025-02-03 19:00:00] BUY at 102065.0, Size: $48399.51, SL: 100227.83, TP: 105126.95
# [2025-02-04 07:00:00] Closed trade at 98550.0, Reason: STOP_LOSS, P/L: $-1666.82 (-3.44%)
# [2025-02-04 07:00:00] BUY at 98550.0, Size: $47399.41, SL: 96776.10, TP: 101506.50
# [2025-02-04 21:00:00] Closed trade at 96531.0, Reason: STOP_LOSS, P/L: $-971.07 (-2.05%)
# [2025-02-04 21:00:00] BUY at 96531.0, Size: $46816.77, SL: 94600.38, TP: 99426.93
# [2025-02-07 14:00:00] Closed trade at 99795.0, Reason: TAKE_PROFIT, P/L: $1583.01 (3.38%)
# [2025-02-07 14:00:00] BUY at 99795.0, Size: $47766.58, SL: 97998.69, TP: 102788.85
# [2025-02-07 16:00:00] Closed trade at 97865.0, Reason: STOP_LOSS, P/L: $-923.79 (-1.93%)
# [2025-02-07 16:00:00] BUY at 97865.0, Size: $47212.30, SL: 96103.43, TP: 100800.95
# [2025-02-07 20:00:00] Closed trade at 95782.0, Reason: STOP_LOSS, P/L: $-1004.89 (-2.13%)
# [2025-02-07 20:00:00] BUY at 95782.0, Size: $46609.37, SL: 94057.92, TP: 98655.46
# [2025-02-18 18:00:00] Closed trade at 93870.0, Reason: STOP_LOSS, P/L: $-930.42 (-2.00%)
# [2025-02-18 18:00:00] BUY at 93870.0, Size: $67541.65, SL: 92461.95, TP: 96216.75
# [2025-02-20 07:00:00] Closed trade at 96889.0, Reason: TAKE_PROFIT, P/L: $2172.24 (3.22%)
# [2025-02-20 07:00:00] BUY at 96889.0, Size: $69453.22, SL: 95435.66, TP: 99311.22
# [2025-02-24 14:00:00] Closed trade at 94648.0, Reason: STOP_LOSS, P/L: $-1606.42 (-2.31%)
# [2025-02-24 14:00:00] BUY at 94648.0, Size: $46390.61, SL: 92755.04, TP: 97487.44
# [2025-02-24 22:00:00] Closed trade at 92477.0, Reason: STOP_LOSS, P/L: $-1064.09 (-2.29%)
# [2025-02-24 22:00:00] BUY at 92477.0, Size: $45752.16, SL: 90627.46, TP: 95251.31
# [2025-02-26 07:00:00] Closed trade at 88636.0, Reason: STOP_LOSS, P/L: $-1900.30 (-4.15%)
# [2025-02-26 07:00:00] BUY at 88636.0, Size: $44611.98, SL: 86863.28, TP: 91295.08
# [2025-02-26 16:00:00] Closed trade at 86696.0, Reason: STOP_LOSS, P/L: $-976.43 (-2.19%)
# [2025-02-26 16:00:00] BUY at 86696.0, Size: $44026.12, SL: 84962.08, TP: 89296.88
# [2025-02-26 18:00:00] Closed trade at 84177.0, Reason: STOP_LOSS, P/L: $-1279.20 (-2.91%)
# [2025-02-26 18:00:00] BUY at 84177.0, Size: $51910.32, SL: 82493.46, TP: 86702.31
# [2025-02-28 07:00:00] Closed trade at 79104.0, Reason: STOP_LOSS, P/L: $-3128.42 (-6.03%)
# [2025-02-28 07:00:00] BUY at 79104.0, Size: $41381.54, SL: 77521.92, TP: 81477.12
# [2025-02-28 14:00:00] Closed trade at 82090.0, Reason: TAKE_PROFIT, P/L: $1562.06 (3.77%)
# [2025-02-28 14:00:00] BUY at 82090.0, Size: $62067.55, SL: 80858.65, TP: 84142.25
# [2025-02-28 16:00:00] Closed trade at 84351.0, Reason: TAKE_PROFIT, P/L: $1709.52 (2.75%)
# [2025-02-28 16:00:00] BUY at 84351.0, Size: $43344.49, SL: 82832.68, TP: 86881.53
# [2025-03-02 15:00:00] Closed trade at 87420.0, Reason: TAKE_PROFIT, P/L: $1577.03 (3.64%)
# [2025-03-02 15:00:00] BUY at 87420.0, Size: $64959.71, SL: 86108.70, TP: 89605.50
# [2025-03-02 16:00:00] Closed trade at 91208.0, Reason: TAKE_PROFIT, P/L: $2814.77 (4.33%)
# [2025-03-02 16:00:00] BUY at 91208.0, Size: $45979.58, SL: 89566.26, TP: 93944.24
# [2025-03-02 17:00:00] Closed trade at 94113.0, Reason: TAKE_PROFIT, P/L: $1464.46 (3.19%)
# [2025-03-02 17:00:00] BUY at 94113.0, Size: $46858.25, SL: 92418.97, TP: 96936.39
# [2025-03-04 07:00:00] Closed trade at 83142.0, Reason: STOP_LOSS, P/L: $-5462.39 (-11.66%)
# [2025-03-04 07:00:00] BUY at 83142.0, Size: $63918.54, SL: 81894.87, TP: 85220.55
# [2025-03-04 17:00:00] Closed trade at 85418.0, Reason: TAKE_PROFIT, P/L: $1749.76 (2.74%)
# [2025-03-04 17:00:00] BUY at 85418.0, Size: $44630.68, SL: 83709.64, TP: 87980.54
# [2025-03-04 19:00:00] Closed trade at 88221.0, Reason: TAKE_PROFIT, P/L: $1464.56 (3.28%)
# [2025-03-04 19:00:00] BUY at 88221.0, Size: $45509.41, SL: 86633.02, TP: 90867.63
# [2025-03-06 07:00:00] Closed trade at 91343.0, Reason: TAKE_PROFIT, P/L: $1610.51 (3.54%)
# [2025-03-06 07:00:00] BUY at 91343.0, Size: $68164.38, SL: 89972.85, TP: 93626.57
# [2025-03-06 13:00:00] Closed trade at 89572.0, Reason: STOP_LOSS, P/L: $-1321.60 (-1.94%)
# [2025-03-06 13:00:00] BUY at 89572.0, Size: $45682.75, SL: 87959.70, TP: 92259.16
# [2025-03-08 07:00:00] Closed trade at 86179.0, Reason: STOP_LOSS, P/L: $-1730.47 (-3.79%)
# [2025-03-08 07:00:00] BUY at 86179.0, Size: $65478.56, SL: 84886.32, TP: 88333.47
# [2025-03-10 07:00:00] Closed trade at 82317.0, Reason: STOP_LOSS, P/L: $-2934.34 (-4.48%)
# [2025-03-10 07:00:00] BUY at 82317.0, Size: $42883.87, SL: 80670.66, TP: 84786.51
# [2025-03-10 14:00:00] Closed trade at 79807.0, Reason: STOP_LOSS, P/L: $-1307.61 (-3.05%)
# [2025-03-10 14:00:00] BUY at 79807.0, Size: $35082.75, SL: 78210.86, TP: 82201.21
# [2025-03-10 18:00:00] Closed trade at 77600.0, Reason: STOP_LOSS, P/L: $-970.19 (-2.77%)
# [2025-03-10 18:00:00] BUY at 77600.0, Size: $41517.19, SL: 76048.00, TP: 79928.00
# [2025-03-12 07:00:00] Closed trade at 82409.0, Reason: TAKE_PROFIT, P/L: $2572.89 (6.20%)
# [2025-03-12 07:00:00] BUY at 82409.0, Size: $43060.93, SL: 80925.64, TP: 84881.27
#
# ===== BACKTEST RESULTS =====
# Initial Balance: $10000.00
# Final Balance: $28707.28
# Profit/Loss: $18707.28 (187.07%)
# Total Trades: 1939
# Win Rate: 45.02%
# Average Win: $608.65
# Average Loss: $-440.51
# Profit Factor: 1.13
# Maximum Drawdown: nan%
#
# ===== REGIME PREDICTION ACCURACY =====
# Overall Accuracy: 49.95%
# Regime 0: 48.91% (3901/7976)
# Regime 1: 60.70% (6423/10581)
# Regime 2: 51.56% (1155/2240)
# Regime 3: 42.57% (1046/2457)
# Regime 4: 46.03% (5549/12055)
# Regime 5: 44.45% (3518/7915)
#
# ===== ASSESSMENT =====
# The regime classification system is SOMEWHAT PREDICTIVE but needs REFINEMENT.
#
# ===== SUGGESTIONS FOR IMPROVEMENT =====
# 1. Focus on improving prediction for Regimes 3 and 5
# 2. Adjust position sizing based on regime prediction confidence
# 3. Add additional market indicators to confirm regime transitions
# 4. Optimize stop-loss and take-profit levels for each regime
